# %%
from collections import Counter

# %%
import nltk

# %%
import pickle
import pandas as pd

# %%
from nltk.tokenize import sent_tokenize, word_tokenize
from nltk.stem import PorterStemmer, LancasterStemmer

# %% [markdown]
# # All sentenses from CSV

# %%
all_sentences = pickle.load(open('label_sentences.pkl', 'rb'))

# %%
all_sentences
# Out:
# [('00001', 'a person is walking forwards'),
#  ('00002', 'a person walks 4 steps forward'),
#  ('00003', 'a human walking'),
#  ('00004', 'a person walks forward at medium speed'),
#  ('00004', 'human slowly goes forward'),
#  ('00005', 'a human walks four slow steps forward'),
#  ('00006', 'a person goes four and half steps forward'),
#  ('00006', 'a person walking forward slightly to the right'),
#  ('00007', 'a person walks slowly for four steps and stops'),
#  ('00007', 'a person walks four steps to the forward direction'),
#  ('00008', 'a person walks slowly 4 steps forward'),
#  ('00009', 'a person stands, then walks a few steps, then stops again'),
#  ('00009',
#   'someone is walking forward slowly doing 4 steps starting with the left leg'),
#  ('00009', 'a person makes 4 steps forward slowly'),
#  ('00010', 'a human walking backwards'),
#  ('00011', 'a person walks backwards four steps starting with the left foot'),
#  ('00011', 'somebody walks backwards'),
#  ('00013', 'a person walking backwards for a few steps'),
#  ('00014', 'a person walks four steps backward'),
#  ('00015', 'a person walks backwards'),
#  ('00016', 'a person walks backward at a slow speed'),
#  ('00016',
#   'a human is walking 4 steps backwards and starting with its left food'),
#  ('00016', 'a person walks backwards'),
#  ('00016', 'some is reverse walking'),
#  ('00016', 'a person takes 4 steps backwards'),
#  ('00016', 'a person moves backwards 4 steps before standing still'),
#  ('00016', 'someone is walking backwards'),
#  ('00016', 'a man is walking backwards'),
#  ('00016', 'somebody walks a few steps backward'),
#  ('00017', 'a person walks four steps backwards'),
#  ('00017', 'a person walks backwards slowly'),
#  ('00017', 'somebody walks backward'),
#  ('00018', 'a person is walking backwards'),
#  ('00019', 'a person turns in a circle'),
#  ('00019', 'someone walks in a circle counterclockwise'),
#  ('00019', 'somebody wals a circle anticlockwise'),
#  ('00020', 'a person walks in a circle counter clockwise'),
#  ('00021', 'a person walks in a square'),
#  ('00022', 'the person is walking in a circular shape'),
#  ('00022', 'a human walks slowly a full circle to its left'),
#  ('00022', 'a person walks a full counter-clockwise circle'),
#  ('00022', 'a person walks in a circle pattern one time'),
#  ('00023', 'a person walks in a counter-clockwise circle'),
#  ('00023', 'somebody is walking in a circle'),
#  ('00023', 'person walking in a circle'),
#  ('00023', 'a person is walking in a circle'),
#  ('00023', 'someone slowly walks a full circle to the left'),
#  ('00023', 'walking in a slow circle'),
#  ('00023', 'someone walks a complete circle'),
#  ('00023', 'a person turns around to the beginning'),
#  ('00023', 'someone is walking a whole round to his left side'),
#  ('00023', 'a person is walking in a circle shape'),
#  ('00023', 'a person walks a circle to the left'),
#  ('00024', 'a person walks a circle'),
#  ('00025', 'a person walking in a circle to the left'),
#  ('00025', 'a person walks a circle in the left direction'),
#  ('00026', 'a person walks in a counter-clockwise circle'),
#  ('00026', 'someone walks in a circle counterclockwise'),
#  ('00027', 'the person is walking through a  circular path'),
#  ('00027', 'a human is walking in circle'),
#  ('00028', 'human goes in a circle clockwise'),
#  ('00029', 'a person walking in a circle to the right'),
#  ('00029', 'somebody walks a circle clockwise'),
#  ('00030', 'a person walks in a clockwise circle'),
#  ('00030', 'a person running in a full circle, clockwise'),
#  ('00031', 'a person walks a circle clock-wise'),
#  ('00031', 'a person walks in clock-wise circle'),
#  ('00031', 'a human is walking in a circle to the right'),
#  ('00032', 'a person walks in a circle clockwise'),
#  ('00032', 'a person walks in a circle and looks facing down'),
#  ('00032', 'a person walks a circle in the right direction'),
#  ('00032', 'the human walks a circle (right turn)'),
#  ('00033', 'a person walks in a circle clockwise'),
#  ('00033', 'a person walks in a circle to his right side'),
#  ('00034', 'a human walking in a circle clockwise'),
#  ('00034', 'a person walks in a little circle'),
#  ('00035', 'a person walks a circle'),
#  ('00036', 'a person walks in circle in clockwise direction'),
#  ('00037', 'a person walks a circle clockwise'),
#  ('00037', 'a perons walks a circle clockwise'),
#  ('00037', 'a man walks in circle'),
#  ('00038', 'a person walking in a quarter circle to the right'),
#  ('00038', 'a person walks while turning to the right'),
#  ('00039',
#   'a person is walking forward four steps starting with the right foot and performing a right-turn of 90°'),
#  ('00039', 'a human performs a tight 90° right curve'),
#  ('00040', 'a person walks 90° of a circle to his right'),
#  ('00040', 'a person walks a quarter circle to the right, taking four steps'),
#  ('00040', 'a person is turning right while walking'),
#  ('00041', 'someone walks three steps in curve to the right'),
#  ('00041', 'a person walks a small half circle'),
#  ('00041', 'somebody walks a quarter circle in clockwise direction'),
#  ('00042', 'subject walks a quarter circle clockwise'),
#  ('00042', 'a person walks in a 90° curve to his right'),
#  ('00042', 'a person waits on a atm line and then goes to the machine'),
#  ('00042', 'a human sit'),
#  ('00043', 'a person walks clockwise in a circle with 4 steps'),
#  ('00043', 'a human performs a tight 90° curve to the right'),
#  ('00043', 'a human sit down'),
#  ('00044', 'a person walks a quarter rightwards circle'),
#  ('00044', 'a person walks in a quarter circle'),
#  ('00045', 'human walks in a quater circle clockwise'),
#  ('00046', 'a person walks a quarter circle clockwise with 4 steps'),
#  ('00047', 'a person is walking a left-turn'),
#  ('00047', 'a person walking forward in a 90° curve'),
#  ('00047', 'a person walks a quarter circle to the right, taking four steps'),
#  ('00048', 'person walking backwards'),
#  ('00048', 'human goes backwards starting with left'),
#  ('00049', 'subject walks backwards'),
#  ('00049', 'a person takes 4 steps backwards starting with left'),
#  ('00049', 'a person walks some steps backwards'),
#  ('00050', 'person walking backwards'),
#  ('00050', 'someone walks slowly backwards'),
#  ('00050', 'a person makes 4 steps backwards'),
#  ('00051', 'a person walks backwards'),
#  ('00052', 'the person is walking backwards'),
#  ('00052', 'a person walks some steps backwards'),
#  ('00053', 'a person walking backwards for 4 steps'),
#  ('00053', 'a person slowly walking backwards'),
#  ('00053', 'someone walks straight reverse and stop in four steps'),
#  ('00054', 'a person is walking backwards in a straight line'),
#  ('00054', 'human goes backwards starting with left'),
#  ('00055', 'a person walks backward 4 steps'),
#  ('00055', 'someone walks backwards 4 steps starting with the left leg'),
#  ('00055', 'a person takes some steps backwards'),
#  ('00056', 'a  human walking backwards'),
#  ('00056', 'the human is walking backwards'),
#  ('00057', 'a person walks backwards'),
#  ('00057', 'someone is walking backwards 4 steps starting with the left leg'),
#  ('00058', 'a person walks in circle'),
#  ('00059', 'human goes in a circle counterclockwise'),
#  ('00059', 'a human is walking in a circle to its left'),
#  ('00060', 'a human walking in a circle counterclockwise'),
#  ('00061', 'someone walks in a counter-clockwise circle'),
#  ('00061', 'a human walks in a circle with a diameter of 2m'),
#  ('00061', 'someone walk in a full counter-clockwise circle'),
#  ('00061', 'a person walks in a full circle'),
#  ('00061', 'someone makes a circle'),
#  ('00061', 'he turns around'),
#  ('00061', 'a person walks a circle'),
#  ('00061', 'someone walks one round'),
#  ('00061', 'a person walks a full anti-clockwise circle'),
#  ('00061', 'a person walks in a circle counterclockwise'),
#  ('00061', 'a person walks a circle to the left'),
#  ('00061', 'the human walks a circle'),
#  ('00061', 'a human walks in circle counterclockwise'),
#  ('00062', 'a person walks in a counter-clockwise circle'),
#  ('00062', 'a person walks in a circle to the left side'),
#  ('00063', 'a person is walking in small circles'),
#  ('00063', 'a person walks in a circle to the left'),
#  ('00064', 'a human walking in a circle counterclockwise'),
#  ('00064', 'someone is walking a circle to the left'),
#  ('00065', 'someone walks in a circle to the left'),
#  ('00066', 'a person walking in a circle to the left'),
#  ('00067', 'a person walks in a counter-clockwise circle'),
#  ('00067', 'a human walks in a counter-clockwise circle'),
#  ('00067', 'person walking in a circle'),
#  ('00067', 'someone walks around slowly'),
#  ('00067', 'walking in a small circle'),
#  ('00067', 'the person walked in a circle'),
#  ('00067', 'a person walks a circle'),
#  ('00067', 'a person walks in a circle to his left side'),
#  ('00067', 'human goes in a circle counterclockwise'),
#  ('00067', 'someone walks a anticlockwise'),
#  ('00068', 'someone walks a right circle'),
#  ('00069', 'a person is walking in a clockwise circle'),
#  ('00070', 'a person walks a circle clockwise'),
#  ('00070', 'someone walks in a small circle to the right'),
#  ('00071', 'a human walking in a circle clockwise'),
#  ('00071', 'a person walks a circle, radius approximatly 1,5 m'),
#  ('00072', 'a person walks in a circle'),
#  ('00073', 'a person walks in a circle'),
#  ('00074', 'a person is walking in a small circle'),
#  ('00075', 'subject walks in a circle clockwise'),
#  ('00075', 'a person walks a right sided circle, radius approximatly 50cm'),
#  ('00076', 'a person walking in a circle to the right'),
#  ('00077', 'a person walks in a clockwise circle'),
#  ('00077', 'a person walks in a clockwise circle'),
#  ('00077', 'a person walking in a circle'),
#  ('00077', 'a person turns to his right '),
#  ('00077', 'someone is walking one round to his side'),
#  ('00077', 'a person is walking to the left by making a circle shape'),
#  ('00077', 'a person goes around in a circuit'),
#  ('00077', 'a person walks in a circle to the right'),
#  ('00077', 'somebody walks a circle clockwise'),
#  ('00078', 'subject walks in a quarter circle counterclockwise'),
#  ('00078', 'a person walks a quarter, left-sided circle'),
#  ('00079',
#   'the person is walking to the left by following a half circle path'),
#  ('00079', 'a person moves to the left'),
#  ('00079', 'a person walks to the left'),
#  ('00079', 'somebody walks a quarter circle anticlockwise'),
#  ('00080', 'a person walks in a quarter circle'),
#  ('00080', 'a person is walking a quarter circle to the left'),
#  ('00080', 'a person walks in a quarter of a small circle'),
#  ('00081', 'a person walks and turns to the left'),
#  ('00081', 'someone walks a left turn'),
#  ('00082', 'subject walks in a quarter circle counterclockwise'),
#  ('00082', 'a person walks to the left performing a quarter circle'),
#  ('00083', 'a human makes a left turn'),
#  ('00083', 'a person goes left around a corner'),
#  ('00084', 'a person walking slowly in a quartercircle to the left'),
#  ('00085', 'a human walks a quarter of a circle to the left'),
#  ('00085', 'the human perfoms a left turn'),
#  ('00086', 'a person walks a 90 degrees curve to the left'),
#  ('00086', 'somebody walks a quarter circle against the clockwise direction'),
#  ('00087', 'a person walks towards the left'),
#  ('00087',
#   'human goes in a quater circle counterclockwise starting with left'),
#  ('00087', 'a person walking a left turn'),
#  ('00088', 'a person is turning right'),
#  ('00089', 'a human walks a quarter of a circle to the right'),
#  ('00090', 'a person walks and turns to the right'),
#  ('00091', 'a person walks in a right turn'),
#  ('00091', 'a person walks a quarter circle clockwise'),
#  ('00092', 'the person is making a wide turn to the right'),
#  ('00092', 'a person walks in a quarter circle to the right'),
#  ('00093', 'person walking to the right'),
#  ('00093', 'human goes in a quarter circle clockwise starting with right'),
#  ('00093', 'someone is walking a quarter circle to the right'),
#  ('00094', 'a person walking in a quarter circle to the right'),
#  ('00094', 'the human perfoms a right turn'),
#  ('00094', 'someone slowly turns a right corner'),
#  ('00095', 'a human turning right'),
#  ('00095', 'a human performs a 90° right curve'),
#  ('00095', 'a person walks in a curve to the right'),
#  ('00096', 'a person turns right'),
#  ('00097', 'human goes in quater circle clockwise'),
#  ('00097', 'a person walks a quarter circle to the right'),
#  ('00097', 'a person turns right'),
#  ('00097', 'a person walks slowly a right curve'),
#  ('00098', 'the person is performing a forward walk'),
#  ('00098', 'a person is walking relaxed'),
#  ('00098', 'a person is walking forward'),
#  ('00098', 'a person walks slowly forwards'),
#  ('00098', 'a person walks forward'),
#  ('00098', 'a person walks forwards'),
#  ('00099', 'a person walk 5 steps forward'),
#  ('00099', 'a human is slowly moving forward'),
#  ('00099', 'a person takes 4 steps forward'),
#  ('00099', 'a person takes 4 forward steps'),
#  ('00100', 'a person walks forward'),
#  ('00101', 'a person walks 2 meters forward'),
#  ('00101', 'a person is walking'),
#  ('00102', 'the subject walks forward'),
#  ('00102', 'person walking forwards'),
#  ('00102', 'someone walks away'),
#  ('00102', 'a person walks forward'),
#  ('00102', 'a person just walks'),
#  ('00102', 'a person walks straight forward some steps'),
#  ('00102', 'a person walks 5 steps beginning with the left foot'),
#  ('00103', 'someone moves forward in a slow walk'),
#  ('00103', 'a person walks slowly forwards'),
#  ('00104', 'a person walks forward'),
#  ('00105', 'a person walks forward'),
#  ('00105', 'human goes forward'),
#  ('00106', 'a human looking to the left and then walking forwards'),
#  ('00106', 'a person walks forwards'),
#  ('00106', 'a person walks'),
#  ('00107', 'a human walking forward'),
#  ('00108', 'a person walks backwards'),
#  ('00108', 'a person walks backwards'),
#  ('00108', 'a person walks backwards four steps'),
#  ('00108', 'a person is stepping back'),
#  ('00108', 'slowly backing off'),
#  ('00108', 'someone is doing a few steps backwards'),
#  ('00108', 'person walking backwards'),
#  ('00108', 'a person walks four steps backwards'),
#  ('00108', 'a person walks 5 steps backward'),
#  ('00108', 'a person moves backward some meters'),
#  ('00108',
#   'a human is walking backwards tilting its head a little bit beforehand'),
#  ('00108', 'a person does 4 steps backwards'),
#  ('00108', 'a person walking backwards while moving slightly to his left'),
#  ('00108', 'a person backing away from something'),
#  ('00108', 'human goes backwards'),
#  ('00108', 'a man walks backwards'),
#  ('00109', 'a person walks 4 steps backwards'),
#  ('00110', 'a person walks backwards, arms swinging by his side'),
#  ('00110', 'human goes backwards starting with left'),
#  ('00110', 'a person walks backwards'),
#  ('00110', 'a man is walking backwards'),
#  ('00111', 'a person walks backward at medium speed'),
#  ('00111', 'a person walking backwards'),
#  ('00112', 'someone walks backwards'),
#  ('00112', 'a human is slowly walking backwards'),
#  ('00112', 'a person walks backwards'),
#  ('00113', 'a person walks four steps backward'),
#  ('00113', 'human goes backwards'),
#  ('00114', 'a person walking backwards'),
#  ('00114', 'a person walking backwards'),
#  ('00114', 'someone walks backwards'),
#  ('00114', 'a person walks backwards'),
#  ('00114', 'human slowly goes backwards'),
#  ('00116', 'a persons walks backward with medium speed'),
#  ('00116', 'someone is walking backwards starting with the left leg'),
#  ('00116', 'a person walds backwards some steps'),
#  ('00116', 'walking backwards for a few steps'),
#  ('00116', 'a person walks backwards'),
#  ('00116', 'a person walks backwards for five steps'),
#  ('00117', 'a person walks backwards'),
#  ('00118', 'human walks in a circle counterclockwise'),
#  ('00118', 'someone is walking in a circle counterclockwise'),
#  ('00118', 'a person walks in a circle to the left'),
#  ('00119', 'a person walks in a circle to the left'),
#  ('00119', 'somebody walks a 7/8 circle anticlockwise'),
#  ('00120', 'a person walks counterclockwise in a small circle'),
#  ('00121',
#   'a person walks counter-clockwise in an incomplete circle and stops facing to the right relative to the starting position'),
#  ('00121', 'the human walks a circle'),
#  ('00122', 'a person walks counterclockwise in a small circle'),
#  ('00122', 'a person walks counte clockwise in a circle'),
#  ('00122', 'a person walks in a circle'),
#  ('00123', 'a person walks in a circle counter-clockwise'),
#  ('00124', 'a human walks in a full circle'),
#  ('00124', 'a persons walks in a circle to the left'),
#  ('00125', 'a person walks in a circle counterclockwise'),
#  ('00125', 'the human walks a circle'),
#  ('00126', 'a human walking in a circle counterclockwise'),
#  ('00126', 'a person walks in a circle to the left'),
#  ('00127', 'a person moves in a circle counterclockwise'),
#  ('00128', 'a human walking in a circle clockwise'),
#  ('00129', 'a person walks in a clockwise circle'),
#  ('00129',
#   'a human performs a full 360° curve to the right, ending where it started'),
#  ('00130', 'a person walks in a small circle, to the right'),
#  ('00130', 'human goes in a circle clockwise starting with right'),
#  ('00130', 'a person walks in a circle to the right'),
#  ('00130', 'person walking in a circle'),
#  ('00131', 'a person walks a full circle'),
#  ('00131', 'a person walks a circle to the right'),
#  ('00132', 'person walking in a circle'),
#  ('00132', 'someone walks in a clockwise circle'),
#  ('00133', 'a human walking in a circle clockwise'),
#  ('00133', 'a person walks a circle to the right'),
#  ('00134', 'a person walks a circle clockwise'),
#  ('00134', 'a person walks a circle to the right'),
#  ('00135', 'a person walks clockwise in a circle'),
#  ('00136', 'a human walking in a circle clockwise'),
#  ('00136', 'a person is walking in a circle clockwise'),
#  ('00136', 'a human goes around the circle clockwise'),
#  ('00136', 'someone walks a larger clockwise'),
#  ('00136', 'a person walks in a circle to the right'),
#  ('00137', 'a person walks clockwise in a small circle'),
#  ('00138', 'the human walks a left bend'),
#  ('00139', 'a human walks and turns to the left'),
#  ('00139', 'a person is walking in a curve to left'),
#  ('00139', 'a person turns left'),
#  ('00140', 'a human is making a counter-clockwise turn'),
#  ('00140', 'a person is walking a quarter counter-clockwise circle'),
#  ('00140', 'a person walks to the left performin a quater circle'),
#  ('00140', 'a person turns left'),
#  ('00141', 'a person starts walking in a circular motion towards the left'),
#  ('00141', 'a person walks a 90 degree curve to the left'),
#  ('00141', 'a person walks in a quarter circle'),
#  ('00142', 'a person walks around a corner'),
#  ('00142', 'a person walks and turns 90 degrees to the left'),
#  ('00142', 'a person walks a quarter circle to the left'),
#  ('00143', 'a person turns 90° to the left at medium speed'),
#  ('00144', 'a person walks a quarter of a small circle counterclockwise'),
#  ('00144', 'subject walks in a quarter circle counterclockwise'),
#  ('00144', 'some walks a quarter circle to the left'),
#  ('00145', 'a person walks and turns to the left'),
#  ('00145', 'a person walks in a quarter-circle'),
#  ('00145', 'a human performing a u-turn'),
#  ('00145',
#   'a person is walking two meters straight, than one step to the left'),
#  ('00145', 'a person walks along and turns to the left'),
#  ('00145', 'a person walks a curve to the left'),
#  ('00145', 'someone is walking a quarter round to his left side'),
#  ('00145', 'a person walks a 90 degree turn towards the left'),
#  ('00145', 'a person first walks and then turns to the left'),
#  ('00145', 'a person walks to the left'),
#  ('00145', 'a human is walking in a 90° right curve'),
#  ('00145', 'someone walks in a quarter circle to the left'),
#  ('00146', 'a human turning left'),
#  ('00146', 'a person walks a left turn of 90 degrees'),
#  ('00147', 'a person walks forwards, slowly turning to the left and stops'),
#  ('00147', 'someone walks a left turn'),
#  ('00147', 'a person turns left'),
#  ('00148', 'a person walks in a quarter circle clockwise with 4 steps'),
#  ('00148', 'a person walks a quarter, right sided circle'),
#  ('00149', 'a person walks a quarter circle clockwise with 4 steps'),
#  ('00149', 'human performs a bending walking movement to the right'),
#  ('00150', 'a person walks forward while gradually turning to the right'),
#  ('00151', 'a person is turning right'),
#  ('00151', 'a human is walking in a quarter of a circle to the right'),
#  ('00151', 'a human is performing a 90° right curve'),
#  ('00152', 'person walking to the right'),
#  ('00152', 'a person walks and turns right'),
#  ('00152', 'a person walks to the right'),
#  ('00153', 'a person goes to the right slowly'),
#  ('00153', 'a person walks a right curve'),
#  ('00154', 'a person turns right at medium speed'),
#  ('00154', 'a person walks to the right in a quter circle'),
#  ('00155', 'a person turns right'),
#  ('00155', 'a person slowly walks a 90° turn in four steps'),
#  ('00156', 'the person is first walking ahead and then turning to the right'),
#  ('00157', 'a person turns right'),
#  ('00158', 'person walking forwards'),
#  ('00158', 'someone walks slowly'),
#  ('00158', 'a person walks forward'),
#  ('00158', 'a human takes slow steps forward'),
#  ('00158', 'a person walks forward'),
#  ('00159', 'a person is walking slowly and stops'),
#  ('00159', 'a person walks forward'),
#  ('00160', 'a person walks forward'),
#  ('00160', 'someone walks forward'),
#  ('00161', 'a person goes slowly 5 steps forward'),
#  ('00161', 'a person walks slowly forward'),
#  ('00161', 'a person slowly walks 4 steps forwards'),
#  ('00162', 'a person walks 4 steps forward'),
#  ('00162', 'a person walks 4 steps'),
#  ('00163', 'a person walks forward'),
#  ('00163', 'a person walks a few steps forwards'),
#  ('00164', 'a person walks forward'),
#  ('00164', 'a person walks 4 steps forward'),
#  ('00165', 'someone walks forward'),
#  ('00165', 'a person takes 5 steps forward'),
#  ('00165', 'a person walks forwards quite slow'),
#  ('00166', 'a human walking slowly'),
#  ('00167', 'the person is walking forward'),
#  ('00167', 'the human perfoms a couple of steps'),
#  ('00167', 'a person walks forward'),
#  ('00168', 'a human goes slowly 5 steps backward'),
#  ('00168', 'a person takes 5 steps backwards staring with the left foot'),
#  ('00168', 'a person walks backwards'),
#  ('00168', 'a person walks five steps backwards'),
#  ('00169', 'a person walking backwards 4 steps with relatively small steps'),
#  ('00169', 'a person takes 4 steps backwards starting with the left foot'),
#  ('00169', 'a person takes five backward steps'),
#  ('00170', 'the person is walking backwards'),
#  ('00170', 'a person walkes backward'),
#  ('00171', 'a person walks slowly five steps backwards'),
#  ('00171', 'a person is walking backwards'),
#  ('00171', 'someone walks backwards'),
#  ('00172', 'a person goes back 4 steps'),
#  ('00173', 'a human walking backwards'),
#  ('00173', 'a person steps backwards'),
#  ('00173', 'a person takes some steps backwards'),
#  ('00174', 'a person takes four steps back'),
#  ('00174', 'a person walks back some meters'),
#  ('00175', 'a person walks 4 steps to the backward direction'),
#  ('00175', 'a person makes 4 steps backwards'),
#  ('00175', 'a person walks backwards'),
#  ('00175', 'a person slowly retreats'),
#  ('00175', 'someone walks backwards'),
#  ('00176', 'a person walks a few steps backwards'),
#  ('00176', 'a person walks backwards about 4 steps'),
#  ('00177', 'a person walks backwards'),
#  ('00177', 'someone walks backward'),
#  ('00177', 'a person walks backwards'),
#  ('00177', 'a person slowly walks backward'),
#  ('00177', 'a person walks 5 steps backwards'),
#  ('00177', 'a person taking a few steps backwards'),
#  ('00178', 'a human walking in circles'),
#  ('00178', 'a person walks in a counter-clockwise circle'),
#  ('00178', 'some walks anticlockwise'),
#  ('00178', 'a person walks in a circle to the left'),
#  ('00179', 'a person walks around in a circle anti-clockwise'),
#  ('00179', 'someone walks in a circle counterclockwise'),
#  ('00179', 'a person walks in a circle to the left taking 8 steps'),
#  ('00180', 'a person walks in a circle to the left'),
#  ('00180', 'a person is walking in a circle counter-clockwise'),
#  ('00180', 'a human is walking in circle'),
#  ('00181', 'a person walks in a small circle counterclockwise'),
#  ('00181', 'a human walks in circles counterclockwise making long steps'),
#  ('00182', 'a person walks clockwise in a circle'),
#  ('00183', 'a person walks in circles'),
#  ('00183', 'a person walks forward counterclockwise in a circle'),
#  ('00183', 'a person walks in a circle to the left'),
#  ('00184', 'a person walks slowly in a counterclockwise small circle'),
#  ('00185', 'a human walks in a counter-clockwise circle'),
#  ('00186', 'a person walks a circle'),
#  ('00186', 'subject walks in a circle counterclockwise'),
#  ('00187', 'a person walking in a circle to the left'),
#  ('00188', 'a person walks in a clockwise circle'),
#  ('00189', 'a human is walking clockwise in a circle'),
#  ('00189', 'a person walks a circle to the right'),
#  ('00190', 'a person walks a circle'),
#  ('00191', 'someone walks a clockwise circle'),
#  ('00191', 'a person is walking a clockwise circle'),
#  ('00191', 'a person walks in a circle'),
#  ('00191', 'a human is walking in circle to the right'),
#  ('00192', 'the person is walking in a circular shape'),
#  ('00192', 'person walks a circle'),
#  ('00193', 'a person walks in a circle clockwise'),
#  ('00194', 'someone is walking a small clockwise circle'),
#  ('00194', 'a person walks in circle to his right side'),
#  ('00194', 'a person walks in a circle to the right'),
#  ('00195', 'a person walks a circle clockwise'),
#  ('00196', 'someone walks in a clockwise circle'),
#  ('00196', 'human goes in a circle clockwise starting with right'),
#  ('00197', 'a person walking in a circle to the right'),
#  ('00197', 'a person walks in a cirlce to the right'),
#  ('00198', 'a person goes to the right'),
#  ('00199', 'the human walks a right bend'),
#  ('00199', 'somone walks in a quarter circle to the right'),
#  ('00200', 'someone walks in a slight right curve'),
#  ('00201', 'person walking to the right'),
#  ('00201', 'human goes in a quarter circle clockwise starting with right'),
#  ('00202',
#   'a person is walking forward starting with the right feet and performing five steps while turning to the right with an angle of 90°'),
#  ('00202', 'a person walks in a quarter circle to the right'),
#  ('00203', 'a person walks a quarter circle to the right'),
#  ('00204', 'a person turns 90° to the right at medium speed'),
#  ('00204', 'a person is turning right while walking'),
#  ('00205', 'a person walks to the right'),
#  ('00206', 'a human is making a clockwise turn'),
#  ('00206', 'a person is walking a quarter circle in clockwise direction'),
#  ('00207', 'a person turns right'),
#  ('00207', 'a person walks a quarter circle clockwise with 4 steps'),
#  ('00207', 'a person walks a 90° curve to his right'),
#  ('00207', 'someone turns right'),
#  ('00208', 'a person walks forward very slowly'),
#  ('00208', 'subject walks forward slowly'),
#  ('00208', 'a person walks forward quite slow'),
#  ('00209', 'a person walks slowly and stops'),
#  ('00209', 'a person walks straight forwards for some meters'),
#  ('00210', 'a person walks 4 steps forward'),
#  ('00211', 'subject walks forward'),
#  ('00211', 'a person starts walking 4 steps forward and then stops'),
#  ('00212', 'a person walking a few steps'),
#  ('00213',
#   'a human walks at a slight left angle for five steps and then stops'),
#  ('00213', 'someone walks forward'),
#  ('00214', 'a person walks 4 steps forward'),
#  ('00215', 'a person walks forwards'),
#  ('00216', 'a person walking a few steps forward'),
#  ('00217', 'a person walking forwards for a few steps'),
#  ('00217', 'a person walks forwards'),
#  ('00218', 'person walking backwards'),
#  ('00218', 'human goes backwards starting with left'),
#  ('00218', 'a person is walking backwards'),
#  ('00218', 'a person walks backwards'),
#  ('00219', 'someone walks slowly backwards'),
#  ('00219', 'a person walks backwards'),
#  ('00219', 'a person slowly walks back taking 4 steps'),
#  ('00222', 'a person moves backwards'),
#  ('00223', 'a person walks backwards'),
#  ('00223', 'a person walks backwards'),
#  ('00224', 'someone walks backwards four steps'),
#  ('00224', 'a person walks backward'),
#  ('00225', 'a person walks backwards'),
#  ('00225', 'human goes backwards'),
#  ('00225', 'a person walks a few steps backward'),
#  ('00225', 'somebody walks backwards'),
#  ('00226', 'a person walks backwards'),
#  ('00227', 'subject walks in a full circle counterclockwise'),
#  ('00227', 'the human walks a circle'),
#  ('00228', 'person walking in a circle'),
#  ('00228', 'a person walks in a counter-clockwise circle'),
#  ('00228', 'a person walks in a circle to the left'),
#  ('00228',
#   'a person moves anti-clockwise in a cirle and needs 8 steps to complete the circle'),
#  ('00228', 'a person walks in a small circle'),
#  ('00229', 'a person walks in a narrow counter-clockwise circle'),
#  ('00229', 'subject in small circle counterclockwise'),
#  ('00229', 'someone slowly walks in a small circle to the left'),
#  ('00229', 'someone walks a circle'),
#  ('00229', 'a human walks slowly in circles, counterclockwise'),
#  ('00229', 'a human goes a circle left around'),
#  ('00230', 'subject walks in a quarter circle counterclockwise'),
#  ('00230', 'a person is walking in a circle'),
#  ('00231', 'a person walks counter-clockwise in a circle'),
#  ('00231', 'a person walks in a circle'),
#  ('00231', 'somebody walks a circle anticlockwise'),
#  ('00232', 'walk in a circle'),
#  ('00232', 'a person walks a circle in the left direction'),
#  ('00232', 'a person walks in a circle'),
#  ('00233', 'the person make a walk along a circular path'),
#  ('00233', 'someone is walking in a circle counterclockwise'),
#  ('00233', 'a person walks a circle to the left'),
#  ('00233', 'a person is walking in a circle'),
#  ('00234', 'a person moves in a circle'),
#  ('00235', 'a person moves in a circle clockwise'),
#  ('00235', 'a human walks a small circle to its left'),
#  ('00236', 'a person walks in a small circle counter clockwise'),
#  ('00237', 'a human walking in a circle clockwise'),
#  ('00237', 'a person walks a full circle to the right'),
#  ('00238', 'subject walks in a circle clockwise'),
#  ('00239', 'a person walking slowly in a circle to the right'),
#  ('00239', 'a person walks forward in a circle clockwise'),
#  ('00239', 'a person walks in a circle to the right'),
#  ('00240', 'a person walks in circles'),
#  ('00240', 'a person is walking in a clockwise circle'),
#  ('00241', 'a person walks in a circle'),
#  ('00241', 'someone goes around in a circuit'),
#  ('00241', 'a person walks in a circle to the right'),
#  ('00241', 'a human is performing a right 360° curve'),
#  ('00242', 'a person walks in a circle'),
#  ('00243', 'subject walks in a circle clockwise'),
#  ('00243', 'a person walks clockwise forward in a circle'),
#  ('00244', 'a person walks slowly in a circle in clockwise direction'),
#  ('00244',
#   'a human walks slowly a full circle to its right and ends up on the spot where it started'),
#  ('00245', 'a person walks in a clockwise circle'),
#  ('00245', 'a person walks in a little circle'),
#  ('00245', 'a person walks forward in a circle clockwise'),
#  ('00246', 'a person performs a circular movement'),
#  ('00246', 'walking in a circle to the right'),
#  ('00247', 'someone walks a quarter-circle to the right'),
#  ('00247', 'a person slowly walks a quarter ride sided circle'),
#  ('00248', 'a human walks and turns to the right'),
#  ('00248', 'someone walks a right turn'),
#  ('00248', 'a person walks to the right'),
#  ('00249', 'a human is making a clockwise turn'),
#  ('00249', 'a person walks to the right'),
#  ('00250', 'a person turns left at medium speed'),
#  ('00251', 'a human walks a 90 degree arc to the right'),
#  ('00251', 'someone walks a circle clockwise'),
#  ('00251', 'a person walks a circle'),
#  ('00252', 'a person starts a circular movement towards the right'),
#  ('00252', 'someone walks a right turn'),
#  ('00253', 'a person turns around a corner towards the right'),
#  ('00253', 'a person walks a 90 degree curve to the right'),
#  ('00254', 'a person walks a left turn'),
#  ('00254', 'a person turns to his right'),
#  ('00254', 'human performs a bending walking motion to its right hand side'),
#  ('00255', 'someone walks a quarter-circle to the right'),
#  ('00255', 'someone walks a right turn'),
#  ('00255', 'a human performs a 90° curve tu the right'),
#  ('00255', 'a human walks a quarter to his right'),
#  ('00255', 'a person turns right'),
#  ('00256', 'a person walks forward and performs a turn to the right'),
#  ('00256', 'a person walks in a quarter-circle to the right'),
#  ('00256', 'a person walks towards me'),
#  ('00256', 'someone comes close to the camera'),
#  ('00256', 'a person is walking in a curve to the right'),
#  ('00256', 'someone comes very close to the observer'),
#  ('00256', 'a human takes a 90 degree right turn'),
#  ('00256', 'a person walking five steps to the right'),
#  ('00256', 'a person walks slowly a curve'),
#  ('00256', 'a person walks in a 90 degree turn towards the right'),
#  ('00256', 'a human slowly turns right by 5 steps'),
#  ('00256',
#   'a person walks  a quarter circle with a radius of approximately 1 meter to the right'),
#  ('00256', 'a human is performing a 90° curve to the right'),
#  ('00256', 'a person is walking a quarter of a circle to its right'),
#  ('00256', 'a person walks to the right performing a quarter circle'),
#  ('00256', 'a person walks forward in a 90° curve to his right'),
#  ('00256', 'the human perfoms a right turn'),
#  ('00256', 'a person is doing slow a 90° right turn in five steps'),
#  ('00256', 'human performs a bending walking motion to the right'),
#  ('00257', 'a person starts a circular movement towards the left'),
#  ('00257',
#   'human slowly goes in a quater circle counterclockwise starting with right'),
#  ('00258', 'a man walks a quarter of a circle towards the left'),
#  ('00258',
#   'human goes in a quarter circle counterclockwise starting with right'),
#  ('00258', 'a human walks slowly a quarter of a circle to its left'),
#  ('00259', 'a person walks while gradually turning to the left'),
#  ('00260', 'the human walks a 90-degree left bend'),
#  ('00260', 'a person walking to the left'),
#  ('00260', 'a person turns left'),
#  ('00260', 'someone is walking half a round to his left side'),
#  ('00260', 'a person walks and turns to the left'),
#  ('00260',
#   'a person walks a quarter circle with a radius of approximately 1 meter to the left'),
#  ('00260', 'a person walks to the left in a quater circle'),
#  ('00260', 'a person walking forward in a 90° curve'),
#  ('00260', 'the human perfoms a left turn'),
#  ('00262', 'a person walks a quarter circle counter clockwise with 4 steps'),
#  ('00262', 'a person is taking a left turn while walking'),
#  ('00262', 'a person walks a 90 degree curve to the left'),
#  ('00263', 'someone performs a slow move around a corner to the left'),
#  ('00263', 'the human perfoms a left turn'),
#  ('00264', 'a human turning left'),
#  ('00265', 'a erson walks in a quarter circle'),
#  ('00265', 'a person walks to the left performing a quater circle'),
#  ('00265', 'a person walks in a 90° curve to his left'),
#  ('00266', 'a person turns left'),
#  ('00266', 'someone left something on the ground when he walks  a corner'),
#  ('00267', 'the person is walking backwards'),
#  ('00267', 'a person walks backwards'),
#  ('00268', 'a person is walking backwards'),
#  ('00268', 'a person walks 5 steps backwards'),
#  ('00269', 'a person is walking backwards'),
#  ('00269', 'a person walks backward'),
#  ('00269', 'someone walks backwards 4 steps starting with the left leg'),
#  ('00269', 'the human perfoms a couple of steps backwards'),
#  ('00269', 'human goes backwards at medium velocity'),
#  ('00270', 'a person takes four steps back'),
#  ('00270', 'a person does 4 steps backwards slowly'),
#  ('00271', 'a subject is walking backward four steps'),
#  ('00271', 'a person is walking backwards'),
#  ('00272', 'a person is walking backwards'),
#  ('00273', 'a person is taking four steps back'),
#  ('00273', 'a person walks 4 steps backwards'),
#  ('00273', 'a person walks backwards in a straight line'),
#  ('00274', 'a human walking backwards'),
#  ('00274', 'a person walks backwards'),
#  ('00274', 'a person is walking backwards'),
#  ('00275', 'someone is taking a few steps back'),
#  ('00275', 'a person walks backward'),
#  ('00275', 'a human walks backwards'),
#  ('00276', 'a human walking backwards'),
#  ('00276', 'a human walks backwards'),
#  ('00276', 'a person is walking backwards'),
#  ('00277', 'person walking in a circle to the left'),
#  ('00277', 'a person walks in a counter-clockwise circle'),
#  ('00277', 'a person walks in a circle to the left'),
#  ('00277', 'someone walks in a circle to the right'),
#  ('00278', 'a person walking in a circle to the left'),
#  ('00279', 'subject walks in a full circle counterclockwise'),
#  ('00280', 'a person walking in a circle to the left'),
#  ('00281', 'a person walks in a circle'),
#  ('00281', 'a person walks a circle to the left'),
#  ('00282', 'a person walks a circle counter-clockwise'),
#  ('00282', 'someone walks in a circle counterclockwise'),
#  ('00283', 'the person performs a circular walk'),
#  ('00283', 'a person walks in a circle'),
#  ('00283', 'a person walks a quarter circle in the left direction'),
#  ('00283', 'a person walks in a circle'),
#  ('00284', 'subject walks in a circle counterclockwise'),
#  ('00284', 'a human walks in a circle to its left'),
#  ('00284', 'a person is walking a full circle to the left'),
#  ('00285', 'person walks in a circle'),
#  ('00286', 'a person moves in a circle'),
#  ('00286', 'a person walks in a circle'),
#  ('00286', 'someone walks a full circle to the left'),
#  ('00287', 'person walking in a circle'),
#  ('00287', 'human goes in a circle clockwise starting with right'),
#  ('00287', 'a person moves in a circle'),
#  ('00287', 'a person is walking in a circle clockwise'),
#  ('00288', 'a person walks clockwise in a small circle'),
#  ('00289', 'a person walks clockwise in a circle'),
#  ('00289', 'human goes in a circle clockwise'),
#  ('00289', 'someone walks a full circle to the right'),
#  ('00290', 'a human walking in a circle clockwise'),
#  ('00291', 'a human waling in a circle clockwise'),
#  ('00291', 'a person walks in a little circle'),
#  ('00291', 'a person walks in a small circle to the right'),
#  ('00292', 'a person walks clockwise in a small circle'),
#  ('00293', 'a person walks confidently in cirlces'),
#  ('00293', 'a person walks in a circle to the right'),
#  ('00294', 'a human walks in a circle'),
#  ('00295', 'a human walk in a circle'),
#  ('00295', 'a person walks a circle to the right'),
#  ('00296', 'a person walks in a circle counterclockwise'),
#  ('00297', 'a person walks a 90° turn to his left'),
#  ('00297', 'subject walks in quarter circle counterclockwise'),
#  ('00297', 'a person turns around a left corner'),
#  ('00298', 'a person walks a quarter circle to his left'),
#  ('00299', 'a person walks counter clockwise in a circle'),
#  ('00299', 'human performs a bending walking movement to the left'),
#  ('00300', 'human walks in a quater circle counterclockwise'),
#  ('00300', 'a person turns left'),
#  ('00301', 'a person walks while turning to the left'),
#  ('00301', 'a person takes a quarter of a circle to the left'),
#  ('00302', 'the person is first walking ahead and then turning to the left'),
#  ('00302', 'a person walks to the left in a quarter circle'),
#  ('00303', 'a person walking in a quarter circle to the left'),
#  ('00304', 'a person walks forward while turning to the left'),
#  ('00304', 'a person walks a quater circle to the left in five forward steps'),
#  ('00304', 'the human perfoms a left turn'),
#  ('00305', 'subject walks a quarter circle counterclockwise'),
#  ('00305', 'a person walks to the left performing a quarter circle'),
#  ('00305', 'the human perfoms a left turn'),
#  ('00306', 'a human walks in a left bend'),
#  ('00307', 'a person walks forward while turning to the right'),
#  ('00307',
#   'a person goes to the right, where it passes through a quarter circle line along'),
#  ('00308', 'a person walking in a curve to the right and then standing still'),
#  ('00308', 'a human walks a quarter turn to the right'),
#  ('00309', 'a human is walking in a 90 degree curve to the right'),
#  ('00310', 'a person walks while turning to the right'),
#  ('00310', 'human goes in a quater circle clockwise starting with right'),
#  ('00310', 'a person walks to the right performing a quater circle'),
#  ('00311', 'a person walks a quarter circle to the right'),
#  ('00311', 'a person turns right'),
#  ('00312', 'a person walks a 90 degree curve to the right'),
#  ('00312', 'a person is walking in a right curve'),
#  ('00313', 'subject walks in a quarter circle clockwise'),
#  ('00314', 'a person walking in a 90 degrees curve to the right'),
#  ('00314', 'a person turns right'),
#  ('00315', 'a person walks a quarter circle clockwise with 4 steps'),
#  ('00316', 'a person turns right'),
#  ('00317', 'a person walks forwards for four steps'),
#  ('00318', 'someone walks forward'),
#  ('00318', 'someone walks forward'),
#  ('00319', 'a person walks forward'),
#  ('00319', 'a person walkes forward'),
#  ('00320', 'person walking to the front'),
#  ('00320', 'someone walks forward'),
#  ('00320', 'a person makes 4 steps forward'),
#  ('00320', 'a human performs a jump to the left'),
#  ('00321', 'person walking forwards'),
#  ('00321', 'a person walks forward'),
#  ('00321', 'a human walks 4 steps forward on one line'),
#  ('00321', 'a person walking forward'),
#  ('00322', 'person walking forwards'),
#  ('00322', 'a person walks forward'),
#  ('00322', 'a person just walks forward'),
#  ('00323', 'a person goes four and a half steps forward'),
#  ('00324', 'subject walks forward'),
#  ('00324', 'a human is walking forward'),
#  ('00325', 'a person walks four steps forward'),
#  ('00325', 'a person is walking'),
#  ('00326', 'someone walks four steps forwards'),
#  ('00326', 'someone is walking forward 4 steps starting with the left leg'),
#  ('00326', 'a human is slowly walking forward'),
#  ('00326', 'a person walks forward'),
#  ('00327',
#   'a person walks backwards in a straight line slightly swinging his arms by his sides as he does so'),
#  ('00327', 'someone walks backward'),
#  ('00327', 'a human walks 4 steps backwards on one line'),
#  ('00328', 'a person walks backwards'),
#  ('00329', 'a human walks 4 steps backwards'),
#  ('00330', 'a human is walking backwards'),
#  ('00331', 'person standing and then walking back'),
#  ('00331', 'a person walks backwards'),
#  ('00331', 'a person takes some steps backwards'),
#  ('00331', 'a person walkes backwards'),
#  ('00331', 'a man walks a few steps backwards'),
#  ('00332', 'a person walks backwards'),
#  ('00332', 'someone walks backward'),
#  ('00332',
#   'a human walks 3 bigger and 1 smaller steps backwards and is starting with its left foot'),
#  ('00332', 'a person walks backwards'),
#  ('00332', 'somebody walks slowly backwards'),
#  ('00333', 'a person walks backwards'),
#  ('00334', 'someone is walking backwards four steps'),
#  ('00334', 'someone does 4 steps backward starting with the left leg'),
#  ('00334', 'a human is walking backwards'),
#  ('00334', 'a person walks 4 steps backwards'),
#  ('00334', 'a human is walking backwards'),
#  ('00335', 'person walking backwards'),
#  ('00335', 'a person walks backward'),
#  ('00336', 'a human walks four steps backwards'),
#  ('00336', 'a person taes some steps backwards'),
#  ('00336', 'a person walks 5 steps backwards'),
#  ('00336', 'a human starts walking backwards'),
#  ('00337', 'a person walks counter clockwise in a circle'),
#  ('00338', 'a person walks in a circle'),
#  ('00339', 'a person walks counterclockwise in a small circle'),
#  ('00339',
#   'a human walks in a counterclockwise circle, completing one round in 8 steps'),
#  ('00339',
#   'a human walks a full circle to its left and stops right before where it started'),
#  ('00340', 'subject walks in a full circle counterclockwise'),
#  ('00341', 'a person walks counter clockwise in a circle'),
#  ('00341',
#   'someone walks in a circle of appoximately 2 meters in diameter  to the right'),
#  ('00342', 'person walking in a circle to the left'),
#  ('00342', 'a person walks counter-clockwise circle'),
#  ('00342', 'someone walks a larger anticlockwise'),
#  ('00343', 'walking counter clock-wise in a circle'),
#  ('00343', 'a person walks in a circle round an axis'),
#  ('00344', 'a person walks counterclockwise in a small circle'),
#  ('00344', 'a person walks a circle'),
#  ('00345', 'a person walking in a circle to the left'),
#  ('00346', 'subject walks in a full circle counterclockwise'),
#  ('00346', 'a person walks forward in a counterclockwise circle'),
#  ('00347',
#   'the person is walking back to the initial position by following a circular shape'),
#  ('00347', 'a person walks in a circle to the right'),
#  ('00347', 'somebody walks a circle clockwise'),
#  ('00348', 'subject walks in a full circle clockwise'),
#  ('00348', 'some walks clockwise'),
#  ('00348', 'a person walks in a circle to the right'),
#  ('00348', 'a man walks in small circle to the right'),
#  ('00349', 'a person walks in a circle'),
#  ('00349', 'a person walks to the right in a circle'),
#  ('00349', 'a person walks in a circle to his right side'),
#  ('00350', 'a human walks in a full circle clockwise'),
#  ('00350', 'a person walks in a clockwise circle'),
#  ('00350', 'a person walks in a circle clockwise'),
#  ('00351', 'a person walks clockwise in a circle'),
#  ('00352', 'a person walks in a circle'),
#  ('00352', 'a person walks in a circle to the right'),
#  ('00353', 'a human walks in a circle clockwise'),
#  ('00354', 'a person walks in a circle clockwise'),
#  ('00355', 'someone walks a full clockwise circle'),
#  ('00355', 'a person is walking in a circle in clockwise direction'),
#  ('00356', 'a person walks in a circle'),
#  ('00356', 'a human performs a jump to the left'),
#  ('00357', 'someone walks a few steps in a left bend'),
#  ('00358', 'a persons turns 90° to the left'),
#  ('00358', 'a person walks a quarter left sides circle'),
#  ('00358', 'a person turns left'),
#  ('00359', 'a person walks a quarter of a circle counterclockwise'),
#  ('00359', 'a human walks a quarter to the left'),
#  ('00360', 'person walking in a curve to the left'),
#  ('00360',
#   'human goes in a quater circle counterclockwise starting with left'),
#  ('00361', 'a person walks while turning to the left'),
#  ('00361',
#   'a person goes to the left, where it passes through a quarter circle line along'),
#  ('00361', 'someone turns a left corner'),
#  ('00362', 'subject walks in a quarter circle counterclockwise'),
#  ('00362', 'a person walks to the left performing a quarter circle'),
#  ('00363', 'subject walks in a quarter circle counterclockwise'),
#  ('00364', 'a person turns left'),
#  ('00364', 'someone walks a left turn'),
#  ('00365',
#   'human goes in a quarter circle counterclockwise starting with left'),
#  ('00366', 'a person walks a quarter circle clockwise with 4 steps'),
#  ('00367', 'a human turning right'),
#  ('00367', 'a person walks a quarter of a circle to its right'),
#  ('00367', 'a person walks a quarter circle to the right'),
#  ('00368', 'a person walks a quarter circle clockwise with 4 steps'),
#  ('00369', 'human walks in clockwise circle starting with right leg'),
#  ('00369', 'a human is performing a tight 90° right curve'),
#  ('00370', 'a person turns right'),
#  ('00370', 'a person walks 90degrees to the right'),
#  ('00371', 'a person walks a quarter circle clockwise with 4 steps'),
#  ('00372', 'a person walks while gradually turning to the right'),
#  ('00372', 'a person turns right'),
#  ('00372', 'a person walks to the right 90 degrees'),
#  ('00373', 'a person walks a quarter of a circle'),
#  ('00373',
#   'a person walks 90degrees to the right performing a quarter circle'),
#  ('00373', 'somebody walks a quarter circle clockwise'),
#  ('00374', 'person walking to the right'),
#  ('00374', 'a person walks forward while turning to the right'),
#  ('00375', 'a human walks a very slow 90 degree arc to the right'),
#  ('00375', 'human goes in a quarter circle clockwise starting with right'),
#  ('00376', 'someone walks forward'),
#  ('00377', 'a person walks'),
#  ('00377', 'a person is walking forward'),
#  ('00378', 'a person walks forward'),
#  ('00379', 'a person walks 4 steps in the forward direction'),
#  ('00380', 'a person walks forward'),
#  ('00381', 'a person walks forward'),
#  ('00381', 'person walking forwards'),
#  ('00381', 'someone goes away'),
#  ('00381', 'walking five steps in a straight line'),
#  ('00381', 'a person walks forward'),
#  ('00381', 'a person walks straight forward a few meters'),
#  ('00381', 'a person is walking forward'),
#  ('00381', 'a person walks forward'),
#  ('00381', 'a person walks five steps'),
#  ('00382', 'a person goes five steps forward'),
#  ('00383',
#   'a person walking very normal, with an average speed for 5 steps while its arms are swinging normally on every step'),
#  ('00383', 'a person walks forwards'),
#  ('00384', 'a person walks forward'),
#  ('00384', 'a person walks 4 steps forward in a straight line'),
#  ('00384', 'a person walkes forward'),
#  ('00385', 'a person walks four steps backward'),
#  ('00385', 'someone takes 4 steps backwards starting with left'),
#  ('00386', 'person walks backward'),
#  ('00386', 'a human walks 4 steps backwards on a line'),
#  ('00386', 'a human is walking backwards'),
#  ('00387', 'subject walks three steps backwards'),
#  ('00388', 'someone moves backwards in a walk'),
#  ('00388', 'a human walks backwards while looking forward'),
#  ('00388', 'a person walks backwards a few steps'),
#  ('00388', 'a person walks backwards fast'),
#  ('00388', 'a person takes 5 steps backwards'),
#  ('00389', 'a person walks four steps backward'),
#  ('00389', 'a person walks some meters back'),
#  ('00389', 'a person walks backwards for four steps'),
#  ('00390', 'subject walks backwards'),
#  ('00390', 'a person is walking backwards'),
#  ('00390', 'human goes backwards'),
#  ('00391', 'a person walks backwards'),
#  ('00391', 'a person walks backward'),
#  ('00391', 'a person walks backwards'),
#  ('00391', 'human goes backwards'),
#  ('00392', 'a person is walking quickly backwards'),
#  ('00392', 'a person walkes backwards'),
#  ('00393', 'a person walks backwards'),
#  ('00393', 'a person walking backwards'),
#  ('00394', 'subject walks backwards'),
#  ('00394', 'a person walking backwards'),
#  ('00396', 'a person walks counter clockwise in a circle'),
#  ('00396', 'a person walks in a counter-clockwise circle'),
#  ('00397', 'someone walks a full circle'),
#  ('00397',
#   'a person walking forward three quarters of a circle counterclockwise'),
#  ('00397', 'a person walks in a circle to the left'),
#  ('00398', 'a person walks in a circle'),
#  ('00398', 'a person is doing a three quarter counter-clockwise circle'),
#  ('00398', 'a person walks three fourth of a circle to the left'),
#  ('00399', 'a human walking in a circle counter clockwise'),
#  ('00399', 'a human walks three quarter of a circle to its left'),
#  ('00400', 'a person walks in a circle to he left'),
#  ('00401', 'the human walks a counter-clockwise circle'),
#  ('00401', 'a human walks in a circle'),
#  ('00402', 'someone is walking a circle'),
#  ('00402', 'a person walks three fourth of a circle'),
#  ('00402', 'a person walks in a three quarter circle to his left side'),
#  ('00403', 'a human walks around in a clockwise circle'),
#  ('00403', 'someone walks in a circle clockwise'),
#  ('00403', 'someone is walking in a circle clockwise'),
#  ('00403', 'a person walks in a circle'),
#  ('00404',
#   'a person walks in clock-wise circle and stops facing 90 degrees to the left relative from the starting position'),
#  ('00404', 'a human is walking three quarter of a circle to its right'),
#  ('00404', 'a person walks in a circle'),
#  ('00405', 'a person walks in a rightward circle'),
#  ('00406',
#   'the person is walking back to the initial position by following a circular path'),
#  ('00407', 'a human walks a right circle'),
#  ('00407', 'a person walks a circle, radius approximatly 1,5 meters'),
#  ('00407', 'a person walks in a cricle to the right'),
#  ('00408', 'a human walks in a clockwise circle'),
#  ('00408', 'a human goes around, circulates'),
#  ('00408', 'human goes in a circle clockwise'),
#  ('00409', 'a person walks a circle clockwise'),
#  ('00410', 'someone walks a 90 degrees curve to the left'),
#  ('00410', 'a person walks forward in a 90° curve to his left'),
#  ('00411', 'a person walks a quarter circle'),
#  ('00412', 'a person walks to the left one-quarter of a rotation'),
#  ('00412', 'a person walks a quarter circle two the left'),
#  ('00412', 'a person walks a 90 degree turn to the left'),
#  ('00412', 'a person walks in a quarter circle to the left'),
#  ('00413', 'person walks around a corner'),
#  ('00414', 'a person is turning right'),
#  ('00414', 'a person walks to the right performing a quarter circle'),
#  ('00415',
#   'a human moves in a quarter circle, makes a break and move in another quarter circle'),
#  ('00415', 'someone is walking forward and then turning right'),
#  ('00415',
#   'a person walks forwards performing a quarter circle to the right and then walks back to its origin position in the same way'),
#  ('00416', 'a human turning right'),
#  ('00417', 'person looks around and then walks around a corner'),
#  ('00417', 'a person walks forwards performing a quarter circle to the right'),
#  ('00417', 'a person walks forward in a 90° curve to the right'),
#  ('00417', 'a person is turning right while walking'),
#  ('00418', 'a person walks in 90 degree curve to the right'),
#  ('00419', 'a person walking in a quarter circle to the right'),
#  ('00420', 'the person is turning right'),
#  ('00421', 'a person walks a ninety degree curve to the left'),
#  ('00422', 'a person walks forward anf turns slightly to the right'),
#  ('00422', 'a person walks and turns 90 degrees to the right'),
#  ('00422', 'a human is walking in a 90° right curve'),
#  ('00423', 'a human turning right'),
#  ('00424', 'a person walks slowly forward'),
#  ('00424', 'a person takes a few slow steps forward'),
#  ...]

# %% [markdown]
# # Tokenizing

# %%
tknzr = nltk.tokenize.TweetTokenizer()

# %%
tknzr.tokenize(all_sentences[0][1])
# Out:
# ['a', 'person', 'is', 'walking', 'forwards']

# %%
tokenized_sentences = [(s[0], tknzr.tokenize(s[1])) for s in all_sentences]

# %%
tokenized_sentences
# Out:
# [('00001', ['a', 'person', 'is', 'walking', 'forwards']),
#  ('00002', ['a', 'person', 'walks', '4', 'steps', 'forward']),
#  ('00003', ['a', 'human', 'walking']),
#  ('00004', ['a', 'person', 'walks', 'forward', 'at', 'medium', 'speed']),
#  ('00004', ['human', 'slowly', 'goes', 'forward']),
#  ('00005', ['a', 'human', 'walks', 'four', 'slow', 'steps', 'forward']),
#  ('00006', ['a', 'person', 'goes', 'four', 'and', 'half', 'steps', 'forward']),
#  ('00006',
#   ['a', 'person', 'walking', 'forward', 'slightly', 'to', 'the', 'right']),
#  ('00007',
#   ['a', 'person', 'walks', 'slowly', 'for', 'four', 'steps', 'and', 'stops']),
#  ('00007',
#   ['a',
#    'person',
#    'walks',
#    'four',
#    'steps',
#    'to',
#    'the',
#    'forward',
#    'direction']),
#  ('00008', ['a', 'person', 'walks', 'slowly', '4', 'steps', 'forward']),
#  ('00009',
#   ['a',
#    'person',
#    'stands',
#    ',',
#    'then',
#    'walks',
#    'a',
#    'few',
#    'steps',
#    ',',
#    'then',
#    'stops',
#    'again']),
#  ('00009',
#   ['someone',
#    'is',
#    'walking',
#    'forward',
#    'slowly',
#    'doing',
#    '4',
#    'steps',
#    'starting',
#    'with',
#    'the',
#    'left',
#    'leg']),
#  ('00009', ['a', 'person', 'makes', '4', 'steps', 'forward', 'slowly']),
#  ('00010', ['a', 'human', 'walking', 'backwards']),
#  ('00011',
#   ['a',
#    'person',
#    'walks',
#    'backwards',
#    'four',
#    'steps',
#    'starting',
#    'with',
#    'the',
#    'left',
#    'foot']),
#  ('00011', ['somebody', 'walks', 'backwards']),
#  ('00013',
#   ['a', 'person', 'walking', 'backwards', 'for', 'a', 'few', 'steps']),
#  ('00014', ['a', 'person', 'walks', 'four', 'steps', 'backward']),
#  ('00015', ['a', 'person', 'walks', 'backwards']),
#  ('00016', ['a', 'person', 'walks', 'backward', 'at', 'a', 'slow', 'speed']),
#  ('00016',
#   ['a',
#    'human',
#    'is',
#    'walking',
#    '4',
#    'steps',
#    'backwards',
#    'and',
#    'starting',
#    'with',
#    'its',
#    'left',
#    'food']),
#  ('00016', ['a', 'person', 'walks', 'backwards']),
#  ('00016', ['some', 'is', 'reverse', 'walking']),
#  ('00016', ['a', 'person', 'takes', '4', 'steps', 'backwards']),
#  ('00016',
#   ['a',
#    'person',
#    'moves',
#    'backwards',
#    '4',
#    'steps',
#    'before',
#    'standing',
#    'still']),
#  ('00016', ['someone', 'is', 'walking', 'backwards']),
#  ('00016', ['a', 'man', 'is', 'walking', 'backwards']),
#  ('00016', ['somebody', 'walks', 'a', 'few', 'steps', 'backward']),
#  ('00017', ['a', 'person', 'walks', 'four', 'steps', 'backwards']),
#  ('00017', ['a', 'person', 'walks', 'backwards', 'slowly']),
#  ('00017', ['somebody', 'walks', 'backward']),
#  ('00018', ['a', 'person', 'is', 'walking', 'backwards']),
#  ('00019', ['a', 'person', 'turns', 'in', 'a', 'circle']),
#  ('00019', ['someone', 'walks', 'in', 'a', 'circle', 'counterclockwise']),
#  ('00019', ['somebody', 'wals', 'a', 'circle', 'anticlockwise']),
#  ('00020',
#   ['a', 'person', 'walks', 'in', 'a', 'circle', 'counter', 'clockwise']),
#  ('00021', ['a', 'person', 'walks', 'in', 'a', 'square']),
#  ('00022', ['the', 'person', 'is', 'walking', 'in', 'a', 'circular', 'shape']),
#  ('00022',
#   ['a',
#    'human',
#    'walks',
#    'slowly',
#    'a',
#    'full',
#    'circle',
#    'to',
#    'its',
#    'left']),
#  ('00022',
#   ['a', 'person', 'walks', 'a', 'full', 'counter-clockwise', 'circle']),
#  ('00022',
#   ['a', 'person', 'walks', 'in', 'a', 'circle', 'pattern', 'one', 'time']),
#  ('00023', ['a', 'person', 'walks', 'in', 'a', 'counter-clockwise', 'circle']),
#  ('00023', ['somebody', 'is', 'walking', 'in', 'a', 'circle']),
#  ('00023', ['person', 'walking', 'in', 'a', 'circle']),
#  ('00023', ['a', 'person', 'is', 'walking', 'in', 'a', 'circle']),
#  ('00023',
#   ['someone', 'slowly', 'walks', 'a', 'full', 'circle', 'to', 'the', 'left']),
#  ('00023', ['walking', 'in', 'a', 'slow', 'circle']),
#  ('00023', ['someone', 'walks', 'a', 'complete', 'circle']),
#  ('00023', ['a', 'person', 'turns', 'around', 'to', 'the', 'beginning']),
#  ('00023',
#   ['someone',
#    'is',
#    'walking',
#    'a',
#    'whole',
#    'round',
#    'to',
#    'his',
#    'left',
#    'side']),
#  ('00023', ['a', 'person', 'is', 'walking', 'in', 'a', 'circle', 'shape']),
#  ('00023', ['a', 'person', 'walks', 'a', 'circle', 'to', 'the', 'left']),
#  ('00024', ['a', 'person', 'walks', 'a', 'circle']),
#  ('00025',
#   ['a', 'person', 'walking', 'in', 'a', 'circle', 'to', 'the', 'left']),
#  ('00025',
#   ['a', 'person', 'walks', 'a', 'circle', 'in', 'the', 'left', 'direction']),
#  ('00026', ['a', 'person', 'walks', 'in', 'a', 'counter-clockwise', 'circle']),
#  ('00026', ['someone', 'walks', 'in', 'a', 'circle', 'counterclockwise']),
#  ('00027',
#   ['the', 'person', 'is', 'walking', 'through', 'a', 'circular', 'path']),
#  ('00027', ['a', 'human', 'is', 'walking', 'in', 'circle']),
#  ('00028', ['human', 'goes', 'in', 'a', 'circle', 'clockwise']),
#  ('00029',
#   ['a', 'person', 'walking', 'in', 'a', 'circle', 'to', 'the', 'right']),
#  ('00029', ['somebody', 'walks', 'a', 'circle', 'clockwise']),
#  ('00030', ['a', 'person', 'walks', 'in', 'a', 'clockwise', 'circle']),
#  ('00030',
#   ['a', 'person', 'running', 'in', 'a', 'full', 'circle', ',', 'clockwise']),
#  ('00031', ['a', 'person', 'walks', 'a', 'circle', 'clock-wise']),
#  ('00031', ['a', 'person', 'walks', 'in', 'clock-wise', 'circle']),
#  ('00031',
#   ['a', 'human', 'is', 'walking', 'in', 'a', 'circle', 'to', 'the', 'right']),
#  ('00032', ['a', 'person', 'walks', 'in', 'a', 'circle', 'clockwise']),
#  ('00032',
#   ['a',
#    'person',
#    'walks',
#    'in',
#    'a',
#    'circle',
#    'and',
#    'looks',
#    'facing',
#    'down']),
#  ('00032',
#   ['a', 'person', 'walks', 'a', 'circle', 'in', 'the', 'right', 'direction']),
#  ('00032',
#   ['the', 'human', 'walks', 'a', 'circle', '(', 'right', 'turn', ')']),
#  ('00033', ['a', 'person', 'walks', 'in', 'a', 'circle', 'clockwise']),
#  ('00033',
#   ['a', 'person', 'walks', 'in', 'a', 'circle', 'to', 'his', 'right', 'side']),
#  ('00034', ['a', 'human', 'walking', 'in', 'a', 'circle', 'clockwise']),
#  ('00034', ['a', 'person', 'walks', 'in', 'a', 'little', 'circle']),
#  ('00035', ['a', 'person', 'walks', 'a', 'circle']),
#  ('00036',
#   ['a', 'person', 'walks', 'in', 'circle', 'in', 'clockwise', 'direction']),
#  ('00037', ['a', 'person', 'walks', 'a', 'circle', 'clockwise']),
#  ('00037', ['a', 'perons', 'walks', 'a', 'circle', 'clockwise']),
#  ('00037', ['a', 'man', 'walks', 'in', 'circle']),
#  ('00038',
#   ['a',
#    'person',
#    'walking',
#    'in',
#    'a',
#    'quarter',
#    'circle',
#    'to',
#    'the',
#    'right']),
#  ('00038', ['a', 'person', 'walks', 'while', 'turning', 'to', 'the', 'right']),
#  ('00039',
#   ['a',
#    'person',
#    'is',
#    'walking',
#    'forward',
#    'four',
#    'steps',
#    'starting',
#    'with',
#    'the',
#    'right',
#    'foot',
#    'and',
#    'performing',
#    'a',
#    'right-turn',
#    'of',
#    '90',
#    '°']),
#  ('00039',
#   ['a', 'human', 'performs', 'a', 'tight', '90', '°', 'right', 'curve']),
#  ('00040',
#   ['a',
#    'person',
#    'walks',
#    '90',
#    '°',
#    'of',
#    'a',
#    'circle',
#    'to',
#    'his',
#    'right']),
#  ('00040',
#   ['a',
#    'person',
#    'walks',
#    'a',
#    'quarter',
#    'circle',
#    'to',
#    'the',
#    'right',
#    ',',
#    'taking',
#    'four',
#    'steps']),
#  ('00040', ['a', 'person', 'is', 'turning', 'right', 'while', 'walking']),
#  ('00041',
#   ['someone', 'walks', 'three', 'steps', 'in', 'curve', 'to', 'the', 'right']),
#  ('00041', ['a', 'person', 'walks', 'a', 'small', 'half', 'circle']),
#  ('00041',
#   ['somebody',
#    'walks',
#    'a',
#    'quarter',
#    'circle',
#    'in',
#    'clockwise',
#    'direction']),
#  ('00042', ['subject', 'walks', 'a', 'quarter', 'circle', 'clockwise']),
#  ('00042',
#   ['a',
#    'person',
#    'walks',
#    'in',
#    'a',
#    '90',
#    '°',
#    'curve',
#    'to',
#    'his',
#    'right']),
#  ('00042',
#   ['a',
#    'person',
#    'waits',
#    'on',
#    'a',
#    'atm',
#    'line',
#    'and',
#    'then',
#    'goes',
#    'to',
#    'the',
#    'machine']),
#  ('00042', ['a', 'human', 'sit']),
#  ('00043',
#   ['a',
#    'person',
#    'walks',
#    'clockwise',
#    'in',
#    'a',
#    'circle',
#    'with',
#    '4',
#    'steps']),
#  ('00043',
#   ['a',
#    'human',
#    'performs',
#    'a',
#    'tight',
#    '90',
#    '°',
#    'curve',
#    'to',
#    'the',
#    'right']),
#  ('00043', ['a', 'human', 'sit', 'down']),
#  ('00044', ['a', 'person', 'walks', 'a', 'quarter', 'rightwards', 'circle']),
#  ('00044', ['a', 'person', 'walks', 'in', 'a', 'quarter', 'circle']),
#  ('00045', ['human', 'walks', 'in', 'a', 'quater', 'circle', 'clockwise']),
#  ('00046',
#   ['a',
#    'person',
#    'walks',
#    'a',
#    'quarter',
#    'circle',
#    'clockwise',
#    'with',
#    '4',
#    'steps']),
#  ('00047', ['a', 'person', 'is', 'walking', 'a', 'left-turn']),
#  ('00047',
#   ['a', 'person', 'walking', 'forward', 'in', 'a', '90', '°', 'curve']),
#  ('00047',
#   ['a',
#    'person',
#    'walks',
#    'a',
#    'quarter',
#    'circle',
#    'to',
#    'the',
#    'right',
#    ',',
#    'taking',
#    'four',
#    'steps']),
#  ('00048', ['person', 'walking', 'backwards']),
#  ('00048', ['human', 'goes', 'backwards', 'starting', 'with', 'left']),
#  ('00049', ['subject', 'walks', 'backwards']),
#  ('00049',
#   ['a',
#    'person',
#    'takes',
#    '4',
#    'steps',
#    'backwards',
#    'starting',
#    'with',
#    'left']),
#  ('00049', ['a', 'person', 'walks', 'some', 'steps', 'backwards']),
#  ('00050', ['person', 'walking', 'backwards']),
#  ('00050', ['someone', 'walks', 'slowly', 'backwards']),
#  ('00050', ['a', 'person', 'makes', '4', 'steps', 'backwards']),
#  ('00051', ['a', 'person', 'walks', 'backwards']),
#  ('00052', ['the', 'person', 'is', 'walking', 'backwards']),
#  ('00052', ['a', 'person', 'walks', 'some', 'steps', 'backwards']),
#  ('00053', ['a', 'person', 'walking', 'backwards', 'for', '4', 'steps']),
#  ('00053', ['a', 'person', 'slowly', 'walking', 'backwards']),
#  ('00053',
#   ['someone',
#    'walks',
#    'straight',
#    'reverse',
#    'and',
#    'stop',
#    'in',
#    'four',
#    'steps']),
#  ('00054',
#   ['a',
#    'person',
#    'is',
#    'walking',
#    'backwards',
#    'in',
#    'a',
#    'straight',
#    'line']),
#  ('00054', ['human', 'goes', 'backwards', 'starting', 'with', 'left']),
#  ('00055', ['a', 'person', 'walks', 'backward', '4', 'steps']),
#  ('00055',
#   ['someone',
#    'walks',
#    'backwards',
#    '4',
#    'steps',
#    'starting',
#    'with',
#    'the',
#    'left',
#    'leg']),
#  ('00055', ['a', 'person', 'takes', 'some', 'steps', 'backwards']),
#  ('00056', ['a', 'human', 'walking', 'backwards']),
#  ('00056', ['the', 'human', 'is', 'walking', 'backwards']),
#  ('00057', ['a', 'person', 'walks', 'backwards']),
#  ('00057',
#   ['someone',
#    'is',
#    'walking',
#    'backwards',
#    '4',
#    'steps',
#    'starting',
#    'with',
#    'the',
#    'left',
#    'leg']),
#  ('00058', ['a', 'person', 'walks', 'in', 'circle']),
#  ('00059', ['human', 'goes', 'in', 'a', 'circle', 'counterclockwise']),
#  ('00059',
#   ['a', 'human', 'is', 'walking', 'in', 'a', 'circle', 'to', 'its', 'left']),
#  ('00060', ['a', 'human', 'walking', 'in', 'a', 'circle', 'counterclockwise']),
#  ('00061', ['someone', 'walks', 'in', 'a', 'counter-clockwise', 'circle']),
#  ('00061',
#   ['a',
#    'human',
#    'walks',
#    'in',
#    'a',
#    'circle',
#    'with',
#    'a',
#    'diameter',
#    'of',
#    '2m']),
#  ('00061',
#   ['someone', 'walk', 'in', 'a', 'full', 'counter-clockwise', 'circle']),
#  ('00061', ['a', 'person', 'walks', 'in', 'a', 'full', 'circle']),
#  ('00061', ['someone', 'makes', 'a', 'circle']),
#  ('00061', ['he', 'turns', 'around']),
#  ('00061', ['a', 'person', 'walks', 'a', 'circle']),
#  ('00061', ['someone', 'walks', 'one', 'round']),
#  ('00061', ['a', 'person', 'walks', 'a', 'full', 'anti-clockwise', 'circle']),
#  ('00061', ['a', 'person', 'walks', 'in', 'a', 'circle', 'counterclockwise']),
#  ('00061', ['a', 'person', 'walks', 'a', 'circle', 'to', 'the', 'left']),
#  ('00061', ['the', 'human', 'walks', 'a', 'circle']),
#  ('00061', ['a', 'human', 'walks', 'in', 'circle', 'counterclockwise']),
#  ('00062', ['a', 'person', 'walks', 'in', 'a', 'counter-clockwise', 'circle']),
#  ('00062',
#   ['a', 'person', 'walks', 'in', 'a', 'circle', 'to', 'the', 'left', 'side']),
#  ('00063', ['a', 'person', 'is', 'walking', 'in', 'small', 'circles']),
#  ('00063', ['a', 'person', 'walks', 'in', 'a', 'circle', 'to', 'the', 'left']),
#  ('00064', ['a', 'human', 'walking', 'in', 'a', 'circle', 'counterclockwise']),
#  ('00064', ['someone', 'is', 'walking', 'a', 'circle', 'to', 'the', 'left']),
#  ('00065', ['someone', 'walks', 'in', 'a', 'circle', 'to', 'the', 'left']),
#  ('00066',
#   ['a', 'person', 'walking', 'in', 'a', 'circle', 'to', 'the', 'left']),
#  ('00067', ['a', 'person', 'walks', 'in', 'a', 'counter-clockwise', 'circle']),
#  ('00067', ['a', 'human', 'walks', 'in', 'a', 'counter-clockwise', 'circle']),
#  ('00067', ['person', 'walking', 'in', 'a', 'circle']),
#  ('00067', ['someone', 'walks', 'around', 'slowly']),
#  ('00067', ['walking', 'in', 'a', 'small', 'circle']),
#  ('00067', ['the', 'person', 'walked', 'in', 'a', 'circle']),
#  ('00067', ['a', 'person', 'walks', 'a', 'circle']),
#  ('00067',
#   ['a', 'person', 'walks', 'in', 'a', 'circle', 'to', 'his', 'left', 'side']),
#  ('00067', ['human', 'goes', 'in', 'a', 'circle', 'counterclockwise']),
#  ('00067', ['someone', 'walks', 'a', 'anticlockwise']),
#  ('00068', ['someone', 'walks', 'a', 'right', 'circle']),
#  ('00069', ['a', 'person', 'is', 'walking', 'in', 'a', 'clockwise', 'circle']),
#  ('00070', ['a', 'person', 'walks', 'a', 'circle', 'clockwise']),
#  ('00070',
#   ['someone', 'walks', 'in', 'a', 'small', 'circle', 'to', 'the', 'right']),
#  ('00071', ['a', 'human', 'walking', 'in', 'a', 'circle', 'clockwise']),
#  ('00071',
#   ['a',
#    'person',
#    'walks',
#    'a',
#    'circle',
#    ',',
#    'radius',
#    'approximatly',
#    '1,5',
#    'm']),
#  ('00072', ['a', 'person', 'walks', 'in', 'a', 'circle']),
#  ('00073', ['a', 'person', 'walks', 'in', 'a', 'circle']),
#  ('00074', ['a', 'person', 'is', 'walking', 'in', 'a', 'small', 'circle']),
#  ('00075', ['subject', 'walks', 'in', 'a', 'circle', 'clockwise']),
#  ('00075',
#   ['a',
#    'person',
#    'walks',
#    'a',
#    'right',
#    'sided',
#    'circle',
#    ',',
#    'radius',
#    'approximatly',
#    '50cm']),
#  ('00076',
#   ['a', 'person', 'walking', 'in', 'a', 'circle', 'to', 'the', 'right']),
#  ('00077', ['a', 'person', 'walks', 'in', 'a', 'clockwise', 'circle']),
#  ('00077', ['a', 'person', 'walks', 'in', 'a', 'clockwise', 'circle']),
#  ('00077', ['a', 'person', 'walking', 'in', 'a', 'circle']),
#  ('00077', ['a', 'person', 'turns', 'to', 'his', 'right']),
#  ('00077', ['someone', 'is', 'walking', 'one', 'round', 'to', 'his', 'side']),
#  ('00077',
#   ['a',
#    'person',
#    'is',
#    'walking',
#    'to',
#    'the',
#    'left',
#    'by',
#    'making',
#    'a',
#    'circle',
#    'shape']),
#  ('00077', ['a', 'person', 'goes', 'around', 'in', 'a', 'circuit']),
#  ('00077',
#   ['a', 'person', 'walks', 'in', 'a', 'circle', 'to', 'the', 'right']),
#  ('00077', ['somebody', 'walks', 'a', 'circle', 'clockwise']),
#  ('00078',
#   ['subject', 'walks', 'in', 'a', 'quarter', 'circle', 'counterclockwise']),
#  ('00078',
#   ['a', 'person', 'walks', 'a', 'quarter', ',', 'left-sided', 'circle']),
#  ('00079',
#   ['the',
#    'person',
#    'is',
#    'walking',
#    'to',
#    'the',
#    'left',
#    'by',
#    'following',
#    'a',
#    'half',
#    'circle',
#    'path']),
#  ('00079', ['a', 'person', 'moves', 'to', 'the', 'left']),
#  ('00079', ['a', 'person', 'walks', 'to', 'the', 'left']),
#  ('00079', ['somebody', 'walks', 'a', 'quarter', 'circle', 'anticlockwise']),
#  ('00080', ['a', 'person', 'walks', 'in', 'a', 'quarter', 'circle']),
#  ('00080',
#   ['a',
#    'person',
#    'is',
#    'walking',
#    'a',
#    'quarter',
#    'circle',
#    'to',
#    'the',
#    'left']),
#  ('00080',
#   ['a',
#    'person',
#    'walks',
#    'in',
#    'a',
#    'quarter',
#    'of',
#    'a',
#    'small',
#    'circle']),
#  ('00081', ['a', 'person', 'walks', 'and', 'turns', 'to', 'the', 'left']),
#  ('00081', ['someone', 'walks', 'a', 'left', 'turn']),
#  ('00082',
#   ['subject', 'walks', 'in', 'a', 'quarter', 'circle', 'counterclockwise']),
#  ('00082',
#   ['a',
#    'person',
#    'walks',
#    'to',
#    'the',
#    'left',
#    'performing',
#    'a',
#    'quarter',
#    'circle']),
#  ('00083', ['a', 'human', 'makes', 'a', 'left', 'turn']),
#  ('00083', ['a', 'person', 'goes', 'left', 'around', 'a', 'corner']),
#  ('00084',
#   ['a',
#    'person',
#    'walking',
#    'slowly',
#    'in',
#    'a',
#    'quartercircle',
#    'to',
#    'the',
#    'left']),
#  ('00085',
#   ['a',
#    'human',
#    'walks',
#    'a',
#    'quarter',
#    'of',
#    'a',
#    'circle',
#    'to',
#    'the',
#    'left']),
#  ('00085', ['the', 'human', 'perfoms', 'a', 'left', 'turn']),
#  ('00086',
#   ['a',
#    'person',
#    'walks',
#    'a',
#    '90',
#    'degrees',
#    'curve',
#    'to',
#    'the',
#    'left']),
#  ('00086',
#   ['somebody',
#    'walks',
#    'a',
#    'quarter',
#    'circle',
#    'against',
#    'the',
#    'clockwise',
#    'direction']),
#  ('00087', ['a', 'person', 'walks', 'towards', 'the', 'left']),
#  ('00087',
#   ['human',
#    'goes',
#    'in',
#    'a',
#    'quater',
#    'circle',
#    'counterclockwise',
#    'starting',
#    'with',
#    'left']),
#  ('00087', ['a', 'person', 'walking', 'a', 'left', 'turn']),
#  ('00088', ['a', 'person', 'is', 'turning', 'right']),
#  ('00089',
#   ['a',
#    'human',
#    'walks',
#    'a',
#    'quarter',
#    'of',
#    'a',
#    'circle',
#    'to',
#    'the',
#    'right']),
#  ('00090', ['a', 'person', 'walks', 'and', 'turns', 'to', 'the', 'right']),
#  ('00091', ['a', 'person', 'walks', 'in', 'a', 'right', 'turn']),
#  ('00091', ['a', 'person', 'walks', 'a', 'quarter', 'circle', 'clockwise']),
#  ('00092',
#   ['the',
#    'person',
#    'is',
#    'making',
#    'a',
#    'wide',
#    'turn',
#    'to',
#    'the',
#    'right']),
#  ('00092',
#   ['a',
#    'person',
#    'walks',
#    'in',
#    'a',
#    'quarter',
#    'circle',
#    'to',
#    'the',
#    'right']),
#  ('00093', ['person', 'walking', 'to', 'the', 'right']),
#  ('00093',
#   ['human',
#    'goes',
#    'in',
#    'a',
#    'quarter',
#    'circle',
#    'clockwise',
#    'starting',
#    'with',
#    'right']),
#  ('00093',
#   ['someone',
#    'is',
#    'walking',
#    'a',
#    'quarter',
#    'circle',
#    'to',
#    'the',
#    'right']),
#  ('00094',
#   ['a',
#    'person',
#    'walking',
#    'in',
#    'a',
#    'quarter',
#    'circle',
#    'to',
#    'the',
#    'right']),
#  ('00094', ['the', 'human', 'perfoms', 'a', 'right', 'turn']),
#  ('00094', ['someone', 'slowly', 'turns', 'a', 'right', 'corner']),
#  ('00095', ['a', 'human', 'turning', 'right']),
#  ('00095', ['a', 'human', 'performs', 'a', '90', '°', 'right', 'curve']),
#  ('00095', ['a', 'person', 'walks', 'in', 'a', 'curve', 'to', 'the', 'right']),
#  ('00096', ['a', 'person', 'turns', 'right']),
#  ('00097', ['human', 'goes', 'in', 'quater', 'circle', 'clockwise']),
#  ('00097',
#   ['a', 'person', 'walks', 'a', 'quarter', 'circle', 'to', 'the', 'right']),
#  ('00097', ['a', 'person', 'turns', 'right']),
#  ('00097', ['a', 'person', 'walks', 'slowly', 'a', 'right', 'curve']),
#  ('00098', ['the', 'person', 'is', 'performing', 'a', 'forward', 'walk']),
#  ('00098', ['a', 'person', 'is', 'walking', 'relaxed']),
#  ('00098', ['a', 'person', 'is', 'walking', 'forward']),
#  ('00098', ['a', 'person', 'walks', 'slowly', 'forwards']),
#  ('00098', ['a', 'person', 'walks', 'forward']),
#  ('00098', ['a', 'person', 'walks', 'forwards']),
#  ('00099', ['a', 'person', 'walk', '5', 'steps', 'forward']),
#  ('00099', ['a', 'human', 'is', 'slowly', 'moving', 'forward']),
#  ('00099', ['a', 'person', 'takes', '4', 'steps', 'forward']),
#  ('00099', ['a', 'person', 'takes', '4', 'forward', 'steps']),
#  ('00100', ['a', 'person', 'walks', 'forward']),
#  ('00101', ['a', 'person', 'walks', '2', 'meters', 'forward']),
#  ('00101', ['a', 'person', 'is', 'walking']),
#  ('00102', ['the', 'subject', 'walks', 'forward']),
#  ('00102', ['person', 'walking', 'forwards']),
#  ('00102', ['someone', 'walks', 'away']),
#  ('00102', ['a', 'person', 'walks', 'forward']),
#  ('00102', ['a', 'person', 'just', 'walks']),
#  ('00102', ['a', 'person', 'walks', 'straight', 'forward', 'some', 'steps']),
#  ('00102',
#   ['a',
#    'person',
#    'walks',
#    '5',
#    'steps',
#    'beginning',
#    'with',
#    'the',
#    'left',
#    'foot']),
#  ('00103', ['someone', 'moves', 'forward', 'in', 'a', 'slow', 'walk']),
#  ('00103', ['a', 'person', 'walks', 'slowly', 'forwards']),
#  ('00104', ['a', 'person', 'walks', 'forward']),
#  ('00105', ['a', 'person', 'walks', 'forward']),
#  ('00105', ['human', 'goes', 'forward']),
#  ('00106',
#   ['a',
#    'human',
#    'looking',
#    'to',
#    'the',
#    'left',
#    'and',
#    'then',
#    'walking',
#    'forwards']),
#  ('00106', ['a', 'person', 'walks', 'forwards']),
#  ('00106', ['a', 'person', 'walks']),
#  ('00107', ['a', 'human', 'walking', 'forward']),
#  ('00108', ['a', 'person', 'walks', 'backwards']),
#  ('00108', ['a', 'person', 'walks', 'backwards']),
#  ('00108', ['a', 'person', 'walks', 'backwards', 'four', 'steps']),
#  ('00108', ['a', 'person', 'is', 'stepping', 'back']),
#  ('00108', ['slowly', 'backing', 'off']),
#  ('00108', ['someone', 'is', 'doing', 'a', 'few', 'steps', 'backwards']),
#  ('00108', ['person', 'walking', 'backwards']),
#  ('00108', ['a', 'person', 'walks', 'four', 'steps', 'backwards']),
#  ('00108', ['a', 'person', 'walks', '5', 'steps', 'backward']),
#  ('00108', ['a', 'person', 'moves', 'backward', 'some', 'meters']),
#  ('00108',
#   ['a',
#    'human',
#    'is',
#    'walking',
#    'backwards',
#    'tilting',
#    'its',
#    'head',
#    'a',
#    'little',
#    'bit',
#    'beforehand']),
#  ('00108', ['a', 'person', 'does', '4', 'steps', 'backwards']),
#  ('00108',
#   ['a',
#    'person',
#    'walking',
#    'backwards',
#    'while',
#    'moving',
#    'slightly',
#    'to',
#    'his',
#    'left']),
#  ('00108', ['a', 'person', 'backing', 'away', 'from', 'something']),
#  ('00108', ['human', 'goes', 'backwards']),
#  ('00108', ['a', 'man', 'walks', 'backwards']),
#  ('00109', ['a', 'person', 'walks', '4', 'steps', 'backwards']),
#  ('00110',
#   ['a',
#    'person',
#    'walks',
#    'backwards',
#    ',',
#    'arms',
#    'swinging',
#    'by',
#    'his',
#    'side']),
#  ('00110', ['human', 'goes', 'backwards', 'starting', 'with', 'left']),
#  ('00110', ['a', 'person', 'walks', 'backwards']),
#  ('00110', ['a', 'man', 'is', 'walking', 'backwards']),
#  ('00111', ['a', 'person', 'walks', 'backward', 'at', 'medium', 'speed']),
#  ('00111', ['a', 'person', 'walking', 'backwards']),
#  ('00112', ['someone', 'walks', 'backwards']),
#  ('00112', ['a', 'human', 'is', 'slowly', 'walking', 'backwards']),
#  ('00112', ['a', 'person', 'walks', 'backwards']),
#  ('00113', ['a', 'person', 'walks', 'four', 'steps', 'backward']),
#  ('00113', ['human', 'goes', 'backwards']),
#  ('00114', ['a', 'person', 'walking', 'backwards']),
#  ('00114', ['a', 'person', 'walking', 'backwards']),
#  ('00114', ['someone', 'walks', 'backwards']),
#  ('00114', ['a', 'person', 'walks', 'backwards']),
#  ('00114', ['human', 'slowly', 'goes', 'backwards']),
#  ('00116', ['a', 'persons', 'walks', 'backward', 'with', 'medium', 'speed']),
#  ('00116',
#   ['someone',
#    'is',
#    'walking',
#    'backwards',
#    'starting',
#    'with',
#    'the',
#    'left',
#    'leg']),
#  ('00116', ['a', 'person', 'walds', 'backwards', 'some', 'steps']),
#  ('00116', ['walking', 'backwards', 'for', 'a', 'few', 'steps']),
#  ('00116', ['a', 'person', 'walks', 'backwards']),
#  ('00116', ['a', 'person', 'walks', 'backwards', 'for', 'five', 'steps']),
#  ('00117', ['a', 'person', 'walks', 'backwards']),
#  ('00118', ['human', 'walks', 'in', 'a', 'circle', 'counterclockwise']),
#  ('00118',
#   ['someone', 'is', 'walking', 'in', 'a', 'circle', 'counterclockwise']),
#  ('00118', ['a', 'person', 'walks', 'in', 'a', 'circle', 'to', 'the', 'left']),
#  ('00119', ['a', 'person', 'walks', 'in', 'a', 'circle', 'to', 'the', 'left']),
#  ('00119', ['somebody', 'walks', 'a', '7/8', 'circle', 'anticlockwise']),
#  ('00120',
#   ['a', 'person', 'walks', 'counterclockwise', 'in', 'a', 'small', 'circle']),
#  ('00121',
#   ['a',
#    'person',
#    'walks',
#    'counter-clockwise',
#    'in',
#    'an',
#    'incomplete',
#    'circle',
#    'and',
#    'stops',
#    'facing',
#    'to',
#    'the',
#    'right',
#    'relative',
#    'to',
#    'the',
#    'starting',
#    'position']),
#  ('00121', ['the', 'human', 'walks', 'a', 'circle']),
#  ('00122',
#   ['a', 'person', 'walks', 'counterclockwise', 'in', 'a', 'small', 'circle']),
#  ('00122',
#   ['a', 'person', 'walks', 'counte', 'clockwise', 'in', 'a', 'circle']),
#  ('00122', ['a', 'person', 'walks', 'in', 'a', 'circle']),
#  ('00123', ['a', 'person', 'walks', 'in', 'a', 'circle', 'counter-clockwise']),
#  ('00124', ['a', 'human', 'walks', 'in', 'a', 'full', 'circle']),
#  ('00124',
#   ['a', 'persons', 'walks', 'in', 'a', 'circle', 'to', 'the', 'left']),
#  ('00125', ['a', 'person', 'walks', 'in', 'a', 'circle', 'counterclockwise']),
#  ('00125', ['the', 'human', 'walks', 'a', 'circle']),
#  ('00126', ['a', 'human', 'walking', 'in', 'a', 'circle', 'counterclockwise']),
#  ('00126', ['a', 'person', 'walks', 'in', 'a', 'circle', 'to', 'the', 'left']),
#  ('00127', ['a', 'person', 'moves', 'in', 'a', 'circle', 'counterclockwise']),
#  ('00128', ['a', 'human', 'walking', 'in', 'a', 'circle', 'clockwise']),
#  ('00129', ['a', 'person', 'walks', 'in', 'a', 'clockwise', 'circle']),
#  ('00129',
#   ['a',
#    'human',
#    'performs',
#    'a',
#    'full',
#    '360',
#    '°',
#    'curve',
#    'to',
#    'the',
#    'right',
#    ',',
#    'ending',
#    'where',
#    'it',
#    'started']),
#  ('00130',
#   ['a',
#    'person',
#    'walks',
#    'in',
#    'a',
#    'small',
#    'circle',
#    ',',
#    'to',
#    'the',
#    'right']),
#  ('00130',
#   ['human',
#    'goes',
#    'in',
#    'a',
#    'circle',
#    'clockwise',
#    'starting',
#    'with',
#    'right']),
#  ('00130',
#   ['a', 'person', 'walks', 'in', 'a', 'circle', 'to', 'the', 'right']),
#  ('00130', ['person', 'walking', 'in', 'a', 'circle']),
#  ('00131', ['a', 'person', 'walks', 'a', 'full', 'circle']),
#  ('00131', ['a', 'person', 'walks', 'a', 'circle', 'to', 'the', 'right']),
#  ('00132', ['person', 'walking', 'in', 'a', 'circle']),
#  ('00132', ['someone', 'walks', 'in', 'a', 'clockwise', 'circle']),
#  ('00133', ['a', 'human', 'walking', 'in', 'a', 'circle', 'clockwise']),
#  ('00133', ['a', 'person', 'walks', 'a', 'circle', 'to', 'the', 'right']),
#  ('00134', ['a', 'person', 'walks', 'a', 'circle', 'clockwise']),
#  ('00134', ['a', 'person', 'walks', 'a', 'circle', 'to', 'the', 'right']),
#  ('00135', ['a', 'person', 'walks', 'clockwise', 'in', 'a', 'circle']),
#  ('00136', ['a', 'human', 'walking', 'in', 'a', 'circle', 'clockwise']),
#  ('00136', ['a', 'person', 'is', 'walking', 'in', 'a', 'circle', 'clockwise']),
#  ('00136', ['a', 'human', 'goes', 'around', 'the', 'circle', 'clockwise']),
#  ('00136', ['someone', 'walks', 'a', 'larger', 'clockwise']),
#  ('00136',
#   ['a', 'person', 'walks', 'in', 'a', 'circle', 'to', 'the', 'right']),
#  ('00137',
#   ['a', 'person', 'walks', 'clockwise', 'in', 'a', 'small', 'circle']),
#  ('00138', ['the', 'human', 'walks', 'a', 'left', 'bend']),
#  ('00139', ['a', 'human', 'walks', 'and', 'turns', 'to', 'the', 'left']),
#  ('00139', ['a', 'person', 'is', 'walking', 'in', 'a', 'curve', 'to', 'left']),
#  ('00139', ['a', 'person', 'turns', 'left']),
#  ('00140', ['a', 'human', 'is', 'making', 'a', 'counter-clockwise', 'turn']),
#  ('00140',
#   ['a',
#    'person',
#    'is',
#    'walking',
#    'a',
#    'quarter',
#    'counter-clockwise',
#    'circle']),
#  ('00140',
#   ['a',
#    'person',
#    'walks',
#    'to',
#    'the',
#    'left',
#    'performin',
#    'a',
#    'quater',
#    'circle']),
#  ('00140', ['a', 'person', 'turns', 'left']),
#  ('00141',
#   ['a',
#    'person',
#    'starts',
#    'walking',
#    'in',
#    'a',
#    'circular',
#    'motion',
#    'towards',
#    'the',
#    'left']),
#  ('00141',
#   ['a', 'person', 'walks', 'a', '90', 'degree', 'curve', 'to', 'the', 'left']),
#  ('00141', ['a', 'person', 'walks', 'in', 'a', 'quarter', 'circle']),
#  ('00142', ['a', 'person', 'walks', 'around', 'a', 'corner']),
#  ('00142',
#   ['a',
#    'person',
#    'walks',
#    'and',
#    'turns',
#    '90',
#    'degrees',
#    'to',
#    'the',
#    'left']),
#  ('00142',
#   ['a', 'person', 'walks', 'a', 'quarter', 'circle', 'to', 'the', 'left']),
#  ('00143',
#   ['a',
#    'person',
#    'turns',
#    '90',
#    '°',
#    'to',
#    'the',
#    'left',
#    'at',
#    'medium',
#    'speed']),
#  ('00144',
#   ['a',
#    'person',
#    'walks',
#    'a',
#    'quarter',
#    'of',
#    'a',
#    'small',
#    'circle',
#    'counterclockwise']),
#  ('00144',
#   ['subject', 'walks', 'in', 'a', 'quarter', 'circle', 'counterclockwise']),
#  ('00144', ['some', 'walks', 'a', 'quarter', 'circle', 'to', 'the', 'left']),
#  ('00145', ['a', 'person', 'walks', 'and', 'turns', 'to', 'the', 'left']),
#  ('00145', ['a', 'person', 'walks', 'in', 'a', 'quarter-circle']),
#  ('00145', ['a', 'human', 'performing', 'a', 'u-turn']),
#  ('00145',
#   ['a',
#    'person',
#    'is',
#    'walking',
#    'two',
#    'meters',
#    'straight',
#    ',',
#    'than',
#    'one',
#    'step',
#    'to',
#    'the',
#    'left']),
#  ('00145',
#   ['a', 'person', 'walks', 'along', 'and', 'turns', 'to', 'the', 'left']),
#  ('00145', ['a', 'person', 'walks', 'a', 'curve', 'to', 'the', 'left']),
#  ('00145',
#   ['someone',
#    'is',
#    'walking',
#    'a',
#    'quarter',
#    'round',
#    'to',
#    'his',
#    'left',
#    'side']),
#  ('00145',
#   ['a',
#    'person',
#    'walks',
#    'a',
#    '90',
#    'degree',
#    'turn',
#    'towards',
#    'the',
#    'left']),
#  ('00145',
#   ['a',
#    'person',
#    'first',
#    'walks',
#    'and',
#    'then',
#    'turns',
#    'to',
#    'the',
#    'left']),
#  ('00145', ['a', 'person', 'walks', 'to', 'the', 'left']),
#  ('00145',
#   ['a', 'human', 'is', 'walking', 'in', 'a', '90', '°', 'right', 'curve']),
#  ('00145',
#   ['someone', 'walks', 'in', 'a', 'quarter', 'circle', 'to', 'the', 'left']),
#  ('00146', ['a', 'human', 'turning', 'left']),
#  ('00146',
#   ['a', 'person', 'walks', 'a', 'left', 'turn', 'of', '90', 'degrees']),
#  ('00147',
#   ['a',
#    'person',
#    'walks',
#    'forwards',
#    ',',
#    'slowly',
#    'turning',
#    'to',
#    'the',
#    'left',
#    'and',
#    'stops']),
#  ('00147', ['someone', 'walks', 'a', 'left', 'turn']),
#  ('00147', ['a', 'person', 'turns', 'left']),
#  ('00148',
#   ['a',
#    'person',
#    'walks',
#    'in',
#    'a',
#    'quarter',
#    'circle',
#    'clockwise',
#    'with',
#    '4',
#    'steps']),
#  ('00148',
#   ['a', 'person', 'walks', 'a', 'quarter', ',', 'right', 'sided', 'circle']),
#  ('00149',
#   ['a',
#    'person',
#    'walks',
#    'a',
#    'quarter',
#    'circle',
#    'clockwise',
#    'with',
#    '4',
#    'steps']),
#  ('00149',
#   ['human',
#    'performs',
#    'a',
#    'bending',
#    'walking',
#    'movement',
#    'to',
#    'the',
#    'right']),
#  ('00150',
#   ['a',
#    'person',
#    'walks',
#    'forward',
#    'while',
#    'gradually',
#    'turning',
#    'to',
#    'the',
#    'right']),
#  ('00151', ['a', 'person', 'is', 'turning', 'right']),
#  ('00151',
#   ['a',
#    'human',
#    'is',
#    'walking',
#    'in',
#    'a',
#    'quarter',
#    'of',
#    'a',
#    'circle',
#    'to',
#    'the',
#    'right']),
#  ('00151',
#   ['a', 'human', 'is', 'performing', 'a', '90', '°', 'right', 'curve']),
#  ('00152', ['person', 'walking', 'to', 'the', 'right']),
#  ('00152', ['a', 'person', 'walks', 'and', 'turns', 'right']),
#  ('00152', ['a', 'person', 'walks', 'to', 'the', 'right']),
#  ('00153', ['a', 'person', 'goes', 'to', 'the', 'right', 'slowly']),
#  ('00153', ['a', 'person', 'walks', 'a', 'right', 'curve']),
#  ('00154', ['a', 'person', 'turns', 'right', 'at', 'medium', 'speed']),
#  ('00154',
#   ['a',
#    'person',
#    'walks',
#    'to',
#    'the',
#    'right',
#    'in',
#    'a',
#    'quter',
#    'circle']),
#  ('00155', ['a', 'person', 'turns', 'right']),
#  ('00155',
#   ['a',
#    'person',
#    'slowly',
#    'walks',
#    'a',
#    '90',
#    '°',
#    'turn',
#    'in',
#    'four',
#    'steps']),
#  ('00156',
#   ['the',
#    'person',
#    'is',
#    'first',
#    'walking',
#    'ahead',
#    'and',
#    'then',
#    'turning',
#    'to',
#    'the',
#    'right']),
#  ('00157', ['a', 'person', 'turns', 'right']),
#  ('00158', ['person', 'walking', 'forwards']),
#  ('00158', ['someone', 'walks', 'slowly']),
#  ('00158', ['a', 'person', 'walks', 'forward']),
#  ('00158', ['a', 'human', 'takes', 'slow', 'steps', 'forward']),
#  ('00158', ['a', 'person', 'walks', 'forward']),
#  ('00159', ['a', 'person', 'is', 'walking', 'slowly', 'and', 'stops']),
#  ('00159', ['a', 'person', 'walks', 'forward']),
#  ('00160', ['a', 'person', 'walks', 'forward']),
#  ('00160', ['someone', 'walks', 'forward']),
#  ('00161', ['a', 'person', 'goes', 'slowly', '5', 'steps', 'forward']),
#  ('00161', ['a', 'person', 'walks', 'slowly', 'forward']),
#  ('00161', ['a', 'person', 'slowly', 'walks', '4', 'steps', 'forwards']),
#  ('00162', ['a', 'person', 'walks', '4', 'steps', 'forward']),
#  ('00162', ['a', 'person', 'walks', '4', 'steps']),
#  ('00163', ['a', 'person', 'walks', 'forward']),
#  ('00163', ['a', 'person', 'walks', 'a', 'few', 'steps', 'forwards']),
#  ('00164', ['a', 'person', 'walks', 'forward']),
#  ('00164', ['a', 'person', 'walks', '4', 'steps', 'forward']),
#  ('00165', ['someone', 'walks', 'forward']),
#  ('00165', ['a', 'person', 'takes', '5', 'steps', 'forward']),
#  ('00165', ['a', 'person', 'walks', 'forwards', 'quite', 'slow']),
#  ('00166', ['a', 'human', 'walking', 'slowly']),
#  ('00167', ['the', 'person', 'is', 'walking', 'forward']),
#  ('00167', ['the', 'human', 'perfoms', 'a', 'couple', 'of', 'steps']),
#  ('00167', ['a', 'person', 'walks', 'forward']),
#  ('00168', ['a', 'human', 'goes', 'slowly', '5', 'steps', 'backward']),
#  ('00168',
#   ['a',
#    'person',
#    'takes',
#    '5',
#    'steps',
#    'backwards',
#    'staring',
#    'with',
#    'the',
#    'left',
#    'foot']),
#  ('00168', ['a', 'person', 'walks', 'backwards']),
#  ('00168', ['a', 'person', 'walks', 'five', 'steps', 'backwards']),
#  ('00169',
#   ['a',
#    'person',
#    'walking',
#    'backwards',
#    '4',
#    'steps',
#    'with',
#    'relatively',
#    'small',
#    'steps']),
#  ('00169',
#   ['a',
#    'person',
#    'takes',
#    '4',
#    'steps',
#    'backwards',
#    'starting',
#    'with',
#    'the',
#    'left',
#    'foot']),
#  ('00169', ['a', 'person', 'takes', 'five', 'backward', 'steps']),
#  ('00170', ['the', 'person', 'is', 'walking', 'backwards']),
#  ('00170', ['a', 'person', 'walkes', 'backward']),
#  ('00171', ['a', 'person', 'walks', 'slowly', 'five', 'steps', 'backwards']),
#  ('00171', ['a', 'person', 'is', 'walking', 'backwards']),
#  ('00171', ['someone', 'walks', 'backwards']),
#  ('00172', ['a', 'person', 'goes', 'back', '4', 'steps']),
#  ('00173', ['a', 'human', 'walking', 'backwards']),
#  ('00173', ['a', 'person', 'steps', 'backwards']),
#  ('00173', ['a', 'person', 'takes', 'some', 'steps', 'backwards']),
#  ('00174', ['a', 'person', 'takes', 'four', 'steps', 'back']),
#  ('00174', ['a', 'person', 'walks', 'back', 'some', 'meters']),
#  ('00175',
#   ['a',
#    'person',
#    'walks',
#    '4',
#    'steps',
#    'to',
#    'the',
#    'backward',
#    'direction']),
#  ('00175', ['a', 'person', 'makes', '4', 'steps', 'backwards']),
#  ('00175', ['a', 'person', 'walks', 'backwards']),
#  ('00175', ['a', 'person', 'slowly', 'retreats']),
#  ('00175', ['someone', 'walks', 'backwards']),
#  ('00176', ['a', 'person', 'walks', 'a', 'few', 'steps', 'backwards']),
#  ('00176', ['a', 'person', 'walks', 'backwards', 'about', '4', 'steps']),
#  ('00177', ['a', 'person', 'walks', 'backwards']),
#  ('00177', ['someone', 'walks', 'backward']),
#  ('00177', ['a', 'person', 'walks', 'backwards']),
#  ('00177', ['a', 'person', 'slowly', 'walks', 'backward']),
#  ('00177', ['a', 'person', 'walks', '5', 'steps', 'backwards']),
#  ('00177', ['a', 'person', 'taking', 'a', 'few', 'steps', 'backwards']),
#  ('00178', ['a', 'human', 'walking', 'in', 'circles']),
#  ('00178', ['a', 'person', 'walks', 'in', 'a', 'counter-clockwise', 'circle']),
#  ('00178', ['some', 'walks', 'anticlockwise']),
#  ('00178', ['a', 'person', 'walks', 'in', 'a', 'circle', 'to', 'the', 'left']),
#  ('00179',
#   ['a', 'person', 'walks', 'around', 'in', 'a', 'circle', 'anti-clockwise']),
#  ('00179', ['someone', 'walks', 'in', 'a', 'circle', 'counterclockwise']),
#  ('00179',
#   ['a',
#    'person',
#    'walks',
#    'in',
#    'a',
#    'circle',
#    'to',
#    'the',
#    'left',
#    'taking',
#    '8',
#    'steps']),
#  ('00180', ['a', 'person', 'walks', 'in', 'a', 'circle', 'to', 'the', 'left']),
#  ('00180',
#   ['a', 'person', 'is', 'walking', 'in', 'a', 'circle', 'counter-clockwise']),
#  ('00180', ['a', 'human', 'is', 'walking', 'in', 'circle']),
#  ('00181',
#   ['a', 'person', 'walks', 'in', 'a', 'small', 'circle', 'counterclockwise']),
#  ('00181',
#   ['a',
#    'human',
#    'walks',
#    'in',
#    'circles',
#    'counterclockwise',
#    'making',
#    'long',
#    'steps']),
#  ('00182', ['a', 'person', 'walks', 'clockwise', 'in', 'a', 'circle']),
#  ('00183', ['a', 'person', 'walks', 'in', 'circles']),
#  ('00183',
#   ['a',
#    'person',
#    'walks',
#    'forward',
#    'counterclockwise',
#    'in',
#    'a',
#    'circle']),
#  ('00183', ['a', 'person', 'walks', 'in', 'a', 'circle', 'to', 'the', 'left']),
#  ('00184',
#   ['a',
#    'person',
#    'walks',
#    'slowly',
#    'in',
#    'a',
#    'counterclockwise',
#    'small',
#    'circle']),
#  ('00185', ['a', 'human', 'walks', 'in', 'a', 'counter-clockwise', 'circle']),
#  ('00186', ['a', 'person', 'walks', 'a', 'circle']),
#  ('00186', ['subject', 'walks', 'in', 'a', 'circle', 'counterclockwise']),
#  ('00187',
#   ['a', 'person', 'walking', 'in', 'a', 'circle', 'to', 'the', 'left']),
#  ('00188', ['a', 'person', 'walks', 'in', 'a', 'clockwise', 'circle']),
#  ('00189', ['a', 'human', 'is', 'walking', 'clockwise', 'in', 'a', 'circle']),
#  ('00189', ['a', 'person', 'walks', 'a', 'circle', 'to', 'the', 'right']),
#  ('00190', ['a', 'person', 'walks', 'a', 'circle']),
#  ('00191', ['someone', 'walks', 'a', 'clockwise', 'circle']),
#  ('00191', ['a', 'person', 'is', 'walking', 'a', 'clockwise', 'circle']),
#  ('00191', ['a', 'person', 'walks', 'in', 'a', 'circle']),
#  ('00191',
#   ['a', 'human', 'is', 'walking', 'in', 'circle', 'to', 'the', 'right']),
#  ('00192', ['the', 'person', 'is', 'walking', 'in', 'a', 'circular', 'shape']),
#  ('00192', ['person', 'walks', 'a', 'circle']),
#  ('00193', ['a', 'person', 'walks', 'in', 'a', 'circle', 'clockwise']),
#  ('00194', ['someone', 'is', 'walking', 'a', 'small', 'clockwise', 'circle']),
#  ('00194',
#   ['a', 'person', 'walks', 'in', 'circle', 'to', 'his', 'right', 'side']),
#  ('00194',
#   ['a', 'person', 'walks', 'in', 'a', 'circle', 'to', 'the', 'right']),
#  ('00195', ['a', 'person', 'walks', 'a', 'circle', 'clockwise']),
#  ('00196', ['someone', 'walks', 'in', 'a', 'clockwise', 'circle']),
#  ('00196',
#   ['human',
#    'goes',
#    'in',
#    'a',
#    'circle',
#    'clockwise',
#    'starting',
#    'with',
#    'right']),
#  ('00197',
#   ['a', 'person', 'walking', 'in', 'a', 'circle', 'to', 'the', 'right']),
#  ('00197',
#   ['a', 'person', 'walks', 'in', 'a', 'cirlce', 'to', 'the', 'right']),
#  ('00198', ['a', 'person', 'goes', 'to', 'the', 'right']),
#  ('00199', ['the', 'human', 'walks', 'a', 'right', 'bend']),
#  ('00199',
#   ['somone', 'walks', 'in', 'a', 'quarter', 'circle', 'to', 'the', 'right']),
#  ('00200', ['someone', 'walks', 'in', 'a', 'slight', 'right', 'curve']),
#  ('00201', ['person', 'walking', 'to', 'the', 'right']),
#  ('00201',
#   ['human',
#    'goes',
#    'in',
#    'a',
#    'quarter',
#    'circle',
#    'clockwise',
#    'starting',
#    'with',
#    'right']),
#  ('00202',
#   ['a',
#    'person',
#    'is',
#    'walking',
#    'forward',
#    'starting',
#    'with',
#    'the',
#    'right',
#    'feet',
#    'and',
#    'performing',
#    'five',
#    'steps',
#    'while',
#    'turning',
#    'to',
#    'the',
#    'right',
#    'with',
#    'an',
#    'angle',
#    'of',
#    '90',
#    '°']),
#  ('00202',
#   ['a',
#    'person',
#    'walks',
#    'in',
#    'a',
#    'quarter',
#    'circle',
#    'to',
#    'the',
#    'right']),
#  ('00203',
#   ['a', 'person', 'walks', 'a', 'quarter', 'circle', 'to', 'the', 'right']),
#  ('00204',
#   ['a',
#    'person',
#    'turns',
#    '90',
#    '°',
#    'to',
#    'the',
#    'right',
#    'at',
#    'medium',
#    'speed']),
#  ('00204', ['a', 'person', 'is', 'turning', 'right', 'while', 'walking']),
#  ('00205', ['a', 'person', 'walks', 'to', 'the', 'right']),
#  ('00206', ['a', 'human', 'is', 'making', 'a', 'clockwise', 'turn']),
#  ('00206',
#   ['a',
#    'person',
#    'is',
#    'walking',
#    'a',
#    'quarter',
#    'circle',
#    'in',
#    'clockwise',
#    'direction']),
#  ('00207', ['a', 'person', 'turns', 'right']),
#  ('00207',
#   ['a',
#    'person',
#    'walks',
#    'a',
#    'quarter',
#    'circle',
#    'clockwise',
#    'with',
#    '4',
#    'steps']),
#  ('00207',
#   ['a', 'person', 'walks', 'a', '90', '°', 'curve', 'to', 'his', 'right']),
#  ('00207', ['someone', 'turns', 'right']),
#  ('00208', ['a', 'person', 'walks', 'forward', 'very', 'slowly']),
#  ('00208', ['subject', 'walks', 'forward', 'slowly']),
#  ('00208', ['a', 'person', 'walks', 'forward', 'quite', 'slow']),
#  ('00209', ['a', 'person', 'walks', 'slowly', 'and', 'stops']),
#  ('00209',
#   ['a', 'person', 'walks', 'straight', 'forwards', 'for', 'some', 'meters']),
#  ('00210', ['a', 'person', 'walks', '4', 'steps', 'forward']),
#  ('00211', ['subject', 'walks', 'forward']),
#  ('00211',
#   ['a',
#    'person',
#    'starts',
#    'walking',
#    '4',
#    'steps',
#    'forward',
#    'and',
#    'then',
#    'stops']),
#  ('00212', ['a', 'person', 'walking', 'a', 'few', 'steps']),
#  ('00213',
#   ['a',
#    'human',
#    'walks',
#    'at',
#    'a',
#    'slight',
#    'left',
#    'angle',
#    'for',
#    'five',
#    'steps',
#    'and',
#    'then',
#    'stops']),
#  ('00213', ['someone', 'walks', 'forward']),
#  ('00214', ['a', 'person', 'walks', '4', 'steps', 'forward']),
#  ('00215', ['a', 'person', 'walks', 'forwards']),
#  ('00216', ['a', 'person', 'walking', 'a', 'few', 'steps', 'forward']),
#  ('00217', ['a', 'person', 'walking', 'forwards', 'for', 'a', 'few', 'steps']),
#  ('00217', ['a', 'person', 'walks', 'forwards']),
#  ('00218', ['person', 'walking', 'backwards']),
#  ('00218', ['human', 'goes', 'backwards', 'starting', 'with', 'left']),
#  ('00218', ['a', 'person', 'is', 'walking', 'backwards']),
#  ('00218', ['a', 'person', 'walks', 'backwards']),
#  ('00219', ['someone', 'walks', 'slowly', 'backwards']),
#  ('00219', ['a', 'person', 'walks', 'backwards']),
#  ('00219', ['a', 'person', 'slowly', 'walks', 'back', 'taking', '4', 'steps']),
#  ('00222', ['a', 'person', 'moves', 'backwards']),
#  ('00223', ['a', 'person', 'walks', 'backwards']),
#  ('00223', ['a', 'person', 'walks', 'backwards']),
#  ('00224', ['someone', 'walks', 'backwards', 'four', 'steps']),
#  ('00224', ['a', 'person', 'walks', 'backward']),
#  ('00225', ['a', 'person', 'walks', 'backwards']),
#  ('00225', ['human', 'goes', 'backwards']),
#  ('00225', ['a', 'person', 'walks', 'a', 'few', 'steps', 'backward']),
#  ('00225', ['somebody', 'walks', 'backwards']),
#  ('00226', ['a', 'person', 'walks', 'backwards']),
#  ('00227',
#   ['subject', 'walks', 'in', 'a', 'full', 'circle', 'counterclockwise']),
#  ('00227', ['the', 'human', 'walks', 'a', 'circle']),
#  ('00228', ['person', 'walking', 'in', 'a', 'circle']),
#  ('00228', ['a', 'person', 'walks', 'in', 'a', 'counter-clockwise', 'circle']),
#  ('00228', ['a', 'person', 'walks', 'in', 'a', 'circle', 'to', 'the', 'left']),
#  ('00228',
#   ['a',
#    'person',
#    'moves',
#    'anti-clockwise',
#    'in',
#    'a',
#    'cirle',
#    'and',
#    'needs',
#    '8',
#    'steps',
#    'to',
#    'complete',
#    'the',
#    'circle']),
#  ('00228', ['a', 'person', 'walks', 'in', 'a', 'small', 'circle']),
#  ('00229',
#   ['a',
#    'person',
#    'walks',
#    'in',
#    'a',
#    'narrow',
#    'counter-clockwise',
#    'circle']),
#  ('00229', ['subject', 'in', 'small', 'circle', 'counterclockwise']),
#  ('00229',
#   ['someone',
#    'slowly',
#    'walks',
#    'in',
#    'a',
#    'small',
#    'circle',
#    'to',
#    'the',
#    'left']),
#  ('00229', ['someone', 'walks', 'a', 'circle']),
#  ('00229',
#   ['a', 'human', 'walks', 'slowly', 'in', 'circles', ',', 'counterclockwise']),
#  ('00229', ['a', 'human', 'goes', 'a', 'circle', 'left', 'around']),
#  ('00230',
#   ['subject', 'walks', 'in', 'a', 'quarter', 'circle', 'counterclockwise']),
#  ('00230', ['a', 'person', 'is', 'walking', 'in', 'a', 'circle']),
#  ('00231', ['a', 'person', 'walks', 'counter-clockwise', 'in', 'a', 'circle']),
#  ('00231', ['a', 'person', 'walks', 'in', 'a', 'circle']),
#  ('00231', ['somebody', 'walks', 'a', 'circle', 'anticlockwise']),
#  ('00232', ['walk', 'in', 'a', 'circle']),
#  ('00232',
#   ['a', 'person', 'walks', 'a', 'circle', 'in', 'the', 'left', 'direction']),
#  ('00232', ['a', 'person', 'walks', 'in', 'a', 'circle']),
#  ('00233',
#   ['the', 'person', 'make', 'a', 'walk', 'along', 'a', 'circular', 'path']),
#  ('00233',
#   ['someone', 'is', 'walking', 'in', 'a', 'circle', 'counterclockwise']),
#  ('00233', ['a', 'person', 'walks', 'a', 'circle', 'to', 'the', 'left']),
#  ('00233', ['a', 'person', 'is', 'walking', 'in', 'a', 'circle']),
#  ('00234', ['a', 'person', 'moves', 'in', 'a', 'circle']),
#  ('00235', ['a', 'person', 'moves', 'in', 'a', 'circle', 'clockwise']),
#  ('00235',
#   ['a', 'human', 'walks', 'a', 'small', 'circle', 'to', 'its', 'left']),
#  ('00236',
#   ['a',
#    'person',
#    'walks',
#    'in',
#    'a',
#    'small',
#    'circle',
#    'counter',
#    'clockwise']),
#  ('00237', ['a', 'human', 'walking', 'in', 'a', 'circle', 'clockwise']),
#  ('00237',
#   ['a', 'person', 'walks', 'a', 'full', 'circle', 'to', 'the', 'right']),
#  ('00238', ['subject', 'walks', 'in', 'a', 'circle', 'clockwise']),
#  ('00239',
#   ['a',
#    'person',
#    'walking',
#    'slowly',
#    'in',
#    'a',
#    'circle',
#    'to',
#    'the',
#    'right']),
#  ('00239',
#   ['a', 'person', 'walks', 'forward', 'in', 'a', 'circle', 'clockwise']),
#  ('00239',
#   ['a', 'person', 'walks', 'in', 'a', 'circle', 'to', 'the', 'right']),
#  ('00240', ['a', 'person', 'walks', 'in', 'circles']),
#  ('00240', ['a', 'person', 'is', 'walking', 'in', 'a', 'clockwise', 'circle']),
#  ('00241', ['a', 'person', 'walks', 'in', 'a', 'circle']),
#  ('00241', ['someone', 'goes', 'around', 'in', 'a', 'circuit']),
#  ('00241',
#   ['a', 'person', 'walks', 'in', 'a', 'circle', 'to', 'the', 'right']),
#  ('00241',
#   ['a', 'human', 'is', 'performing', 'a', 'right', '360', '°', 'curve']),
#  ('00242', ['a', 'person', 'walks', 'in', 'a', 'circle']),
#  ('00243', ['subject', 'walks', 'in', 'a', 'circle', 'clockwise']),
#  ('00243',
#   ['a', 'person', 'walks', 'clockwise', 'forward', 'in', 'a', 'circle']),
#  ('00244',
#   ['a',
#    'person',
#    'walks',
#    'slowly',
#    'in',
#    'a',
#    'circle',
#    'in',
#    'clockwise',
#    'direction']),
#  ('00244',
#   ['a',
#    'human',
#    'walks',
#    'slowly',
#    'a',
#    'full',
#    'circle',
#    'to',
#    'its',
#    'right',
#    'and',
#    'ends',
#    'up',
#    'on',
#    'the',
#    'spot',
#    'where',
#    'it',
#    'started']),
#  ('00245', ['a', 'person', 'walks', 'in', 'a', 'clockwise', 'circle']),
#  ('00245', ['a', 'person', 'walks', 'in', 'a', 'little', 'circle']),
#  ('00245',
#   ['a', 'person', 'walks', 'forward', 'in', 'a', 'circle', 'clockwise']),
#  ('00246', ['a', 'person', 'performs', 'a', 'circular', 'movement']),
#  ('00246', ['walking', 'in', 'a', 'circle', 'to', 'the', 'right']),
#  ('00247', ['someone', 'walks', 'a', 'quarter-circle', 'to', 'the', 'right']),
#  ('00247',
#   ['a',
#    'person',
#    'slowly',
#    'walks',
#    'a',
#    'quarter',
#    'ride',
#    'sided',
#    'circle']),
#  ('00248', ['a', 'human', 'walks', 'and', 'turns', 'to', 'the', 'right']),
#  ('00248', ['someone', 'walks', 'a', 'right', 'turn']),
#  ('00248', ['a', 'person', 'walks', 'to', 'the', 'right']),
#  ('00249', ['a', 'human', 'is', 'making', 'a', 'clockwise', 'turn']),
#  ('00249', ['a', 'person', 'walks', 'to', 'the', 'right']),
#  ('00250', ['a', 'person', 'turns', 'left', 'at', 'medium', 'speed']),
#  ('00251',
#   ['a', 'human', 'walks', 'a', '90', 'degree', 'arc', 'to', 'the', 'right']),
#  ('00251', ['someone', 'walks', 'a', 'circle', 'clockwise']),
#  ('00251', ['a', 'person', 'walks', 'a', 'circle']),
#  ('00252',
#   ['a',
#    'person',
#    'starts',
#    'a',
#    'circular',
#    'movement',
#    'towards',
#    'the',
#    'right']),
#  ('00252', ['someone', 'walks', 'a', 'right', 'turn']),
#  ('00253',
#   ['a',
#    'person',
#    'turns',
#    'around',
#    'a',
#    'corner',
#    'towards',
#    'the',
#    'right']),
#  ('00253',
#   ['a',
#    'person',
#    'walks',
#    'a',
#    '90',
#    'degree',
#    'curve',
#    'to',
#    'the',
#    'right']),
#  ('00254', ['a', 'person', 'walks', 'a', 'left', 'turn']),
#  ('00254', ['a', 'person', 'turns', 'to', 'his', 'right']),
#  ('00254',
#   ['human',
#    'performs',
#    'a',
#    'bending',
#    'walking',
#    'motion',
#    'to',
#    'its',
#    'right',
#    'hand',
#    'side']),
#  ('00255', ['someone', 'walks', 'a', 'quarter-circle', 'to', 'the', 'right']),
#  ('00255', ['someone', 'walks', 'a', 'right', 'turn']),
#  ('00255',
#   ['a', 'human', 'performs', 'a', '90', '°', 'curve', 'tu', 'the', 'right']),
#  ('00255', ['a', 'human', 'walks', 'a', 'quarter', 'to', 'his', 'right']),
#  ('00255', ['a', 'person', 'turns', 'right']),
#  ('00256',
#   ['a',
#    'person',
#    'walks',
#    'forward',
#    'and',
#    'performs',
#    'a',
#    'turn',
#    'to',
#    'the',
#    'right']),
#  ('00256',
# ...
#  ('00339',
#   ['a', 'person', 'walks', 'counterclockwise', 'in', 'a', 'small', 'circle']),
#  ('00339',
#   ['a',
#    'human',
#    'walks',
#    'in',
#    'a',
#    'counterclockwise',
#    'circle',
#    ',',
#    'completing',
#    'one',
#    'round',
#    'in',
#    '8',
#    'steps']),
#  ('00339',
#   ['a',
#    'human',
#    'walks',
#    'a',
#    'full',
#    'circle',
#    'to',
#    'its',
#    'left',
#    'and',
#    'stops',
#    'right',
#    'before',
#    'where',
#    'it',
#    'started']),
#  ('00340',
#   ['subject', 'walks', 'in', 'a', 'full', 'circle', 'counterclockwise']),
#  ('00341',
#   ['a', 'person', 'walks', 'counter', 'clockwise', 'in', 'a', 'circle']),
#  ('00341',
#   ['someone',
#    'walks',
#    'in',
#    'a',
#    'circle',
#    'of',
#    'appoximately',
#    '2',
#    'meters',
#    'in',
#    'diameter',
#    'to',
#    'the',
#    'right']),
#  ('00342', ['person', 'walking', 'in', 'a', 'circle', 'to', 'the', 'left']),
#  ('00342', ['a', 'person', 'walks', 'counter-clockwise', 'circle']),
#  ('00342', ['someone', 'walks', 'a', 'larger', 'anticlockwise']),
#  ('00343', ['walking', 'counter', 'clock-wise', 'in', 'a', 'circle']),
#  ('00343',
#   ['a', 'person', 'walks', 'in', 'a', 'circle', 'round', 'an', 'axis']),
#  ('00344',
#   ['a', 'person', 'walks', 'counterclockwise', 'in', 'a', 'small', 'circle']),
#  ('00344', ['a', 'person', 'walks', 'a', 'circle']),
#  ('00345',
#   ['a', 'person', 'walking', 'in', 'a', 'circle', 'to', 'the', 'left']),
#  ('00346',
#   ['subject', 'walks', 'in', 'a', 'full', 'circle', 'counterclockwise']),
#  ('00346',
#   ['a',
#    'person',
#    'walks',
#    'forward',
#    'in',
#    'a',
#    'counterclockwise',
#    'circle']),
#  ('00347',
#   ['the',
#    'person',
#    'is',
#    'walking',
#    'back',
#    'to',
#    'the',
#    'initial',
#    'position',
#    'by',
#    'following',
#    'a',
#    'circular',
#    'shape']),
#  ('00347',
#   ['a', 'person', 'walks', 'in', 'a', 'circle', 'to', 'the', 'right']),
#  ('00347', ['somebody', 'walks', 'a', 'circle', 'clockwise']),
#  ('00348', ['subject', 'walks', 'in', 'a', 'full', 'circle', 'clockwise']),
#  ('00348', ['some', 'walks', 'clockwise']),
#  ('00348',
#   ['a', 'person', 'walks', 'in', 'a', 'circle', 'to', 'the', 'right']),
#  ('00348',
#   ['a', 'man', 'walks', 'in', 'small', 'circle', 'to', 'the', 'right']),
#  ('00349', ['a', 'person', 'walks', 'in', 'a', 'circle']),
#  ('00349',
#   ['a', 'person', 'walks', 'to', 'the', 'right', 'in', 'a', 'circle']),
#  ('00349',
#   ['a', 'person', 'walks', 'in', 'a', 'circle', 'to', 'his', 'right', 'side']),
#  ('00350', ['a', 'human', 'walks', 'in', 'a', 'full', 'circle', 'clockwise']),
#  ('00350', ['a', 'person', 'walks', 'in', 'a', 'clockwise', 'circle']),
#  ('00350', ['a', 'person', 'walks', 'in', 'a', 'circle', 'clockwise']),
#  ('00351', ['a', 'person', 'walks', 'clockwise', 'in', 'a', 'circle']),
#  ('00352', ['a', 'person', 'walks', 'in', 'a', 'circle']),
#  ('00352',
#   ['a', 'person', 'walks', 'in', 'a', 'circle', 'to', 'the', 'right']),
#  ('00353', ['a', 'human', 'walks', 'in', 'a', 'circle', 'clockwise']),
#  ('00354', ['a', 'person', 'walks', 'in', 'a', 'circle', 'clockwise']),
#  ('00355', ['someone', 'walks', 'a', 'full', 'clockwise', 'circle']),
#  ('00355',
#   ['a',
#    'person',
#    'is',
#    'walking',
#    'in',
#    'a',
#    'circle',
#    'in',
#    'clockwise',
#    'direction']),
#  ('00356', ['a', 'person', 'walks', 'in', 'a', 'circle']),
#  ('00356', ['a', 'human', 'performs', 'a', 'jump', 'to', 'the', 'left']),
#  ('00357',
#   ['someone', 'walks', 'a', 'few', 'steps', 'in', 'a', 'left', 'bend']),
#  ('00358', ['a', 'persons', 'turns', '90', '°', 'to', 'the', 'left']),
#  ('00358',
#   ['a', 'person', 'walks', 'a', 'quarter', 'left', 'sides', 'circle']),
#  ('00358', ['a', 'person', 'turns', 'left']),
#  ('00359',
#   ['a',
#    'person',
#    'walks',
#    'a',
#    'quarter',
#    'of',
#    'a',
#    'circle',
#    'counterclockwise']),
#  ('00359', ['a', 'human', 'walks', 'a', 'quarter', 'to', 'the', 'left']),
#  ('00360', ['person', 'walking', 'in', 'a', 'curve', 'to', 'the', 'left']),
#  ('00360',
#   ['human',
#    'goes',
#    'in',
#    'a',
#    'quater',
#    'circle',
#    'counterclockwise',
#    'starting',
#    'with',
#    'left']),
#  ('00361', ['a', 'person', 'walks', 'while', 'turning', 'to', 'the', 'left']),
#  ('00361',
#   ['a',
#    'person',
#    'goes',
#    'to',
#    'the',
#    'left',
#    ',',
#    'where',
#    'it',
#    'passes',
#    'through',
#    'a',
#    'quarter',
#    'circle',
#    'line',
#    'along']),
#  ('00361', ['someone', 'turns', 'a', 'left', 'corner']),
#  ('00362',
#   ['subject', 'walks', 'in', 'a', 'quarter', 'circle', 'counterclockwise']),
#  ('00362',
#   ['a',
#    'person',
#    'walks',
#    'to',
#    'the',
#    'left',
#    'performing',
#    'a',
#    'quarter',
#    'circle']),
#  ('00363',
#   ['subject', 'walks', 'in', 'a', 'quarter', 'circle', 'counterclockwise']),
#  ('00364', ['a', 'person', 'turns', 'left']),
#  ('00364', ['someone', 'walks', 'a', 'left', 'turn']),
#  ('00365',
#   ['human',
#    'goes',
#    'in',
#    'a',
#    'quarter',
#    'circle',
#    'counterclockwise',
#    'starting',
#    'with',
#    'left']),
#  ('00366',
#   ['a',
#    'person',
#    'walks',
#    'a',
#    'quarter',
#    'circle',
#    'clockwise',
#    'with',
#    '4',
#    'steps']),
#  ('00367', ['a', 'human', 'turning', 'right']),
#  ('00367',
#   ['a',
#    'person',
#    'walks',
#    'a',
#    'quarter',
#    'of',
#    'a',
#    'circle',
#    'to',
#    'its',
#    'right']),
#  ('00367',
#   ['a', 'person', 'walks', 'a', 'quarter', 'circle', 'to', 'the', 'right']),
#  ('00368',
#   ['a',
#    'person',
#    'walks',
#    'a',
#    'quarter',
#    'circle',
#    'clockwise',
#    'with',
#    '4',
#    'steps']),
#  ('00369',
#   ['human',
#    'walks',
#    'in',
#    'clockwise',
#    'circle',
#    'starting',
#    'with',
#    'right',
#    'leg']),
#  ('00369',
#   ['a',
#    'human',
#    'is',
#    'performing',
#    'a',
#    'tight',
#    '90',
#    '°',
#    'right',
#    'curve']),
#  ('00370', ['a', 'person', 'turns', 'right']),
#  ('00370', ['a', 'person', 'walks', '90degrees', 'to', 'the', 'right']),
#  ('00371',
#   ['a',
#    'person',
#    'walks',
#    'a',
#    'quarter',
#    'circle',
#    'clockwise',
#    'with',
#    '4',
#    'steps']),
#  ('00372',
#   ['a',
#    'person',
#    'walks',
#    'while',
#    'gradually',
#    'turning',
#    'to',
#    'the',
#    'right']),
#  ('00372', ['a', 'person', 'turns', 'right']),
#  ('00372', ['a', 'person', 'walks', 'to', 'the', 'right', '90', 'degrees']),
#  ('00373', ['a', 'person', 'walks', 'a', 'quarter', 'of', 'a', 'circle']),
#  ('00373',
#   ['a',
#    'person',
#    'walks',
#    '90degrees',
#    'to',
#    'the',
#    'right',
#    'performing',
#    'a',
#    'quarter',
#    'circle']),
#  ('00373', ['somebody', 'walks', 'a', 'quarter', 'circle', 'clockwise']),
#  ('00374', ['person', 'walking', 'to', 'the', 'right']),
#  ('00374',
#   ['a',
#    'person',
#    'walks',
#    'forward',
#    'while',
#    'turning',
#    'to',
#    'the',
#    'right']),
#  ('00375',
#   ['a',
#    'human',
#    'walks',
#    'a',
#    'very',
#    'slow',
#    '90',
#    'degree',
#    'arc',
#    'to',
#    'the',
#    'right']),
#  ('00375',
#   ['human',
#    'goes',
#    'in',
#    'a',
#    'quarter',
#    'circle',
#    'clockwise',
#    'starting',
#    'with',
#    'right']),
#  ('00376', ['someone', 'walks', 'forward']),
#  ('00377', ['a', 'person', 'walks']),
#  ('00377', ['a', 'person', 'is', 'walking', 'forward']),
#  ('00378', ['a', 'person', 'walks', 'forward']),
#  ('00379',
#   ['a', 'person', 'walks', '4', 'steps', 'in', 'the', 'forward', 'direction']),
#  ('00380', ['a', 'person', 'walks', 'forward']),
#  ('00381', ['a', 'person', 'walks', 'forward']),
#  ('00381', ['person', 'walking', 'forwards']),
#  ('00381', ['someone', 'goes', 'away']),
#  ('00381', ['walking', 'five', 'steps', 'in', 'a', 'straight', 'line']),
#  ('00381', ['a', 'person', 'walks', 'forward']),
#  ('00381',
#   ['a', 'person', 'walks', 'straight', 'forward', 'a', 'few', 'meters']),
#  ('00381', ['a', 'person', 'is', 'walking', 'forward']),
#  ('00381', ['a', 'person', 'walks', 'forward']),
#  ('00381', ['a', 'person', 'walks', 'five', 'steps']),
#  ('00382', ['a', 'person', 'goes', 'five', 'steps', 'forward']),
#  ('00383',
#   ['a',
#    'person',
#    'walking',
#    'very',
#    'normal',
#    ',',
#    'with',
#    'an',
#    'average',
#    'speed',
#    'for',
#    '5',
#    'steps',
#    'while',
#    'its',
#    'arms',
#    'are',
#    'swinging',
#    'normally',
#    'on',
#    'every',
#    'step']),
#  ('00383', ['a', 'person', 'walks', 'forwards']),
#  ('00384', ['a', 'person', 'walks', 'forward']),
#  ('00384',
#   ['a',
#    'person',
#    'walks',
#    '4',
#    'steps',
#    'forward',
#    'in',
#    'a',
#    'straight',
#    'line']),
#  ('00384', ['a', 'person', 'walkes', 'forward']),
#  ('00385', ['a', 'person', 'walks', 'four', 'steps', 'backward']),
#  ('00385',
#   ['someone', 'takes', '4', 'steps', 'backwards', 'starting', 'with', 'left']),
#  ('00386', ['person', 'walks', 'backward']),
#  ('00386',
#   ['a', 'human', 'walks', '4', 'steps', 'backwards', 'on', 'a', 'line']),
#  ('00386', ['a', 'human', 'is', 'walking', 'backwards']),
#  ('00387', ['subject', 'walks', 'three', 'steps', 'backwards']),
#  ('00388', ['someone', 'moves', 'backwards', 'in', 'a', 'walk']),
#  ('00388',
#   ['a', 'human', 'walks', 'backwards', 'while', 'looking', 'forward']),
#  ('00388', ['a', 'person', 'walks', 'backwards', 'a', 'few', 'steps']),
#  ('00388', ['a', 'person', 'walks', 'backwards', 'fast']),
#  ('00388', ['a', 'person', 'takes', '5', 'steps', 'backwards']),
#  ('00389', ['a', 'person', 'walks', 'four', 'steps', 'backward']),
#  ('00389', ['a', 'person', 'walks', 'some', 'meters', 'back']),
#  ('00389', ['a', 'person', 'walks', 'backwards', 'for', 'four', 'steps']),
#  ('00390', ['subject', 'walks', 'backwards']),
#  ('00390', ['a', 'person', 'is', 'walking', 'backwards']),
#  ('00390', ['human', 'goes', 'backwards']),
#  ('00391', ['a', 'person', 'walks', 'backwards']),
#  ('00391', ['a', 'person', 'walks', 'backward']),
#  ('00391', ['a', 'person', 'walks', 'backwards']),
#  ('00391', ['human', 'goes', 'backwards']),
#  ('00392', ['a', 'person', 'is', 'walking', 'quickly', 'backwards']),
#  ('00392', ['a', 'person', 'walkes', 'backwards']),
#  ('00393', ['a', 'person', 'walks', 'backwards']),
#  ('00393', ['a', 'person', 'walking', 'backwards']),
#  ('00394', ['subject', 'walks', 'backwards']),
#  ('00394', ['a', 'person', 'walking', 'backwards']),
#  ('00396',
#   ['a', 'person', 'walks', 'counter', 'clockwise', 'in', 'a', 'circle']),
#  ('00396', ['a', 'person', 'walks', 'in', 'a', 'counter-clockwise', 'circle']),
#  ('00397', ['someone', 'walks', 'a', 'full', 'circle']),
#  ('00397',
#   ['a',
#    'person',
#    'walking',
#    'forward',
#    'three',
#    'quarters',
#    'of',
#    'a',
#    'circle',
#    'counterclockwise']),
#  ('00397', ['a', 'person', 'walks', 'in', 'a', 'circle', 'to', 'the', 'left']),
#  ('00398', ['a', 'person', 'walks', 'in', 'a', 'circle']),
#  ('00398',
#   ['a',
#    'person',
#    'is',
#    'doing',
#    'a',
#    'three',
#    'quarter',
#    'counter-clockwise',
#    'circle']),
#  ('00398',
#   ['a',
#    'person',
#    'walks',
#    'three',
#    'fourth',
#    'of',
#    'a',
#    'circle',
#    'to',
#    'the',
#    'left']),
#  ('00399',
#   ['a', 'human', 'walking', 'in', 'a', 'circle', 'counter', 'clockwise']),
#  ('00399',
#   ['a',
#    'human',
#    'walks',
#    'three',
#    'quarter',
#    'of',
#    'a',
#    'circle',
#    'to',
#    'its',
#    'left']),
#  ('00400', ['a', 'person', 'walks', 'in', 'a', 'circle', 'to', 'he', 'left']),
#  ('00401', ['the', 'human', 'walks', 'a', 'counter-clockwise', 'circle']),
#  ('00401', ['a', 'human', 'walks', 'in', 'a', 'circle']),
#  ('00402', ['someone', 'is', 'walking', 'a', 'circle']),
#  ('00402', ['a', 'person', 'walks', 'three', 'fourth', 'of', 'a', 'circle']),
#  ('00402',
#   ['a',
#    'person',
#    'walks',
#    'in',
#    'a',
#    'three',
#    'quarter',
#    'circle',
#    'to',
#    'his',
#    'left',
#    'side']),
#  ('00403',
#   ['a', 'human', 'walks', 'around', 'in', 'a', 'clockwise', 'circle']),
#  ('00403', ['someone', 'walks', 'in', 'a', 'circle', 'clockwise']),
#  ('00403', ['someone', 'is', 'walking', 'in', 'a', 'circle', 'clockwise']),
#  ('00403', ['a', 'person', 'walks', 'in', 'a', 'circle']),
#  ('00404',
#   ['a',
#    'person',
#    'walks',
#    'in',
#    'clock-wise',
#    'circle',
#    'and',
#    'stops',
#    'facing',
#    '90',
#    'degrees',
#    'to',
#    'the',
#    'left',
#    'relative',
#    'from',
#    'the',
#    'starting',
#    'position']),
#  ('00404',
#   ['a',
#    'human',
#    'is',
#    'walking',
#    'three',
#    'quarter',
#    'of',
#    'a',
#    'circle',
#    'to',
#    'its',
#    'right']),
#  ('00404', ['a', 'person', 'walks', 'in', 'a', 'circle']),
#  ('00405', ['a', 'person', 'walks', 'in', 'a', 'rightward', 'circle']),
#  ('00406',
#   ['the',
#    'person',
#    'is',
#    'walking',
#    'back',
#    'to',
#    'the',
#    'initial',
#    'position',
#    'by',
#    'following',
#    'a',
#    'circular',
#    'path']),
#  ('00407', ['a', 'human', 'walks', 'a', 'right', 'circle']),
#  ('00407',
#   ['a',
#    'person',
#    'walks',
#    'a',
#    'circle',
#    ',',
#    'radius',
#    'approximatly',
#    '1,5',
#    'meters']),
#  ('00407',
#   ['a', 'person', 'walks', 'in', 'a', 'cricle', 'to', 'the', 'right']),
#  ('00408', ['a', 'human', 'walks', 'in', 'a', 'clockwise', 'circle']),
#  ('00408', ['a', 'human', 'goes', 'around', ',', 'circulates']),
#  ('00408', ['human', 'goes', 'in', 'a', 'circle', 'clockwise']),
#  ('00409', ['a', 'person', 'walks', 'a', 'circle', 'clockwise']),
#  ('00410',
#   ['someone', 'walks', 'a', '90', 'degrees', 'curve', 'to', 'the', 'left']),
#  ('00410',
#   ['a',
#    'person',
#    'walks',
#    'forward',
#    'in',
#    'a',
#    '90',
#    '°',
#    'curve',
#    'to',
#    'his',
#    'left']),
#  ('00411', ['a', 'person', 'walks', 'a', 'quarter', 'circle']),
#  ('00412',
#   ['a',
#    'person',
#    'walks',
#    'to',
#    'the',
#    'left',
#    'one-quarter',
#    'of',
#    'a',
#    'rotation']),
#  ('00412',
#   ['a', 'person', 'walks', 'a', 'quarter', 'circle', 'two', 'the', 'left']),
#  ('00412',
#   ['a', 'person', 'walks', 'a', '90', 'degree', 'turn', 'to', 'the', 'left']),
#  ('00412',
#   ['a',
#    'person',
#    'walks',
#    'in',
#    'a',
#    'quarter',
#    'circle',
#    'to',
#    'the',
#    'left']),
#  ('00413', ['person', 'walks', 'around', 'a', 'corner']),
#  ('00414', ['a', 'person', 'is', 'turning', 'right']),
#  ('00414',
#   ['a',
#    'person',
#    'walks',
#    'to',
#    'the',
#    'right',
#    'performing',
#    'a',
#    'quarter',
#    'circle']),
#  ('00415',
#   ['a',
#    'human',
#    'moves',
#    'in',
#    'a',
#    'quarter',
#    'circle',
#    ',',
#    'makes',
#    'a',
#    'break',
#    'and',
#    'move',
#    'in',
#    'another',
#    'quarter',
#    'circle']),
#  ('00415',
#   ['someone', 'is', 'walking', 'forward', 'and', 'then', 'turning', 'right']),
#  ('00415',
#   ['a',
#    'person',
#    'walks',
#    'forwards',
#    'performing',
#    'a',
#    'quarter',
#    'circle',
#    'to',
#    'the',
#    'right',
#    'and',
#    'then',
#    'walks',
#    'back',
#    'to',
#    'its',
#    'origin',
#    'position',
#    'in',
#    'the',
#    'same',
#    'way']),
#  ('00416', ['a', 'human', 'turning', 'right']),
#  ('00417',
#   ['person',
#    'looks',
#    'around',
#    'and',
#    'then',
#    'walks',
#    'around',
#    'a',
#    'corner']),
#  ('00417',
#   ['a',
#    'person',
#    'walks',
#    'forwards',
#    'performing',
#    'a',
#    'quarter',
#    'circle',
#    'to',
#    'the',
#    'right']),
#  ('00417',
#   ['a',
#    'person',
#    'walks',
#    'forward',
#    'in',
#    'a',
#    '90',
#    '°',
#    'curve',
#    'to',
#    'the',
#    'right']),
#  ('00417', ['a', 'person', 'is', 'turning', 'right', 'while', 'walking']),
#  ('00418',
#   ['a',
#    'person',
#    'walks',
#    'in',
#    '90',
#    'degree',
#    'curve',
#    'to',
#    'the',
#    'right']),
#  ('00419',
#   ['a',
#    'person',
#    'walking',
#    'in',
#    'a',
#    'quarter',
#    'circle',
#    'to',
#    'the',
#    'right']),
#  ('00420', ['the', 'person', 'is', 'turning', 'right']),
#  ('00421',
#   ['a',
#    'person',
#    'walks',
#    'a',
#    'ninety',
#    'degree',
#    'curve',
#    'to',
#    'the',
#    'left']),
#  ('00422',
#   ['a',
#    'person',
#    'walks',
#    'forward',
#    'anf',
#    'turns',
#    'slightly',
#    'to',
#    'the',
#    'right']),
#  ('00422',
#   ['a',
#    'person',
#    'walks',
#    'and',
#    'turns',
#    '90',
#    'degrees',
#    'to',
#    'the',
#    'right']),
#  ('00422',
#   ['a', 'human', 'is', 'walking', 'in', 'a', '90', '°', 'right', 'curve']),
#  ('00423', ['a', 'human', 'turning', 'right']),
#  ('00424', ['a', 'person', 'walks', 'slowly', 'forward']),
#  ('00424', ['a', 'person', 'takes', 'a', 'few', 'slow', 'steps', 'forward']),
#  ...]

# %%
len(tokenized_sentences)
# Out:
# 6353

# %%
tokenized_words = []
for a in tokenized_sentences:
    print(a)
    tokenized_words.extend(a[1])
# Out:
# ('00001', ['a', 'person', 'is', 'walking', 'forwards'])
# ('00002', ['a', 'person', 'walks', '4', 'steps', 'forward'])
# ('00003', ['a', 'human', 'walking'])
# ('00004', ['a', 'person', 'walks', 'forward', 'at', 'medium', 'speed'])
# ('00004', ['human', 'slowly', 'goes', 'forward'])
# ('00005', ['a', 'human', 'walks', 'four', 'slow', 'steps', 'forward'])
# ('00006', ['a', 'person', 'goes', 'four', 'and', 'half', 'steps', 'forward'])
# ('00006', ['a', 'person', 'walking', 'forward', 'slightly', 'to', 'the', 'right'])
# ('00007', ['a', 'person', 'walks', 'slowly', 'for', 'four', 'steps', 'and', 'stops'])
# ('00007', ['a', 'person', 'walks', 'four', 'steps', 'to', 'the', 'forward', 'direction'])
# ('00008', ['a', 'person', 'walks', 'slowly', '4', 'steps', 'forward'])
# ('00009', ['a', 'person', 'stands', ',', 'then', 'walks', 'a', 'few', 'steps', ',', 'then', 'stops', 'again'])
# ('00009', ['someone', 'is', 'walking', 'forward', 'slowly', 'doing', '4', 'steps', 'starting', 'with', 'the', 'left', 'leg'])
# ('00009', ['a', 'person', 'makes', '4', 'steps', 'forward', 'slowly'])
# ('00010', ['a', 'human', 'walking', 'backwards'])
# ('00011', ['a', 'person', 'walks', 'backwards', 'four', 'steps', 'starting', 'with', 'the', 'left', 'foot'])
# ('00011', ['somebody', 'walks', 'backwards'])
# ('00013', ['a', 'person', 'walking', 'backwards', 'for', 'a', 'few', 'steps'])
# ('00014', ['a', 'person', 'walks', 'four', 'steps', 'backward'])
# ('00015', ['a', 'person', 'walks', 'backwards'])
# ('00016', ['a', 'person', 'walks', 'backward', 'at', 'a', 'slow', 'speed'])
# ('00016', ['a', 'human', 'is', 'walking', '4', 'steps', 'backwards', 'and', 'starting', 'with', 'its', 'left', 'food'])
# ('00016', ['a', 'person', 'walks', 'backwards'])
# ('00016', ['some', 'is', 'reverse', 'walking'])
# ('00016', ['a', 'person', 'takes', '4', 'steps', 'backwards'])
# ('00016', ['a', 'person', 'moves', 'backwards', '4', 'steps', 'before', 'standing', 'still'])
# ('00016', ['someone', 'is', 'walking', 'backwards'])
# ('00016', ['a', 'man', 'is', 'walking', 'backwards'])
# ('00016', ['somebody', 'walks', 'a', 'few', 'steps', 'backward'])
# ('00017', ['a', 'person', 'walks', 'four', 'steps', 'backwards'])
# ('00017', ['a', 'person', 'walks', 'backwards', 'slowly'])
# ('00017', ['somebody', 'walks', 'backward'])
# ('00018', ['a', 'person', 'is', 'walking', 'backwards'])
# ('00019', ['a', 'person', 'turns', 'in', 'a', 'circle'])
# ('00019', ['someone', 'walks', 'in', 'a', 'circle', 'counterclockwise'])
# ('00019', ['somebody', 'wals', 'a', 'circle', 'anticlockwise'])
# ('00020', ['a', 'person', 'walks', 'in', 'a', 'circle', 'counter', 'clockwise'])
# ('00021', ['a', 'person', 'walks', 'in', 'a', 'square'])
# ('00022', ['the', 'person', 'is', 'walking', 'in', 'a', 'circular', 'shape'])
# ('00022', ['a', 'human', 'walks', 'slowly', 'a', 'full', 'circle', 'to', 'its', 'left'])
# ('00022', ['a', 'person', 'walks', 'a', 'full', 'counter-clockwise', 'circle'])
# ('00022', ['a', 'person', 'walks', 'in', 'a', 'circle', 'pattern', 'one', 'time'])
# ('00023', ['a', 'person', 'walks', 'in', 'a', 'counter-clockwise', 'circle'])
# ('00023', ['somebody', 'is', 'walking', 'in', 'a', 'circle'])
# ('00023', ['person', 'walking', 'in', 'a', 'circle'])
# ('00023', ['a', 'person', 'is', 'walking', 'in', 'a', 'circle'])
# ('00023', ['someone', 'slowly', 'walks', 'a', 'full', 'circle', 'to', 'the', 'left'])
# ('00023', ['walking', 'in', 'a', 'slow', 'circle'])
# ('00023', ['someone', 'walks', 'a', 'complete', 'circle'])
# ('00023', ['a', 'person', 'turns', 'around', 'to', 'the', 'beginning'])
# ('00023', ['someone', 'is', 'walking', 'a', 'whole', 'round', 'to', 'his', 'left', 'side'])
# ('00023', ['a', 'person', 'is', 'walking', 'in', 'a', 'circle', 'shape'])
# ('00023', ['a', 'person', 'walks', 'a', 'circle', 'to', 'the', 'left'])
# ('00024', ['a', 'person', 'walks', 'a', 'circle'])
# ('00025', ['a', 'person', 'walking', 'in', 'a', 'circle', 'to', 'the', 'left'])
# ('00025', ['a', 'person', 'walks', 'a', 'circle', 'in', 'the', 'left', 'direction'])
# ('00026', ['a', 'person', 'walks', 'in', 'a', 'counter-clockwise', 'circle'])
# ('00026', ['someone', 'walks', 'in', 'a', 'circle', 'counterclockwise'])
# ('00027', ['the', 'person', 'is', 'walking', 'through', 'a', 'circular', 'path'])
# ('00027', ['a', 'human', 'is', 'walking', 'in', 'circle'])
# ('00028', ['human', 'goes', 'in', 'a', 'circle', 'clockwise'])
# ('00029', ['a', 'person', 'walking', 'in', 'a', 'circle', 'to', 'the', 'right'])
# ('00029', ['somebody', 'walks', 'a', 'circle', 'clockwise'])
# ('00030', ['a', 'person', 'walks', 'in', 'a', 'clockwise', 'circle'])
# ('00030', ['a', 'person', 'running', 'in', 'a', 'full', 'circle', ',', 'clockwise'])
# ('00031', ['a', 'person', 'walks', 'a', 'circle', 'clock-wise'])
# ('00031', ['a', 'person', 'walks', 'in', 'clock-wise', 'circle'])
# ('00031', ['a', 'human', 'is', 'walking', 'in', 'a', 'circle', 'to', 'the', 'right'])
# ('00032', ['a', 'person', 'walks', 'in', 'a', 'circle', 'clockwise'])
# ('00032', ['a', 'person', 'walks', 'in', 'a', 'circle', 'and', 'looks', 'facing', 'down'])
# ('00032', ['a', 'person', 'walks', 'a', 'circle', 'in', 'the', 'right', 'direction'])
# ('00032', ['the', 'human', 'walks', 'a', 'circle', '(', 'right', 'turn', ')'])
# ('00033', ['a', 'person', 'walks', 'in', 'a', 'circle', 'clockwise'])
# ('00033', ['a', 'person', 'walks', 'in', 'a', 'circle', 'to', 'his', 'right', 'side'])
# ('00034', ['a', 'human', 'walking', 'in', 'a', 'circle', 'clockwise'])
# ('00034', ['a', 'person', 'walks', 'in', 'a', 'little', 'circle'])
# ('00035', ['a', 'person', 'walks', 'a', 'circle'])
# ('00036', ['a', 'person', 'walks', 'in', 'circle', 'in', 'clockwise', 'direction'])
# ('00037', ['a', 'person', 'walks', 'a', 'circle', 'clockwise'])
# ('00037', ['a', 'perons', 'walks', 'a', 'circle', 'clockwise'])
# ('00037', ['a', 'man', 'walks', 'in', 'circle'])
# ('00038', ['a', 'person', 'walking', 'in', 'a', 'quarter', 'circle', 'to', 'the', 'right'])
# ('00038', ['a', 'person', 'walks', 'while', 'turning', 'to', 'the', 'right'])
# ('00039', ['a', 'person', 'is', 'walking', 'forward', 'four', 'steps', 'starting', 'with', 'the', 'right', 'foot', 'and', 'performing', 'a', 'right-turn', 'of', '90', '°'])
# ('00039', ['a', 'human', 'performs', 'a', 'tight', '90', '°', 'right', 'curve'])
# ('00040', ['a', 'person', 'walks', '90', '°', 'of', 'a', 'circle', 'to', 'his', 'right'])
# ('00040', ['a', 'person', 'walks', 'a', 'quarter', 'circle', 'to', 'the', 'right', ',', 'taking', 'four', 'steps'])
# ('00040', ['a', 'person', 'is', 'turning', 'right', 'while', 'walking'])
# ('00041', ['someone', 'walks', 'three', 'steps', 'in', 'curve', 'to', 'the', 'right'])
# ('00041', ['a', 'person', 'walks', 'a', 'small', 'half', 'circle'])
# ('00041', ['somebody', 'walks', 'a', 'quarter', 'circle', 'in', 'clockwise', 'direction'])
# ('00042', ['subject', 'walks', 'a', 'quarter', 'circle', 'clockwise'])
# ('00042', ['a', 'person', 'walks', 'in', 'a', '90', '°', 'curve', 'to', 'his', 'right'])
# ('00042', ['a', 'person', 'waits', 'on', 'a', 'atm', 'line', 'and', 'then', 'goes', 'to', 'the', 'machine'])
# ('00042', ['a', 'human', 'sit'])
# ('00043', ['a', 'person', 'walks', 'clockwise', 'in', 'a', 'circle', 'with', '4', 'steps'])
# ('00043', ['a', 'human', 'performs', 'a', 'tight', '90', '°', 'curve', 'to', 'the', 'right'])
# ('00043', ['a', 'human', 'sit', 'down'])
# ('00044', ['a', 'person', 'walks', 'a', 'quarter', 'rightwards', 'circle'])
# ('00044', ['a', 'person', 'walks', 'in', 'a', 'quarter', 'circle'])
# ('00045', ['human', 'walks', 'in', 'a', 'quater', 'circle', 'clockwise'])
# ('00046', ['a', 'person', 'walks', 'a', 'quarter', 'circle', 'clockwise', 'with', '4', 'steps'])
# ('00047', ['a', 'person', 'is', 'walking', 'a', 'left-turn'])
# ('00047', ['a', 'person', 'walking', 'forward', 'in', 'a', '90', '°', 'curve'])
# ('00047', ['a', 'person', 'walks', 'a', 'quarter', 'circle', 'to', 'the', 'right', ',', 'taking', 'four', 'steps'])
# ('00048', ['person', 'walking', 'backwards'])
# ('00048', ['human', 'goes', 'backwards', 'starting', 'with', 'left'])
# ('00049', ['subject', 'walks', 'backwards'])
# ('00049', ['a', 'person', 'takes', '4', 'steps', 'backwards', 'starting', 'with', 'left'])
# ('00049', ['a', 'person', 'walks', 'some', 'steps', 'backwards'])
# ('00050', ['person', 'walking', 'backwards'])
# ('00050', ['someone', 'walks', 'slowly', 'backwards'])
# ('00050', ['a', 'person', 'makes', '4', 'steps', 'backwards'])
# ('00051', ['a', 'person', 'walks', 'backwards'])
# ('00052', ['the', 'person', 'is', 'walking', 'backwards'])
# ('00052', ['a', 'person', 'walks', 'some', 'steps', 'backwards'])
# ('00053', ['a', 'person', 'walking', 'backwards', 'for', '4', 'steps'])
# ('00053', ['a', 'person', 'slowly', 'walking', 'backwards'])
# ('00053', ['someone', 'walks', 'straight', 'reverse', 'and', 'stop', 'in', 'four', 'steps'])
# ('00054', ['a', 'person', 'is', 'walking', 'backwards', 'in', 'a', 'straight', 'line'])
# ('00054', ['human', 'goes', 'backwards', 'starting', 'with', 'left'])
# ('00055', ['a', 'person', 'walks', 'backward', '4', 'steps'])
# ('00055', ['someone', 'walks', 'backwards', '4', 'steps', 'starting', 'with', 'the', 'left', 'leg'])
# ('00055', ['a', 'person', 'takes', 'some', 'steps', 'backwards'])
# ('00056', ['a', 'human', 'walking', 'backwards'])
# ('00056', ['the', 'human', 'is', 'walking', 'backwards'])
# ('00057', ['a', 'person', 'walks', 'backwards'])
# ('00057', ['someone', 'is', 'walking', 'backwards', '4', 'steps', 'starting', 'with', 'the', 'left', 'leg'])
# ('00058', ['a', 'person', 'walks', 'in', 'circle'])
# ('00059', ['human', 'goes', 'in', 'a', 'circle', 'counterclockwise'])
# ('00059', ['a', 'human', 'is', 'walking', 'in', 'a', 'circle', 'to', 'its', 'left'])
# ('00060', ['a', 'human', 'walking', 'in', 'a', 'circle', 'counterclockwise'])
# ('00061', ['someone', 'walks', 'in', 'a', 'counter-clockwise', 'circle'])
# ('00061', ['a', 'human', 'walks', 'in', 'a', 'circle', 'with', 'a', 'diameter', 'of', '2m'])
# ('00061', ['someone', 'walk', 'in', 'a', 'full', 'counter-clockwise', 'circle'])
# ('00061', ['a', 'person', 'walks', 'in', 'a', 'full', 'circle'])
# ('00061', ['someone', 'makes', 'a', 'circle'])
# ('00061', ['he', 'turns', 'around'])
# ('00061', ['a', 'person', 'walks', 'a', 'circle'])
# ('00061', ['someone', 'walks', 'one', 'round'])
# ('00061', ['a', 'person', 'walks', 'a', 'full', 'anti-clockwise', 'circle'])
# ('00061', ['a', 'person', 'walks', 'in', 'a', 'circle', 'counterclockwise'])
# ('00061', ['a', 'person', 'walks', 'a', 'circle', 'to', 'the', 'left'])
# ('00061', ['the', 'human', 'walks', 'a', 'circle'])
# ('00061', ['a', 'human', 'walks', 'in', 'circle', 'counterclockwise'])
# ('00062', ['a', 'person', 'walks', 'in', 'a', 'counter-clockwise', 'circle'])
# ('00062', ['a', 'person', 'walks', 'in', 'a', 'circle', 'to', 'the', 'left', 'side'])
# ('00063', ['a', 'person', 'is', 'walking', 'in', 'small', 'circles'])
# ('00063', ['a', 'person', 'walks', 'in', 'a', 'circle', 'to', 'the', 'left'])
# ('00064', ['a', 'human', 'walking', 'in', 'a', 'circle', 'counterclockwise'])
# ('00064', ['someone', 'is', 'walking', 'a', 'circle', 'to', 'the', 'left'])
# ('00065', ['someone', 'walks', 'in', 'a', 'circle', 'to', 'the', 'left'])
# ('00066', ['a', 'person', 'walking', 'in', 'a', 'circle', 'to', 'the', 'left'])
# ('00067', ['a', 'person', 'walks', 'in', 'a', 'counter-clockwise', 'circle'])
# ('00067', ['a', 'human', 'walks', 'in', 'a', 'counter-clockwise', 'circle'])
# ('00067', ['person', 'walking', 'in', 'a', 'circle'])
# ('00067', ['someone', 'walks', 'around', 'slowly'])
# ('00067', ['walking', 'in', 'a', 'small', 'circle'])
# ('00067', ['the', 'person', 'walked', 'in', 'a', 'circle'])
# ('00067', ['a', 'person', 'walks', 'a', 'circle'])
# ('00067', ['a', 'person', 'walks', 'in', 'a', 'circle', 'to', 'his', 'left', 'side'])
# ('00067', ['human', 'goes', 'in', 'a', 'circle', 'counterclockwise'])
# ('00067', ['someone', 'walks', 'a', 'anticlockwise'])
# ('00068', ['someone', 'walks', 'a', 'right', 'circle'])
# ('00069', ['a', 'person', 'is', 'walking', 'in', 'a', 'clockwise', 'circle'])
# ('00070', ['a', 'person', 'walks', 'a', 'circle', 'clockwise'])
# ('00070', ['someone', 'walks', 'in', 'a', 'small', 'circle', 'to', 'the', 'right'])
# ('00071', ['a', 'human', 'walking', 'in', 'a', 'circle', 'clockwise'])
# ('00071', ['a', 'person', 'walks', 'a', 'circle', ',', 'radius', 'approximatly', '1,5', 'm'])
# ('00072', ['a', 'person', 'walks', 'in', 'a', 'circle'])
# ('00073', ['a', 'person', 'walks', 'in', 'a', 'circle'])
# ('00074', ['a', 'person', 'is', 'walking', 'in', 'a', 'small', 'circle'])
# ('00075', ['subject', 'walks', 'in', 'a', 'circle', 'clockwise'])
# ('00075', ['a', 'person', 'walks', 'a', 'right', 'sided', 'circle', ',', 'radius', 'approximatly', '50cm'])
# ('00076', ['a', 'person', 'walking', 'in', 'a', 'circle', 'to', 'the', 'right'])
# ('00077', ['a', 'person', 'walks', 'in', 'a', 'clockwise', 'circle'])
# ('00077', ['a', 'person', 'walks', 'in', 'a', 'clockwise', 'circle'])
# ('00077', ['a', 'person', 'walking', 'in', 'a', 'circle'])
# ('00077', ['a', 'person', 'turns', 'to', 'his', 'right'])
# ('00077', ['someone', 'is', 'walking', 'one', 'round', 'to', 'his', 'side'])
# ('00077', ['a', 'person', 'is', 'walking', 'to', 'the', 'left', 'by', 'making', 'a', 'circle', 'shape'])
# ('00077', ['a', 'person', 'goes', 'around', 'in', 'a', 'circuit'])
# ('00077', ['a', 'person', 'walks', 'in', 'a', 'circle', 'to', 'the', 'right'])
# ('00077', ['somebody', 'walks', 'a', 'circle', 'clockwise'])
# ('00078', ['subject', 'walks', 'in', 'a', 'quarter', 'circle', 'counterclockwise'])
# ('00078', ['a', 'person', 'walks', 'a', 'quarter', ',', 'left-sided', 'circle'])
# ('00079', ['the', 'person', 'is', 'walking', 'to', 'the', 'left', 'by', 'following', 'a', 'half', 'circle', 'path'])
# ('00079', ['a', 'person', 'moves', 'to', 'the', 'left'])
# ('00079', ['a', 'person', 'walks', 'to', 'the', 'left'])
# ('00079', ['somebody', 'walks', 'a', 'quarter', 'circle', 'anticlockwise'])
# ('00080', ['a', 'person', 'walks', 'in', 'a', 'quarter', 'circle'])
# ('00080', ['a', 'person', 'is', 'walking', 'a', 'quarter', 'circle', 'to', 'the', 'left'])
# ('00080', ['a', 'person', 'walks', 'in', 'a', 'quarter', 'of', 'a', 'small', 'circle'])
# ('00081', ['a', 'person', 'walks', 'and', 'turns', 'to', 'the', 'left'])
# ('00081', ['someone', 'walks', 'a', 'left', 'turn'])
# ('00082', ['subject', 'walks', 'in', 'a', 'quarter', 'circle', 'counterclockwise'])
# ('00082', ['a', 'person', 'walks', 'to', 'the', 'left', 'performing', 'a', 'quarter', 'circle'])
# ('00083', ['a', 'human', 'makes', 'a', 'left', 'turn'])
# ('00083', ['a', 'person', 'goes', 'left', 'around', 'a', 'corner'])
# ('00084', ['a', 'person', 'walking', 'slowly', 'in', 'a', 'quartercircle', 'to', 'the', 'left'])
# ('00085', ['a', 'human', 'walks', 'a', 'quarter', 'of', 'a', 'circle', 'to', 'the', 'left'])
# ('00085', ['the', 'human', 'perfoms', 'a', 'left', 'turn'])
# ('00086', ['a', 'person', 'walks', 'a', '90', 'degrees', 'curve', 'to', 'the', 'left'])
# ('00086', ['somebody', 'walks', 'a', 'quarter', 'circle', 'against', 'the', 'clockwise', 'direction'])
# ('00087', ['a', 'person', 'walks', 'towards', 'the', 'left'])
# ('00087', ['human', 'goes', 'in', 'a', 'quater', 'circle', 'counterclockwise', 'starting', 'with', 'left'])
# ('00087', ['a', 'person', 'walking', 'a', 'left', 'turn'])
# ('00088', ['a', 'person', 'is', 'turning', 'right'])
# ('00089', ['a', 'human', 'walks', 'a', 'quarter', 'of', 'a', 'circle', 'to', 'the', 'right'])
# ('00090', ['a', 'person', 'walks', 'and', 'turns', 'to', 'the', 'right'])
# ('00091', ['a', 'person', 'walks', 'in', 'a', 'right', 'turn'])
# ('00091', ['a', 'person', 'walks', 'a', 'quarter', 'circle', 'clockwise'])
# ('00092', ['the', 'person', 'is', 'making', 'a', 'wide', 'turn', 'to', 'the', 'right'])
# ('00092', ['a', 'person', 'walks', 'in', 'a', 'quarter', 'circle', 'to', 'the', 'right'])
# ('00093', ['person', 'walking', 'to', 'the', 'right'])
# ('00093', ['human', 'goes', 'in', 'a', 'quarter', 'circle', 'clockwise', 'starting', 'with', 'right'])
# ('00093', ['someone', 'is', 'walking', 'a', 'quarter', 'circle', 'to', 'the', 'right'])
# ('00094', ['a', 'person', 'walking', 'in', 'a', 'quarter', 'circle', 'to', 'the', 'right'])
# ('00094', ['the', 'human', 'perfoms', 'a', 'right', 'turn'])
# ('00094', ['someone', 'slowly', 'turns', 'a', 'right', 'corner'])
# ('00095', ['a', 'human', 'turning', 'right'])
# ('00095', ['a', 'human', 'performs', 'a', '90', '°', 'right', 'curve'])
# ('00095', ['a', 'person', 'walks', 'in', 'a', 'curve', 'to', 'the', 'right'])
# ('00096', ['a', 'person', 'turns', 'right'])
# ('00097', ['human', 'goes', 'in', 'quater', 'circle', 'clockwise'])
# ('00097', ['a', 'person', 'walks', 'a', 'quarter', 'circle', 'to', 'the', 'right'])
# ('00097', ['a', 'person', 'turns', 'right'])
# ('00097', ['a', 'person', 'walks', 'slowly', 'a', 'right', 'curve'])
# ('00098', ['the', 'person', 'is', 'performing', 'a', 'forward', 'walk'])
# ('00098', ['a', 'person', 'is', 'walking', 'relaxed'])
# ('00098', ['a', 'person', 'is', 'walking', 'forward'])
# ('00098', ['a', 'person', 'walks', 'slowly', 'forwards'])
# ('00098', ['a', 'person', 'walks', 'forward'])
# ('00098', ['a', 'person', 'walks', 'forwards'])
# ('00099', ['a', 'person', 'walk', '5', 'steps', 'forward'])
# ('00099', ['a', 'human', 'is', 'slowly', 'moving', 'forward'])
# ('00099', ['a', 'person', 'takes', '4', 'steps', 'forward'])
# ('00099', ['a', 'person', 'takes', '4', 'forward', 'steps'])
# ('00100', ['a', 'person', 'walks', 'forward'])
# ('00101', ['a', 'person', 'walks', '2', 'meters', 'forward'])
# ('00101', ['a', 'person', 'is', 'walking'])
# ('00102', ['the', 'subject', 'walks', 'forward'])
# ('00102', ['person', 'walking', 'forwards'])
# ('00102', ['someone', 'walks', 'away'])
# ('00102', ['a', 'person', 'walks', 'forward'])
# ('00102', ['a', 'person', 'just', 'walks'])
# ('00102', ['a', 'person', 'walks', 'straight', 'forward', 'some', 'steps'])
# ('00102', ['a', 'person', 'walks', '5', 'steps', 'beginning', 'with', 'the', 'left', 'foot'])
# ('00103', ['someone', 'moves', 'forward', 'in', 'a', 'slow', 'walk'])
# ('00103', ['a', 'person', 'walks', 'slowly', 'forwards'])
# ('00104', ['a', 'person', 'walks', 'forward'])
# ('00105', ['a', 'person', 'walks', 'forward'])
# ('00105', ['human', 'goes', 'forward'])
# ('00106', ['a', 'human', 'looking', 'to', 'the', 'left', 'and', 'then', 'walking', 'forwards'])
# ('00106', ['a', 'person', 'walks', 'forwards'])
# ('00106', ['a', 'person', 'walks'])
# ('00107', ['a', 'human', 'walking', 'forward'])
# ('00108', ['a', 'person', 'walks', 'backwards'])
# ('00108', ['a', 'person', 'walks', 'backwards'])
# ('00108', ['a', 'person', 'walks', 'backwards', 'four', 'steps'])
# ('00108', ['a', 'person', 'is', 'stepping', 'back'])
# ('00108', ['slowly', 'backing', 'off'])
# ('00108', ['someone', 'is', 'doing', 'a', 'few', 'steps', 'backwards'])
# ('00108', ['person', 'walking', 'backwards'])
# ('00108', ['a', 'person', 'walks', 'four', 'steps', 'backwards'])
# ('00108', ['a', 'person', 'walks', '5', 'steps', 'backward'])
# ('00108', ['a', 'person', 'moves', 'backward', 'some', 'meters'])
# ('00108', ['a', 'human', 'is', 'walking', 'backwards', 'tilting', 'its', 'head', 'a', 'little', 'bit', 'beforehand'])
# ('00108', ['a', 'person', 'does', '4', 'steps', 'backwards'])
# ('00108', ['a', 'person', 'walking', 'backwards', 'while', 'moving', 'slightly', 'to', 'his', 'left'])
# ('00108', ['a', 'person', 'backing', 'away', 'from', 'something'])
# ('00108', ['human', 'goes', 'backwards'])
# ('00108', ['a', 'man', 'walks', 'backwards'])
# ('00109', ['a', 'person', 'walks', '4', 'steps', 'backwards'])
# ('00110', ['a', 'person', 'walks', 'backwards', ',', 'arms', 'swinging', 'by', 'his', 'side'])
# ('00110', ['human', 'goes', 'backwards', 'starting', 'with', 'left'])
# ('00110', ['a', 'person', 'walks', 'backwards'])
# ('00110', ['a', 'man', 'is', 'walking', 'backwards'])
# ('00111', ['a', 'person', 'walks', 'backward', 'at', 'medium', 'speed'])
# ('00111', ['a', 'person', 'walking', 'backwards'])
# ('00112', ['someone', 'walks', 'backwards'])
# ('00112', ['a', 'human', 'is', 'slowly', 'walking', 'backwards'])
# ('00112', ['a', 'person', 'walks', 'backwards'])
# ('00113', ['a', 'person', 'walks', 'four', 'steps', 'backward'])
# ('00113', ['human', 'goes', 'backwards'])
# ('00114', ['a', 'person', 'walking', 'backwards'])
# ('00114', ['a', 'person', 'walking', 'backwards'])
# ('00114', ['someone', 'walks', 'backwards'])
# ('00114', ['a', 'person', 'walks', 'backwards'])
# ('00114', ['human', 'slowly', 'goes', 'backwards'])
# ('00116', ['a', 'persons', 'walks', 'backward', 'with', 'medium', 'speed'])
# ('00116', ['someone', 'is', 'walking', 'backwards', 'starting', 'with', 'the', 'left', 'leg'])
# ('00116', ['a', 'person', 'walds', 'backwards', 'some', 'steps'])
# ('00116', ['walking', 'backwards', 'for', 'a', 'few', 'steps'])
# ('00116', ['a', 'person', 'walks', 'backwards'])
# ('00116', ['a', 'person', 'walks', 'backwards', 'for', 'five', 'steps'])
# ('00117', ['a', 'person', 'walks', 'backwards'])
# ('00118', ['human', 'walks', 'in', 'a', 'circle', 'counterclockwise'])
# ('00118', ['someone', 'is', 'walking', 'in', 'a', 'circle', 'counterclockwise'])
# ('00118', ['a', 'person', 'walks', 'in', 'a', 'circle', 'to', 'the', 'left'])
# ('00119', ['a', 'person', 'walks', 'in', 'a', 'circle', 'to', 'the', 'left'])
# ('00119', ['somebody', 'walks', 'a', '7/8', 'circle', 'anticlockwise'])
# ('00120', ['a', 'person', 'walks', 'counterclockwise', 'in', 'a', 'small', 'circle'])
# ('00121', ['a', 'person', 'walks', 'counter-clockwise', 'in', 'an', 'incomplete', 'circle', 'and', 'stops', 'facing', 'to', 'the', 'right', 'relative', 'to', 'the', 'starting', 'position'])
# ('00121', ['the', 'human', 'walks', 'a', 'circle'])
# ('00122', ['a', 'person', 'walks', 'counterclockwise', 'in', 'a', 'small', 'circle'])
# ('00122', ['a', 'person', 'walks', 'counte', 'clockwise', 'in', 'a', 'circle'])
# ('00122', ['a', 'person', 'walks', 'in', 'a', 'circle'])
# ('00123', ['a', 'person', 'walks', 'in', 'a', 'circle', 'counter-clockwise'])
# ('00124', ['a', 'human', 'walks', 'in', 'a', 'full', 'circle'])
# ('00124', ['a', 'persons', 'walks', 'in', 'a', 'circle', 'to', 'the', 'left'])
# ('00125', ['a', 'person', 'walks', 'in', 'a', 'circle', 'counterclockwise'])
# ('00125', ['the', 'human', 'walks', 'a', 'circle'])
# ('00126', ['a', 'human', 'walking', 'in', 'a', 'circle', 'counterclockwise'])
# ('00126', ['a', 'person', 'walks', 'in', 'a', 'circle', 'to', 'the', 'left'])
# ('00127', ['a', 'person', 'moves', 'in', 'a', 'circle', 'counterclockwise'])
# ('00128', ['a', 'human', 'walking', 'in', 'a', 'circle', 'clockwise'])
# ('00129', ['a', 'person', 'walks', 'in', 'a', 'clockwise', 'circle'])
# ('00129', ['a', 'human', 'performs', 'a', 'full', '360', '°', 'curve', 'to', 'the', 'right', ',', 'ending', 'where', 'it', 'started'])
# ('00130', ['a', 'person', 'walks', 'in', 'a', 'small', 'circle', ',', 'to', 'the', 'right'])
# ('00130', ['human', 'goes', 'in', 'a', 'circle', 'clockwise', 'starting', 'with', 'right'])
# ('00130', ['a', 'person', 'walks', 'in', 'a', 'circle', 'to', 'the', 'right'])
# ('00130', ['person', 'walking', 'in', 'a', 'circle'])
# ('00131', ['a', 'person', 'walks', 'a', 'full', 'circle'])
# ('00131', ['a', 'person', 'walks', 'a', 'circle', 'to', 'the', 'right'])
# ('00132', ['person', 'walking', 'in', 'a', 'circle'])
# ('00132', ['someone', 'walks', 'in', 'a', 'clockwise', 'circle'])
# ('00133', ['a', 'human', 'walking', 'in', 'a', 'circle', 'clockwise'])
# ('00133', ['a', 'person', 'walks', 'a', 'circle', 'to', 'the', 'right'])
# ('00134', ['a', 'person', 'walks', 'a', 'circle', 'clockwise'])
# ('00134', ['a', 'person', 'walks', 'a', 'circle', 'to', 'the', 'right'])
# ('00135', ['a', 'person', 'walks', 'clockwise', 'in', 'a', 'circle'])
# ('00136', ['a', 'human', 'walking', 'in', 'a', 'circle', 'clockwise'])
# ('00136', ['a', 'person', 'is', 'walking', 'in', 'a', 'circle', 'clockwise'])
# ('00136', ['a', 'human', 'goes', 'around', 'the', 'circle', 'clockwise'])
# ('00136', ['someone', 'walks', 'a', 'larger', 'clockwise'])
# ('00136', ['a', 'person', 'walks', 'in', 'a', 'circle', 'to', 'the', 'right'])
# ('00137', ['a', 'person', 'walks', 'clockwise', 'in', 'a', 'small', 'circle'])
# ('00138', ['the', 'human', 'walks', 'a', 'left', 'bend'])
# ('00139', ['a', 'human', 'walks', 'and', 'turns', 'to', 'the', 'left'])
# ('00139', ['a', 'person', 'is', 'walking', 'in', 'a', 'curve', 'to', 'left'])
# ('00139', ['a', 'person', 'turns', 'left'])
# ('00140', ['a', 'human', 'is', 'making', 'a', 'counter-clockwise', 'turn'])
# ('00140', ['a', 'person', 'is', 'walking', 'a', 'quarter', 'counter-clockwise', 'circle'])
# ('00140', ['a', 'person', 'walks', 'to', 'the', 'left', 'performin', 'a', 'quater', 'circle'])
# ('00140', ['a', 'person', 'turns', 'left'])
# ('00141', ['a', 'person', 'starts', 'walking', 'in', 'a', 'circular', 'motion', 'towards', 'the', 'left'])
# ('00141', ['a', 'person', 'walks', 'a', '90', 'degree', 'curve', 'to', 'the', 'left'])
# ('00141', ['a', 'person', 'walks', 'in', 'a', 'quarter', 'circle'])
# ('00142', ['a', 'person', 'walks', 'around', 'a', 'corner'])
# ('00142', ['a', 'person', 'walks', 'and', 'turns', '90', 'degrees', 'to', 'the', 'left'])
# ('00142', ['a', 'person', 'walks', 'a', 'quarter', 'circle', 'to', 'the', 'left'])
# ('00143', ['a', 'person', 'turns', '90', '°', 'to', 'the', 'left', 'at', 'medium', 'speed'])
# ('00144', ['a', 'person', 'walks', 'a', 'quarter', 'of', 'a', 'small', 'circle', 'counterclockwise'])
# ('00144', ['subject', 'walks', 'in', 'a', 'quarter', 'circle', 'counterclockwise'])
# ('00144', ['some', 'walks', 'a', 'quarter', 'circle', 'to', 'the', 'left'])
# ('00145', ['a', 'person', 'walks', 'and', 'turns', 'to', 'the', 'left'])
# ('00145', ['a', 'person', 'walks', 'in', 'a', 'quarter-circle'])
# ('00145', ['a', 'human', 'performing', 'a', 'u-turn'])
# ('00145', ['a', 'person', 'is', 'walking', 'two', 'meters', 'straight', ',', 'than', 'one', 'step', 'to', 'the', 'left'])
# ('00145', ['a', 'person', 'walks', 'along', 'and', 'turns', 'to', 'the', 'left'])
# ('00145', ['a', 'person', 'walks', 'a', 'curve', 'to', 'the', 'left'])
# ('00145', ['someone', 'is', 'walking', 'a', 'quarter', 'round', 'to', 'his', 'left', 'side'])
# ('00145', ['a', 'person', 'walks', 'a', '90', 'degree', 'turn', 'towards', 'the', 'left'])
# ('00145', ['a', 'person', 'first', 'walks', 'and', 'then', 'turns', 'to', 'the', 'left'])
# ('00145', ['a', 'person', 'walks', 'to', 'the', 'left'])
# ('00145', ['a', 'human', 'is', 'walking', 'in', 'a', '90', '°', 'right', 'curve'])
# ('00145', ['someone', 'walks', 'in', 'a', 'quarter', 'circle', 'to', 'the', 'left'])
# ('00146', ['a', 'human', 'turning', 'left'])
# ('00146', ['a', 'person', 'walks', 'a', 'left', 'turn', 'of', '90', 'degrees'])
# ('00147', ['a', 'person', 'walks', 'forwards', ',', 'slowly', 'turning', 'to', 'the', 'left', 'and', 'stops'])
# ('00147', ['someone', 'walks', 'a', 'left', 'turn'])
# ('00147', ['a', 'person', 'turns', 'left'])
# ('00148', ['a', 'person', 'walks', 'in', 'a', 'quarter', 'circle', 'clockwise', 'with', '4', 'steps'])
# ('00148', ['a', 'person', 'walks', 'a', 'quarter', ',', 'right', 'sided', 'circle'])
# ('00149', ['a', 'person', 'walks', 'a', 'quarter', 'circle', 'clockwise', 'with', '4', 'steps'])
# ('00149', ['human', 'performs', 'a', 'bending', 'walking', 'movement', 'to', 'the', 'right'])
# ('00150', ['a', 'person', 'walks', 'forward', 'while', 'gradually', 'turning', 'to', 'the', 'right'])
# ('00151', ['a', 'person', 'is', 'turning', 'right'])
# ('00151', ['a', 'human', 'is', 'walking', 'in', 'a', 'quarter', 'of', 'a', 'circle', 'to', 'the', 'right'])
# ('00151', ['a', 'human', 'is', 'performing', 'a', '90', '°', 'right', 'curve'])
# ('00152', ['person', 'walking', 'to', 'the', 'right'])
# ('00152', ['a', 'person', 'walks', 'and', 'turns', 'right'])
# ('00152', ['a', 'person', 'walks', 'to', 'the', 'right'])
# ('00153', ['a', 'person', 'goes', 'to', 'the', 'right', 'slowly'])
# ('00153', ['a', 'person', 'walks', 'a', 'right', 'curve'])
# ('00154', ['a', 'person', 'turns', 'right', 'at', 'medium', 'speed'])
# ('00154', ['a', 'person', 'walks', 'to', 'the', 'right', 'in', 'a', 'quter', 'circle'])
# ('00155', ['a', 'person', 'turns', 'right'])
# ('00155', ['a', 'person', 'slowly', 'walks', 'a', '90', '°', 'turn', 'in', 'four', 'steps'])
# ('00156', ['the', 'person', 'is', 'first', 'walking', 'ahead', 'and', 'then', 'turning', 'to', 'the', 'right'])
# ('00157', ['a', 'person', 'turns', 'right'])
# ('00158', ['person', 'walking', 'forwards'])
# ('00158', ['someone', 'walks', 'slowly'])
# ('00158', ['a', 'person', 'walks', 'forward'])
# ('00158', ['a', 'human', 'takes', 'slow', 'steps', 'forward'])
# ('00158', ['a', 'person', 'walks', 'forward'])
# ('00159', ['a', 'person', 'is', 'walking', 'slowly', 'and', 'stops'])
# ('00159', ['a', 'person', 'walks', 'forward'])
# ('00160', ['a', 'person', 'walks', 'forward'])
# ('00160', ['someone', 'walks', 'forward'])
# ('00161', ['a', 'person', 'goes', 'slowly', '5', 'steps', 'forward'])
# ('00161', ['a', 'person', 'walks', 'slowly', 'forward'])
# ('00161', ['a', 'person', 'slowly', 'walks', '4', 'steps', 'forwards'])
# ('00162', ['a', 'person', 'walks', '4', 'steps', 'forward'])
# ('00162', ['a', 'person', 'walks', '4', 'steps'])
# ('00163', ['a', 'person', 'walks', 'forward'])
# ('00163', ['a', 'person', 'walks', 'a', 'few', 'steps', 'forwards'])
# ('00164', ['a', 'person', 'walks', 'forward'])
# ('00164', ['a', 'person', 'walks', '4', 'steps', 'forward'])
# ('00165', ['someone', 'walks', 'forward'])
# ('00165', ['a', 'person', 'takes', '5', 'steps', 'forward'])
# ('00165', ['a', 'person', 'walks', 'forwards', 'quite', 'slow'])
# ('00166', ['a', 'human', 'walking', 'slowly'])
# ('00167', ['the', 'person', 'is', 'walking', 'forward'])
# ('00167', ['the', 'human', 'perfoms', 'a', 'couple', 'of', 'steps'])
# ('00167', ['a', 'person', 'walks', 'forward'])
# ('00168', ['a', 'human', 'goes', 'slowly', '5', 'steps', 'backward'])
# ('00168', ['a', 'person', 'takes', '5', 'steps', 'backwards', 'staring', 'with', 'the', 'left', 'foot'])
# ('00168', ['a', 'person', 'walks', 'backwards'])
# ('00168', ['a', 'person', 'walks', 'five', 'steps', 'backwards'])
# ('00169', ['a', 'person', 'walking', 'backwards', '4', 'steps', 'with', 'relatively', 'small', 'steps'])
# ('00169', ['a', 'person', 'takes', '4', 'steps', 'backwards', 'starting', 'with', 'the', 'left', 'foot'])
# ('00169', ['a', 'person', 'takes', 'five', 'backward', 'steps'])
# ('00170', ['the', 'person', 'is', 'walking', 'backwards'])
# ('00170', ['a', 'person', 'walkes', 'backward'])
# ('00171', ['a', 'person', 'walks', 'slowly', 'five', 'steps', 'backwards'])
# ('00171', ['a', 'person', 'is', 'walking', 'backwards'])
# ('00171', ['someone', 'walks', 'backwards'])
# ('00172', ['a', 'person', 'goes', 'back', '4', 'steps'])
# ('00173', ['a', 'human', 'walking', 'backwards'])
# ('00173', ['a', 'person', 'steps', 'backwards'])
# ('00173', ['a', 'person', 'takes', 'some', 'steps', 'backwards'])
# ('00174', ['a', 'person', 'takes', 'four', 'steps', 'back'])
# ('00174', ['a', 'person', 'walks', 'back', 'some', 'meters'])
# ('00175', ['a', 'person', 'walks', '4', 'steps', 'to', 'the', 'backward', 'direction'])
# ('00175', ['a', 'person', 'makes', '4', 'steps', 'backwards'])
# ('00175', ['a', 'person', 'walks', 'backwards'])
# ('00175', ['a', 'person', 'slowly', 'retreats'])
# ('00175', ['someone', 'walks', 'backwards'])
# ('00176', ['a', 'person', 'walks', 'a', 'few', 'steps', 'backwards'])
# ('00176', ['a', 'person', 'walks', 'backwards', 'about', '4', 'steps'])
# ('00177', ['a', 'person', 'walks', 'backwards'])
# ('00177', ['someone', 'walks', 'backward'])
# ('00177', ['a', 'person', 'walks', 'backwards'])
# ('00177', ['a', 'person', 'slowly', 'walks', 'backward'])
# ('00177', ['a', 'person', 'walks', '5', 'steps', 'backwards'])
# ('00177', ['a', 'person', 'taking', 'a', 'few', 'steps', 'backwards'])
# ('00178', ['a', 'human', 'walking', 'in', 'circles'])
# ('00178', ['a', 'person', 'walks', 'in', 'a', 'counter-clockwise', 'circle'])
# ('00178', ['some', 'walks', 'anticlockwise'])
# ('00178', ['a', 'person', 'walks', 'in', 'a', 'circle', 'to', 'the', 'left'])
# ('00179', ['a', 'person', 'walks', 'around', 'in', 'a', 'circle', 'anti-clockwise'])
# ('00179', ['someone', 'walks', 'in', 'a', 'circle', 'counterclockwise'])
# ('00179', ['a', 'person', 'walks', 'in', 'a', 'circle', 'to', 'the', 'left', 'taking', '8', 'steps'])
# ('00180', ['a', 'person', 'walks', 'in', 'a', 'circle', 'to', 'the', 'left'])
# ('00180', ['a', 'person', 'is', 'walking', 'in', 'a', 'circle', 'counter-clockwise'])
# ('00180', ['a', 'human', 'is', 'walking', 'in', 'circle'])
# ('00181', ['a', 'person', 'walks', 'in', 'a', 'small', 'circle', 'counterclockwise'])
# ('00181', ['a', 'human', 'walks', 'in', 'circles', 'counterclockwise', 'making', 'long', 'steps'])
# ('00182', ['a', 'person', 'walks', 'clockwise', 'in', 'a', 'circle'])
# ('00183', ['a', 'person', 'walks', 'in', 'circles'])
# ('00183', ['a', 'person', 'walks', 'forward', 'counterclockwise', 'in', 'a', 'circle'])
# ('00183', ['a', 'person', 'walks', 'in', 'a', 'circle', 'to', 'the', 'left'])
# ('00184', ['a', 'person', 'walks', 'slowly', 'in', 'a', 'counterclockwise', 'small', 'circle'])
# ('00185', ['a', 'human', 'walks', 'in', 'a', 'counter-clockwise', 'circle'])
# ('00186', ['a', 'person', 'walks', 'a', 'circle'])
# ('00186', ['subject', 'walks', 'in', 'a', 'circle', 'counterclockwise'])
# ('00187', ['a', 'person', 'walking', 'in', 'a', 'circle', 'to', 'the', 'left'])
# ('00188', ['a', 'person', 'walks', 'in', 'a', 'clockwise', 'circle'])
# ('00189', ['a', 'human', 'is', 'walking', 'clockwise', 'in', 'a', 'circle'])
# ('00189', ['a', 'person', 'walks', 'a', 'circle', 'to', 'the', 'right'])
# ('00190', ['a', 'person', 'walks', 'a', 'circle'])
# ('00191', ['someone', 'walks', 'a', 'clockwise', 'circle'])
# ('00191', ['a', 'person', 'is', 'walking', 'a', 'clockwise', 'circle'])
# ('00191', ['a', 'person', 'walks', 'in', 'a', 'circle'])
# ('00191', ['a', 'human', 'is', 'walking', 'in', 'circle', 'to', 'the', 'right'])
# ('00192', ['the', 'person', 'is', 'walking', 'in', 'a', 'circular', 'shape'])
# ('00192', ['person', 'walks', 'a', 'circle'])
# ('00193', ['a', 'person', 'walks', 'in', 'a', 'circle', 'clockwise'])
# ('00194', ['someone', 'is', 'walking', 'a', 'small', 'clockwise', 'circle'])
# ('00194', ['a', 'person', 'walks', 'in', 'circle', 'to', 'his', 'right', 'side'])
# ('00194', ['a', 'person', 'walks', 'in', 'a', 'circle', 'to', 'the', 'right'])
# ('00195', ['a', 'person', 'walks', 'a', 'circle', 'clockwise'])
# ('00196', ['someone', 'walks', 'in', 'a', 'clockwise', 'circle'])
# ('00196', ['human', 'goes', 'in', 'a', 'circle', 'clockwise', 'starting', 'with', 'right'])
# ('00197', ['a', 'person', 'walking', 'in', 'a', 'circle', 'to', 'the', 'right'])
# ('00197', ['a', 'person', 'walks', 'in', 'a', 'cirlce', 'to', 'the', 'right'])
# ('00198', ['a', 'person', 'goes', 'to', 'the', 'right'])
# ('00199', ['the', 'human', 'walks', 'a', 'right', 'bend'])
# ('00199', ['somone', 'walks', 'in', 'a', 'quarter', 'circle', 'to', 'the', 'right'])
# ('00200', ['someone', 'walks', 'in', 'a', 'slight', 'right', 'curve'])
# ('00201', ['person', 'walking', 'to', 'the', 'right'])
# ('00201', ['human', 'goes', 'in', 'a', 'quarter', 'circle', 'clockwise', 'starting', 'with', 'right'])
# ('00202', ['a', 'person', 'is', 'walking', 'forward', 'starting', 'with', 'the', 'right', 'feet', 'and', 'performing', 'five', 'steps', 'while', 'turning', 'to', 'the', 'right', 'with', 'an', 'angle', 'of', '90', '°'])
# ('00202', ['a', 'person', 'walks', 'in', 'a', 'quarter', 'circle', 'to', 'the', 'right'])
# ('00203', ['a', 'person', 'walks', 'a', 'quarter', 'circle', 'to', 'the', 'right'])
# ('00204', ['a', 'person', 'turns', '90', '°', 'to', 'the', 'right', 'at', 'medium', 'speed'])
# ('00204', ['a', 'person', 'is', 'turning', 'right', 'while', 'walking'])
# ('00205', ['a', 'person', 'walks', 'to', 'the', 'right'])
# ('00206', ['a', 'human', 'is', 'making', 'a', 'clockwise', 'turn'])
# ('00206', ['a', 'person', 'is', 'walking', 'a', 'quarter', 'circle', 'in', 'clockwise', 'direction'])
# ('00207', ['a', 'person', 'turns', 'right'])
# ('00207', ['a', 'person', 'walks', 'a', 'quarter', 'circle', 'clockwise', 'with', '4', 'steps'])
# ('00207', ['a', 'person', 'walks', 'a', '90', '°', 'curve', 'to', 'his', 'right'])
# ('00207', ['someone', 'turns', 'right'])
# ('00208', ['a', 'person', 'walks', 'forward', 'very', 'slowly'])
# ('00208', ['subject', 'walks', 'forward', 'slowly'])
# ('00208', ['a', 'person', 'walks', 'forward', 'quite', 'slow'])
# ('00209', ['a', 'person', 'walks', 'slowly', 'and', 'stops'])
# ('00209', ['a', 'person', 'walks', 'straight', 'forwards', 'for', 'some', 'meters'])
# ('00210', ['a', 'person', 'walks', '4', 'steps', 'forward'])
# ('00211', ['subject', 'walks', 'forward'])
# ('00211', ['a', 'person', 'starts', 'walking', '4', 'steps', 'forward', 'and', 'then', 'stops'])
# ('00212', ['a', 'person', 'walking', 'a', 'few', 'steps'])
# ('00213', ['a', 'human', 'walks', 'at', 'a', 'slight', 'left', 'angle', 'for', 'five', 'steps', 'and', 'then', 'stops'])
# ('00213', ['someone', 'walks', 'forward'])
# ('00214', ['a', 'person', 'walks', '4', 'steps', 'forward'])
# ('00215', ['a', 'person', 'walks', 'forwards'])
# ('00216', ['a', 'person', 'walking', 'a', 'few', 'steps', 'forward'])
# ('00217', ['a', 'person', 'walking', 'forwards', 'for', 'a', 'few', 'steps'])
# ('00217', ['a', 'person', 'walks', 'forwards'])
# ('00218', ['person', 'walking', 'backwards'])
# ('00218', ['human', 'goes', 'backwards', 'starting', 'with', 'left'])
# ('00218', ['a', 'person', 'is', 'walking', 'backwards'])
# ('00218', ['a', 'person', 'walks', 'backwards'])
# ('00219', ['someone', 'walks', 'slowly', 'backwards'])
# ('00219', ['a', 'person', 'walks', 'backwards'])
# ('00219', ['a', 'person', 'slowly', 'walks', 'back', 'taking', '4', 'steps'])
# ('00222', ['a', 'person', 'moves', 'backwards'])
# ('00223', ['a', 'person', 'walks', 'backwards'])
# ('00223', ['a', 'person', 'walks', 'backwards'])
# ('00224', ['someone', 'walks', 'backwards', 'four', 'steps'])
# ('00224', ['a', 'person', 'walks', 'backward'])
# ('00225', ['a', 'person', 'walks', 'backwards'])
# ('00225', ['human', 'goes', 'backwards'])
# ('00225', ['a', 'person', 'walks', 'a', 'few', 'steps', 'backward'])
# ('00225', ['somebody', 'walks', 'backwards'])
# ('00226', ['a', 'person', 'walks', 'backwards'])
# ('00227', ['subject', 'walks', 'in', 'a', 'full', 'circle', 'counterclockwise'])
# ('00227', ['the', 'human', 'walks', 'a', 'circle'])
# ('00228', ['person', 'walking', 'in', 'a', 'circle'])
# ('00228', ['a', 'person', 'walks', 'in', 'a', 'counter-clockwise', 'circle'])
# ('00228', ['a', 'person', 'walks', 'in', 'a', 'circle', 'to', 'the', 'left'])
# ('00228', ['a', 'person', 'moves', 'anti-clockwise', 'in', 'a', 'cirle', 'and', 'needs', '8', 'steps', 'to', 'complete', 'the', 'circle'])
# ('00228', ['a', 'person', 'walks', 'in', 'a', 'small', 'circle'])
# ('00229', ['a', 'person', 'walks', 'in', 'a', 'narrow', 'counter-clockwise', 'circle'])
# ('00229', ['subject', 'in', 'small', 'circle', 'counterclockwise'])
# ('00229', ['someone', 'slowly', 'walks', 'in', 'a', 'small', 'circle', 'to', 'the', 'left'])
# ('00229', ['someone', 'walks', 'a', 'circle'])
# ('00229', ['a', 'human', 'walks', 'slowly', 'in', 'circles', ',', 'counterclockwise'])
# ('00229', ['a', 'human', 'goes', 'a', 'circle', 'left', 'around'])
# ('00230', ['subject', 'walks', 'in', 'a', 'quarter', 'circle', 'counterclockwise'])
# ('00230', ['a', 'person', 'is', 'walking', 'in', 'a', 'circle'])
# ('00231', ['a', 'person', 'walks', 'counter-clockwise', 'in', 'a', 'circle'])
# ('00231', ['a', 'person', 'walks', 'in', 'a', 'circle'])
# ('00231', ['somebody', 'walks', 'a', 'circle', 'anticlockwise'])
# ('00232', ['walk', 'in', 'a', 'circle'])
# ('00232', ['a', 'person', 'walks', 'a', 'circle', 'in', 'the', 'left', 'direction'])
# ('00232', ['a', 'person', 'walks', 'in', 'a', 'circle'])
# ('00233', ['the', 'person', 'make', 'a', 'walk', 'along', 'a', 'circular', 'path'])
# ('00233', ['someone', 'is', 'walking', 'in', 'a', 'circle', 'counterclockwise'])
# ('00233', ['a', 'person', 'walks', 'a', 'circle', 'to', 'the', 'left'])
# ('00233', ['a', 'person', 'is', 'walking', 'in', 'a', 'circle'])
# ('00234', ['a', 'person', 'moves', 'in', 'a', 'circle'])
# ('00235', ['a', 'person', 'moves', 'in', 'a', 'circle', 'clockwise'])
# ('00235', ['a', 'human', 'walks', 'a', 'small', 'circle', 'to', 'its', 'left'])
# ('00236', ['a', 'person', 'walks', 'in', 'a', 'small', 'circle', 'counter', 'clockwise'])
# ('00237', ['a', 'human', 'walking', 'in', 'a', 'circle', 'clockwise'])
# ('00237', ['a', 'person', 'walks', 'a', 'full', 'circle', 'to', 'the', 'right'])
# ('00238', ['subject', 'walks', 'in', 'a', 'circle', 'clockwise'])
# ('00239', ['a', 'person', 'walking', 'slowly', 'in', 'a', 'circle', 'to', 'the', 'right'])
# ('00239', ['a', 'person', 'walks', 'forward', 'in', 'a', 'circle', 'clockwise'])
# ('00239', ['a', 'person', 'walks', 'in', 'a', 'circle', 'to', 'the', 'right'])
# ('00240', ['a', 'person', 'walks', 'in', 'circles'])
# ('00240', ['a', 'person', 'is', 'walking', 'in', 'a', 'clockwise', 'circle'])
# ('00241', ['a', 'person', 'walks', 'in', 'a', 'circle'])
# ('00241', ['someone', 'goes', 'around', 'in', 'a', 'circuit'])
# ('00241', ['a', 'person', 'walks', 'in', 'a', 'circle', 'to', 'the', 'right'])
# ('00241', ['a', 'human', 'is', 'performing', 'a', 'right', '360', '°', 'curve'])
# ('00242', ['a', 'person', 'walks', 'in', 'a', 'circle'])
# ('00243', ['subject', 'walks', 'in', 'a', 'circle', 'clockwise'])
# ('00243', ['a', 'person', 'walks', 'clockwise', 'forward', 'in', 'a', 'circle'])
# ('00244', ['a', 'person', 'walks', 'slowly', 'in', 'a', 'circle', 'in', 'clockwise', 'direction'])
# ('00244', ['a', 'human', 'walks', 'slowly', 'a', 'full', 'circle', 'to', 'its', 'right', 'and', 'ends', 'up', 'on', 'the', 'spot', 'where', 'it', 'started'])
# ('00245', ['a', 'person', 'walks', 'in', 'a', 'clockwise', 'circle'])
# ('00245', ['a', 'person', 'walks', 'in', 'a', 'little', 'circle'])
# ('00245', ['a', 'person', 'walks', 'forward', 'in', 'a', 'circle', 'clockwise'])
# ('00246', ['a', 'person', 'performs', 'a', 'circular', 'movement'])
# ('00246', ['walking', 'in', 'a', 'circle', 'to', 'the', 'right'])
# ('00247', ['someone', 'walks', 'a', 'quarter-circle', 'to', 'the', 'right'])
# ('00247', ['a', 'person', 'slowly', 'walks', 'a', 'quarter', 'ride', 'sided', 'circle'])
# ('00248', ['a', 'human', 'walks', 'and', 'turns', 'to', 'the', 'right'])
# ('00248', ['someone', 'walks', 'a', 'right', 'turn'])
# ('00248', ['a', 'person', 'walks', 'to', 'the', 'right'])
# ('00249', ['a', 'human', 'is', 'making', 'a', 'clockwise', 'turn'])
# ('00249', ['a', 'person', 'walks', 'to', 'the', 'right'])
# ('00250', ['a', 'person', 'turns', 'left', 'at', 'medium', 'speed'])
# ('00251', ['a', 'human', 'walks', 'a', '90', 'degree', 'arc', 'to', 'the', 'right'])
# ('00251', ['someone', 'walks', 'a', 'circle', 'clockwise'])
# ('00251', ['a', 'person', 'walks', 'a', 'circle'])
# ('00252', ['a', 'person', 'starts', 'a', 'circular', 'movement', 'towards', 'the', 'right'])
# ('00252', ['someone', 'walks', 'a', 'right', 'turn'])
# ('00253', ['a', 'person', 'turns', 'around', 'a', 'corner', 'towards', 'the', 'right'])
# ('00253', ['a', 'person', 'walks', 'a', '90', 'degree', 'curve', 'to', 'the', 'right'])
# ('00254', ['a', 'person', 'walks', 'a', 'left', 'turn'])
# ('00254', ['a', 'person', 'turns', 'to', 'his', 'right'])
# ('00254', ['human', 'performs', 'a', 'bending', 'walking', 'motion', 'to', 'its', 'right', 'hand', 'side'])
# ('00255', ['someone', 'walks', 'a', 'quarter-circle', 'to', 'the', 'right'])
# ('00255', ['someone', 'walks', 'a', 'right', 'turn'])
# ('00255', ['a', 'human', 'performs', 'a', '90', '°', 'curve', 'tu', 'the', 'right'])
# ('00255', ['a', 'human', 'walks', 'a', 'quarter', 'to', 'his', 'right'])
# ('00255', ['a', 'person', 'turns', 'right'])
# ('00256', ['a', 'person', 'walks', 'forward', 'and', 'performs', 'a', 'turn', 'to', 'the', 'right'])
# ('00256', ['a', 'person', 'walks', 'in', 'a', 'quarter-circle', 'to', 'the', 'right'])
# ('00256', ['a', 'person', 'walks', 'towards', 'me'])
# ('00256', ['someone', 'comes', 'close', 'to', 'the', 'camera'])
# ('00256', ['a', 'person', 'is', 'walking', 'in', 'a', 'curve', 'to', 'the', 'right'])
# ('00256', ['someone', 'comes', 'very', 'close', 'to', 'the', 'observer'])
# ('00256', ['a', 'human', 'takes', 'a', '90', 'degree', 'right', 'turn'])
# ('00256', ['a', 'person', 'walking', 'five', 'steps', 'to', 'the', 'right'])
# ('00256', ['a', 'person', 'walks', 'slowly', 'a', 'curve'])
# ('00256', ['a', 'person', 'walks', 'in', 'a', '90', 'degree', 'turn', 'towards', 'the', 'right'])
# ('00256', ['a', 'human', 'slowly', 'turns', 'right', 'by', '5', 'steps'])
# ('00256', ['a', 'person', 'walks', 'a', 'quarter', 'circle', 'with', 'a', 'radius', 'of', 'approximately', '1', 'meter', 'to', 'the', 'right'])
# ('00256', ['a', 'human', 'is', 'performing', 'a', '90', '°', 'curve', 'to', 'the', 'right'])
# ('00256', ['a', 'person', 'is', 'walking', 'a', 'quarter', 'of', 'a', 'circle', 'to', 'its', 'right'])
# ('00256', ['a', 'person', 'walks', 'to', 'the', 'right', 'performing', 'a', 'quarter', 'circle'])
# ('00256', ['a', 'person', 'walks', 'forward', 'in', 'a', '90', '°', 'curve', 'to', 'his', 'right'])
# ('00256', ['the', 'human', 'perfoms', 'a', 'right', 'turn'])
# ('00256', ['a', 'person', 'is', 'doing', 'slow', 'a', '90', '°', 'right', 'turn', 'in', 'five', 'steps'])
# ('00256', ['human', 'performs', 'a', 'bending', 'walking', 'motion', 'to', 'the', 'right'])
# ('00257', ['a', 'person', 'starts', 'a', 'circular', 'movement', 'towards', 'the', 'left'])
# ('00257', ['human', 'slowly', 'goes', 'in', 'a', 'quater', 'circle', 'counterclockwise', 'starting', 'with', 'right'])
# ('00258', ['a', 'man', 'walks', 'a', 'quarter', 'of', 'a', 'circle', 'towards', 'the', 'left'])
# ('00258', ['human', 'goes', 'in', 'a', 'quarter', 'circle', 'counterclockwise', 'starting', 'with', 'right'])
# ('00258', ['a', 'human', 'walks', 'slowly', 'a', 'quarter', 'of', 'a', 'circle', 'to', 'its', 'left'])
# ('00259', ['a', 'person', 'walks', 'while', 'gradually', 'turning', 'to', 'the', 'left'])
# ('00260', ['the', 'human', 'walks', 'a', '90', '-', 'degree', 'left', 'bend'])
# ('00260', ['a', 'person', 'walking', 'to', 'the', 'left'])
# ('00260', ['a', 'person', 'turns', 'left'])
# ('00260', ['someone', 'is', 'walking', 'half', 'a', 'round', 'to', 'his', 'left', 'side'])
# ('00260', ['a', 'person', 'walks', 'and', 'turns', 'to', 'the', 'left'])
# ('00260', ['a', 'person', 'walks', 'a', 'quarter', 'circle', 'with', 'a', 'radius', 'of', 'approximately', '1', 'meter', 'to', 'the', 'left'])
# ('00260', ['a', 'person', 'walks', 'to', 'the', 'left', 'in', 'a', 'quater', 'circle'])
# ('00260', ['a', 'person', 'walking', 'forward', 'in', 'a', '90', '°', 'curve'])
# ('00260', ['the', 'human', 'perfoms', 'a', 'left', 'turn'])
# ('00262', ['a', 'person', 'walks', 'a', 'quarter', 'circle', 'counter', 'clockwise', 'with', '4', 'steps'])
# ('00262', ['a', 'person', 'is', 'taking', 'a', 'left', 'turn', 'while', 'walking'])
# ('00262', ['a', 'person', 'walks', 'a', '90', 'degree', 'curve', 'to', 'the', 'left'])
# ('00263', ['someone', 'performs', 'a', 'slow', 'move', 'around', 'a', 'corner', 'to', 'the', 'left'])
# ('00263', ['the', 'human', 'perfoms', 'a', 'left', 'turn'])
# ('00264', ['a', 'human', 'turning', 'left'])
# ('00265', ['a', 'erson', 'walks', 'in', 'a', 'quarter', 'circle'])
# ('00265', ['a', 'person', 'walks', 'to', 'the', 'left', 'performing', 'a', 'quater', 'circle'])
# ('00265', ['a', 'person', 'walks', 'in', 'a', '90', '°', 'curve', 'to', 'his', 'left'])
# ('00266', ['a', 'person', 'turns', 'left'])
# ('00266', ['someone', 'left', 'something', 'on', 'the', 'ground', 'when', 'he', 'walks', 'a', 'corner'])
# ('00267', ['the', 'person', 'is', 'walking', 'backwards'])
# ('00267', ['a', 'person', 'walks', 'backwards'])
# ('00268', ['a', 'person', 'is', 'walking', 'backwards'])
# ('00268', ['a', 'person', 'walks', '5', 'steps', 'backwards'])
# ('00269', ['a', 'person', 'is', 'walking', 'backwards'])
# ('00269', ['a', 'person', 'walks', 'backward'])
# ('00269', ['someone', 'walks', 'backwards', '4', 'steps', 'starting', 'with', 'the', 'left', 'leg'])
# ('00269', ['the', 'human', 'perfoms', 'a', 'couple', 'of', 'steps', 'backwards'])
# ('00269', ['human', 'goes', 'backwards', 'at', 'medium', 'velocity'])
# ('00270', ['a', 'person', 'takes', 'four', 'steps', 'back'])
# ('00270', ['a', 'person', 'does', '4', 'steps', 'backwards', 'slowly'])
# ('00271', ['a', 'subject', 'is', 'walking', 'backward', 'four', 'steps'])
# ('00271', ['a', 'person', 'is', 'walking', 'backwards'])
# ('00272', ['a', 'person', 'is', 'walking', 'backwards'])
# ...
# ('03606', ['person', 'cautiously', 'walking', 'through', 'uneven', ',', 'wiggly', 'terrain', ',', 'possibly', 'stones', 'under', 'water'])
# ('03607', ['a', 'person', 'slowly', 'walks', 'approximately', '4', 'meters', 'forward'])
# ('03611', ['a', 'person', 'makes', 'a', 'far', 'jump'])
# ('03614', ['a', 'person', 'jumps', 'with', 'both', 'legs', 'approximately', '30', 'centimeters', 'forward'])
# ('03617', ['a', 'human', 'jumps', 'while', 'turning', 'to', 'its', 'left', 'hand', 'side'])
# ('03618', ['a', 'person', 'jumps', 'once'])
# ('03620', ['a', 'person', 'is', 'jumping', 'forward', 'and', 'doing', 'a', '90', 'degree', 'twist'])
# ('03624', ['a', 'person', 'jumps', 'up', 'and', 'spins', '180', '°', 'on', 'both', 'feed', 'while', 'jumping'])
# ('03627', ['a', 'man', 'is', 'jumping', 'and', 'turns', '270', 'degrees'])
# ('03628', ['a', 'person', 'walks', 'forward', 'and', 'turns', 'around'])
# ('03629', ['a', 'human', 'performs', 'a', '270', '°', 'counter', 'clockwise', 'jump'])
# ('03630', ['a', 'person', 'jumps', 'up', 'and', 'trurns', '360', '°', 'around', 'himself', 'before', 'landing'])
# ('03631', ['the', 'person', 'does', 'a', '360', 'clockwise', 'jump'])
# ('03632', ['a', 'human', 'performs', 'a', '360', '°', 'jump'])
# ('03635', ['a', 'person', 'that', 'is', 'going', 'forward', 'stops', 'immediately'])
# ('03636', ['a', 'human', 'walks', 'fast'])
# ('03637', ['a', 'person', 'performing', 'three', 'jumps'])
# ('03639', ['a', 'person', 'is', 'performing', 'multiple', 'jumps', 'on', 'the', 'spot', 'by', 'first', 'turning', '90', 'degrees', ',', 'then', '180', 'degrees', 'and', 'finally', '360', 'degrees', 'to', 'the', 'left'])
# ('03641', ['a', 'human', 'walks', 'over', 'a', 'platform'])
# ('03642', ['a', 'person', 'walking', 'straight', 'and', 'overstepping', 'a', 'wide', 'obstacle'])
# ('03643', ['the', 'subject', 'is', 'throwing', 'and', 'catching', 'an', 'object'])
# ('03645', ['someone', 'swings', 'their', 'hip', 'while', 'dancing'])
# ('03646', ['a', 'person', 'is', 'streching', 'himself'])
# ('03647', ['a', 'person', 'is', 'fighting', 'against', 'something', 'or', 'someone'])
# ('03650', ['a', 'person', 'sits', 'down', 'and', 'gets', 'up', 'again'])
# ('03654', ['a', 'human', 'hikes', 'his', 'shoulders', 'and', 'raises', 'his', 'hands'])
# ('03655', ['a', 'fat', 'person', 'high', 'fives'])
# ('03656', ['a', 'man', 'call', 'someone', 'to', 'come'])
# ('03657', ['a', 'person', 'walks', 'while', 'punching', 'the', 'air', 'with', 'his', 'right', 'hand', 'one', 'time'])
# ('03662', ['a', 'person', 'is', 'slowly', 'walking', 'and', 'turning', 'in', 'right', 'angles'])
# ('03663', ['a', 'person', 'is', 'walking', 'in', 'a', 'slalom'])
# ('03664', ['a', 'human', 'walking', 'backwards'])
# ('03665', ['walking', 'to', 'the', 'right', 'side', 'and', 'returning'])
# ('03669', ['a', 'person', 'is', 'slowly', 'walking', 'forward'])
# ('03670', ['a', 'person', 'walks', 'straight'])
# ('03671', ['a', 'person', 'walking', 'forward'])
# ('03673', ['a', 'person', 'walks', 'fast'])
# ('03674', ['a', 'person', 'is', 'walking', 'forward', 'with', 'swinging', 'arms'])
# ('03676', ['a', 'human', 'is', 'walking', 'straight'])
# ('03678', ['a', 'person', 'is', 'slowly', 'walking', 'forward'])
# ('03680', ['a', 'person', 'is', 'walking', '5', 'steps', 'forward', 'with', 'a', 'little', 'break', 'after', 'step', '2'])
# ('03682', ['a', 'human', 'runs', 'forward'])
# ('03683', ['a', 'man', 'is', 'running'])
# ('03684', ['a', 'person', 'is', 'jogging', 'to', 'the', 'left'])
# ('03685', ['a', 'human', 'jogs'])
# ('03686', ['a', 'person', 'is', 'slowly', 'jogging', 'forward'])
# ('03687', ['a', 'person', 'is', 'slowing', 'down', 'from', 'running'])
# ('03689', ['a', 'person', 'runs', 'forward'])
# ('03691', ['a', 'human', 'jogs'])
# ('03694', ['a', 'human', 'runs', 'and', 'jumps', 'slightly'])
# ('03695', ['a', 'man', 'strid', 'forth'])
# ('03697', ['a', 'person', 'jumps', 'over', 'a', 'hurdle', '-'])
# ('03699', ['a', 'human', 'runs', ',', 'looks', 'on', 'the', 'floor', 'while', 'continuing', 'to', 'walk', 'slowly', 'and', 'continues', 'her', 'run'])
# ('03705', ['someone', 'who', 'stopped', 'and', 'started', 'sprinting'])
# ('03706', ['a', 'human', 'walks', 'slowly', 'backward'])
# ('03708', ['baby', 'crawling', 'to', 'the', 'front'])
# ('03711', ['a', 'person', 'lies', 'on', 'the', 'back', 'and', 'stands', 'up'])
# ('03712', ['the', 'lays', 'down', 'on', 'the', 'floor', 'and', 'stands', 'up', 'again'])
# ('03713', ['a', 'person', 'is', 'standing', 'by', 'first', 'turning', 'to', 'the', 'left', 'and', 'using', 'his', 'hands', 'and', 'knees', 'as', 'support'])
# ('03715', ['a', 'sitting', 'person', 'is', 'standing', 'up'])
# ('03717', ['a', 'person', 'lays', 'down'])
# ('03719', ['walking', 'to', 'the', 'front', 'turn', 'around', 'and', 'walking', 'back'])
# ('03720', ['a', 'human', 'stands', 'like', 'he', 'or', 'she', 'wants', 'to', 'sit', 'down', 'in', 'the', 'next', 'moment'])
# ('03722', ['a', 'person', 'lifts', 'something', 'up', 'using', 'two', 'hands', 'but', 'without', 'bending', 'their', 'knees'])
# ('03723', ['a', 'human', 'picks', 'something', 'up'])
# ('03726', ['a', 'person', 'is', 'lying', 'on', 'the', 'ground', 'and', 'rolls', 'onto', 'the', 'left', 'side'])
# ('03728', ['a', 'person', 'turns', 'then', 'walks', 'in', 'a', 'circle'])
# ('03730', ['a', 'person', 'rolls', 'their', 'head', 'and', 'shoulders'])
# ('03731', ['a', 'person', 'walks', 'to', 'the', 'right', 'and', 'then', 'to', 'the', 'left', 'with', 'lateral', 'steps'])
# ('03732', ['a', 'person', 'takes', 'a', 'couple', 'of', 'forward', 'steps', 'swaying', ',', 'turns', 'around', 'and', 'walks', 'back'])
# ('03733', ['a', 'person', 'doing', 'a', 'step', 'to', 'left', 'while', 'looking', 'throughful'])
# ('03734', ['a', 'human', 'steps', 'over', 'a', 'small', 'obstacle'])
# ('03736', ['a', 'person', 'goes', 'up', 'and', 'down', 'an', 'object'])
# ('03737', ['a', 'human', 'stretches', 'with', 'the', 'arms', 'over', 'her', 'head'])
# ('03742', ['a', 'person', 'is', 'waving', 'the', 'right', 'hand'])
# ('03746', ['a', 'person', 'is', 'performing', 'a', 'downward', 'facing', 'dog', ',', 'performing', 'some', 'stretching', 'moves', 'and', 'goes', 'back', 'to', 'downward', 'facing', 'dog'])
# ('03748', ['a', 'human', 'lies', 'on', 'his', 'side', 'and', 'stands', 'up'])
# ('03749', ['a', 'person', 'warms', 'up', 'his', 'body', 'like', 'preparing', 'for', 'a', 'sport'])
# ('03750', ['a', 'man', 'is', 'standing', 'up', 'and', 'turns', 'around'])
# ('03753', ['a', 'person', 'walks', 'up', 'and', 'down', 'a', 'podest'])
# ('03754', ['a', 'person', 'goes', 'upstairs', 'then', 'goes', 'downstairs'])
# ('03755', ['a', 'human', 'walks', 'upstairs', 'and', 'then', 'downstairs', 'twice'])
# ('03757', ['a', 'person', 'sits', 'on', 'the', 'ground', 'with', 'his', 'legs', 'stretched', 'out', ',', 'then', 'completely', 'lies', 'down', 'with', 'his', 'back', 'and', 'afterwards', 'stands', 'up', 'again', 'and', 'walks', 'away'])
# ('03762', ['a', 'human', 'walks', 'forward', ',', 'sits', 'down', 'on', 'the', 'floor', 'with', 'its', 'legs', 'parallel', 'to', 'the', 'floor', 'and', 'then', 'performs', 'some', 'kind', 'of', 'streching', 'movement'])
# ('03764', ['a', 'person', 'picks', 'up', 'and', 'object', 'and', 'place', 'it', 'on', 'a', 'surface', 'in', 'front', 'of', 'him'])
# ('03766', ['a', 'person', 'picks', 'something', 'up', 'from', 'the', 'ground', 'with', 'both', 'hands', 'and', 'gives', 'it', 'to', 'someone', 'standing', 'in', 'front', 'of', 'him'])
# ('03767', ['a', 'person', 'picks', 'up', 'an', 'object', 'from', 'the', 'ground'])
# ('03771', ['a', 'human', 'picks', 'something', 'up', 'from', 'the', 'ground', 'and', 'places', 'the', 'object', 'on', 'a', 'table', 'in', 'front', 'of', 'him'])
# ('03776', ['a', 'person', 'makes', 'a', 'small', 'jump', 'forward', 'with', 'both', 'feet'])
# ('03777', ['a', 'person', 'hops', 'forward', 'about', '20', 'cm'])
# ('03778', ['a', 'person', 'is', 'making', 'a', 'jump', 'forward', 'with', 'both', 'feet'])
# ('03780', ['a', 'persons', 'jumps', 'half', 'a', 'meter', 'to', 'the', 'front'])
# ('03781', ['a', 'person', 'jumps', 'forward'])
# ('03783', ['a', 'man', 'jump', 'a', 'step', 'front'])
# ('03784', ['a', 'human', 'performs', 'a', 'jump', 'to', 'the', 'front'])
# ('03785', ['a', 'person', 'jumping', 'with', 'both', 'feet'])
# ('03787', ['a', 'human', 'performs', 'a', 'jump'])
# ('03788', ['a', 'person', 'makes', 'a', 'small', 'jump'])
# ('03790', ['a', 'person', 'hops', 'forward'])
# ('03791', ['the', 'jump', 'persons', 'a', 'leap', 'forward'])
# ('03793', ['a', 'human', 'jumps', 'approximately', 'half', 'a', 'meter', 'forward'])
# ('03795', ['a', 'person', 'jumps', 'approximately', '50', 'centimeters', 'forward'])
# ('03797', ['a', 'human', 'performs', 'a', 'jump'])
# ('03798', ['a', 'person', 'jumps', 'to', 'the', 'front'])
# ('03799', ['a', 'person', 'is', 'jumping', 'forward'])
# ('03800', ['jump', 'with', 'both', 'feet', 'about', '50', 'centimeters', 'forward'])
# ('03801', ['a', 'person', 'jumps', 'with', 'both', 'legs', 'approximately', '1', 'meter', 'forward'])
# ('03802', ['human', 'jumps', 'forward'])
# ('03805', ['a', 'person', 'walking', 'like', 'a', 'monkey'])
# ('03806', ['someone', 'walks', 'and', 'jumps', 'around', 'like', 'a', 'chimpanzee'])
# ('03811', ['a', 'man', 'puts', 'his', 'hands', 'back', 'and', 'kicks', 'or', 'he', 'ist', 'dancing'])
# ('03813', ['a', 'human', 'walks', 'slowly', 'while', 'bonding', 'forward'])
# ('03817', ['a', 'person', 'is', 'walking', 'slowly', 'and', 'strongly', 'bent', 'over', 'forward', 'while', 'repeatedly', 'dragging', 'his', 'arms', 'to', 'his', 'hip'])
# ('03824', ['multiple', 'times', ',', 'a', 'human', 'walks', 'forwards', ',', 'turns', 'around', 'and', 'walks', 'back', 'again'])
# ('03825', ['a', 'person', 'is', 'repeatedly', 'carefully', 'walking', 'in', 'one', 'direction', 'and', 'stopping', 'again', 'to', 'look', 'around'])
# ('03826', ['a', 'drunk', 'person', 'walking'])
# ('03828', ['a', 'person', 'steps', 'on', 'a', 'step', 'to', 'the', 'right', 'in', 'front', 'of', 'him'])
# ('03830', ['the', 'person', 'steps', 'half', 'a', 'meter', 'to', 'the', 'right', 'while', 'looking', 'at', 'his', 'feet'])
# ('03832', ['someonewho', 'makes', 'a', 'big', 'stept', 'to', 'the', 'right-front'])
# ('03833', ['a', 'person', 'is', 'making', 'one', 'step', 'right', 'foreground'])
# ('03834', ['a', 'person', 'making', 'one', 'step', 'forward'])
# ('03836', ['a', 'person', 'makes', 'a', 'step', 'down', 'from', 'higher', 'ground'])
# ('03837', ['a', 'human', 'peforms', 'a', 'pose', 'like', 'while', 'doing', 'knee', 'bends'])
# ('03839', ['a', 'person', 'performs', 'a', 'diagonal', 'step', 'right', 'front', 'starting', 'with', 'his', 'right', 'leg'])
# ('03841', ['a', 'human', 'steps', 'down', 'a', 'low', 'platform'])
# ('03842', ['a', 'person', 'is', 'making', 'a', 'sidestep', 'to', 'the', 'left'])
# ('03846', ['a', 'human', 'takes', 'one', 'large', 'step'])
# ('03849', ['a', 'person', 'is', 'going', 'on', 'step', 'up', 'on', 'the', 'stairs'])
# ('03851', ['a', 'human', 'steps', 'on', 'a', 'platform', 'with', 'one', 'large', 'step'])
# ('03853', ['a', 'human', 'goes', 'upstairs'])
# ('03854', ['a', 'man', 'take', 'something', 'up', 'on', 'the', 'ground', ',', 'and', 'put', 'it', 'into', 'the', 'shelf'])
# ('03855', ['a', 'person', 'is', 'walking', 'foward', 'afterwards', 'the', 'person', 'is', 'going', 'up', 'some', 'stairs'])
# ('03856', ['a', 'human', 'is', 'walking', 'on', 'a', 'line', 'and', 'up', 'a', 'step'])
# ('03857', ['a', 'person', 'moves', 'forward', 'and', 'then', 'climbs', 'staircases'])
# ('03860', ['a', 'human', 'walks', 'upstairs'])
# ('03861', ['a', 'human', 'walks', 'up', 'stairs'])
# ('03862', ['a', 'person', 'is', 'walking', 'around', 'a', 'corner', 'by', 'turning', '90', 'degrees', 'to', 'the', 'left'])
# ('03863', ['a', 'human', 'walks', 'and', 'takes', 'a', '90', '°', 'turn'])
# ('03865', ['a', 'person', 'walks', 'straight', 'forwards', 'and', 'then', 'walks', 'to', 'the', 'right'])
# ('03866', ['a', 'person', 'jumping', 'one', 'step'])
# ('03868', ['a', 'human', 'performs', 'a', 'jump'])
# ('03873', ['a', 'human', 'jumps', 'forward', 'with', 'both', 'legs'])
# ('03874', ['a', 'human', 'performs', 'a', 'jump', 'forwards'])
# ('03876', ['a', 'person', 'jumps', 'approximately', 'a', 'meter', 'forward', 'with', 'both', 'feet'])
# ('03877', ['a', 'person', 'jumps', 'and', 'rotates', '90', 'degrees', 'to', 'the', 'left', 'while', 'in', 'flight'])
# ('03878', ['a', 'human', 'jumps', ',', 'turning', '90', 'degrees', 'to', 'the', 'left'])
# ('03879', ['a', 'human', 'jumps', 'and', 'turns', '90', 'degrees'])
# ('03881', ['human', 'takes', 'a', 'step', 'to', 'the', 'right'])
# ('03882', ['a', 'person', 'jumps', 'and', 'turns', '180', 'degrees', 'mid-air'])
# ('03883', ['a', 'person', 'is', 'making', 'a', 'jump', 'around', 'himself', 'by', '180', 'degrees'])
# ('03885', ['a', 'human', 'jumps', 'up', 'with', 'a', '270', 'degree', 'turnaround', 'into', 'the', 'left'])
# ('03890', ['a', 'person', 'do', 'a', '360', 'degree', 'twist'])
# ('03895', ['a', 'human', 'picks', 'up', 'sth', 'from', 'the', 'floor', 'and', 'goes', 'forward'])
# ('03896', ['a', 'person', 'throwing', 'something'])
# ('03898', ['a', 'human', 'plays', 'basketball'])
# ('03899', ['a', 'person', 'makes', 'moves', 'like', 'bouncing', 'a', 'basketball', 'and', 'throwing', 'it', 'to', 'a', 'basket'])
# ('03901', ['a', 'human', 'plays', 'basketball', 'and', 'makes', 'a', 'layup'])
# ('03902', ['a', 'person', 'swings', 'a', 'baseball', 'bat', 'twice'])
# ('03903', ['base', 'ball', 'pitching'])
# ('03905', ['a', 'person', 'is', 'jumping', 'forward', 'with', 'both', 'feet'])
# ('03906', ['a', 'human', 'catches', 'and', 'throws', 'something'])
# ('03910', ['a', 'human', 'swims', 'in', 'breaststroke', 'style'])
# ('03913', ['a', 'human', 'is', 'swimming'])
# ('03914', ['a', 'human', 'rests', 'his', 'arms', 'on', 'something', 'in', 'front', 'of', 'him', 'which', 'has', 'the', 'height', 'of', 'his', 'shoulders'])
# ('03916', ['a', 'person', 'is', 'swimming', 'backstroke'])
# ('03917', ['a', 'person', 'is', 'swimming'])
# ('03919', ['a', 'human', 'swims'])
# ('03921', ['a', 'human', 'is', 'swimming'])
# ('03922', ['a', 'person', 'swims', 'butterfly'])
# ('03925', ['a', 'person', 'swims', 'the', 'crawl'])
# ('03926', ['a', 'person', 'is', 'swimming'])
# ('03929', ['a', 'person', 'stands', 'still'])
# ('03930', ['a', 'person', 'is', 'shaking', 'arms', 'and', 'legs', 'like', 'doing', 'a', 'warming', 'up'])
# ('03932', ['someone', 'who', 'starts', 'running'])
# ('03935', ['a', 'person', 'runs', 'forward'])
# ('03937', ['a', 'human', 'runs', 'in', 'a', 'curve'])
# ('03939', ['a', 'human', 'runs', 'in', 'a', 'sharp', 'curve'])
# ('03940', ['a', 'person', 'runs', 'forward'])
# ('03943', ['a', 'human', 'runs', 'in', 'a', '90', '°', 'leftwards', 'curve'])
# ('03944', ['a', 'person', 'is', 'running', 'left', 'and', 'then', 'right', 'around', 'an', 'obstacle'])
# ('03951', ['a', 'person', 'doing', 'a', 'forward', 'role', 'out', 'of', 'a', 'jump'])
# ('03952', ['a', 'human', 'performs', 'a', 'forward', 'roll'])
# ('03953', ['a', 'person', 'jumps', 'over', 'an', 'obstacle', 'while', 'running'])
# ('03954', ['a', 'person', 'jumps', 'approximately', '30', 'centimeters', 'in', 'the', 'air', 'while', 'running'])
# ('03955', ['a', 'person', 'runs', 'and', 'jumps'])
# ('03956', ['a', 'human', 'runs', 'and', 'jumps', 'over', 'an', 'obstacle', 'and', 'continues', 'her', 'run'])
# ('03957', ['while', 'running', ',', 'a', 'human', 'picks', 'something', 'up', 'from', 'the', 'floor'])
# ('03959', ['a', 'man', 'keep', 'down', 'and', 'lateralyl', 'move'])
# ('03960', ['a', 'man', 'bend', 'and', 'keep', 'down', ',', 'move', 'laterally'])
# ('03961', ['a', 'person', 'running', 'and', 'stepipng', 'over', 'one', 'step'])
# ('03962', ['a', 'person', 'runs', 'straight', 'forward'])
# ('03964', ['a', 'person', 'is', 'sprinting', 'up', 'and', 'down', 'a', 'small', 'hill', 'or', 'obstacle'])
# ('03965', ['a', 'person', 'runs', 'forward', ',', 'briefly', 'touches', 'the', 'ground', 'with', 'both', 'hands', 'and', 'then', 'continues', 'running'])
# ('03966', ['a', 'person', 'stumbles', 'on', 'the', 'ground', 'but', 'gets', 'up', 'and', 'keeps', 'on', 'running'])

# %%
# tokenized_words

# %%
len(tokenized_words)
# Out:
# 54324

# %%
tokenized_words_counter  = Counter(tokenized_words)

# %%
tokenized_words_counter.most_common(20)
# Out:
# [('a', 7238),
#  ('person', 4262),
#  ('the', 2259),
#  ('walks', 2258),
#  ('forward', 1562),
#  ('and', 1524),
#  ('to', 1338),
#  ('is', 1257),
#  ('human', 1141),
#  ('right', 1119),
#  ('left', 1059),
#  ('steps', 1038),
#  ('with', 876),
#  ('walking', 874),
#  ('in', 764),
#  ('his', 640),
#  (',', 600),
#  ('circle', 594),
#  ('someone', 547),
#  ('on', 538)]

# %%
len(tokenized_words_counter.most_common())
# Out:
# 1630

# %% [markdown]
# # Stemming

# %%
porter = PorterStemmer()
lancaster=LancasterStemmer()

# %%
stem_sentences = []
for a in tokenized_sentences:
    x = a[0]
    y = [porter.stem(n) for n in a[1]] # use lancaster or porter stemmer
    stem_sentences.append((x, y))

# %%
# stem_sentences

# %%
stem_words = []
for a in stem_sentences:
    stem_words.extend(a[1])

# %%
# stem_words

# %%
len(stem_words)
# Out:
# 54324

# %%
stem_words_counter = Counter(stem_words)

# %%
stem_words_counter.most_common(20)
# Out:
# [('a', 7238),
#  ('person', 4313),
#  ('walk', 3201),
#  ('the', 2259),
#  ('forward', 1947),
#  ('and', 1524),
#  ('to', 1338),
#  ('step', 1294),
#  ('is', 1257),
#  ('human', 1142),
#  ('right', 1119),
#  ('left', 1059),
#  ('with', 876),
#  ('turn', 778),
#  ('in', 764),
#  ('hi', 640),
#  ('circl', 619),
#  (',', 600),
#  ('hand', 570),
#  ('someon', 547)]

# %%
len(stem_words_counter.most_common()) #lancaster stem works count 1194, porter stemer 1256 no stem 1630
# Out:
# 1256

# %%
"Reduction of vacbluary words by " + str((1 - 1194/1630) * 100)  + "%"
# Out:
# 'Reduction of vacbluary words by 26.748466257668714%'

# %% [markdown]
# # POS tagging all stemmed words

# %%
# nltk.download('punkt')

# %%
# nltk.download('averaged_perceptron_tagger')

# %%
stem_sentences[:5]
# Out:
# [('00001', ['a', 'person', 'is', 'walk', 'forward']),
#  ('00002', ['a', 'person', 'walk', '4', 'step', 'forward']),
#  ('00003', ['a', 'human', 'walk']),
#  ('00004', ['a', 'person', 'walk', 'forward', 'at', 'medium', 'speed']),
#  ('00004', ['human', 'slowli', 'goe', 'forward'])]

# %%
unique_stem_words = list(set(stem_words))

# %%
unique_stem_words.sort()

# %%
unique_stem_words
# Out:
# ['"',
#  "'",
#  '(',
#  ')',
#  ',',
#  '-',
#  '/',
#  '05',
#  '1',
#  '1,5',
#  '1-2',
#  '10',
#  '100',
#  '10cm',
#  '110',
#  '15',
#  '180',
#  '180degre',
#  '1m',
#  '2',
#  '20',
#  '20cm',
#  '270',
#  '2m',
#  '3',
#  '3,5',
#  '30',
#  '30cm',
#  '360',
#  '4',
#  '40',
#  '45',
#  '5',
#  '50',
#  '50cm',
#  '6',
#  '7',
#  '7/8',
#  '70cm',
#  '8',
#  '80',
#  '90',
#  '90degre',
#  '<',
#  '</a>',
#  '=',
#  '>',
#  '?',
#  'a',
#  'about',
#  'about-fac',
#  'abov',
#  'abrupt',
#  'abruptli',
#  'absorb',
#  'acceler',
#  'acrobat',
#  'across',
#  'act',
#  'action',
#  'activ',
#  'addit',
#  'after',
#  'afterward',
#  'aga',
#  'again',
#  'againgst',
#  'against',
#  'agress',
#  'ahead',
#  'air',
#  'akwardli',
#  'alcohol',
#  'all',
#  'all-four',
#  'almost',
#  'along',
#  'alongsid',
#  'also',
#  'altern',
#  'ambl',
#  'an',
#  'and',
#  'andddd',
#  'anf',
#  'angl',
#  'anim',
#  'anoth',
#  'anti-clockwis',
#  'anticlockwis',
#  'anyth',
#  'ape',
#  'appear',
#  'appoxim',
#  'approcim',
#  'approxim',
#  'approximatli',
#  'arc',
#  'are',
#  'area',
#  'arm',
#  "arm'",
#  'around',
#  'arrow',
#  'art',
#  'as',
#  'asid',
#  'assist',
#  'assum',
#  'at',
#  'athlet',
#  'atm',
#  'attack',
#  'attent',
#  'avaoid',
#  'averag',
#  'avoid',
#  'away',
#  'awkward',
#  'awkwardli',
#  'axe',
#  'axi',
#  'babi',
#  'back',
#  'backflip',
#  'backsid',
#  'backstep',
#  'backstrok',
#  'backward',
#  'bak',
#  'bakcward',
#  'balac',
#  'balanc',
#  'balk',
#  'ball',
#  'ballet',
#  'ballet-lik',
#  'ballroom',
#  'bang',
#  'banjo',
#  'bar',
#  'base',
#  'basebal',
#  'basic',
#  'baskebal',
#  'basket',
#  'basketbal',
#  'bat',
#  'be',
#  'beam',
#  'beat',
#  'becaus',
#  'beccaus',
#  'bee',
#  'been',
#  'befor',
#  'beforehand',
#  'begin',
#  'behind',
#  'belli',
#  'below',
#  'bend',
#  'bendig',
#  'bent',
#  'besid',
#  'between',
#  'bhind',
#  'bicep',
#  'big',
#  'bigger',
#  'bird',
#  'bit',
#  'block',
#  'board',
#  'bodi',
#  'bodybuild',
#  'bond',
#  'bore',
#  'borh',
#  'both',
#  'bottl',
#  'bottom',
#  'bounc',
#  'bow',
#  'bowl',
#  'box',
#  'boxer',
#  'brake',
#  'brake-danc',
#  'break',
#  'breast',
#  'breaststrok',
#  'brief',
#  'briefli',
#  'bring',
#  'brisk',
#  'briskli',
#  'bu',
#  'buch',
#  'build',
#  'bump',
#  'but',
#  'butterfli',
#  'button',
#  'by',
#  'call',
#  'calmli',
#  'came',
#  'camera',
#  'can',
#  'cannot',
#  'car',
#  'care',
#  'carf',
#  'carri',
#  'cartwheel',
#  'cast',
#  'casual',
#  'catch',
#  'caution',
#  'cautiou',
#  'cautious',
#  'center',
#  'centimet',
#  'centimeter',
#  'certain',
#  'cha',
#  'cha-cha-cha',
#  'chachacha',
#  'chair',
#  'chang',
#  'check',
#  'cheer',
#  'chest',
#  'chicken',
#  'children',
#  'chimpanze',
#  'chord',
#  'circa',
#  'circl',
#  'circuit',
#  'circul',
#  'circular',
#  'ciricl',
#  'cirl',
#  'cirlc',
#  'clap',
#  'classic',
#  'clean',
#  'climb',
#  'clock-wis',
#  'clockwis',
#  'close',
#  'closer',
#  'club',
#  'clumsi',
#  'cm',
#  'collaps',
#  'come',
#  'comfort',
#  'commando',
#  'compens',
#  'compensatori',
#  'complet',
#  'complex',
#  'complic',
#  'concentr',
#  'confid',
#  'confus',
#  'consecut',
#  'conterclockwis',
#  'continiu',
#  'continu',
#  'continuo',
#  'convuls',
#  'cool',
#  'corner',
#  'correct',
#  'count',
#  'counter',
#  'counter-clockwis',
#  'counterbal',
#  'counterclockwis',
#  'countri',
#  'coupl',
#  'cover',
#  'crabwis',
#  'crawl',
#  'crazi',
#  'cricl',
#  'cross',
#  'crosswis',
#  'crouch',
#  'cup',
#  'curl',
#  'current',
#  'curv',
#  'cut',
#  'danc',
#  'dancer',
#  'dangl',
#  'dans',
#  'deceler',
#  'deep',
#  'defeat',
#  'defenc',
#  'defens',
#  'defin',
#  'degre',
#  'degress',
#  'denn',
#  'depress',
#  'descend',
#  'describ',
#  'desk',
#  'detour',
#  'diagon',
#  'diamet',
#  'differ',
#  'dig',
#  'direct',
#  'directli',
#  'disappear',
#  'disori',
#  'display',
#  'distanc',
#  'disturb',
#  'do',
#  'dodg',
#  'doe',
#  'dog',
#  "don't",
#  'done',
#  'door',
#  'down',
#  'downstair',
#  'downward',
#  'drag',
#  'dramat',
#  'drank',
#  'draw',
#  'dribbl',
#  'drift',
#  'drink',
#  'drive',
#  'drop',
#  'drum',
#  'drunk',
#  'drunken',
#  'duck',
#  'due',
#  'durat',
#  'dure',
#  'dwadl',
#  'dynam',
#  'each',
#  'easi',
#  'eat',
#  'edg',
#  'eft',
#  'egyptian',
#  'eight',
#  'elbow',
#  'eleph',
#  'ellips',
#  'els',
#  'empti',
#  'end',
#  'energ',
#  'energet',
#  'enthusiast',
#  'environ',
#  'erson',
#  'evad',
#  'evas',
#  'eventu',
#  'everi',
#  'execis',
#  'exercis',
#  'explor',
#  'extend',
#  'extern',
#  'face',
#  'fall',
#  'famou',
#  'far',
#  'fashion',
#  'fast',
#  'faster',
#  'fastli',
#  'fat',
#  'fear',
#  'feed',
#  'feel',
#  'feeler',
#  'feet',
#  'fell',
#  'fenc',
#  'few',
#  'fight',
#  'fightig',
#  'figur',
#  'final',
#  'find',
#  'finger',
#  'firmli',
#  'first',
#  'fish',
#  'fist',
#  'fit',
#  'five',
#  'flac',
#  'flap',
#  'flat',
#  'flex',
#  'fli',
#  'flic',
#  'flight',
#  'flip',
#  'flip-flopp',
#  'floo',
#  'floor',
#  'flutter',
#  'fold',
#  'follow',
#  'food',
#  'foot',
#  'footbal',
#  'for',
#  'forc',
#  'forcibl',
#  'foreground',
#  'forehand',
#  'foreward',
#  'form',
#  'forth',
#  'forti',
#  'forwad',
#  'forwar',
#  'forward',
#  'forwardd',
#  'four',
#  'four-leg',
#  'fourth',
#  'foward',
#  'foxtrot',
#  'from',
#  'front',
#  'froward',
#  'frustrat',
#  'full',
#  'funnel',
#  'funni',
#  'furious',
#  'further',
#  'gain',
#  'game',
#  'gap',
#  'gear',
#  'geht',
#  'gentl',
#  'gentli',
#  'gesticul',
#  'gestur',
#  'get',
#  'gitarr',
#  'give',
#  'gla',
#  'glanc',
#  'go',
#  'goe',
#  'golf',
#  'goodby',
#  'got',
#  'grab',
#  'gradual',
#  'grasp',
#  'greater',
#  'greet',
#  'grip',
#  'ground',
#  'grund',
#  'guitar',
#  'guitarr',
#  'gun',
#  'gymnast',
#  'gymnat',
#  'ha',
#  'had',
#  'half',
#  'halfheart',
#  'halt',
#  'hamburg',
#  'hand',
#  'handshak',
#  'handspr',
#  'handstand',
#  'hang',
#  'happen',
#  'happi',
#  'hard',
#  'hast',
#  'hasti',
#  'hat',
#  'have',
#  'he',
#  'head',
#  'headphon',
#  'headstand',
#  'heart',
#  'heavi',
#  'heavli',
#  'heel',
#  'height',
#  'held',
#  'hello',
#  'help',
#  'her',
#  'herself',
#  'hi',
#  'high',
#  'high-kick',
#  'higher',
#  'highli',
#  'hight',
#  'hike',
#  'hill',
#  'him',
#  'himself',
#  'hip',
#  'hit',
#  'hobbl',
#  'hold',
#  'hollow',
#  'hop',
#  'hopscotch',
#  'horizont',
#  'how',
#  'href',
#  'http://timmcgrawtourticketscom/',
#  'huge',
#  'huiman',
#  'human',
#  'hunker',
#  'hurdl',
#  'hurri',
#  'i',
#  'if',
#  'imaginari',
#  'imit',
#  'immedi',
#  'imperson',
#  'in',
#  'inclin',
#  'incom',
#  'incomplet',
#  'indic',
#  'init',
#  'initi',
#  'injur',
#  'insect',
#  'insid',
#  'inspect',
#  'instead',
#  'instrument',
#  'instument',
#  'intens',
#  'interact',
#  'intial',
#  'into',
#  'intox',
#  'invis',
#  'is',
#  'ist',
#  'it',
#  "it'",
#  'item',
#  'itsel',
#  'itself',
#  'jab',
#  'jack',
#  'jew',
#  'jog',
#  'jogg',
#  'judo',
#  'jump',
#  'jumping-jack',
#  'just',
#  'karat',
#  'kata',
#  'keep',
#  'key',
#  'kick',
#  'kickbox',
#  'kind',
#  'kite',
#  'knee',
#  'kneel',
#  'knife',
#  'knock',
#  'know',
#  'ladder',
#  'lager',
#  'land',
#  'larg',
#  'larger',
#  'last',
#  'later',
#  'lateralyl',
#  'latin',
#  'laugh',
#  'laughter',
#  'lay',
#  'layup',
#  'lazi',
#  'lead',
#  'lean',
#  'leap',
#  'ledg',
#  'left',
#  'left-diagon',
#  'left-hand',
#  'left-sid',
#  'left-turn',
#  'leftward',
#  'leg',
#  'leisur',
#  'length',
#  'let',
#  "let'",
#  'level',
#  'lie',
#  'lift',
#  'light',
#  'lightli',
#  'lightweight',
#  'like',
#  'limp',
#  'line',
#  'listen',
#  'listlessli',
#  'litll',
#  'littl',
#  'load',
#  'locat',
#  'long',
#  'look',
#  'lookig',
#  'loosen',
#  'lord',
#  'lost',
#  'low',
#  'lower',
#  'lung',
#  'lurch',
#  'lurk',
#  'm',
#  'macarena',
#  'machin',
#  'mainli',
#  'maintain',
#  'make',
#  'male',
#  'man',
#  'mani',
#  'manner',
#  'march',
#  'martial',
#  'materi',
#  'may',
#  'mayb',
#  'mcgraw',
#  'me',
#  'medium',
#  'meter',
#  'metr',
#  'mid-air',
#  'mid-walk',
#  'middl',
#  'midway',
#  'might',
#  'mimic',
#  'mingolf',
#  'minigolf',
#  'mirror',
#  'miss',
#  'mix',
#  'mixer',
#  'moder',
#  'moment',
#  'momentum',
#  'monkey',
#  'moonwalk',
#  'more',
#  'motion',
#  'move',
#  'movement',
#  'multipl',
#  'muscl',
#  'music',
#  'mustach',
#  'n',
#  'narrow',
#  'near',
#  'neck',
#  'need',
#  'next',
#  'nineti',
#  'ninjutsu',
#  'no',
#  'non-straight',
#  'nordic',
#  'normal',
#  'not',
#  'number',
#  'obejct',
#  'object',
#  'obov',
#  'observ',
#  'obstacl',
#  'occasion',
#  'oddli',
#  'of',
#  'off',
#  'old',
#  'ometh',
#  'on',
#  'onc',
#  'one',
#  'one-quart',
#  'onli',
#  'onto',
#  'ontop',
#  'open',
#  'opposit',
#  'or',
#  'orient',
#  'origin',
#  'other',
#  'out',
#  'outstrech',
#  'outstretch',
#  'outward',
#  'over',
#  'overhand',
#  'overstep',
#  'own',
#  'pace',
#  'paddl',
#  'parallel',
#  'paralyz',
#  'parcour',
#  'parkour',
#  'parson',
#  'part',
#  'partial',
#  'particular',
#  'partner',
#  'partway',
#  'pass',
#  'past',
#  'pat',
#  'path',
#  'pattern',
#  'paus',
#  'peform',
#  'penguin',
#  'perfom',
#  'perform',
#  'performin',
#  'performinga',
#  'perhap',
#  'peron',
#  'perosn',
#  'perso',
#  'person',
#  "person'",
#  'persond',
#  'perturb',
#  'pet',
#  'phone',
#  'pick',
#  'pictur',
#  'ping-pong',
#  'pirouett',
#  'pitch',
#  'pivot',
#  'place',
#  'plane',
#  'plank',
#  'platform',
#  'play',
#  'player',
#  'podest',
#  'podium',
#  'point',
#  'pose',
#  'posit',
#  'possibl',
#  'postur',
#  'pot',
#  'pour',
#  'practic',
#  'precis',
#  'predefin',
#  'prepar',
#  'present',
#  'press',
#  'pretend',
#  'pretti',
#  'previou',
#  'probabl',
#  'proce',
#  'process',
#  'prop',
#  'protect',
#  'puch',
#  'punch',
#  'pusehd',
#  'push',
#  'push-recoveri',
#  'pushup',
#  'put',
#  'putt',
#  'quadrangl',
#  'quarter',
#  'quarter-circl',
#  'quartercircl',
#  'quater',
#  'quick',
#  'quickli',
#  'quietli',
#  'quit',
#  'quiver',
#  'quter',
#  'racket',
#  'radiu',
#  'rais',
#  'ramp',
#  'ran',
#  'random',
#  'randomli',
#  'rapid',
#  'rather',
#  'reach',
#  'react',
#  'readi',
#  'realli',
#  'rear',
#  'rebal',
#  'receiv',
#  'recov',
#  'recoveri',
#  'rectangl',
#  'regain',
#  'rel',
#  'relax',
#  'remain',
#  'repeat',
#  'repeatedli',
#  'resembl',
#  'resistens',
#  'respons',
#  'rest',
#  'resum',
#  'retreat',
#  'return',
#  'revers',
#  'revolut',
#  'rhythmic',
#  'ride',
#  'right',
#  'right-front',
#  'right-hand',
#  'right-turn',
#  'rightward',
#  'rigth',
#  'rise',
#  'risen',
#  'rn',
#  'role',
#  'roll',
#  'room',
#  'rope',
#  'rotat',
#  'round',
#  'rub',
#  'ruin',
#  'run',
#  'run-up',
#  's-shape',
#  'sad',
#  'salut',
#  'same',
#  'sand',
#  'saw',
#  'scare',
#  'schich',
#  'scream',
#  'screw',
#  'scrotch',
#  'search',
#  'second',
#  'see',
#  'seem',
#  'select',
#  'semi-circular',
#  'semicircl',
#  'sequenc',
#  'seri',
#  'serv',
#  'set',
#  'seven',
#  'sever',
#  'shake',
#  'shaky-leg',
#  'shape',
#  'sharp',
#  'shave',
#  'she',
#  'shelf',
#  'shift',
#  'shoe',
#  'sholder',
#  'shoot',
#  'short',
#  'shortli',
#  'shot',
#  'shoulder',
#  'shout',
#  'shove',
#  'shovel',
#  'show',
#  'shower',
#  'shrug',
#  'shuffl',
#  'side',
#  'sidejump',
#  'sidekick',
#  'sidestep',
#  'sidewar',
#  'sideward',
#  'sideway',
#  'sign',
#  'similar',
#  'simultan',
#  'sinc',
#  'singer',
#  'singl',
#  'sink',
#  'sir',
#  'sit',
#  'sitestep',
#  'six',
#  'size',
#  'skateboard',
#  'skew',
#  'skill',
#  'sky',
#  'slalom',
#  'slap',
#  'sleepwalk',
#  'slight',
#  'slightli',
#  'slip',
#  'slope',
#  'slouch',
#  'slow',
#  'slow-waltz',
#  'slower',
#  'slowli',
#  'sluggish',
#  'small',
#  'smaller',
#  'smartphon',
#  'smash',
#  'sneak',
#  'so',
#  'soft',
#  'softli',
#  'sole',
#  'some',
#  'somebodi',
#  'someon',
#  'someonewho',
#  'somersault',
#  'someson',
#  'someth',
#  'sometim',
#  'somon',
#  'space',
#  'special',
#  'specif',
#  'speed',
#  'spin',
#  'spine',
#  'spinn',
#  'sport',
#  'spot',
#  'spot-turn',
#  ...]

# %%
tagged_words = nltk.pos_tag(unique_stem_words)

# %%
tags_detected = list(set([a[1] for a in tagged_words])); tags_detected
# Out:
# ['WRB',
#  'TO',
#  'EX',
#  'VBN',
#  'DT',
#  '(',
#  'WDT',
#  'NNS',
#  'PRP',
#  ')',
#  'RP',
#  'FW',
#  ',',
#  '.',
#  'NNP',
#  'JJ',
#  ':',
#  'CD',
#  'JJS',
#  'JJR',
#  'MD',
#  "''",
#  'VB',
#  'RB',
#  'VBD',
#  'VBG',
#  'VBP',
#  'NN',
#  'PRP$',
#  'CC',
#  'RBR',
#  'VBZ',
#  'WP',
#  'IN']

# %%
words_by_tags = {}
for t in tags_detected:
    words = [w[0] for w in tagged_words if w[1] == t]
    words_by_tags[t] = words

# %%
words_by_tags.keys()
# Out:
# dict_keys(['WRB', 'TO', 'EX', 'VBN', 'DT', '(', 'WDT', 'NNS', 'PRP', ')', 'RP', 'FW', ',', '.', 'NNP', 'JJ', ':', 'CD', 'JJS', 'JJR', 'MD', "''", 'VB', 'RB', 'VBD', 'VBG', 'VBP', 'NN', 'PRP$', 'CC', 'RBR', 'VBZ', 'WP', 'IN'])

# %%
words_by_tags
# Out:
# {'WRB': ['how', 'wald', 'when', 'where'],
#  'TO': ['to'],
#  'EX': ['there'],
#  'VBN': ['beam',
#   'been',
#   'centimet',
#   'come',
#   'done',
#   'held',
#   'listen',
#   'risen',
#   'set',
#   'waw'],
#  'DT': ['a',
#   'all',
#   'an',
#   'anoth',
#   'ball',
#   'both',
#   'each',
#   'no',
#   'some',
#   'the'],
#  '(': ['('],
#  'WDT': ['hat', 'wav', 'which'],
#  'NNS': ['children',
#   'els',
#   'feet',
#   'fli',
#   'goodby',
#   'intens',
#   'kata',
#   'nordic',
#   'overstep',
#   'resistens',
#   'respons',
#   'revers',
#   'specif',
#   'steeplechas',
#   'tae'],
#  'PRP': ['he',
#   'herself',
#   'him',
#   'himself',
#   'it',
#   'itself',
#   'me',
#   'she',
#   'them',
#   'they'],
#  ')': [')'],
#  'RP': ['down', 'off', 'themselv', 'turnaround'],
#  'FW': ['evad'],
#  ',': [','],
#  '.': ['?'],
#  'NNP': ['</a>', '=', '>', 'block', 'kick'],
#  'JJ': ['1-2',
#   'about-fac',
#   'abrupt',
#   'act',
#   'agress',
#   'akwardli',
#   'all-four',
#   'altern',
#   'andddd',
#   'anti-clockwis',
#   'approcim',
#   'arrow',
#   'asid',
#   'awkward',
#   'bak',
#   'ballet-lik',
#   'basebal',
#   'basic',
#   'basketbal',
#   'beat',
#   'becaus',
#   'befor',
#   'big',
#   'bottl',
#   'boxer',
#   'brake-danc',
#   'brisk',
#   'buch',
#   'build',
#   'butterfli',
#   'casual',
#   'cautious',
#   'certain',
#   'cha',
#   'cha-cha-cha',
#   'circular',
#   'classic',
#   'clean',
#   'clock-wis',
#   'compensatori',
#   'complex',
#   'convuls',
#   'cool',
#   'correct',
#   'counter-clockwis',
#   'counterbal',
#   'crawl',
#   'crouch',
#   'current',
#   'deceler',
#   'deep',
#   'defin',
#   'direct',
#   'disori',
#   'downward',
#   'draw',
#   'drive',
#   'drunken',
#   'due',
#   'egyptian',
#   'ellips',
#   'extern',
#   'fast',
#   'fastli',
#   'fat',
#   'feeler',
#   'few',
#   'final',
#   'first',
#   'fish',
#   'flat',
#   'flex',
#   'flic',
#   'flip-flopp',
#   'floo',
#   'follow',
#   'forc',
#   'form',
#   'forwad',
#   'forwar',
#   'four-leg',
#   'fourth',
#   'front',
#   'full',
#   'furious',
#   'gitarr',
#   'goe',
#   'grab',
#   'gradual',
#   'half',
#   'halfheart',
#   'hamburg',
#   'hard',
#   'headphon',
#   'hi',
#   'high',
#   'hobbl',
#   'href',
#   'huge',
#   'human',
#   'imaginari',
#   'indic',
#   'initi',
#   'inspect',
#   'instrument',
#   'interact',
#   'intial',
#   'intox',
#   'ist',
#   "it'",
#   'jab',
#   'key',
#   'kite',
#   'knife',
#   'last',
#   'lateralyl',
#   'latin',
#   'layup',
#   'lazi',
#   'lead',
#   'lean',
#   'leap',
#   'left-diagon',
#   'left-hand',
#   'left-sid',
#   'left-turn',
#   "let'",
#   'light',
#   'lightweight',
#   'limp',
#   'listlessli',
#   'long',
#   'low',
#   'male',
#   'martial',
#   'medium',
#   'mid-air',
#   'mid-walk',
#   'miss',
#   'n',
#   'narrow',
#   'next',
#   'nineti',
#   'ninjutsu',
#   'non-straight',
#   'normal',
#   'obejct',
#   'object',
#   'obstacl',
#   'old',
#   'onc',
#   'one-quart',
#   'ontop',
#   'open',
#   'orient',
#   'other',
#   'outstrech',
#   'overhand',
#   'own',
#   'parallel',
#   'partial',
#   'particular',
#   'pat',
#   "person'",
#   'ping-pong',
#   'practic',
#   'present',
#   'puch',
#   'push-recoveri',
#   'putt',
#   'quadrangl',
#   'quarter-circl',
#   'quick',
#   'randomli',
#   'rapid',
#   'readi',
#   'rebal',
#   'repeat',
#   'repeatedli',
#   'resum',
#   'rhythmic',
#   'right-front',
#   'right-hand',
#   'right-turn',
#   'rn',
#   'run-up',
#   'sad',
#   'salut',
#   'same',
#   'scare',
#   'schich',
#   'scrotch',
#   'second',
#   'select',
#   'semi-circular',
#   'sever',
#   'shaky-leg',
#   'sharp',
#   'short',
#   'shot',
#   'shrug',
#   'shuffl',
#   'sidekick',
#   'sidewar',
#   'similar',
#   'sir',
#   'sky',
#   'slightli',
#   'slouch',
#   'slow',
#   'sluggish',
#   'small',
#   'soft',
#   'somon',
#   'special',
#   'spot-turn',
#   'stare',
#   'static',
#   'stir',
#   'stoop',
#   'straightforward',
#   'strech',
#   'stretch',
#   'strid',
#   'strong',
#   'subject',
#   'sudden',
#   'swipe',
#   'symmetr',
#   't',
#   't-pose',
#   'tap',
#   'thean',
#   'thi',
#   'third',
#   'tight',
#   'tini',
#   'togeth',
#   'top',
#   'touch',
#   'tour',
#   'twist',
#   'two-leg',
#   'u',
#   'u-turn',
#   'uneven',
#   'unsteadi',
#   'upper',
#   'upright',
#   'urn',
#   'vertic',
#   'vicious',
#   'volleybal',
#   'wag',
#   'warm',
#   'warm-up',
#   'wawv',
#   'weigh',
#   'weight',
#   'whipe',
#   'wide',
#   'wip',
#   'wipe',
#   'withth',
#   'wolk',
#   'wrist',
#   'wrong',
#   'wuickli',
#   'zig-zag'],
#  ':': ['-'],
#  'CD': ['05',
#   '1',
#   '1,5',
#   '10',
#   '100',
#   '10cm',
#   '110',
#   '15',
#   '180',
#   '180degre',
#   '1m',
#   '2',
#   '20',
#   '20cm',
#   '270',
#   '2m',
#   '3',
#   '3,5',
#   '30',
#   '30cm',
#   '360',
#   '4',
#   '40',
#   '45',
#   '5',
#   '50',
#   '50cm',
#   '6',
#   '7',
#   '7/8',
#   '70cm',
#   '8',
#   '80',
#   '90',
#   '90degre',
#   'eight',
#   'five',
#   'four',
#   'one',
#   'seven',
#   'six',
#   'three',
#   'two'],
#  'JJS': ['podest', 'zest'],
#  'JJR': ['bigger',
#   'greater',
#   'higher',
#   'ladder',
#   'lager',
#   'larger',
#   'lower',
#   'more',
#   'smaller'],
#  'MD': ['can', 'may', 'might', 'will'],
#  "''": ["'"],
#  'VB': ['absorb',
#   'avoid',
#   'be',
#   'bodybuild',
#   'brake',
#   'cannot',
#   'check',
#   'dodg',
#   'doe',
#   'happen',
#   'head',
#   'horizont',
#   'karat',
#   'keep',
#   'kneel',
#   'make',
#   'mayb',
#   'mcgraw',
#   'mimic',
#   'react',
#   'run',
#   'shake',
#   'toe',
#   'wind'],
#  'RB': ['afterward',
#   'again',
#   'againgst',
#   'ahead',
#   'almost',
#   'also',
#   'away',
#   'back',
#   'backstrok',
#   'backward',
#   'close',
#   'counter',
#   'downstair',
#   'far',
#   'fenc',
#   'foreward',
#   'forward',
#   'further',
#   'happi',
#   'instead',
#   'just',
#   'lightli',
#   'not',
#   'quiver',
#   'quter',
#   'random',
#   'rather',
#   'right',
#   'so',
#   'still',
#   'straight',
#   'then',
#   'twice',
#   'upward'],
#  'VBD': ['borh',
#   'came',
#   'cast',
#   'eft',
#   'fell',
#   'figur',
#   'fold',
#   'got',
#   'had',
#   'height',
#   'hight',
#   'hit',
#   'itsel',
#   'lay',
#   'left',
#   'let',
#   'lost',
#   'metr',
#   'moonwalk',
#   'put',
#   'ran',
#   'saw',
#   'screw',
#   'shelf',
#   'slight',
#   'slowli',
#   'sole',
#   'stomp',
#   'stood',
#   'stove',
#   'streight',
#   'strir',
#   'whole'],
#  'VBG': ['swing', 'wing', 'wlking'],
#  'VBP': ['appear',
#   'are',
#   'balk',
#   'cautiou',
#   'chimpanze',
#   'descend',
#   'disappear',
#   'do',
#   'door',
#   'drink',
#   'empti',
#   'exercis',
#   'feel',
#   'firmli',
#   'forehand',
#   'forwardd',
#   'gear',
#   'get',
#   'give',
#   'go',
#   'have',
#   'know',
#   'lurch',
#   'maintain',
#   'march',
#   'need',
#   'parcour',
#   'pose',
#   'pour',
#   'protect',
#   'reach',
#   'rear',
#   'remain',
#   'rest',
#   'revolut',
#   'seem',
#   'shove',
#   'somersault',
#   'spin',
#   'stand',
#   'steer',
#   'stepp',
#   'suggest',
#   'take',
#   "they'r",
#   'think',
#   'trajectori',
#   'trune',
#   'turn',
#   'wake',
#   'walk',
#   'waltz',
#   'want',
#   'wave',
#   'wear'],
#  'NN': ['"',
#   '/',
#   '<',
#   'abov',
#   'abruptli',
#   'acceler',
#   'acrobat',
#   'action',
#   'activ',
#   'addit',
#   'aga',
#   'air',
#   'alcohol',
#   'alongsid',
#   'anf',
#   'angl',
#   'anticlockwis',
#   'anyth',
#   'ape',
#   'approxim',
#   'approximatli',
#   'arc',
#   'area',
#   'arm',
#   "arm'",
#   'art',
#   'assist',
#   'assum',
#   'athlet',
#   'atm',
#   'attack',
#   'attent',
#   'avaoid',
#   'averag',
#   'awkwardli',
#   'axe',
#   'axi',
#   'babi',
#   'backflip',
#   'backsid',
#   'backstep',
#   'bakcward',
#   'balac',
#   'balanc',
#   'ballet',
#   'ballroom',
#   'bang',
#   'banjo',
#   'bar',
#   'base',
#   'baskebal',
#   'basket',
#   'bat',
#   'beccaus',
#   'bee',
#   'beforehand',
#   'begin',
#   'belli',
#   'bend',
#   'bendig',
#   'bent',
#   'besid',
#   'bhind',
#   'bicep',
#   'bird',
#   'bit',
#   'board',
#   'bodi',
#   'bond',
#   'bore',
#   'bottom',
#   'bounc',
#   'bow',
#   'bowl',
#   'box',
#   'break',
#   'breast',
#   'breaststrok',
#   'brief',
#   'briefli',
#   'bring',
#   'briskli',
#   'bu',
#   'bump',
#   'button',
#   'call',
#   'calmli',
#   'camera',
#   'car',
#   'care',
#   'carf',
#   'carri',
#   'cartwheel',
#   'catch',
#   'caution',
#   'center',
#   'centimeter',
#   'chachacha',
#   'chair',
#   'chang',
#   'cheer',
#   'chest',
#   'chicken',
#   'chord',
#   'circa',
#   'circl',
#   'circuit',
#   'circul',
#   'ciricl',
#   'cirl',
#   'cirlc',
#   'clap',
#   'climb',
#   'clockwis',
#   'club',
#   'clumsi',
#   'cm',
#   'comfort',
#   'commando',
#   'complet',
#   'complic',
#   'concentr',
#   'confid',
#   'confus',
#   'consecut',
#   'conterclockwis',
#   'continiu',
#   'continu',
#   'continuo',
#   'corner',
#   'count',
#   'counterclockwis',
#   'countri',
#   'coupl',
#   'cover',
#   'crabwis',
#   'crazi',
#   'cricl',
#   'cross',
#   'crosswis',
#   'cup',
#   'curl',
#   'curv',
#   'cut',
#   'danc',
#   'dancer',
#   'dangl',
#   'defeat',
#   'defenc',
#   'degre',
#   'degress',
#   'denn',
#   'depress',
#   'describ',
#   'desk',
#   'detour',
#   'diagon',
#   'diamet',
#   'differ',
#   'dig',
#   'directli',
#   'display',
#   'distanc',
#   'disturb',
#   'dog',
#   "don't",
#   'drag',
#   'dramat',
#   'drank',
#   'dribbl',
#   'drift',
#   'drop',
#   'drum',
#   'drunk',
#   'duck',
#   'durat',
#   'dure',
#   'dwadl',
#   'easi',
#   'eat',
#   'edg',
#   'elbow',
#   'end',
#   'energ',
#   'energet',
#   'enthusiast',
#   'environ',
#   'erson',
#   'evas',
#   'eventu',
#   'everi',
#   'execis',
#   'explor',
#   'extend',
#   'face',
#   'fall',
#   'famou',
#   'fashion',
#   'fear',
#   'feed',
#   'fight',
#   'fightig',
#   'find',
#   'finger',
#   'fist',
#   'fit',
#   'flac',
#   'flap',
#   'flight',
#   'flip',
#   'floor',
#   'flutter',
#   'food',
#   'foot',
#   'footbal',
#   'forcibl',
#   'foreground',
#   'forth',
#   'forti',
#   'foward',
#   'foxtrot',
#   'froward',
#   'frustrat',
#   'funnel',
#   'funni',
#   'gain',
#   'game',
#   'gap',
#   'geht',
#   'gentl',
#   'gentli',
#   'gesticul',
#   'gestur',
#   'gla',
#   'glanc',
#   'golf',
#   'grasp',
#   'greet',
#   'grip',
#   'ground',
#   'grund',
#   'guitar',
#   'guitarr',
#   'gun',
#   'gymnast',
#   'gymnat',
#   'ha',
#   'halt',
#   'hand',
#   'handshak',
#   'handspr',
#   'handstand',
#   'hang',
#   'hast',
#   'hasti',
#   'headstand',
#   'heart',
#   'heavi',
#   'heavli',
#   'heel',
#   'hello',
#   'help',
#   'high-kick',
#   'highli',
#   'hike',
#   'hill',
#   'hip',
#   'hold',
#   'hollow',
#   'hop',
#   'hopscotch',
#   'http://timmcgrawtourticketscom/',
#   'huiman',
#   'hunker',
#   'hurdl',
#   'hurri',
#   'i',
#   'imit',
#   'immedi',
#   'imperson',
#   'inclin',
#   'incom',
#   'incomplet',
#   'init',
#   'injur',
#   'insect',
#   'insid',
#   'instument',
#   'invis',
#   'item',
#   'jack',
#   'jew',
#   'jog',
#   'jogg',
#   'judo',
#   'jump',
#   'jumping-jack',
#   'kickbox',
#   'kind',
#   'knee',
#   'knock',
#   'land',
#   'larg',
#   'laugh',
#   'laughter',
#   'ledg',
#   'leftward',
#   'leg',
#   'leisur',
#   'length',
#   'level',
#   'lie',
#   'lift',
#   'line',
#   'litll',
#   'littl',
#   'load',
#   'locat',
#   'look',
#   'lookig',
#   'loosen',
#   'lord',
#   'lung',
#   'lurk',
#   'm',
#   'macarena',
#   'machin',
#   'mainli',
#   'man',
#   'mani',
#   'manner',
#   'materi',
#   'meter',
#   'middl',
#   'midway',
#   'mingolf',
#   'minigolf',
#   'mirror',
#   'mix',
#   'mixer',
#   'moder',
#   'moment',
#   'momentum',
#   'monkey',
#   'motion',
#   'move',
#   'movement',
#   'multipl',
#   'muscl',
#   'music',
#   'mustach',
#   'neck',
#   'number',
#   'obov',
#   'observ',
#   'occasion',
#   'oddli',
#   'ometh',
#   'onli',
#   'opposit',
#   'origin',
#   'outstretch',
#   'outward',
#   'pace',
#   'paddl',
#   'paralyz',
#   'parkour',
#   'parson',
#   'part',
#   'partner',
#   'partway',
#   'pass',
#   'path',
#   'pattern',
#   'paus',
#   'peform',
#   'penguin',
#   'perfom',
#   'perform',
#   'performin',
#   'performinga',
#   'perhap',
#   'peron',
#   'perosn',
#   'person',
#   'persond',
#   'perturb',
#   'pet',
#   'phone',
#   'pick',
#   'pictur',
#   'pirouett',
#   'pitch',
#   'pivot',
#   'place',
#   'plane',
#   'plank',
#   'platform',
#   'play',
#   'player',
#   'podium',
#   'point',
#   'posit',
#   'possibl',
#   'postur',
#   'pot',
#   'precis',
#   'predefin',
#   'prepar',
#   'press',
#   'pretend',
#   'pretti',
#   'previou',
#   'probabl',
#   'proce',
#   'process',
#   'prop',
#   'punch',
#   'pusehd',
#   'push',
#   'pushup',
#   'quarter',
#   'quartercircl',
#   'quater',
#   'quickli',
#   'quietli',
#   'quit',
#   'racket',
#   'radiu',
#   'rais',
#   'ramp',
#   'realli',
#   'receiv',
#   'recov',
#   'recoveri',
#   'rectangl',
#   'regain',
#   'rel',
#   'relax',
#   'resembl',
#   'retreat',
#   'return',
#   'ride',
#   'rightward',
#   'rigth',
#   'rise',
#   'role',
#   'roll',
#   'room',
#   'rope',
#   'rotat',
#   'round',
#   'rub',
#   'ruin',
#   's-shape',
#   'sand',
#   'scream',
#   'search',
#   'see',
#   'semicircl',
#   'sequenc',
#   'seri',
#   'serv',
#   'shape',
#   'shave',
#   'shift',
#   'shoe',
#   'sholder',
#   'shoot',
#   'shortli',
#   'shoulder',
#   'shout',
#   'shovel',
#   'show',
#   'side',
#   'sidejump',
#   'sidestep',
#   'sideward',
#   'sideway',
#   'sign',
#   'simultan',
#   'sinc',
#   'singer',
#   'singl',
#   'sink',
#   'sit',
#   'sitestep',
#   'size',
#   'skateboard',
#   'skew',
#   'skill',
#   'slalom',
#   'slap',
#   'sleepwalk',
#   'slip',
#   'slope',
#   'slow-waltz',
#   'slower',
#   'smartphon',
#   'smash',
#   'sneak',
#   'softli',
#   'somebodi',
#   'someon',
#   'someonewho',
#   'someson',
#   'someth',
#   'sometim',
#   'space',
#   'speed',
#   'spine',
#   'spinn',
#   'sport',
#   'spot',
#   'spread',
#   'sprint',
#   'sqat',
#   'squad',
#   'squar',
#   'squat',
#   'stabil',
#   'stabl',
#   'stagger',
#   'stair',
#   'staircas',
#   'stamp',
#   'stanc',
#   'standard',
#   'start',
#   'startspot',
#   'stationari',
#   'stay',
#   'ste',
#   'steep',
#   'step',
#   'stepe',
#   'stepipng',
#   'steplength',
#   'stepston',
#   'stept',
#   'stetch',
#   'sth',
#   'stick',
#   'stiff',
#   'stire',
#   'stomach',
#   'stone',
#   'stop',
#   'stopd',
#   'stork',
#   'street',
#   'stride',
#   'strike',
#   'stroke',
#   'stroll',
#   'strongli',
#   'strum',
#   'strumbl',
#   'stumbel',
#   'stumbl',
#   'style',
#   'subect',
#   'success',
#   'suddenli',
#   'support',
#   'surfac',
#   'suspici',
#   'sway',
#   'swiftli',
#   'swim',
#   't-shape',
#   'tabl',
#   'target',
#   'task',
#   'tenni',
#   'terrain',
#   'therefor',
#   'thing',
#   'thrice',
#   'throat',
#   'throw',
#   'tidi',
#   'tile',
#   'tilt',
#   'tim',
#   'time',
#   'tip',
#   'tipto',
#   'tire',
#   'tone',
#   'torso',
#   'toss',
#   'track',
#   'train',
#   'travel',
#   'tri',
#   'triangl',
#   'trip',
#   'trun',
#   'trunk',
#   'trurn',
#   'ts',
#   'tu',
#   'tumbl',
#   'tune',
#   'ture',
#   'unbalanc',
#   'unsteadili',
#   'upstair',
#   'use',
#   'vari',
#   'variou',
#   'veloc',
#   'veri',
#   'violett',
#   'violin',
#   'visit',
#   'wa',
#   'waist',
#   'wait',
#   'wakl',
#   'wal',
#   'wale',
#   'wall',
#   'walzer',
#   'warmup',
#   'watch',
#   'water',
#   'way',
#   'waypoint',
#   'weird',
#   'wheel',
#   'whip',
#   'whirl',
#   'wider',
#   'wiener',
#   'wiggl',
#   'wiggli',
#   'wish',
#   'wlak',
#   'woman',
#   'work',
#   'write',
#   'yank',
#   'yard',
#   'yoga',
#   'zombi',
#   'zoom',
#   'zwo',
#   '°'],
#  'PRP$': ['her', 'their'],
#  'CC': ['and', 'but', 'eleph', 'or'],
#  'RBR': ['closer', 'faster', 'later'],
#  'VBZ': ['collaps',
#   'compens',
#   'dans',
#   'defens',
#   'dynam',
#   'is',
#   'shower',
#   'therebi'],
#  'WP': ['who'],
#  'IN': ['about',
#   'across',
#   'after',
#   'against',
#   'along',
#   'ambl',
#   'anim',
#   'appoxim',
#   'around',
#   'as',
#   'at',
#   'behind',
#   'below',
#   'between',
#   'by',
#   'for',
#   'from',
#   'if',
#   'in',
#   'into',
#   'like',
#   'near',
#   'of',
#   'on',
#   'onto',
#   'out',
#   'over',
#   'past',
#   'perso',
#   'than',
#   'that',
#   'through',
#   'touchdown',
#   'toward',
#   'trough',
#   'under',
#   'until',
#   'up',
#   'while',
#   'with',
#   'without',
#   'workout']}

# %%
selected_words = eval(open('amended_word_dictionary.txt').read())

# %%
flatened_word_list = []
selected_words_list = [flatened_word_list.extend(a[1]) for a in selected_words.items()]

# %%
flatened_word_list.sort()

# %%
flatened_word_list
# Out:
# ['ahead',
#  'along',
#  'anti-clockwis',
#  'anticlockwis',
#  'are',
#  'around',
#  'attack',
#  'attent',
#  'back',
#  'backflip',
#  'backsid',
#  'backstrok',
#  'backward',
#  'be',
#  'been',
#  'bend',
#  'bent',
#  'block',
#  'borh',
#  'bounc',
#  'bow',
#  'bowl',
#  'box',
#  'by',
#  'call',
#  'came',
#  'cast',
#  'climb',
#  'clockwis',
#  'come',
#  'conterclockwis',
#  'counter',
#  'counter-clockwis',
#  'counterclockwis',
#  'crawl',
#  'danc',
#  'do',
#  'done',
#  'down',
#  'downward',
#  'drink',
#  'drive',
#  'drop',
#  'drunken',
#  'exercis',
#  'fell',
#  'fish',
#  'flac',
#  'flap',
#  'flic',
#  'flight',
#  'flip',
#  'foreward',
#  'forwad',
#  'forwar',
#  'forward',
#  'forwardd',
#  'foward',
#  'froward',
#  'get',
#  'give',
#  'go',
#  'goe',
#  'got',
#  'grab',
#  'had',
#  'halt',
#  'handshak',
#  'handstand',
#  'hang',
#  'have',
#  'held',
#  'high-kick',
#  'hit',
#  'interact',
#  'jog',
#  'jogg',
#  'judo',
#  'jump',
#  'jumping-jack',
#  'kick',
#  'kickbox',
#  'knee',
#  'kneel',
#  'knock',
#  'land',
#  'lay',
#  'lean',
#  'left',
#  'left-diagon',
#  'left-hand',
#  'left-sid',
#  'left-turn',
#  'limp',
#  'long',
#  'lost',
#  'low',
#  'lurch',
#  'make',
#  'march',
#  'mimic',
#  'move',
#  'off',
#  'ontop',
#  'perfom',
#  'perform',
#  'performin',
#  'performinga',
#  'pick',
#  'pirouett',
#  'pivot',
#  'play',
#  'pose',
#  'pour',
#  'protect',
#  'punch',
#  'pusehd',
#  'push',
#  'pushup',
#  'put',
#  'ran',
#  'reach',
#  'react',
#  'rear',
#  'receiv',
#  'rest',
#  'revolut',
#  'rightward',
#  'rigth',
#  'rise',
#  'risen',
#  'role',
#  'roll',
#  'run',
#  's-shape',
#  'salut',
#  'set',
#  'shake',
#  'shave',
#  'shove',
#  'show',
#  'shuffl',
#  'sidejump',
#  'sidekick',
#  'sidestep',
#  'sideward',
#  'sideway',
#  'singl',
#  'sit',
#  'slalom',
#  'slap',
#  'sleepwalk',
#  'slip',
#  'spin',
#  'spine',
#  'spinn',
#  'squad',
#  'stand',
#  'steer',
#  'stepp',
#  'stood',
#  'strir',
#  'swim',
#  'swing',
#  'swipe',
#  't-shape',
#  'touch',
#  'toward',
#  'turn',
#  'u-turn',
#  'up',
#  'upward',
#  'wake',
#  'walk',
#  'waltz',
#  'wear',
#  'whip',
#  'whirl',
#  'wind',
#  'wip',
#  'wipe',
#  'wlak',
#  'work',
#  'write',
#  'yoga']

# %% [markdown]
# # Filtering labels to selected words

# %%
stem_sentences
# Out:
# [('00001', ['a', 'person', 'is', 'walk', 'forward']),
#  ('00002', ['a', 'person', 'walk', '4', 'step', 'forward']),
#  ('00003', ['a', 'human', 'walk']),
#  ('00004', ['a', 'person', 'walk', 'forward', 'at', 'medium', 'speed']),
#  ('00004', ['human', 'slowli', 'goe', 'forward']),
#  ('00005', ['a', 'human', 'walk', 'four', 'slow', 'step', 'forward']),
#  ('00006', ['a', 'person', 'goe', 'four', 'and', 'half', 'step', 'forward']),
#  ('00006',
#   ['a', 'person', 'walk', 'forward', 'slightli', 'to', 'the', 'right']),
#  ('00007',
#   ['a', 'person', 'walk', 'slowli', 'for', 'four', 'step', 'and', 'stop']),
#  ('00007',
#   ['a', 'person', 'walk', 'four', 'step', 'to', 'the', 'forward', 'direct']),
#  ('00008', ['a', 'person', 'walk', 'slowli', '4', 'step', 'forward']),
#  ('00009',
#   ['a',
#    'person',
#    'stand',
#    ',',
#    'then',
#    'walk',
#    'a',
#    'few',
#    'step',
#    ',',
#    'then',
#    'stop',
#    'again']),
#  ('00009',
#   ['someon',
#    'is',
#    'walk',
#    'forward',
#    'slowli',
#    'do',
#    '4',
#    'step',
#    'start',
#    'with',
#    'the',
#    'left',
#    'leg']),
#  ('00009', ['a', 'person', 'make', '4', 'step', 'forward', 'slowli']),
#  ('00010', ['a', 'human', 'walk', 'backward']),
#  ('00011',
#   ['a',
#    'person',
#    'walk',
#    'backward',
#    'four',
#    'step',
#    'start',
#    'with',
#    'the',
#    'left',
#    'foot']),
#  ('00011', ['somebodi', 'walk', 'backward']),
#  ('00013', ['a', 'person', 'walk', 'backward', 'for', 'a', 'few', 'step']),
#  ('00014', ['a', 'person', 'walk', 'four', 'step', 'backward']),
#  ('00015', ['a', 'person', 'walk', 'backward']),
#  ('00016', ['a', 'person', 'walk', 'backward', 'at', 'a', 'slow', 'speed']),
#  ('00016',
#   ['a',
#    'human',
#    'is',
#    'walk',
#    '4',
#    'step',
#    'backward',
#    'and',
#    'start',
#    'with',
#    'it',
#    'left',
#    'food']),
#  ('00016', ['a', 'person', 'walk', 'backward']),
#  ('00016', ['some', 'is', 'revers', 'walk']),
#  ('00016', ['a', 'person', 'take', '4', 'step', 'backward']),
#  ('00016',
#   ['a', 'person', 'move', 'backward', '4', 'step', 'befor', 'stand', 'still']),
#  ('00016', ['someon', 'is', 'walk', 'backward']),
#  ('00016', ['a', 'man', 'is', 'walk', 'backward']),
#  ('00016', ['somebodi', 'walk', 'a', 'few', 'step', 'backward']),
#  ('00017', ['a', 'person', 'walk', 'four', 'step', 'backward']),
#  ('00017', ['a', 'person', 'walk', 'backward', 'slowli']),
#  ('00017', ['somebodi', 'walk', 'backward']),
#  ('00018', ['a', 'person', 'is', 'walk', 'backward']),
#  ('00019', ['a', 'person', 'turn', 'in', 'a', 'circl']),
#  ('00019', ['someon', 'walk', 'in', 'a', 'circl', 'counterclockwis']),
#  ('00019', ['somebodi', 'wal', 'a', 'circl', 'anticlockwis']),
#  ('00020', ['a', 'person', 'walk', 'in', 'a', 'circl', 'counter', 'clockwis']),
#  ('00021', ['a', 'person', 'walk', 'in', 'a', 'squar']),
#  ('00022', ['the', 'person', 'is', 'walk', 'in', 'a', 'circular', 'shape']),
#  ('00022',
#   ['a', 'human', 'walk', 'slowli', 'a', 'full', 'circl', 'to', 'it', 'left']),
#  ('00022', ['a', 'person', 'walk', 'a', 'full', 'counter-clockwis', 'circl']),
#  ('00022',
#   ['a', 'person', 'walk', 'in', 'a', 'circl', 'pattern', 'one', 'time']),
#  ('00023', ['a', 'person', 'walk', 'in', 'a', 'counter-clockwis', 'circl']),
#  ('00023', ['somebodi', 'is', 'walk', 'in', 'a', 'circl']),
#  ('00023', ['person', 'walk', 'in', 'a', 'circl']),
#  ('00023', ['a', 'person', 'is', 'walk', 'in', 'a', 'circl']),
#  ('00023',
#   ['someon', 'slowli', 'walk', 'a', 'full', 'circl', 'to', 'the', 'left']),
#  ('00023', ['walk', 'in', 'a', 'slow', 'circl']),
#  ('00023', ['someon', 'walk', 'a', 'complet', 'circl']),
#  ('00023', ['a', 'person', 'turn', 'around', 'to', 'the', 'begin']),
#  ('00023',
#   ['someon', 'is', 'walk', 'a', 'whole', 'round', 'to', 'hi', 'left', 'side']),
#  ('00023', ['a', 'person', 'is', 'walk', 'in', 'a', 'circl', 'shape']),
#  ('00023', ['a', 'person', 'walk', 'a', 'circl', 'to', 'the', 'left']),
#  ('00024', ['a', 'person', 'walk', 'a', 'circl']),
#  ('00025', ['a', 'person', 'walk', 'in', 'a', 'circl', 'to', 'the', 'left']),
#  ('00025',
#   ['a', 'person', 'walk', 'a', 'circl', 'in', 'the', 'left', 'direct']),
#  ('00026', ['a', 'person', 'walk', 'in', 'a', 'counter-clockwis', 'circl']),
#  ('00026', ['someon', 'walk', 'in', 'a', 'circl', 'counterclockwis']),
#  ('00027',
#   ['the', 'person', 'is', 'walk', 'through', 'a', 'circular', 'path']),
#  ('00027', ['a', 'human', 'is', 'walk', 'in', 'circl']),
#  ('00028', ['human', 'goe', 'in', 'a', 'circl', 'clockwis']),
#  ('00029', ['a', 'person', 'walk', 'in', 'a', 'circl', 'to', 'the', 'right']),
#  ('00029', ['somebodi', 'walk', 'a', 'circl', 'clockwis']),
#  ('00030', ['a', 'person', 'walk', 'in', 'a', 'clockwis', 'circl']),
#  ('00030',
#   ['a', 'person', 'run', 'in', 'a', 'full', 'circl', ',', 'clockwis']),
#  ('00031', ['a', 'person', 'walk', 'a', 'circl', 'clock-wis']),
#  ('00031', ['a', 'person', 'walk', 'in', 'clock-wis', 'circl']),
#  ('00031',
#   ['a', 'human', 'is', 'walk', 'in', 'a', 'circl', 'to', 'the', 'right']),
#  ('00032', ['a', 'person', 'walk', 'in', 'a', 'circl', 'clockwis']),
#  ('00032',
#   ['a', 'person', 'walk', 'in', 'a', 'circl', 'and', 'look', 'face', 'down']),
#  ('00032',
#   ['a', 'person', 'walk', 'a', 'circl', 'in', 'the', 'right', 'direct']),
#  ('00032', ['the', 'human', 'walk', 'a', 'circl', '(', 'right', 'turn', ')']),
#  ('00033', ['a', 'person', 'walk', 'in', 'a', 'circl', 'clockwis']),
#  ('00033',
#   ['a', 'person', 'walk', 'in', 'a', 'circl', 'to', 'hi', 'right', 'side']),
#  ('00034', ['a', 'human', 'walk', 'in', 'a', 'circl', 'clockwis']),
#  ('00034', ['a', 'person', 'walk', 'in', 'a', 'littl', 'circl']),
#  ('00035', ['a', 'person', 'walk', 'a', 'circl']),
#  ('00036', ['a', 'person', 'walk', 'in', 'circl', 'in', 'clockwis', 'direct']),
#  ('00037', ['a', 'person', 'walk', 'a', 'circl', 'clockwis']),
#  ('00037', ['a', 'peron', 'walk', 'a', 'circl', 'clockwis']),
#  ('00037', ['a', 'man', 'walk', 'in', 'circl']),
#  ('00038',
#   ['a',
#    'person',
#    'walk',
#    'in',
#    'a',
#    'quarter',
#    'circl',
#    'to',
#    'the',
#    'right']),
#  ('00038', ['a', 'person', 'walk', 'while', 'turn', 'to', 'the', 'right']),
#  ('00039',
#   ['a',
#    'person',
#    'is',
#    'walk',
#    'forward',
#    'four',
#    'step',
#    'start',
#    'with',
#    'the',
#    'right',
#    'foot',
#    'and',
#    'perform',
#    'a',
#    'right-turn',
#    'of',
#    '90',
#    '°']),
#  ('00039',
#   ['a', 'human', 'perform', 'a', 'tight', '90', '°', 'right', 'curv']),
#  ('00040',
#   ['a', 'person', 'walk', '90', '°', 'of', 'a', 'circl', 'to', 'hi', 'right']),
#  ('00040',
#   ['a',
#    'person',
#    'walk',
#    'a',
#    'quarter',
#    'circl',
#    'to',
#    'the',
#    'right',
#    ',',
#    'take',
#    'four',
#    'step']),
#  ('00040', ['a', 'person', 'is', 'turn', 'right', 'while', 'walk']),
#  ('00041',
#   ['someon', 'walk', 'three', 'step', 'in', 'curv', 'to', 'the', 'right']),
#  ('00041', ['a', 'person', 'walk', 'a', 'small', 'half', 'circl']),
#  ('00041',
#   ['somebodi', 'walk', 'a', 'quarter', 'circl', 'in', 'clockwis', 'direct']),
#  ('00042', ['subject', 'walk', 'a', 'quarter', 'circl', 'clockwis']),
#  ('00042',
#   ['a', 'person', 'walk', 'in', 'a', '90', '°', 'curv', 'to', 'hi', 'right']),
#  ('00042',
#   ['a',
#    'person',
#    'wait',
#    'on',
#    'a',
#    'atm',
#    'line',
#    'and',
#    'then',
#    'goe',
#    'to',
#    'the',
#    'machin']),
#  ('00042', ['a', 'human', 'sit']),
#  ('00043',
#   ['a',
#    'person',
#    'walk',
#    'clockwis',
#    'in',
#    'a',
#    'circl',
#    'with',
#    '4',
#    'step']),
#  ('00043',
#   ['a',
#    'human',
#    'perform',
#    'a',
#    'tight',
#    '90',
#    '°',
#    'curv',
#    'to',
#    'the',
#    'right']),
#  ('00043', ['a', 'human', 'sit', 'down']),
#  ('00044', ['a', 'person', 'walk', 'a', 'quarter', 'rightward', 'circl']),
#  ('00044', ['a', 'person', 'walk', 'in', 'a', 'quarter', 'circl']),
#  ('00045', ['human', 'walk', 'in', 'a', 'quater', 'circl', 'clockwis']),
#  ('00046',
#   ['a',
#    'person',
#    'walk',
#    'a',
#    'quarter',
#    'circl',
#    'clockwis',
#    'with',
#    '4',
#    'step']),
#  ('00047', ['a', 'person', 'is', 'walk', 'a', 'left-turn']),
#  ('00047', ['a', 'person', 'walk', 'forward', 'in', 'a', '90', '°', 'curv']),
#  ('00047',
#   ['a',
#    'person',
#    'walk',
#    'a',
#    'quarter',
#    'circl',
#    'to',
#    'the',
#    'right',
#    ',',
#    'take',
#    'four',
#    'step']),
#  ('00048', ['person', 'walk', 'backward']),
#  ('00048', ['human', 'goe', 'backward', 'start', 'with', 'left']),
#  ('00049', ['subject', 'walk', 'backward']),
#  ('00049',
#   ['a', 'person', 'take', '4', 'step', 'backward', 'start', 'with', 'left']),
#  ('00049', ['a', 'person', 'walk', 'some', 'step', 'backward']),
#  ('00050', ['person', 'walk', 'backward']),
#  ('00050', ['someon', 'walk', 'slowli', 'backward']),
#  ('00050', ['a', 'person', 'make', '4', 'step', 'backward']),
#  ('00051', ['a', 'person', 'walk', 'backward']),
#  ('00052', ['the', 'person', 'is', 'walk', 'backward']),
#  ('00052', ['a', 'person', 'walk', 'some', 'step', 'backward']),
#  ('00053', ['a', 'person', 'walk', 'backward', 'for', '4', 'step']),
#  ('00053', ['a', 'person', 'slowli', 'walk', 'backward']),
#  ('00053',
#   ['someon',
#    'walk',
#    'straight',
#    'revers',
#    'and',
#    'stop',
#    'in',
#    'four',
#    'step']),
#  ('00054',
#   ['a', 'person', 'is', 'walk', 'backward', 'in', 'a', 'straight', 'line']),
#  ('00054', ['human', 'goe', 'backward', 'start', 'with', 'left']),
#  ('00055', ['a', 'person', 'walk', 'backward', '4', 'step']),
#  ('00055',
#   ['someon',
#    'walk',
#    'backward',
#    '4',
#    'step',
#    'start',
#    'with',
#    'the',
#    'left',
#    'leg']),
#  ('00055', ['a', 'person', 'take', 'some', 'step', 'backward']),
#  ('00056', ['a', 'human', 'walk', 'backward']),
#  ('00056', ['the', 'human', 'is', 'walk', 'backward']),
#  ('00057', ['a', 'person', 'walk', 'backward']),
#  ('00057',
#   ['someon',
#    'is',
#    'walk',
#    'backward',
#    '4',
#    'step',
#    'start',
#    'with',
#    'the',
#    'left',
#    'leg']),
#  ('00058', ['a', 'person', 'walk', 'in', 'circl']),
#  ('00059', ['human', 'goe', 'in', 'a', 'circl', 'counterclockwis']),
#  ('00059',
#   ['a', 'human', 'is', 'walk', 'in', 'a', 'circl', 'to', 'it', 'left']),
#  ('00060', ['a', 'human', 'walk', 'in', 'a', 'circl', 'counterclockwis']),
#  ('00061', ['someon', 'walk', 'in', 'a', 'counter-clockwis', 'circl']),
#  ('00061',
#   ['a',
#    'human',
#    'walk',
#    'in',
#    'a',
#    'circl',
#    'with',
#    'a',
#    'diamet',
#    'of',
#    '2m']),
#  ('00061', ['someon', 'walk', 'in', 'a', 'full', 'counter-clockwis', 'circl']),
#  ('00061', ['a', 'person', 'walk', 'in', 'a', 'full', 'circl']),
#  ('00061', ['someon', 'make', 'a', 'circl']),
#  ('00061', ['he', 'turn', 'around']),
#  ('00061', ['a', 'person', 'walk', 'a', 'circl']),
#  ('00061', ['someon', 'walk', 'one', 'round']),
#  ('00061', ['a', 'person', 'walk', 'a', 'full', 'anti-clockwis', 'circl']),
#  ('00061', ['a', 'person', 'walk', 'in', 'a', 'circl', 'counterclockwis']),
#  ('00061', ['a', 'person', 'walk', 'a', 'circl', 'to', 'the', 'left']),
#  ('00061', ['the', 'human', 'walk', 'a', 'circl']),
#  ('00061', ['a', 'human', 'walk', 'in', 'circl', 'counterclockwis']),
#  ('00062', ['a', 'person', 'walk', 'in', 'a', 'counter-clockwis', 'circl']),
#  ('00062',
#   ['a', 'person', 'walk', 'in', 'a', 'circl', 'to', 'the', 'left', 'side']),
#  ('00063', ['a', 'person', 'is', 'walk', 'in', 'small', 'circl']),
#  ('00063', ['a', 'person', 'walk', 'in', 'a', 'circl', 'to', 'the', 'left']),
#  ('00064', ['a', 'human', 'walk', 'in', 'a', 'circl', 'counterclockwis']),
#  ('00064', ['someon', 'is', 'walk', 'a', 'circl', 'to', 'the', 'left']),
#  ('00065', ['someon', 'walk', 'in', 'a', 'circl', 'to', 'the', 'left']),
#  ('00066', ['a', 'person', 'walk', 'in', 'a', 'circl', 'to', 'the', 'left']),
#  ('00067', ['a', 'person', 'walk', 'in', 'a', 'counter-clockwis', 'circl']),
#  ('00067', ['a', 'human', 'walk', 'in', 'a', 'counter-clockwis', 'circl']),
#  ('00067', ['person', 'walk', 'in', 'a', 'circl']),
#  ('00067', ['someon', 'walk', 'around', 'slowli']),
#  ('00067', ['walk', 'in', 'a', 'small', 'circl']),
#  ('00067', ['the', 'person', 'walk', 'in', 'a', 'circl']),
#  ('00067', ['a', 'person', 'walk', 'a', 'circl']),
#  ('00067',
#   ['a', 'person', 'walk', 'in', 'a', 'circl', 'to', 'hi', 'left', 'side']),
#  ('00067', ['human', 'goe', 'in', 'a', 'circl', 'counterclockwis']),
#  ('00067', ['someon', 'walk', 'a', 'anticlockwis']),
#  ('00068', ['someon', 'walk', 'a', 'right', 'circl']),
#  ('00069', ['a', 'person', 'is', 'walk', 'in', 'a', 'clockwis', 'circl']),
#  ('00070', ['a', 'person', 'walk', 'a', 'circl', 'clockwis']),
#  ('00070',
#   ['someon', 'walk', 'in', 'a', 'small', 'circl', 'to', 'the', 'right']),
#  ('00071', ['a', 'human', 'walk', 'in', 'a', 'circl', 'clockwis']),
#  ('00071',
#   ['a',
#    'person',
#    'walk',
#    'a',
#    'circl',
#    ',',
#    'radiu',
#    'approximatli',
#    '1,5',
#    'm']),
#  ('00072', ['a', 'person', 'walk', 'in', 'a', 'circl']),
#  ('00073', ['a', 'person', 'walk', 'in', 'a', 'circl']),
#  ('00074', ['a', 'person', 'is', 'walk', 'in', 'a', 'small', 'circl']),
#  ('00075', ['subject', 'walk', 'in', 'a', 'circl', 'clockwis']),
#  ('00075',
#   ['a',
#    'person',
#    'walk',
#    'a',
#    'right',
#    'side',
#    'circl',
#    ',',
#    'radiu',
#    'approximatli',
#    '50cm']),
#  ('00076', ['a', 'person', 'walk', 'in', 'a', 'circl', 'to', 'the', 'right']),
#  ('00077', ['a', 'person', 'walk', 'in', 'a', 'clockwis', 'circl']),
#  ('00077', ['a', 'person', 'walk', 'in', 'a', 'clockwis', 'circl']),
#  ('00077', ['a', 'person', 'walk', 'in', 'a', 'circl']),
#  ('00077', ['a', 'person', 'turn', 'to', 'hi', 'right']),
#  ('00077', ['someon', 'is', 'walk', 'one', 'round', 'to', 'hi', 'side']),
#  ('00077',
#   ['a',
#    'person',
#    'is',
#    'walk',
#    'to',
#    'the',
#    'left',
#    'by',
#    'make',
#    'a',
#    'circl',
#    'shape']),
#  ('00077', ['a', 'person', 'goe', 'around', 'in', 'a', 'circuit']),
#  ('00077', ['a', 'person', 'walk', 'in', 'a', 'circl', 'to', 'the', 'right']),
#  ('00077', ['somebodi', 'walk', 'a', 'circl', 'clockwis']),
#  ('00078',
#   ['subject', 'walk', 'in', 'a', 'quarter', 'circl', 'counterclockwis']),
#  ('00078', ['a', 'person', 'walk', 'a', 'quarter', ',', 'left-sid', 'circl']),
#  ('00079',
#   ['the',
#    'person',
#    'is',
#    'walk',
#    'to',
#    'the',
#    'left',
#    'by',
#    'follow',
#    'a',
#    'half',
#    'circl',
#    'path']),
#  ('00079', ['a', 'person', 'move', 'to', 'the', 'left']),
#  ('00079', ['a', 'person', 'walk', 'to', 'the', 'left']),
#  ('00079', ['somebodi', 'walk', 'a', 'quarter', 'circl', 'anticlockwis']),
#  ('00080', ['a', 'person', 'walk', 'in', 'a', 'quarter', 'circl']),
#  ('00080',
#   ['a', 'person', 'is', 'walk', 'a', 'quarter', 'circl', 'to', 'the', 'left']),
#  ('00080',
#   ['a', 'person', 'walk', 'in', 'a', 'quarter', 'of', 'a', 'small', 'circl']),
#  ('00081', ['a', 'person', 'walk', 'and', 'turn', 'to', 'the', 'left']),
#  ('00081', ['someon', 'walk', 'a', 'left', 'turn']),
#  ('00082',
#   ['subject', 'walk', 'in', 'a', 'quarter', 'circl', 'counterclockwis']),
#  ('00082',
#   ['a',
#    'person',
#    'walk',
#    'to',
#    'the',
#    'left',
#    'perform',
#    'a',
#    'quarter',
#    'circl']),
#  ('00083', ['a', 'human', 'make', 'a', 'left', 'turn']),
#  ('00083', ['a', 'person', 'goe', 'left', 'around', 'a', 'corner']),
#  ('00084',
#   ['a',
#    'person',
#    'walk',
#    'slowli',
#    'in',
#    'a',
#    'quartercircl',
#    'to',
#    'the',
#    'left']),
#  ('00085',
#   ['a',
#    'human',
#    'walk',
#    'a',
#    'quarter',
#    'of',
#    'a',
#    'circl',
#    'to',
#    'the',
#    'left']),
#  ('00085', ['the', 'human', 'perfom', 'a', 'left', 'turn']),
#  ('00086',
#   ['a', 'person', 'walk', 'a', '90', 'degre', 'curv', 'to', 'the', 'left']),
#  ('00086',
#   ['somebodi',
#    'walk',
#    'a',
#    'quarter',
#    'circl',
#    'against',
#    'the',
#    'clockwis',
#    'direct']),
#  ('00087', ['a', 'person', 'walk', 'toward', 'the', 'left']),
#  ('00087',
#   ['human',
#    'goe',
#    'in',
#    'a',
#    'quater',
#    'circl',
#    'counterclockwis',
#    'start',
#    'with',
#    'left']),
#  ('00087', ['a', 'person', 'walk', 'a', 'left', 'turn']),
#  ('00088', ['a', 'person', 'is', 'turn', 'right']),
#  ('00089',
#   ['a',
#    'human',
#    'walk',
#    'a',
#    'quarter',
#    'of',
#    'a',
#    'circl',
#    'to',
#    'the',
#    'right']),
#  ('00090', ['a', 'person', 'walk', 'and', 'turn', 'to', 'the', 'right']),
#  ('00091', ['a', 'person', 'walk', 'in', 'a', 'right', 'turn']),
#  ('00091', ['a', 'person', 'walk', 'a', 'quarter', 'circl', 'clockwis']),
#  ('00092',
#   ['the', 'person', 'is', 'make', 'a', 'wide', 'turn', 'to', 'the', 'right']),
#  ('00092',
#   ['a',
#    'person',
#    'walk',
#    'in',
#    'a',
#    'quarter',
#    'circl',
#    'to',
#    'the',
#    'right']),
#  ('00093', ['person', 'walk', 'to', 'the', 'right']),
#  ('00093',
#   ['human',
#    'goe',
#    'in',
#    'a',
#    'quarter',
#    'circl',
#    'clockwis',
#    'start',
#    'with',
#    'right']),
#  ('00093',
#   ['someon', 'is', 'walk', 'a', 'quarter', 'circl', 'to', 'the', 'right']),
#  ('00094',
#   ['a',
#    'person',
#    'walk',
#    'in',
#    'a',
#    'quarter',
#    'circl',
#    'to',
#    'the',
#    'right']),
#  ('00094', ['the', 'human', 'perfom', 'a', 'right', 'turn']),
#  ('00094', ['someon', 'slowli', 'turn', 'a', 'right', 'corner']),
#  ('00095', ['a', 'human', 'turn', 'right']),
#  ('00095', ['a', 'human', 'perform', 'a', '90', '°', 'right', 'curv']),
#  ('00095', ['a', 'person', 'walk', 'in', 'a', 'curv', 'to', 'the', 'right']),
#  ('00096', ['a', 'person', 'turn', 'right']),
#  ('00097', ['human', 'goe', 'in', 'quater', 'circl', 'clockwis']),
#  ('00097',
#   ['a', 'person', 'walk', 'a', 'quarter', 'circl', 'to', 'the', 'right']),
#  ('00097', ['a', 'person', 'turn', 'right']),
#  ('00097', ['a', 'person', 'walk', 'slowli', 'a', 'right', 'curv']),
#  ('00098', ['the', 'person', 'is', 'perform', 'a', 'forward', 'walk']),
#  ('00098', ['a', 'person', 'is', 'walk', 'relax']),
#  ('00098', ['a', 'person', 'is', 'walk', 'forward']),
#  ('00098', ['a', 'person', 'walk', 'slowli', 'forward']),
#  ('00098', ['a', 'person', 'walk', 'forward']),
#  ('00098', ['a', 'person', 'walk', 'forward']),
#  ('00099', ['a', 'person', 'walk', '5', 'step', 'forward']),
#  ('00099', ['a', 'human', 'is', 'slowli', 'move', 'forward']),
#  ('00099', ['a', 'person', 'take', '4', 'step', 'forward']),
#  ('00099', ['a', 'person', 'take', '4', 'forward', 'step']),
#  ('00100', ['a', 'person', 'walk', 'forward']),
#  ('00101', ['a', 'person', 'walk', '2', 'meter', 'forward']),
#  ('00101', ['a', 'person', 'is', 'walk']),
#  ('00102', ['the', 'subject', 'walk', 'forward']),
#  ('00102', ['person', 'walk', 'forward']),
#  ('00102', ['someon', 'walk', 'away']),
#  ('00102', ['a', 'person', 'walk', 'forward']),
#  ('00102', ['a', 'person', 'just', 'walk']),
#  ('00102', ['a', 'person', 'walk', 'straight', 'forward', 'some', 'step']),
#  ('00102',
#   ['a',
#    'person',
#    'walk',
#    '5',
#    'step',
#    'begin',
#    'with',
#    'the',
#    'left',
#    'foot']),
#  ('00103', ['someon', 'move', 'forward', 'in', 'a', 'slow', 'walk']),
#  ('00103', ['a', 'person', 'walk', 'slowli', 'forward']),
#  ('00104', ['a', 'person', 'walk', 'forward']),
#  ('00105', ['a', 'person', 'walk', 'forward']),
#  ('00105', ['human', 'goe', 'forward']),
#  ('00106',
#   ['a',
#    'human',
#    'look',
#    'to',
#    'the',
#    'left',
#    'and',
#    'then',
#    'walk',
#    'forward']),
#  ('00106', ['a', 'person', 'walk', 'forward']),
#  ('00106', ['a', 'person', 'walk']),
#  ('00107', ['a', 'human', 'walk', 'forward']),
#  ('00108', ['a', 'person', 'walk', 'backward']),
#  ('00108', ['a', 'person', 'walk', 'backward']),
#  ('00108', ['a', 'person', 'walk', 'backward', 'four', 'step']),
#  ('00108', ['a', 'person', 'is', 'step', 'back']),
#  ('00108', ['slowli', 'back', 'off']),
#  ('00108', ['someon', 'is', 'do', 'a', 'few', 'step', 'backward']),
#  ('00108', ['person', 'walk', 'backward']),
#  ('00108', ['a', 'person', 'walk', 'four', 'step', 'backward']),
#  ('00108', ['a', 'person', 'walk', '5', 'step', 'backward']),
#  ('00108', ['a', 'person', 'move', 'backward', 'some', 'meter']),
#  ('00108',
#   ['a',
#    'human',
#    'is',
#    'walk',
#    'backward',
#    'tilt',
#    'it',
#    'head',
#    'a',
#    'littl',
#    'bit',
#    'beforehand']),
#  ('00108', ['a', 'person', 'doe', '4', 'step', 'backward']),
#  ('00108',
#   ['a',
#    'person',
#    'walk',
#    'backward',
#    'while',
#    'move',
#    'slightli',
#    'to',
#    'hi',
#    'left']),
#  ('00108', ['a', 'person', 'back', 'away', 'from', 'someth']),
#  ('00108', ['human', 'goe', 'backward']),
#  ('00108', ['a', 'man', 'walk', 'backward']),
#  ('00109', ['a', 'person', 'walk', '4', 'step', 'backward']),
#  ('00110',
#   ['a',
#    'person',
#    'walk',
#    'backward',
#    ',',
#    'arm',
#    'swing',
#    'by',
#    'hi',
#    'side']),
#  ('00110', ['human', 'goe', 'backward', 'start', 'with', 'left']),
#  ('00110', ['a', 'person', 'walk', 'backward']),
#  ('00110', ['a', 'man', 'is', 'walk', 'backward']),
#  ('00111', ['a', 'person', 'walk', 'backward', 'at', 'medium', 'speed']),
#  ('00111', ['a', 'person', 'walk', 'backward']),
#  ('00112', ['someon', 'walk', 'backward']),
#  ('00112', ['a', 'human', 'is', 'slowli', 'walk', 'backward']),
#  ('00112', ['a', 'person', 'walk', 'backward']),
#  ('00113', ['a', 'person', 'walk', 'four', 'step', 'backward']),
#  ('00113', ['human', 'goe', 'backward']),
#  ('00114', ['a', 'person', 'walk', 'backward']),
#  ('00114', ['a', 'person', 'walk', 'backward']),
#  ('00114', ['someon', 'walk', 'backward']),
#  ('00114', ['a', 'person', 'walk', 'backward']),
#  ('00114', ['human', 'slowli', 'goe', 'backward']),
#  ('00116', ['a', 'person', 'walk', 'backward', 'with', 'medium', 'speed']),
#  ('00116',
#   ['someon', 'is', 'walk', 'backward', 'start', 'with', 'the', 'left', 'leg']),
#  ('00116', ['a', 'person', 'wald', 'backward', 'some', 'step']),
#  ('00116', ['walk', 'backward', 'for', 'a', 'few', 'step']),
#  ('00116', ['a', 'person', 'walk', 'backward']),
#  ('00116', ['a', 'person', 'walk', 'backward', 'for', 'five', 'step']),
#  ('00117', ['a', 'person', 'walk', 'backward']),
#  ('00118', ['human', 'walk', 'in', 'a', 'circl', 'counterclockwis']),
#  ('00118', ['someon', 'is', 'walk', 'in', 'a', 'circl', 'counterclockwis']),
#  ('00118', ['a', 'person', 'walk', 'in', 'a', 'circl', 'to', 'the', 'left']),
#  ('00119', ['a', 'person', 'walk', 'in', 'a', 'circl', 'to', 'the', 'left']),
#  ('00119', ['somebodi', 'walk', 'a', '7/8', 'circl', 'anticlockwis']),
#  ('00120',
#   ['a', 'person', 'walk', 'counterclockwis', 'in', 'a', 'small', 'circl']),
#  ('00121',
#   ['a',
#    'person',
#    'walk',
#    'counter-clockwis',
#    'in',
#    'an',
#    'incomplet',
#    'circl',
#    'and',
#    'stop',
#    'face',
#    'to',
#    'the',
#    'right',
#    'rel',
#    'to',
#    'the',
#    'start',
#    'posit']),
#  ('00121', ['the', 'human', 'walk', 'a', 'circl']),
#  ('00122',
#   ['a', 'person', 'walk', 'counterclockwis', 'in', 'a', 'small', 'circl']),
#  ('00122', ['a', 'person', 'walk', 'count', 'clockwis', 'in', 'a', 'circl']),
#  ('00122', ['a', 'person', 'walk', 'in', 'a', 'circl']),
#  ('00123', ['a', 'person', 'walk', 'in', 'a', 'circl', 'counter-clockwis']),
#  ('00124', ['a', 'human', 'walk', 'in', 'a', 'full', 'circl']),
#  ('00124', ['a', 'person', 'walk', 'in', 'a', 'circl', 'to', 'the', 'left']),
#  ('00125', ['a', 'person', 'walk', 'in', 'a', 'circl', 'counterclockwis']),
#  ('00125', ['the', 'human', 'walk', 'a', 'circl']),
#  ('00126', ['a', 'human', 'walk', 'in', 'a', 'circl', 'counterclockwis']),
#  ('00126', ['a', 'person', 'walk', 'in', 'a', 'circl', 'to', 'the', 'left']),
#  ('00127', ['a', 'person', 'move', 'in', 'a', 'circl', 'counterclockwis']),
#  ('00128', ['a', 'human', 'walk', 'in', 'a', 'circl', 'clockwis']),
#  ('00129', ['a', 'person', 'walk', 'in', 'a', 'clockwis', 'circl']),
#  ('00129',
#   ['a',
#    'human',
#    'perform',
#    'a',
#    'full',
#    '360',
#    '°',
#    'curv',
#    'to',
#    'the',
#    'right',
#    ',',
#    'end',
#    'where',
#    'it',
#    'start']),
#  ('00130',
#   ['a',
#    'person',
#    'walk',
#    'in',
#    'a',
#    'small',
#    'circl',
#    ',',
#    'to',
#    'the',
#    'right']),
#  ('00130',
#   ['human', 'goe', 'in', 'a', 'circl', 'clockwis', 'start', 'with', 'right']),
#  ('00130', ['a', 'person', 'walk', 'in', 'a', 'circl', 'to', 'the', 'right']),
#  ('00130', ['person', 'walk', 'in', 'a', 'circl']),
#  ('00131', ['a', 'person', 'walk', 'a', 'full', 'circl']),
#  ('00131', ['a', 'person', 'walk', 'a', 'circl', 'to', 'the', 'right']),
#  ('00132', ['person', 'walk', 'in', 'a', 'circl']),
#  ('00132', ['someon', 'walk', 'in', 'a', 'clockwis', 'circl']),
#  ('00133', ['a', 'human', 'walk', 'in', 'a', 'circl', 'clockwis']),
#  ('00133', ['a', 'person', 'walk', 'a', 'circl', 'to', 'the', 'right']),
#  ('00134', ['a', 'person', 'walk', 'a', 'circl', 'clockwis']),
#  ('00134', ['a', 'person', 'walk', 'a', 'circl', 'to', 'the', 'right']),
#  ('00135', ['a', 'person', 'walk', 'clockwis', 'in', 'a', 'circl']),
#  ('00136', ['a', 'human', 'walk', 'in', 'a', 'circl', 'clockwis']),
#  ('00136', ['a', 'person', 'is', 'walk', 'in', 'a', 'circl', 'clockwis']),
#  ('00136', ['a', 'human', 'goe', 'around', 'the', 'circl', 'clockwis']),
#  ('00136', ['someon', 'walk', 'a', 'larger', 'clockwis']),
#  ('00136', ['a', 'person', 'walk', 'in', 'a', 'circl', 'to', 'the', 'right']),
#  ('00137', ['a', 'person', 'walk', 'clockwis', 'in', 'a', 'small', 'circl']),
#  ('00138', ['the', 'human', 'walk', 'a', 'left', 'bend']),
#  ('00139', ['a', 'human', 'walk', 'and', 'turn', 'to', 'the', 'left']),
#  ('00139', ['a', 'person', 'is', 'walk', 'in', 'a', 'curv', 'to', 'left']),
#  ('00139', ['a', 'person', 'turn', 'left']),
#  ('00140', ['a', 'human', 'is', 'make', 'a', 'counter-clockwis', 'turn']),
#  ('00140',
#   ['a', 'person', 'is', 'walk', 'a', 'quarter', 'counter-clockwis', 'circl']),
#  ('00140',
#   ['a',
#    'person',
#    'walk',
#    'to',
#    'the',
#    'left',
#    'performin',
#    'a',
#    'quater',
#    'circl']),
#  ('00140', ['a', 'person', 'turn', 'left']),
#  ('00141',
#   ['a',
#    'person',
#    'start',
#    'walk',
#    'in',
#    'a',
#    'circular',
#    'motion',
#    'toward',
#    'the',
#    'left']),
#  ('00141',
#   ['a', 'person', 'walk', 'a', '90', 'degre', 'curv', 'to', 'the', 'left']),
#  ('00141', ['a', 'person', 'walk', 'in', 'a', 'quarter', 'circl']),
#  ('00142', ['a', 'person', 'walk', 'around', 'a', 'corner']),
#  ('00142',
#   ['a', 'person', 'walk', 'and', 'turn', '90', 'degre', 'to', 'the', 'left']),
#  ('00142',
#   ['a', 'person', 'walk', 'a', 'quarter', 'circl', 'to', 'the', 'left']),
#  ('00143',
#   ['a',
#    'person',
#    'turn',
#    '90',
#    '°',
#    'to',
#    'the',
#    'left',
#    'at',
#    'medium',
#    'speed']),
#  ('00144',
#   ['a',
#    'person',
#    'walk',
#    'a',
#    'quarter',
#    'of',
#    'a',
#    'small',
#    'circl',
#    'counterclockwis']),
#  ('00144',
#   ['subject', 'walk', 'in', 'a', 'quarter', 'circl', 'counterclockwis']),
#  ('00144', ['some', 'walk', 'a', 'quarter', 'circl', 'to', 'the', 'left']),
#  ('00145', ['a', 'person', 'walk', 'and', 'turn', 'to', 'the', 'left']),
#  ('00145', ['a', 'person', 'walk', 'in', 'a', 'quarter-circl']),
#  ('00145', ['a', 'human', 'perform', 'a', 'u-turn']),
#  ('00145',
#   ['a',
#    'person',
#    'is',
#    'walk',
#    'two',
#    'meter',
#    'straight',
#    ',',
#    'than',
#    'one',
#    'step',
#    'to',
#    'the',
#    'left']),
#  ('00145',
#   ['a', 'person', 'walk', 'along', 'and', 'turn', 'to', 'the', 'left']),
#  ('00145', ['a', 'person', 'walk', 'a', 'curv', 'to', 'the', 'left']),
#  ('00145',
#   ['someon',
#    'is',
#    'walk',
#    'a',
#    'quarter',
#    'round',
#    'to',
#    'hi',
#    'left',
#    'side']),
#  ('00145',
#   ['a',
#    'person',
#    'walk',
#    'a',
#    '90',
#    'degre',
#    'turn',
#    'toward',
#    'the',
#    'left']),
#  ('00145',
#   ['a',
#    'person',
#    'first',
#    'walk',
#    'and',
#    'then',
#    'turn',
#    'to',
#    'the',
#    'left']),
#  ('00145', ['a', 'person', 'walk', 'to', 'the', 'left']),
#  ('00145',
#   ['a', 'human', 'is', 'walk', 'in', 'a', '90', '°', 'right', 'curv']),
#  ('00145',
#   ['someon', 'walk', 'in', 'a', 'quarter', 'circl', 'to', 'the', 'left']),
#  ('00146', ['a', 'human', 'turn', 'left']),
#  ('00146', ['a', 'person', 'walk', 'a', 'left', 'turn', 'of', '90', 'degre']),
#  ('00147',
#   ['a',
#    'person',
#    'walk',
#    'forward',
#    ',',
#    'slowli',
#    'turn',
#    'to',
#    'the',
#    'left',
#    'and',
#    'stop']),
#  ('00147', ['someon', 'walk', 'a', 'left', 'turn']),
#  ('00147', ['a', 'person', 'turn', 'left']),
#  ('00148',
#   ['a',
#    'person',
#    'walk',
#    'in',
#    'a',
#    'quarter',
#    'circl',
#    'clockwis',
#    'with',
#    '4',
#    'step']),
#  ('00148',
#   ['a', 'person', 'walk', 'a', 'quarter', ',', 'right', 'side', 'circl']),
#  ('00149',
#   ['a',
#    'person',
#    'walk',
#    'a',
#    'quarter',
#    'circl',
#    'clockwis',
#    'with',
#    '4',
#    'step']),
#  ('00149',
#   ['human', 'perform', 'a', 'bend', 'walk', 'movement', 'to', 'the', 'right']),
#  ('00150',
#   ['a',
#    'person',
#    'walk',
#    'forward',
#    'while',
#    'gradual',
#    'turn',
#    'to',
#    'the',
#    'right']),
#  ('00151', ['a', 'person', 'is', 'turn', 'right']),
#  ('00151',
#   ['a',
#    'human',
#    'is',
#    'walk',
#    'in',
#    'a',
#    'quarter',
#    'of',
#    'a',
#    'circl',
#    'to',
#    'the',
#    'right']),
#  ('00151', ['a', 'human', 'is', 'perform', 'a', '90', '°', 'right', 'curv']),
#  ('00152', ['person', 'walk', 'to', 'the', 'right']),
#  ('00152', ['a', 'person', 'walk', 'and', 'turn', 'right']),
#  ('00152', ['a', 'person', 'walk', 'to', 'the', 'right']),
#  ('00153', ['a', 'person', 'goe', 'to', 'the', 'right', 'slowli']),
#  ('00153', ['a', 'person', 'walk', 'a', 'right', 'curv']),
#  ('00154', ['a', 'person', 'turn', 'right', 'at', 'medium', 'speed']),
#  ('00154',
#   ['a', 'person', 'walk', 'to', 'the', 'right', 'in', 'a', 'quter', 'circl']),
#  ('00155', ['a', 'person', 'turn', 'right']),
#  ('00155',
#   ['a',
#    'person',
#    'slowli',
#    'walk',
#    'a',
#    '90',
#    '°',
#    'turn',
#    'in',
#    'four',
#    'step']),
#  ('00156',
#   ['the',
#    'person',
#    'is',
#    'first',
#    'walk',
#    'ahead',
#    'and',
#    'then',
#    'turn',
#    'to',
#    'the',
#    'right']),
#  ('00157', ['a', 'person', 'turn', 'right']),
#  ('00158', ['person', 'walk', 'forward']),
#  ('00158', ['someon', 'walk', 'slowli']),
#  ('00158', ['a', 'person', 'walk', 'forward']),
#  ('00158', ['a', 'human', 'take', 'slow', 'step', 'forward']),
#  ('00158', ['a', 'person', 'walk', 'forward']),
#  ('00159', ['a', 'person', 'is', 'walk', 'slowli', 'and', 'stop']),
#  ('00159', ['a', 'person', 'walk', 'forward']),
#  ('00160', ['a', 'person', 'walk', 'forward']),
#  ('00160', ['someon', 'walk', 'forward']),
#  ('00161', ['a', 'person', 'goe', 'slowli', '5', 'step', 'forward']),
#  ('00161', ['a', 'person', 'walk', 'slowli', 'forward']),
#  ('00161', ['a', 'person', 'slowli', 'walk', '4', 'step', 'forward']),
#  ('00162', ['a', 'person', 'walk', '4', 'step', 'forward']),
#  ('00162', ['a', 'person', 'walk', '4', 'step']),
#  ('00163', ['a', 'person', 'walk', 'forward']),
#  ('00163', ['a', 'person', 'walk', 'a', 'few', 'step', 'forward']),
#  ('00164', ['a', 'person', 'walk', 'forward']),
#  ('00164', ['a', 'person', 'walk', '4', 'step', 'forward']),
#  ('00165', ['someon', 'walk', 'forward']),
#  ('00165', ['a', 'person', 'take', '5', 'step', 'forward']),
#  ('00165', ['a', 'person', 'walk', 'forward', 'quit', 'slow']),
#  ('00166', ['a', 'human', 'walk', 'slowli']),
#  ('00167', ['the', 'person', 'is', 'walk', 'forward']),
#  ('00167', ['the', 'human', 'perfom', 'a', 'coupl', 'of', 'step']),
#  ('00167', ['a', 'person', 'walk', 'forward']),
#  ('00168', ['a', 'human', 'goe', 'slowli', '5', 'step', 'backward']),
#  ('00168',
#   ['a',
#    'person',
#    'take',
#    '5',
#    'step',
#    'backward',
#    'stare',
#    'with',
#    'the',
#    'left',
#    'foot']),
#  ('00168', ['a', 'person', 'walk', 'backward']),
#  ('00168', ['a', 'person', 'walk', 'five', 'step', 'backward']),
#  ('00169',
#   ['a',
#    'person',
#    'walk',
#    'backward',
#    '4',
#    'step',
#    'with',
#    'rel',
#    'small',
#    'step']),
#  ('00169',
#   ['a',
#    'person',
#    'take',
#    '4',
#    'step',
#    'backward',
#    'start',
#    'with',
#    'the',
#    'left',
#    'foot']),
#  ('00169', ['a', 'person', 'take', 'five', 'backward', 'step']),
#  ('00170', ['the', 'person', 'is', 'walk', 'backward']),
#  ('00170', ['a', 'person', 'walk', 'backward']),
#  ('00171', ['a', 'person', 'walk', 'slowli', 'five', 'step', 'backward']),
#  ('00171', ['a', 'person', 'is', 'walk', 'backward']),
#  ('00171', ['someon', 'walk', 'backward']),
#  ('00172', ['a', 'person', 'goe', 'back', '4', 'step']),
#  ('00173', ['a', 'human', 'walk', 'backward']),
#  ('00173', ['a', 'person', 'step', 'backward']),
#  ('00173', ['a', 'person', 'take', 'some', 'step', 'backward']),
#  ('00174', ['a', 'person', 'take', 'four', 'step', 'back']),
#  ('00174', ['a', 'person', 'walk', 'back', 'some', 'meter']),
#  ('00175',
#   ['a', 'person', 'walk', '4', 'step', 'to', 'the', 'backward', 'direct']),
#  ('00175', ['a', 'person', 'make', '4', 'step', 'backward']),
#  ('00175', ['a', 'person', 'walk', 'backward']),
#  ('00175', ['a', 'person', 'slowli', 'retreat']),
#  ('00175', ['someon', 'walk', 'backward']),
#  ('00176', ['a', 'person', 'walk', 'a', 'few', 'step', 'backward']),
#  ('00176', ['a', 'person', 'walk', 'backward', 'about', '4', 'step']),
#  ('00177', ['a', 'person', 'walk', 'backward']),
#  ('00177', ['someon', 'walk', 'backward']),
#  ('00177', ['a', 'person', 'walk', 'backward']),
#  ('00177', ['a', 'person', 'slowli', 'walk', 'backward']),
#  ('00177', ['a', 'person', 'walk', '5', 'step', 'backward']),
#  ('00177', ['a', 'person', 'take', 'a', 'few', 'step', 'backward']),
#  ('00178', ['a', 'human', 'walk', 'in', 'circl']),
#  ('00178', ['a', 'person', 'walk', 'in', 'a', 'counter-clockwis', 'circl']),
#  ('00178', ['some', 'walk', 'anticlockwis']),
#  ('00178', ['a', 'person', 'walk', 'in', 'a', 'circl', 'to', 'the', 'left']),
#  ('00179',
#   ['a', 'person', 'walk', 'around', 'in', 'a', 'circl', 'anti-clockwis']),
#  ('00179', ['someon', 'walk', 'in', 'a', 'circl', 'counterclockwis']),
#  ('00179',
#   ['a',
#    'person',
#    'walk',
#    'in',
#    'a',
#    'circl',
#    'to',
#    'the',
#    'left',
#    'take',
#    '8',
#    'step']),
#  ('00180', ['a', 'person', 'walk', 'in', 'a', 'circl', 'to', 'the', 'left']),
#  ('00180',
#   ['a', 'person', 'is', 'walk', 'in', 'a', 'circl', 'counter-clockwis']),
#  ('00180', ['a', 'human', 'is', 'walk', 'in', 'circl']),
#  ('00181',
#   ['a', 'person', 'walk', 'in', 'a', 'small', 'circl', 'counterclockwis']),
#  ('00181',
#   ['a',
#    'human',
#    'walk',
#    'in',
#    'circl',
#    'counterclockwis',
#    'make',
#    'long',
#    'step']),
#  ('00182', ['a', 'person', 'walk', 'clockwis', 'in', 'a', 'circl']),
#  ('00183', ['a', 'person', 'walk', 'in', 'circl']),
#  ('00183',
#   ['a', 'person', 'walk', 'forward', 'counterclockwis', 'in', 'a', 'circl']),
#  ('00183', ['a', 'person', 'walk', 'in', 'a', 'circl', 'to', 'the', 'left']),
#  ('00184',
#   ['a',
#    'person',
#    'walk',
#    'slowli',
#    'in',
#    'a',
#    'counterclockwis',
#    'small',
#    'circl']),
#  ('00185', ['a', 'human', 'walk', 'in', 'a', 'counter-clockwis', 'circl']),
#  ('00186', ['a', 'person', 'walk', 'a', 'circl']),
#  ('00186', ['subject', 'walk', 'in', 'a', 'circl', 'counterclockwis']),
#  ('00187', ['a', 'person', 'walk', 'in', 'a', 'circl', 'to', 'the', 'left']),
#  ('00188', ['a', 'person', 'walk', 'in', 'a', 'clockwis', 'circl']),
#  ('00189', ['a', 'human', 'is', 'walk', 'clockwis', 'in', 'a', 'circl']),
#  ('00189', ['a', 'person', 'walk', 'a', 'circl', 'to', 'the', 'right']),
#  ('00190', ['a', 'person', 'walk', 'a', 'circl']),
#  ('00191', ['someon', 'walk', 'a', 'clockwis', 'circl']),
#  ('00191', ['a', 'person', 'is', 'walk', 'a', 'clockwis', 'circl']),
#  ('00191', ['a', 'person', 'walk', 'in', 'a', 'circl']),
#  ('00191', ['a', 'human', 'is', 'walk', 'in', 'circl', 'to', 'the', 'right']),
#  ('00192', ['the', 'person', 'is', 'walk', 'in', 'a', 'circular', 'shape']),
#  ('00192', ['person', 'walk', 'a', 'circl']),
#  ('00193', ['a', 'person', 'walk', 'in', 'a', 'circl', 'clockwis']),
#  ('00194', ['someon', 'is', 'walk', 'a', 'small', 'clockwis', 'circl']),
#  ('00194',
#   ['a', 'person', 'walk', 'in', 'circl', 'to', 'hi', 'right', 'side']),
#  ('00194', ['a', 'person', 'walk', 'in', 'a', 'circl', 'to', 'the', 'right']),
#  ('00195', ['a', 'person', 'walk', 'a', 'circl', 'clockwis']),
#  ('00196', ['someon', 'walk', 'in', 'a', 'clockwis', 'circl']),
#  ('00196',
#   ['human', 'goe', 'in', 'a', 'circl', 'clockwis', 'start', 'with', 'right']),
#  ('00197', ['a', 'person', 'walk', 'in', 'a', 'circl', 'to', 'the', 'right']),
#  ('00197', ['a', 'person', 'walk', 'in', 'a', 'cirlc', 'to', 'the', 'right']),
#  ('00198', ['a', 'person', 'goe', 'to', 'the', 'right']),
#  ('00199', ['the', 'human', 'walk', 'a', 'right', 'bend']),
#  ('00199',
#   ['somon', 'walk', 'in', 'a', 'quarter', 'circl', 'to', 'the', 'right']),
#  ('00200', ['someon', 'walk', 'in', 'a', 'slight', 'right', 'curv']),
#  ('00201', ['person', 'walk', 'to', 'the', 'right']),
#  ('00201',
#   ['human',
#    'goe',
#    'in',
#    'a',
#    'quarter',
#    'circl',
#    'clockwis',
#    'start',
#    'with',
#    'right']),
#  ('00202',
#   ['a',
#    'person',
#    'is',
#    'walk',
#    'forward',
#    'start',
#    'with',
#    'the',
#    'right',
#    'feet',
#    'and',
#    'perform',
#    'five',
#    'step',
#    'while',
#    'turn',
#    'to',
#    'the',
#    'right',
#    'with',
#    'an',
#    'angl',
#    'of',
#    '90',
#    '°']),
#  ('00202',
#   ['a',
#    'person',
#    'walk',
#    'in',
#    'a',
#    'quarter',
#    'circl',
#    'to',
#    'the',
#    'right']),
#  ('00203',
#   ['a', 'person', 'walk', 'a', 'quarter', 'circl', 'to', 'the', 'right']),
#  ('00204',
#   ['a',
#    'person',
#    'turn',
#    '90',
#    '°',
#    'to',
#    'the',
#    'right',
#    'at',
#    'medium',
#    'speed']),
#  ('00204', ['a', 'person', 'is', 'turn', 'right', 'while', 'walk']),
#  ('00205', ['a', 'person', 'walk', 'to', 'the', 'right']),
#  ('00206', ['a', 'human', 'is', 'make', 'a', 'clockwis', 'turn']),
#  ('00206',
#   ['a',
#    'person',
#    'is',
#    'walk',
#    'a',
#    'quarter',
#    'circl',
#    'in',
#    'clockwis',
#    'direct']),
#  ('00207', ['a', 'person', 'turn', 'right']),
#  ('00207',
#   ['a',
#    'person',
#    'walk',
#    'a',
#    'quarter',
#    'circl',
#    'clockwis',
#    'with',
#    '4',
#    'step']),
#  ('00207',
#   ['a', 'person', 'walk', 'a', '90', '°', 'curv', 'to', 'hi', 'right']),
#  ('00207', ['someon', 'turn', 'right']),
#  ('00208', ['a', 'person', 'walk', 'forward', 'veri', 'slowli']),
#  ('00208', ['subject', 'walk', 'forward', 'slowli']),
#  ('00208', ['a', 'person', 'walk', 'forward', 'quit', 'slow']),
#  ('00209', ['a', 'person', 'walk', 'slowli', 'and', 'stop']),
#  ('00209',
#   ['a', 'person', 'walk', 'straight', 'forward', 'for', 'some', 'meter']),
#  ('00210', ['a', 'person', 'walk', '4', 'step', 'forward']),
#  ('00211', ['subject', 'walk', 'forward']),
#  ('00211',
#   ['a',
#    'person',
#    'start',
#    'walk',
#    '4',
#    'step',
#    'forward',
#    'and',
#    'then',
#    'stop']),
#  ('00212', ['a', 'person', 'walk', 'a', 'few', 'step']),
#  ('00213',
#   ['a',
#    'human',
#    'walk',
#    'at',
#    'a',
#    'slight',
#    'left',
#    'angl',
#    'for',
#    'five',
#    'step',
#    'and',
#    'then',
#    'stop']),
#  ('00213', ['someon', 'walk', 'forward']),
#  ('00214', ['a', 'person', 'walk', '4', 'step', 'forward']),
#  ('00215', ['a', 'person', 'walk', 'forward']),
#  ('00216', ['a', 'person', 'walk', 'a', 'few', 'step', 'forward']),
#  ('00217', ['a', 'person', 'walk', 'forward', 'for', 'a', 'few', 'step']),
#  ('00217', ['a', 'person', 'walk', 'forward']),
#  ('00218', ['person', 'walk', 'backward']),
#  ('00218', ['human', 'goe', 'backward', 'start', 'with', 'left']),
#  ('00218', ['a', 'person', 'is', 'walk', 'backward']),
#  ('00218', ['a', 'person', 'walk', 'backward']),
#  ('00219', ['someon', 'walk', 'slowli', 'backward']),
#  ('00219', ['a', 'person', 'walk', 'backward']),
#  ('00219', ['a', 'person', 'slowli', 'walk', 'back', 'take', '4', 'step']),
#  ('00222', ['a', 'person', 'move', 'backward']),
#  ('00223', ['a', 'person', 'walk', 'backward']),
#  ('00223', ['a', 'person', 'walk', 'backward']),
#  ('00224', ['someon', 'walk', 'backward', 'four', 'step']),
#  ('00224', ['a', 'person', 'walk', 'backward']),
#  ('00225', ['a', 'person', 'walk', 'backward']),
#  ('00225', ['human', 'goe', 'backward']),
#  ('00225', ['a', 'person', 'walk', 'a', 'few', 'step', 'backward']),
#  ('00225', ['somebodi', 'walk', 'backward']),
#  ('00226', ['a', 'person', 'walk', 'backward']),
#  ('00227', ['subject', 'walk', 'in', 'a', 'full', 'circl', 'counterclockwis']),
#  ('00227', ['the', 'human', 'walk', 'a', 'circl']),
#  ('00228', ['person', 'walk', 'in', 'a', 'circl']),
#  ('00228', ['a', 'person', 'walk', 'in', 'a', 'counter-clockwis', 'circl']),
#  ('00228', ['a', 'person', 'walk', 'in', 'a', 'circl', 'to', 'the', 'left']),
#  ('00228',
#   ['a',
#    'person',
#    'move',
#    'anti-clockwis',
#    'in',
#    'a',
#    'cirl',
#    'and',
#    'need',
#    '8',
#    'step',
#    'to',
#    'complet',
#    'the',
#    'circl']),
#  ('00228', ['a', 'person', 'walk', 'in', 'a', 'small', 'circl']),
#  ('00229',
#   ['a', 'person', 'walk', 'in', 'a', 'narrow', 'counter-clockwis', 'circl']),
#  ('00229', ['subject', 'in', 'small', 'circl', 'counterclockwis']),
#  ('00229',
#   ['someon',
#    'slowli',
#    'walk',
#    'in',
#    'a',
#    'small',
#    'circl',
#    'to',
#    'the',
#    'left']),
#  ('00229', ['someon', 'walk', 'a', 'circl']),
#  ('00229',
#   ['a', 'human', 'walk', 'slowli', 'in', 'circl', ',', 'counterclockwis']),
#  ('00229', ['a', 'human', 'goe', 'a', 'circl', 'left', 'around']),
#  ('00230',
#   ['subject', 'walk', 'in', 'a', 'quarter', 'circl', 'counterclockwis']),
#  ('00230', ['a', 'person', 'is', 'walk', 'in', 'a', 'circl']),
#  ('00231', ['a', 'person', 'walk', 'counter-clockwis', 'in', 'a', 'circl']),
#  ('00231', ['a', 'person', 'walk', 'in', 'a', 'circl']),
#  ('00231', ['somebodi', 'walk', 'a', 'circl', 'anticlockwis']),
#  ('00232', ['walk', 'in', 'a', 'circl']),
#  ('00232',
#   ['a', 'person', 'walk', 'a', 'circl', 'in', 'the', 'left', 'direct']),
#  ('00232', ['a', 'person', 'walk', 'in', 'a', 'circl']),
#  ('00233',
#   ['the', 'person', 'make', 'a', 'walk', 'along', 'a', 'circular', 'path']),
#  ('00233', ['someon', 'is', 'walk', 'in', 'a', 'circl', 'counterclockwis']),
#  ('00233', ['a', 'person', 'walk', 'a', 'circl', 'to', 'the', 'left']),
#  ('00233', ['a', 'person', 'is', 'walk', 'in', 'a', 'circl']),
#  ('00234', ['a', 'person', 'move', 'in', 'a', 'circl']),
#  ('00235', ['a', 'person', 'move', 'in', 'a', 'circl', 'clockwis']),
#  ('00235', ['a', 'human', 'walk', 'a', 'small', 'circl', 'to', 'it', 'left']),
#  ('00236',
#   ['a', 'person', 'walk', 'in', 'a', 'small', 'circl', 'counter', 'clockwis']),
#  ('00237', ['a', 'human', 'walk', 'in', 'a', 'circl', 'clockwis']),
#  ('00237',
#   ['a', 'person', 'walk', 'a', 'full', 'circl', 'to', 'the', 'right']),
#  ('00238', ['subject', 'walk', 'in', 'a', 'circl', 'clockwis']),
#  ('00239',
#   ['a', 'person', 'walk', 'slowli', 'in', 'a', 'circl', 'to', 'the', 'right']),
#  ('00239', ['a', 'person', 'walk', 'forward', 'in', 'a', 'circl', 'clockwis']),
#  ('00239', ['a', 'person', 'walk', 'in', 'a', 'circl', 'to', 'the', 'right']),
#  ('00240', ['a', 'person', 'walk', 'in', 'circl']),
#  ('00240', ['a', 'person', 'is', 'walk', 'in', 'a', 'clockwis', 'circl']),
#  ('00241', ['a', 'person', 'walk', 'in', 'a', 'circl']),
#  ('00241', ['someon', 'goe', 'around', 'in', 'a', 'circuit']),
#  ('00241', ['a', 'person', 'walk', 'in', 'a', 'circl', 'to', 'the', 'right']),
#  ('00241', ['a', 'human', 'is', 'perform', 'a', 'right', '360', '°', 'curv']),
#  ('00242', ['a', 'person', 'walk', 'in', 'a', 'circl']),
#  ('00243', ['subject', 'walk', 'in', 'a', 'circl', 'clockwis']),
#  ('00243', ['a', 'person', 'walk', 'clockwis', 'forward', 'in', 'a', 'circl']),
#  ('00244',
#   ['a',
#    'person',
#    'walk',
#    'slowli',
#    'in',
#    'a',
#    'circl',
#    'in',
#    'clockwis',
#    'direct']),
#  ('00244',
#   ['a',
#    'human',
#    'walk',
#    'slowli',
#    'a',
#    'full',
#    'circl',
#    'to',
#    'it',
#    'right',
#    'and',
#    'end',
#    'up',
#    'on',
#    'the',
#    'spot',
#    'where',
#    'it',
#    'start']),
#  ('00245', ['a', 'person', 'walk', 'in', 'a', 'clockwis', 'circl']),
#  ('00245', ['a', 'person', 'walk', 'in', 'a', 'littl', 'circl']),
#  ('00245', ['a', 'person', 'walk', 'forward', 'in', 'a', 'circl', 'clockwis']),
#  ('00246', ['a', 'person', 'perform', 'a', 'circular', 'movement']),
#  ('00246', ['walk', 'in', 'a', 'circl', 'to', 'the', 'right']),
#  ('00247', ['someon', 'walk', 'a', 'quarter-circl', 'to', 'the', 'right']),
#  ('00247',
#   ['a', 'person', 'slowli', 'walk', 'a', 'quarter', 'ride', 'side', 'circl']),
#  ('00248', ['a', 'human', 'walk', 'and', 'turn', 'to', 'the', 'right']),
#  ('00248', ['someon', 'walk', 'a', 'right', 'turn']),
#  ('00248', ['a', 'person', 'walk', 'to', 'the', 'right']),
#  ('00249', ['a', 'human', 'is', 'make', 'a', 'clockwis', 'turn']),
#  ('00249', ['a', 'person', 'walk', 'to', 'the', 'right']),
#  ('00250', ['a', 'person', 'turn', 'left', 'at', 'medium', 'speed']),
#  ('00251',
#   ['a', 'human', 'walk', 'a', '90', 'degre', 'arc', 'to', 'the', 'right']),
#  ('00251', ['someon', 'walk', 'a', 'circl', 'clockwis']),
#  ('00251', ['a', 'person', 'walk', 'a', 'circl']),
#  ('00252',
#   ['a',
#    'person',
#    'start',
#    'a',
#    'circular',
#    'movement',
#    'toward',
#    'the',
#    'right']),
#  ('00252', ['someon', 'walk', 'a', 'right', 'turn']),
#  ('00253',
#   ['a', 'person', 'turn', 'around', 'a', 'corner', 'toward', 'the', 'right']),
#  ('00253',
#   ['a', 'person', 'walk', 'a', '90', 'degre', 'curv', 'to', 'the', 'right']),
#  ('00254', ['a', 'person', 'walk', 'a', 'left', 'turn']),
#  ('00254', ['a', 'person', 'turn', 'to', 'hi', 'right']),
#  ('00254',
#   ['human',
#    'perform',
#    'a',
#    'bend',
#    'walk',
#    'motion',
#    'to',
#    'it',
#    'right',
#    'hand',
#    'side']),
#  ('00255', ['someon', 'walk', 'a', 'quarter-circl', 'to', 'the', 'right']),
#  ('00255', ['someon', 'walk', 'a', 'right', 'turn']),
#  ('00255',
#   ['a', 'human', 'perform', 'a', '90', '°', 'curv', 'tu', 'the', 'right']),
#  ('00255', ['a', 'human', 'walk', 'a', 'quarter', 'to', 'hi', 'right']),
#  ('00255', ['a', 'person', 'turn', 'right']),
#  ('00256',
#   ['a',
#    'person',
#    'walk',
#    'forward',
#    'and',
#    'perform',
#    'a',
#    'turn',
#    'to',
#    'the',
#    'right']),
#  ('00256',
#   ['a', 'person', 'walk', 'in', 'a', 'quarter-circl', 'to', 'the', 'right']),
#  ('00256', ['a', 'person', 'walk', 'toward', 'me']),
#  ('00256', ['someon', 'come', 'close', 'to', 'the', 'camera']),
#  ('00256',
#   ['a', 'person', 'is', 'walk', 'in', 'a', 'curv', 'to', 'the', 'right']),
#  ('00256', ['someon', 'come', 'veri', 'close', 'to', 'the', 'observ']),
#  ('00256', ['a', 'human', 'take', 'a', '90', 'degre', 'right', 'turn']),
#  ('00256', ['a', 'person', 'walk', 'five', 'step', 'to', 'the', 'right']),
#  ('00256', ['a', 'person', 'walk', 'slowli', 'a', 'curv']),
#  ('00256',
#   ['a',
#    'person',
#    'walk',
#    'in',
#    'a',
#    '90',
#    'degre',
#    'turn',
#    'toward',
#    'the',
#    'right']),
#  ('00256', ['a', 'human', 'slowli', 'turn', 'right', 'by', '5', 'step']),
#  ('00256',
#   ['a',
#    'person',
#    'walk',
#    'a',
#    'quarter',
#    'circl',
#    'with',
#    'a',
#    'radiu',
#    'of',
#    'approxim',
#    '1',
#    'meter',
#    'to',
#    'the',
#    'right']),
#  ('00256',
#   ['a',
#    'human',
#    'is',
#    'perform',
#    'a',
#    '90',
#    '°',
#    'curv',
#    'to',
#    'the',
#    'right']),
#  ('00256',
#   ['a',
#    'person',
#    'is',
#    'walk',
#    'a',
#    'quarter',
#    'of',
#    'a',
#    'circl',
#    'to',
#    'it',
#    'right']),
#  ('00256',
#   ['a',
#    'person',
#    'walk',
#    'to',
#    'the',
#    'right',
#    'perform',
#    'a',
#    'quarter',
#    'circl']),
#  ('00256',
#   ['a',
#    'person',
#    'walk',
#    'forward',
#    'in',
#    'a',
#    '90',
#    '°',
#    'curv',
#    'to',
#    'hi',
#    'right']),
#  ('00256', ['the', 'human', 'perfom', 'a', 'right', 'turn']),
#  ('00256',
#   ['a',
#    'person',
#    'is',
#    'do',
#    'slow',
#    'a',
#    '90',
#    '°',
#    'right',
#    'turn',
#    'in',
#    'five',
#    'step']),
#  ('00256',
#   ['human', 'perform', 'a', 'bend', 'walk', 'motion', 'to', 'the', 'right']),
#  ('00257',
#   ['a',
#    'person',
#    'start',
#    'a',
#    'circular',
#    'movement',
#    'toward',
#    'the',
#    'left']),
#  ('00257',
#   ['human',
#    'slowli',
#    'goe',
#    'in',
#    'a',
#    'quater',
#    'circl',
#    'counterclockwis',
#    'start',
#    'with',
#    'right']),
#  ('00258',
#   ['a',
#    'man',
#    'walk',
#    'a',
#    'quarter',
#    'of',
#    'a',
#    'circl',
#    'toward',
#    'the',
#    'left']),
#  ('00258',
#   ['human',
#    'goe',
#    'in',
#    'a',
#    'quarter',
#    'circl',
#    'counterclockwis',
#    'start',
#    'with',
#    'right']),
#  ('00258',
#   ['a',
#    'human',
#    'walk',
#    'slowli',
#    'a',
#    'quarter',
#    'of',
#    'a',
#    'circl',
#    'to',
#    'it',
#    'left']),
#  ('00259',
#   ['a', 'person', 'walk', 'while', 'gradual', 'turn', 'to', 'the', 'left']),
#  ('00260', ['the', 'human', 'walk', 'a', '90', '-', 'degre', 'left', 'bend']),
#  ('00260', ['a', 'person', 'walk', 'to', 'the', 'left']),
#  ('00260', ['a', 'person', 'turn', 'left']),
#  ('00260',
#   ['someon', 'is', 'walk', 'half', 'a', 'round', 'to', 'hi', 'left', 'side']),
# ...
#  ('00333', ['a', 'person', 'walk', 'backward']),
#  ('00334', ['someon', 'is', 'walk', 'backward', 'four', 'step']),
#  ('00334',
#   ['someon',
#    'doe',
#    '4',
#    'step',
#    'backward',
#    'start',
#    'with',
#    'the',
#    'left',
#    'leg']),
#  ('00334', ['a', 'human', 'is', 'walk', 'backward']),
#  ('00334', ['a', 'person', 'walk', '4', 'step', 'backward']),
#  ('00334', ['a', 'human', 'is', 'walk', 'backward']),
#  ('00335', ['person', 'walk', 'backward']),
#  ('00335', ['a', 'person', 'walk', 'backward']),
#  ('00336', ['a', 'human', 'walk', 'four', 'step', 'backward']),
#  ('00336', ['a', 'person', 'tae', 'some', 'step', 'backward']),
#  ('00336', ['a', 'person', 'walk', '5', 'step', 'backward']),
#  ('00336', ['a', 'human', 'start', 'walk', 'backward']),
#  ('00337', ['a', 'person', 'walk', 'counter', 'clockwis', 'in', 'a', 'circl']),
#  ('00338', ['a', 'person', 'walk', 'in', 'a', 'circl']),
#  ('00339',
#   ['a', 'person', 'walk', 'counterclockwis', 'in', 'a', 'small', 'circl']),
#  ('00339',
#   ['a',
#    'human',
#    'walk',
#    'in',
#    'a',
#    'counterclockwis',
#    'circl',
#    ',',
#    'complet',
#    'one',
#    'round',
#    'in',
#    '8',
#    'step']),
#  ('00339',
#   ['a',
#    'human',
#    'walk',
#    'a',
#    'full',
#    'circl',
#    'to',
#    'it',
#    'left',
#    'and',
#    'stop',
#    'right',
#    'befor',
#    'where',
#    'it',
#    'start']),
#  ('00340', ['subject', 'walk', 'in', 'a', 'full', 'circl', 'counterclockwis']),
#  ('00341', ['a', 'person', 'walk', 'counter', 'clockwis', 'in', 'a', 'circl']),
#  ('00341',
#   ['someon',
#    'walk',
#    'in',
#    'a',
#    'circl',
#    'of',
#    'appoxim',
#    '2',
#    'meter',
#    'in',
#    'diamet',
#    'to',
#    'the',
#    'right']),
#  ('00342', ['person', 'walk', 'in', 'a', 'circl', 'to', 'the', 'left']),
#  ('00342', ['a', 'person', 'walk', 'counter-clockwis', 'circl']),
#  ('00342', ['someon', 'walk', 'a', 'larger', 'anticlockwis']),
#  ('00343', ['walk', 'counter', 'clock-wis', 'in', 'a', 'circl']),
#  ('00343', ['a', 'person', 'walk', 'in', 'a', 'circl', 'round', 'an', 'axi']),
#  ('00344',
#   ['a', 'person', 'walk', 'counterclockwis', 'in', 'a', 'small', 'circl']),
#  ('00344', ['a', 'person', 'walk', 'a', 'circl']),
#  ('00345', ['a', 'person', 'walk', 'in', 'a', 'circl', 'to', 'the', 'left']),
#  ('00346', ['subject', 'walk', 'in', 'a', 'full', 'circl', 'counterclockwis']),
#  ('00346',
#   ['a', 'person', 'walk', 'forward', 'in', 'a', 'counterclockwis', 'circl']),
#  ('00347',
#   ['the',
#    'person',
#    'is',
#    'walk',
#    'back',
#    'to',
#    'the',
#    'initi',
#    'posit',
#    'by',
#    'follow',
#    'a',
#    'circular',
#    'shape']),
#  ('00347', ['a', 'person', 'walk', 'in', 'a', 'circl', 'to', 'the', 'right']),
#  ('00347', ['somebodi', 'walk', 'a', 'circl', 'clockwis']),
#  ('00348', ['subject', 'walk', 'in', 'a', 'full', 'circl', 'clockwis']),
#  ('00348', ['some', 'walk', 'clockwis']),
#  ('00348', ['a', 'person', 'walk', 'in', 'a', 'circl', 'to', 'the', 'right']),
#  ('00348', ['a', 'man', 'walk', 'in', 'small', 'circl', 'to', 'the', 'right']),
#  ('00349', ['a', 'person', 'walk', 'in', 'a', 'circl']),
#  ('00349', ['a', 'person', 'walk', 'to', 'the', 'right', 'in', 'a', 'circl']),
#  ('00349',
#   ['a', 'person', 'walk', 'in', 'a', 'circl', 'to', 'hi', 'right', 'side']),
#  ('00350', ['a', 'human', 'walk', 'in', 'a', 'full', 'circl', 'clockwis']),
#  ('00350', ['a', 'person', 'walk', 'in', 'a', 'clockwis', 'circl']),
#  ('00350', ['a', 'person', 'walk', 'in', 'a', 'circl', 'clockwis']),
#  ('00351', ['a', 'person', 'walk', 'clockwis', 'in', 'a', 'circl']),
#  ('00352', ['a', 'person', 'walk', 'in', 'a', 'circl']),
#  ('00352', ['a', 'person', 'walk', 'in', 'a', 'circl', 'to', 'the', 'right']),
#  ('00353', ['a', 'human', 'walk', 'in', 'a', 'circl', 'clockwis']),
#  ('00354', ['a', 'person', 'walk', 'in', 'a', 'circl', 'clockwis']),
#  ('00355', ['someon', 'walk', 'a', 'full', 'clockwis', 'circl']),
#  ('00355',
#   ['a',
#    'person',
#    'is',
#    'walk',
#    'in',
#    'a',
#    'circl',
#    'in',
#    'clockwis',
#    'direct']),
#  ('00356', ['a', 'person', 'walk', 'in', 'a', 'circl']),
#  ('00356', ['a', 'human', 'perform', 'a', 'jump', 'to', 'the', 'left']),
#  ('00357', ['someon', 'walk', 'a', 'few', 'step', 'in', 'a', 'left', 'bend']),
#  ('00358', ['a', 'person', 'turn', '90', '°', 'to', 'the', 'left']),
#  ('00358', ['a', 'person', 'walk', 'a', 'quarter', 'left', 'side', 'circl']),
#  ('00358', ['a', 'person', 'turn', 'left']),
#  ('00359',
#   ['a',
#    'person',
#    'walk',
#    'a',
#    'quarter',
#    'of',
#    'a',
#    'circl',
#    'counterclockwis']),
#  ('00359', ['a', 'human', 'walk', 'a', 'quarter', 'to', 'the', 'left']),
#  ('00360', ['person', 'walk', 'in', 'a', 'curv', 'to', 'the', 'left']),
#  ('00360',
#   ['human',
#    'goe',
#    'in',
#    'a',
#    'quater',
#    'circl',
#    'counterclockwis',
#    'start',
#    'with',
#    'left']),
#  ('00361', ['a', 'person', 'walk', 'while', 'turn', 'to', 'the', 'left']),
#  ('00361',
#   ['a',
#    'person',
#    'goe',
#    'to',
#    'the',
#    'left',
#    ',',
#    'where',
#    'it',
#    'pass',
#    'through',
#    'a',
#    'quarter',
#    'circl',
#    'line',
#    'along']),
#  ('00361', ['someon', 'turn', 'a', 'left', 'corner']),
#  ('00362',
#   ['subject', 'walk', 'in', 'a', 'quarter', 'circl', 'counterclockwis']),
#  ('00362',
#   ['a',
#    'person',
#    'walk',
#    'to',
#    'the',
#    'left',
#    'perform',
#    'a',
#    'quarter',
#    'circl']),
#  ('00363',
#   ['subject', 'walk', 'in', 'a', 'quarter', 'circl', 'counterclockwis']),
#  ('00364', ['a', 'person', 'turn', 'left']),
#  ('00364', ['someon', 'walk', 'a', 'left', 'turn']),
#  ('00365',
#   ['human',
#    'goe',
#    'in',
#    'a',
#    'quarter',
#    'circl',
#    'counterclockwis',
#    'start',
#    'with',
#    'left']),
#  ('00366',
#   ['a',
#    'person',
#    'walk',
#    'a',
#    'quarter',
#    'circl',
#    'clockwis',
#    'with',
#    '4',
#    'step']),
#  ('00367', ['a', 'human', 'turn', 'right']),
#  ('00367',
#   ['a',
#    'person',
#    'walk',
#    'a',
#    'quarter',
#    'of',
#    'a',
#    'circl',
#    'to',
#    'it',
#    'right']),
#  ('00367',
#   ['a', 'person', 'walk', 'a', 'quarter', 'circl', 'to', 'the', 'right']),
#  ('00368',
#   ['a',
#    'person',
#    'walk',
#    'a',
#    'quarter',
#    'circl',
#    'clockwis',
#    'with',
#    '4',
#    'step']),
#  ('00369',
#   ['human',
#    'walk',
#    'in',
#    'clockwis',
#    'circl',
#    'start',
#    'with',
#    'right',
#    'leg']),
#  ('00369',
#   ['a', 'human', 'is', 'perform', 'a', 'tight', '90', '°', 'right', 'curv']),
#  ('00370', ['a', 'person', 'turn', 'right']),
#  ('00370', ['a', 'person', 'walk', '90degre', 'to', 'the', 'right']),
#  ('00371',
#   ['a',
#    'person',
#    'walk',
#    'a',
#    'quarter',
#    'circl',
#    'clockwis',
#    'with',
#    '4',
#    'step']),
#  ('00372',
#   ['a', 'person', 'walk', 'while', 'gradual', 'turn', 'to', 'the', 'right']),
#  ('00372', ['a', 'person', 'turn', 'right']),
#  ('00372', ['a', 'person', 'walk', 'to', 'the', 'right', '90', 'degre']),
#  ('00373', ['a', 'person', 'walk', 'a', 'quarter', 'of', 'a', 'circl']),
#  ('00373',
#   ['a',
#    'person',
#    'walk',
#    '90degre',
#    'to',
#    'the',
#    'right',
#    'perform',
#    'a',
#    'quarter',
#    'circl']),
#  ('00373', ['somebodi', 'walk', 'a', 'quarter', 'circl', 'clockwis']),
#  ('00374', ['person', 'walk', 'to', 'the', 'right']),
#  ('00374',
#   ['a', 'person', 'walk', 'forward', 'while', 'turn', 'to', 'the', 'right']),
#  ('00375',
#   ['a',
#    'human',
#    'walk',
#    'a',
#    'veri',
#    'slow',
#    '90',
#    'degre',
#    'arc',
#    'to',
#    'the',
#    'right']),
#  ('00375',
#   ['human',
#    'goe',
#    'in',
#    'a',
#    'quarter',
#    'circl',
#    'clockwis',
#    'start',
#    'with',
#    'right']),
#  ('00376', ['someon', 'walk', 'forward']),
#  ('00377', ['a', 'person', 'walk']),
#  ('00377', ['a', 'person', 'is', 'walk', 'forward']),
#  ('00378', ['a', 'person', 'walk', 'forward']),
#  ('00379',
#   ['a', 'person', 'walk', '4', 'step', 'in', 'the', 'forward', 'direct']),
#  ('00380', ['a', 'person', 'walk', 'forward']),
#  ('00381', ['a', 'person', 'walk', 'forward']),
#  ('00381', ['person', 'walk', 'forward']),
#  ('00381', ['someon', 'goe', 'away']),
#  ('00381', ['walk', 'five', 'step', 'in', 'a', 'straight', 'line']),
#  ('00381', ['a', 'person', 'walk', 'forward']),
#  ('00381',
#   ['a', 'person', 'walk', 'straight', 'forward', 'a', 'few', 'meter']),
#  ('00381', ['a', 'person', 'is', 'walk', 'forward']),
#  ('00381', ['a', 'person', 'walk', 'forward']),
#  ('00381', ['a', 'person', 'walk', 'five', 'step']),
#  ('00382', ['a', 'person', 'goe', 'five', 'step', 'forward']),
#  ('00383',
#   ['a',
#    'person',
#    'walk',
#    'veri',
#    'normal',
#    ',',
#    'with',
#    'an',
#    'averag',
#    'speed',
#    'for',
#    '5',
#    'step',
#    'while',
#    'it',
#    'arm',
#    'are',
#    'swing',
#    'normal',
#    'on',
#    'everi',
#    'step']),
#  ('00383', ['a', 'person', 'walk', 'forward']),
#  ('00384', ['a', 'person', 'walk', 'forward']),
#  ('00384',
#   ['a',
#    'person',
#    'walk',
#    '4',
#    'step',
#    'forward',
#    'in',
#    'a',
#    'straight',
#    'line']),
#  ('00384', ['a', 'person', 'walk', 'forward']),
#  ('00385', ['a', 'person', 'walk', 'four', 'step', 'backward']),
#  ('00385',
#   ['someon', 'take', '4', 'step', 'backward', 'start', 'with', 'left']),
#  ('00386', ['person', 'walk', 'backward']),
#  ('00386', ['a', 'human', 'walk', '4', 'step', 'backward', 'on', 'a', 'line']),
#  ('00386', ['a', 'human', 'is', 'walk', 'backward']),
#  ('00387', ['subject', 'walk', 'three', 'step', 'backward']),
#  ('00388', ['someon', 'move', 'backward', 'in', 'a', 'walk']),
#  ('00388', ['a', 'human', 'walk', 'backward', 'while', 'look', 'forward']),
#  ('00388', ['a', 'person', 'walk', 'backward', 'a', 'few', 'step']),
#  ('00388', ['a', 'person', 'walk', 'backward', 'fast']),
#  ('00388', ['a', 'person', 'take', '5', 'step', 'backward']),
#  ('00389', ['a', 'person', 'walk', 'four', 'step', 'backward']),
#  ('00389', ['a', 'person', 'walk', 'some', 'meter', 'back']),
#  ('00389', ['a', 'person', 'walk', 'backward', 'for', 'four', 'step']),
#  ('00390', ['subject', 'walk', 'backward']),
#  ('00390', ['a', 'person', 'is', 'walk', 'backward']),
#  ('00390', ['human', 'goe', 'backward']),
#  ('00391', ['a', 'person', 'walk', 'backward']),
#  ('00391', ['a', 'person', 'walk', 'backward']),
#  ('00391', ['a', 'person', 'walk', 'backward']),
#  ('00391', ['human', 'goe', 'backward']),
#  ('00392', ['a', 'person', 'is', 'walk', 'quickli', 'backward']),
#  ('00392', ['a', 'person', 'walk', 'backward']),
#  ('00393', ['a', 'person', 'walk', 'backward']),
#  ('00393', ['a', 'person', 'walk', 'backward']),
#  ('00394', ['subject', 'walk', 'backward']),
#  ('00394', ['a', 'person', 'walk', 'backward']),
#  ('00396', ['a', 'person', 'walk', 'counter', 'clockwis', 'in', 'a', 'circl']),
#  ('00396', ['a', 'person', 'walk', 'in', 'a', 'counter-clockwis', 'circl']),
#  ('00397', ['someon', 'walk', 'a', 'full', 'circl']),
#  ('00397',
#   ['a',
#    'person',
#    'walk',
#    'forward',
#    'three',
#    'quarter',
#    'of',
#    'a',
#    'circl',
#    'counterclockwis']),
#  ('00397', ['a', 'person', 'walk', 'in', 'a', 'circl', 'to', 'the', 'left']),
#  ('00398', ['a', 'person', 'walk', 'in', 'a', 'circl']),
#  ('00398',
#   ['a',
#    'person',
#    'is',
#    'do',
#    'a',
#    'three',
#    'quarter',
#    'counter-clockwis',
#    'circl']),
#  ('00398',
#   ['a',
#    'person',
#    'walk',
#    'three',
#    'fourth',
#    'of',
#    'a',
#    'circl',
#    'to',
#    'the',
#    'left']),
#  ('00399', ['a', 'human', 'walk', 'in', 'a', 'circl', 'counter', 'clockwis']),
#  ('00399',
#   ['a',
#    'human',
#    'walk',
#    'three',
#    'quarter',
#    'of',
#    'a',
#    'circl',
#    'to',
#    'it',
#    'left']),
#  ('00400', ['a', 'person', 'walk', 'in', 'a', 'circl', 'to', 'he', 'left']),
#  ('00401', ['the', 'human', 'walk', 'a', 'counter-clockwis', 'circl']),
#  ('00401', ['a', 'human', 'walk', 'in', 'a', 'circl']),
#  ('00402', ['someon', 'is', 'walk', 'a', 'circl']),
#  ('00402', ['a', 'person', 'walk', 'three', 'fourth', 'of', 'a', 'circl']),
#  ('00402',
#   ['a',
#    'person',
#    'walk',
#    'in',
#    'a',
#    'three',
#    'quarter',
#    'circl',
#    'to',
#    'hi',
#    'left',
#    'side']),
#  ('00403', ['a', 'human', 'walk', 'around', 'in', 'a', 'clockwis', 'circl']),
#  ('00403', ['someon', 'walk', 'in', 'a', 'circl', 'clockwis']),
#  ('00403', ['someon', 'is', 'walk', 'in', 'a', 'circl', 'clockwis']),
#  ('00403', ['a', 'person', 'walk', 'in', 'a', 'circl']),
#  ('00404',
#   ['a',
#    'person',
#    'walk',
#    'in',
#    'clock-wis',
#    'circl',
#    'and',
#    'stop',
#    'face',
#    '90',
#    'degre',
#    'to',
#    'the',
#    'left',
#    'rel',
#    'from',
#    'the',
#    'start',
#    'posit']),
#  ('00404',
#   ['a',
#    'human',
#    'is',
#    'walk',
#    'three',
#    'quarter',
#    'of',
#    'a',
#    'circl',
#    'to',
#    'it',
#    'right']),
#  ('00404', ['a', 'person', 'walk', 'in', 'a', 'circl']),
#  ('00405', ['a', 'person', 'walk', 'in', 'a', 'rightward', 'circl']),
#  ('00406',
#   ['the',
#    'person',
#    'is',
#    'walk',
#    'back',
#    'to',
#    'the',
#    'initi',
#    'posit',
#    'by',
#    'follow',
#    'a',
#    'circular',
#    'path']),
#  ('00407', ['a', 'human', 'walk', 'a', 'right', 'circl']),
#  ('00407',
#   ['a',
#    'person',
#    'walk',
#    'a',
#    'circl',
#    ',',
#    'radiu',
#    'approximatli',
#    '1,5',
#    'meter']),
#  ('00407', ['a', 'person', 'walk', 'in', 'a', 'cricl', 'to', 'the', 'right']),
#  ('00408', ['a', 'human', 'walk', 'in', 'a', 'clockwis', 'circl']),
#  ('00408', ['a', 'human', 'goe', 'around', ',', 'circul']),
#  ('00408', ['human', 'goe', 'in', 'a', 'circl', 'clockwis']),
#  ('00409', ['a', 'person', 'walk', 'a', 'circl', 'clockwis']),
#  ('00410',
#   ['someon', 'walk', 'a', '90', 'degre', 'curv', 'to', 'the', 'left']),
#  ('00410',
#   ['a',
#    'person',
#    'walk',
#    'forward',
#    'in',
#    'a',
#    '90',
#    '°',
#    'curv',
#    'to',
#    'hi',
#    'left']),
#  ('00411', ['a', 'person', 'walk', 'a', 'quarter', 'circl']),
#  ('00412',
#   ['a',
#    'person',
#    'walk',
#    'to',
#    'the',
#    'left',
#    'one-quart',
#    'of',
#    'a',
#    'rotat']),
#  ('00412',
#   ['a', 'person', 'walk', 'a', 'quarter', 'circl', 'two', 'the', 'left']),
#  ('00412',
#   ['a', 'person', 'walk', 'a', '90', 'degre', 'turn', 'to', 'the', 'left']),
#  ('00412',
#   ['a', 'person', 'walk', 'in', 'a', 'quarter', 'circl', 'to', 'the', 'left']),
#  ('00413', ['person', 'walk', 'around', 'a', 'corner']),
#  ('00414', ['a', 'person', 'is', 'turn', 'right']),
#  ('00414',
#   ['a',
#    'person',
#    'walk',
#    'to',
#    'the',
#    'right',
#    'perform',
#    'a',
#    'quarter',
#    'circl']),
#  ('00415',
#   ['a',
#    'human',
#    'move',
#    'in',
#    'a',
#    'quarter',
#    'circl',
#    ',',
#    'make',
#    'a',
#    'break',
#    'and',
#    'move',
#    'in',
#    'anoth',
#    'quarter',
#    'circl']),
#  ('00415',
#   ['someon', 'is', 'walk', 'forward', 'and', 'then', 'turn', 'right']),
#  ('00415',
#   ['a',
#    'person',
#    'walk',
#    'forward',
#    'perform',
#    'a',
#    'quarter',
#    'circl',
#    'to',
#    'the',
#    'right',
#    'and',
#    'then',
#    'walk',
#    'back',
#    'to',
#    'it',
#    'origin',
#    'posit',
#    'in',
#    'the',
#    'same',
#    'way']),
#  ('00416', ['a', 'human', 'turn', 'right']),
#  ('00417',
#   ['person',
#    'look',
#    'around',
#    'and',
#    'then',
#    'walk',
#    'around',
#    'a',
#    'corner']),
#  ('00417',
#   ['a',
#    'person',
#    'walk',
#    'forward',
#    'perform',
#    'a',
#    'quarter',
#    'circl',
#    'to',
#    'the',
#    'right']),
#  ('00417',
#   ['a',
#    'person',
#    'walk',
#    'forward',
#    'in',
#    'a',
#    '90',
#    '°',
#    'curv',
#    'to',
#    'the',
#    'right']),
#  ('00417', ['a', 'person', 'is', 'turn', 'right', 'while', 'walk']),
#  ('00418',
#   ['a', 'person', 'walk', 'in', '90', 'degre', 'curv', 'to', 'the', 'right']),
#  ('00419',
#   ['a',
#    'person',
#    'walk',
#    'in',
#    'a',
#    'quarter',
#    'circl',
#    'to',
#    'the',
#    'right']),
#  ('00420', ['the', 'person', 'is', 'turn', 'right']),
#  ('00421',
#   ['a',
#    'person',
#    'walk',
#    'a',
#    'nineti',
#    'degre',
#    'curv',
#    'to',
#    'the',
#    'left']),
#  ('00422',
#   ['a',
#    'person',
#    'walk',
#    'forward',
#    'anf',
#    'turn',
#    'slightli',
#    'to',
#    'the',
#    'right']),
#  ('00422',
#   ['a', 'person', 'walk', 'and', 'turn', '90', 'degre', 'to', 'the', 'right']),
#  ('00422',
#   ['a', 'human', 'is', 'walk', 'in', 'a', '90', '°', 'right', 'curv']),
#  ('00423', ['a', 'human', 'turn', 'right']),
#  ('00424', ['a', 'person', 'walk', 'slowli', 'forward']),
#  ('00424', ['a', 'person', 'take', 'a', 'few', 'slow', 'step', 'forward']),
#  ...]

# %%
stem_sentences[4][1]
# Out:
# ['human', 'slowli', 'goe', 'forward']

# %%
set(stem_sentences[4][1]).intersection(set(flatened_word_list))
# Out:
# {'forward', 'goe'}

# %%
narrowed_sentences = []
for a in stem_sentences:
    element = a[0]
    narrow_sentence = list(set(a[1]).intersection(set(flatened_word_list)))
    #print(element, narrow_sentence)
    narrowed_sentences.append((element, narrow_sentence))

# %%
#[set(a[1]).intersection(set(flatened_word_list)) for a in stem_sentences]

# %%
narrowed_sentences
# Out:
# [('00001', ['walk', 'forward']),
#  ('00002', ['walk', 'forward']),
#  ('00003', ['walk']),
#  ('00004', ['walk', 'forward']),
#  ('00004', ['goe', 'forward']),
#  ('00005', ['walk', 'forward']),
#  ('00006', ['goe', 'forward']),
#  ('00006', ['walk', 'forward']),
#  ('00007', ['walk']),
#  ('00007', ['walk', 'forward']),
#  ('00008', ['walk', 'forward']),
#  ('00009', ['stand', 'walk']),
#  ('00009', ['left', 'do', 'forward', 'walk']),
#  ('00009', ['make', 'forward']),
#  ('00010', ['walk', 'backward']),
#  ('00011', ['left', 'backward', 'walk']),
#  ('00011', ['walk', 'backward']),
#  ('00013', ['walk', 'backward']),
#  ('00014', ['walk', 'backward']),
#  ('00015', ['walk', 'backward']),
#  ('00016', ['walk', 'backward']),
#  ('00016', ['left', 'backward', 'walk']),
#  ('00016', ['walk', 'backward']),
#  ('00016', ['walk']),
#  ('00016', ['backward']),
#  ('00016', ['stand', 'backward', 'move']),
#  ('00016', ['walk', 'backward']),
#  ('00016', ['walk', 'backward']),
#  ('00016', ['walk', 'backward']),
#  ('00017', ['walk', 'backward']),
#  ('00017', ['walk', 'backward']),
#  ('00017', ['walk', 'backward']),
#  ('00018', ['walk', 'backward']),
#  ('00019', ['turn']),
#  ('00019', ['walk', 'counterclockwis']),
#  ('00019', ['anticlockwis']),
#  ('00020', ['counter', 'walk', 'clockwis']),
#  ('00021', ['walk']),
#  ('00022', ['walk']),
#  ('00022', ['left', 'walk']),
#  ('00022', ['counter-clockwis', 'walk']),
#  ('00022', ['walk']),
#  ('00023', ['counter-clockwis', 'walk']),
#  ('00023', ['walk']),
#  ('00023', ['walk']),
#  ('00023', ['walk']),
#  ('00023', ['left', 'walk']),
#  ('00023', ['walk']),
#  ('00023', ['walk']),
#  ('00023', ['around', 'turn']),
#  ('00023', ['left', 'walk']),
#  ('00023', ['walk']),
#  ('00023', ['walk', 'left']),
#  ('00024', ['walk']),
#  ('00025', ['left', 'walk']),
#  ('00025', ['left', 'walk']),
#  ('00026', ['counter-clockwis', 'walk']),
#  ('00026', ['walk', 'counterclockwis']),
#  ('00027', ['walk']),
#  ('00027', ['walk']),
#  ('00028', ['goe', 'clockwis']),
#  ('00029', ['walk']),
#  ('00029', ['walk', 'clockwis']),
#  ('00030', ['walk', 'clockwis']),
#  ('00030', ['run', 'clockwis']),
#  ('00031', ['walk']),
#  ('00031', ['walk']),
#  ('00031', ['walk']),
#  ('00032', ['walk', 'clockwis']),
#  ('00032', ['down', 'walk']),
#  ('00032', ['walk']),
#  ('00032', ['walk', 'turn']),
#  ('00033', ['walk', 'clockwis']),
#  ('00033', ['walk']),
#  ('00034', ['walk', 'clockwis']),
#  ('00034', ['walk']),
#  ('00035', ['walk']),
#  ('00036', ['walk', 'clockwis']),
#  ('00037', ['walk', 'clockwis']),
#  ('00037', ['walk', 'clockwis']),
#  ('00037', ['walk']),
#  ('00038', ['walk']),
#  ('00038', ['walk', 'turn']),
#  ('00039', ['perform', 'forward', 'walk']),
#  ('00039', ['perform']),
#  ('00040', ['walk']),
#  ('00040', ['walk']),
#  ('00040', ['walk', 'turn']),
#  ('00041', ['walk']),
#  ('00041', ['walk']),
#  ('00041', ['walk', 'clockwis']),
#  ('00042', ['walk', 'clockwis']),
#  ('00042', ['walk']),
#  ('00042', ['goe']),
#  ('00042', ['sit']),
#  ('00043', ['walk', 'clockwis']),
#  ('00043', ['perform']),
#  ('00043', ['down', 'sit']),
#  ('00044', ['walk', 'rightward']),
#  ('00044', ['walk']),
#  ('00045', ['walk', 'clockwis']),
#  ('00046', ['walk', 'clockwis']),
#  ('00047', ['walk', 'left-turn']),
#  ('00047', ['walk', 'forward']),
#  ('00047', ['walk']),
#  ('00048', ['walk', 'backward']),
#  ('00048', ['goe', 'left', 'backward']),
#  ('00049', ['walk', 'backward']),
#  ('00049', ['left', 'backward']),
#  ('00049', ['walk', 'backward']),
#  ('00050', ['walk', 'backward']),
#  ('00050', ['walk', 'backward']),
#  ('00050', ['make', 'backward']),
#  ('00051', ['walk', 'backward']),
#  ('00052', ['walk', 'backward']),
#  ('00052', ['walk', 'backward']),
#  ('00053', ['walk', 'backward']),
#  ('00053', ['walk', 'backward']),
#  ('00053', ['walk']),
#  ('00054', ['walk', 'backward']),
#  ('00054', ['goe', 'left', 'backward']),
#  ('00055', ['walk', 'backward']),
#  ('00055', ['left', 'backward', 'walk']),
#  ('00055', ['backward']),
#  ('00056', ['walk', 'backward']),
#  ('00056', ['walk', 'backward']),
#  ('00057', ['walk', 'backward']),
#  ('00057', ['left', 'backward', 'walk']),
#  ('00058', ['walk']),
#  ('00059', ['goe', 'counterclockwis']),
#  ('00059', ['left', 'walk']),
#  ('00060', ['walk', 'counterclockwis']),
#  ('00061', ['counter-clockwis', 'walk']),
#  ('00061', ['walk']),
#  ('00061', ['counter-clockwis', 'walk']),
#  ('00061', ['walk']),
#  ('00061', ['make']),
#  ('00061', ['around', 'turn']),
#  ('00061', ['walk']),
#  ('00061', ['walk']),
#  ('00061', ['walk', 'anti-clockwis']),
#  ('00061', ['walk', 'counterclockwis']),
#  ('00061', ['walk', 'left']),
#  ('00061', ['walk']),
#  ('00061', ['walk', 'counterclockwis']),
#  ('00062', ['counter-clockwis', 'walk']),
#  ('00062', ['left', 'walk']),
#  ('00063', ['walk']),
#  ('00063', ['left', 'walk']),
#  ('00064', ['walk', 'counterclockwis']),
#  ('00064', ['left', 'walk']),
#  ('00065', ['left', 'walk']),
#  ('00066', ['left', 'walk']),
#  ('00067', ['counter-clockwis', 'walk']),
#  ('00067', ['counter-clockwis', 'walk']),
#  ('00067', ['walk']),
#  ('00067', ['walk', 'around']),
#  ('00067', ['walk']),
#  ('00067', ['walk']),
#  ('00067', ['walk']),
#  ('00067', ['left', 'walk']),
#  ('00067', ['goe', 'counterclockwis']),
#  ('00067', ['walk', 'anticlockwis']),
#  ('00068', ['walk']),
#  ('00069', ['walk', 'clockwis']),
#  ('00070', ['walk', 'clockwis']),
#  ('00070', ['walk']),
#  ('00071', ['walk', 'clockwis']),
#  ('00071', ['walk']),
#  ('00072', ['walk']),
#  ('00073', ['walk']),
#  ('00074', ['walk']),
#  ('00075', ['walk', 'clockwis']),
#  ('00075', ['walk']),
#  ('00076', ['walk']),
#  ('00077', ['walk', 'clockwis']),
#  ('00077', ['walk', 'clockwis']),
#  ('00077', ['walk']),
#  ('00077', ['turn']),
#  ('00077', ['walk']),
#  ('00077', ['by', 'walk', 'make', 'left']),
#  ('00077', ['goe', 'around']),
#  ('00077', ['walk']),
#  ('00077', ['walk', 'clockwis']),
#  ('00078', ['walk', 'counterclockwis']),
#  ('00078', ['walk', 'left-sid']),
#  ('00079', ['by', 'left', 'walk']),
#  ('00079', ['left', 'move']),
#  ('00079', ['walk', 'left']),
#  ('00079', ['walk', 'anticlockwis']),
#  ('00080', ['walk']),
#  ('00080', ['left', 'walk']),
#  ('00080', ['walk']),
#  ('00081', ['left', 'turn', 'walk']),
#  ('00081', ['left', 'turn', 'walk']),
#  ('00082', ['walk', 'counterclockwis']),
#  ('00082', ['walk', 'perform', 'left']),
#  ('00083', ['turn', 'left', 'make']),
#  ('00083', ['goe', 'left', 'around']),
#  ('00084', ['left', 'walk']),
#  ('00085', ['left', 'walk']),
#  ('00085', ['turn', 'left', 'perfom']),
#  ('00086', ['left', 'walk']),
#  ('00086', ['walk', 'clockwis']),
#  ('00087', ['left', 'toward', 'walk']),
#  ('00087', ['goe', 'left', 'counterclockwis']),
#  ('00087', ['left', 'turn', 'walk']),
#  ('00088', ['turn']),
#  ('00089', ['walk']),
#  ('00090', ['walk', 'turn']),
#  ('00091', ['walk', 'turn']),
#  ('00091', ['walk', 'clockwis']),
#  ('00092', ['turn', 'make']),
#  ('00092', ['walk']),
#  ('00093', ['walk']),
#  ('00093', ['goe', 'clockwis']),
#  ('00093', ['walk']),
#  ('00094', ['walk']),
#  ('00094', ['turn', 'perfom']),
#  ('00094', ['turn']),
#  ('00095', ['turn']),
#  ('00095', ['perform']),
#  ('00095', ['walk']),
#  ('00096', ['turn']),
#  ('00097', ['goe', 'clockwis']),
#  ('00097', ['walk']),
#  ('00097', ['turn']),
#  ('00097', ['walk']),
#  ('00098', ['walk', 'perform', 'forward']),
#  ('00098', ['walk']),
#  ('00098', ['walk', 'forward']),
#  ('00098', ['walk', 'forward']),
#  ('00098', ['walk', 'forward']),
#  ('00098', ['walk', 'forward']),
#  ('00099', ['walk', 'forward']),
#  ('00099', ['forward', 'move']),
#  ('00099', ['forward']),
#  ('00099', ['forward']),
#  ('00100', ['walk', 'forward']),
#  ('00101', ['walk', 'forward']),
#  ('00101', ['walk']),
#  ('00102', ['walk', 'forward']),
#  ('00102', ['walk', 'forward']),
#  ('00102', ['walk']),
#  ('00102', ['walk', 'forward']),
#  ('00102', ['walk']),
#  ('00102', ['walk', 'forward']),
#  ('00102', ['left', 'walk']),
#  ('00103', ['walk', 'forward', 'move']),
#  ('00103', ['walk', 'forward']),
#  ('00104', ['walk', 'forward']),
#  ('00105', ['walk', 'forward']),
#  ('00105', ['goe', 'forward']),
#  ('00106', ['walk', 'forward', 'left']),
#  ('00106', ['walk', 'forward']),
#  ('00106', ['walk']),
#  ('00107', ['walk', 'forward']),
#  ('00108', ['walk', 'backward']),
#  ('00108', ['walk', 'backward']),
#  ('00108', ['walk', 'backward']),
#  ('00108', ['back']),
#  ('00108', ['back', 'off']),
#  ('00108', ['do', 'backward']),
#  ('00108', ['walk', 'backward']),
#  ('00108', ['walk', 'backward']),
#  ('00108', ['walk', 'backward']),
#  ('00108', ['backward', 'move']),
#  ('00108', ['walk', 'backward']),
#  ('00108', ['backward']),
#  ('00108', ['left', 'backward', 'move', 'walk']),
#  ('00108', ['back']),
#  ('00108', ['goe', 'backward']),
#  ('00108', ['walk', 'backward']),
#  ('00109', ['walk', 'backward']),
#  ('00110', ['swing', 'by', 'walk', 'backward']),
#  ('00110', ['goe', 'left', 'backward']),
#  ('00110', ['walk', 'backward']),
#  ('00110', ['walk', 'backward']),
#  ('00111', ['walk', 'backward']),
#  ('00111', ['walk', 'backward']),
#  ('00112', ['walk', 'backward']),
#  ('00112', ['walk', 'backward']),
#  ('00112', ['walk', 'backward']),
#  ('00113', ['walk', 'backward']),
#  ('00113', ['goe', 'backward']),
#  ('00114', ['walk', 'backward']),
#  ('00114', ['walk', 'backward']),
#  ('00114', ['walk', 'backward']),
#  ('00114', ['walk', 'backward']),
#  ('00114', ['goe', 'backward']),
#  ('00116', ['walk', 'backward']),
#  ('00116', ['left', 'backward', 'walk']),
#  ('00116', ['backward']),
#  ('00116', ['walk', 'backward']),
#  ('00116', ['walk', 'backward']),
#  ('00116', ['walk', 'backward']),
#  ('00117', ['walk', 'backward']),
#  ('00118', ['walk', 'counterclockwis']),
#  ('00118', ['walk', 'counterclockwis']),
#  ('00118', ['left', 'walk']),
#  ('00119', ['left', 'walk']),
#  ('00119', ['walk', 'anticlockwis']),
#  ('00120', ['walk', 'counterclockwis']),
#  ('00121', ['counter-clockwis', 'walk']),
#  ('00121', ['walk']),
#  ('00122', ['walk', 'counterclockwis']),
#  ('00122', ['walk', 'clockwis']),
#  ('00122', ['walk']),
#  ('00123', ['counter-clockwis', 'walk']),
#  ('00124', ['walk']),
#  ('00124', ['left', 'walk']),
#  ('00125', ['walk', 'counterclockwis']),
#  ('00125', ['walk']),
#  ('00126', ['walk', 'counterclockwis']),
#  ('00126', ['left', 'walk']),
#  ('00127', ['move', 'counterclockwis']),
#  ('00128', ['walk', 'clockwis']),
#  ('00129', ['walk', 'clockwis']),
#  ('00129', ['perform']),
#  ('00130', ['walk']),
#  ('00130', ['goe', 'clockwis']),
#  ('00130', ['walk']),
#  ('00130', ['walk']),
#  ('00131', ['walk']),
#  ('00131', ['walk']),
#  ('00132', ['walk']),
#  ('00132', ['walk', 'clockwis']),
#  ('00133', ['walk', 'clockwis']),
#  ('00133', ['walk']),
#  ('00134', ['walk', 'clockwis']),
#  ('00134', ['walk']),
#  ('00135', ['walk', 'clockwis']),
#  ('00136', ['walk', 'clockwis']),
#  ('00136', ['walk', 'clockwis']),
#  ('00136', ['goe', 'around', 'clockwis']),
#  ('00136', ['walk', 'clockwis']),
#  ('00136', ['walk']),
#  ('00137', ['walk', 'clockwis']),
#  ('00138', ['left', 'bend', 'walk']),
#  ('00139', ['left', 'turn', 'walk']),
#  ('00139', ['left', 'walk']),
#  ('00139', ['left', 'turn']),
#  ('00140', ['turn', 'counter-clockwis', 'make']),
#  ('00140', ['counter-clockwis', 'walk']),
#  ('00140', ['performin', 'walk', 'left']),
#  ('00140', ['left', 'turn']),
#  ('00141', ['left', 'toward', 'walk']),
#  ('00141', ['left', 'walk']),
#  ('00141', ['walk']),
#  ('00142', ['around', 'walk']),
#  ('00142', ['left', 'turn', 'walk']),
#  ('00142', ['left', 'walk']),
#  ('00143', ['left', 'turn']),
#  ('00144', ['walk', 'counterclockwis']),
#  ('00144', ['walk', 'counterclockwis']),
#  ('00144', ['left', 'walk']),
#  ('00145', ['left', 'turn', 'walk']),
#  ('00145', ['walk']),
#  ('00145', ['u-turn', 'perform']),
#  ('00145', ['left', 'walk']),
#  ('00145', ['left', 'turn', 'along', 'walk']),
#  ('00145', ['walk', 'left']),
#  ('00145', ['left', 'walk']),
#  ('00145', ['left', 'turn', 'toward', 'walk']),
#  ('00145', ['left', 'turn', 'walk']),
#  ('00145', ['walk', 'left']),
#  ('00145', ['walk']),
#  ('00145', ['left', 'walk']),
#  ('00146', ['left', 'turn']),
#  ('00146', ['left', 'turn', 'walk']),
#  ('00147', ['turn', 'left', 'forward', 'walk']),
#  ('00147', ['left', 'turn', 'walk']),
#  ('00147', ['left', 'turn']),
#  ('00148', ['walk', 'clockwis']),
#  ('00148', ['walk']),
#  ('00149', ['walk', 'clockwis']),
#  ('00149', ['walk', 'perform', 'bend']),
#  ('00150', ['turn', 'walk', 'forward']),
#  ('00151', ['turn']),
#  ('00151', ['walk']),
#  ('00151', ['perform']),
#  ('00152', ['walk']),
#  ('00152', ['walk', 'turn']),
#  ('00152', ['walk']),
#  ('00153', ['goe']),
#  ('00153', ['walk']),
#  ('00154', ['turn']),
#  ('00154', ['walk']),
#  ('00155', ['turn']),
#  ('00155', ['walk', 'turn']),
#  ('00156', ['walk', 'turn', 'ahead']),
#  ('00157', ['turn']),
#  ('00158', ['walk', 'forward']),
#  ('00158', ['walk']),
#  ('00158', ['walk', 'forward']),
#  ('00158', ['forward']),
#  ('00158', ['walk', 'forward']),
#  ('00159', ['walk']),
#  ('00159', ['walk', 'forward']),
#  ('00160', ['walk', 'forward']),
#  ('00160', ['walk', 'forward']),
#  ('00161', ['goe', 'forward']),
#  ('00161', ['walk', 'forward']),
#  ('00161', ['walk', 'forward']),
#  ('00162', ['walk', 'forward']),
#  ('00162', ['walk']),
#  ('00163', ['walk', 'forward']),
#  ('00163', ['walk', 'forward']),
#  ('00164', ['walk', 'forward']),
#  ('00164', ['walk', 'forward']),
#  ('00165', ['walk', 'forward']),
#  ('00165', ['forward']),
#  ('00165', ['walk', 'forward']),
#  ('00166', ['walk']),
#  ('00167', ['walk', 'forward']),
#  ('00167', ['perfom']),
#  ('00167', ['walk', 'forward']),
#  ('00168', ['goe', 'backward']),
#  ('00168', ['left', 'backward']),
#  ('00168', ['walk', 'backward']),
#  ('00168', ['walk', 'backward']),
#  ('00169', ['walk', 'backward']),
#  ('00169', ['left', 'backward']),
#  ('00169', ['backward']),
#  ('00170', ['walk', 'backward']),
#  ('00170', ['walk', 'backward']),
#  ('00171', ['walk', 'backward']),
#  ('00171', ['walk', 'backward']),
#  ('00171', ['walk', 'backward']),
#  ('00172', ['goe', 'back']),
#  ('00173', ['walk', 'backward']),
#  ('00173', ['backward']),
#  ('00173', ['backward']),
#  ('00174', ['back']),
#  ('00174', ['walk', 'back']),
#  ('00175', ['walk', 'backward']),
#  ('00175', ['make', 'backward']),
#  ('00175', ['walk', 'backward']),
#  ('00175', []),
#  ('00175', ['walk', 'backward']),
#  ('00176', ['walk', 'backward']),
#  ('00176', ['walk', 'backward']),
#  ('00177', ['walk', 'backward']),
#  ('00177', ['walk', 'backward']),
#  ('00177', ['walk', 'backward']),
#  ('00177', ['walk', 'backward']),
#  ('00177', ['walk', 'backward']),
#  ('00177', ['backward']),
#  ('00178', ['walk']),
#  ('00178', ['counter-clockwis', 'walk']),
#  ('00178', ['walk', 'anticlockwis']),
#  ('00178', ['left', 'walk']),
#  ('00179', ['around', 'anti-clockwis', 'walk']),
#  ('00179', ['walk', 'counterclockwis']),
#  ('00179', ['left', 'walk']),
#  ('00180', ['left', 'walk']),
#  ('00180', ['counter-clockwis', 'walk']),
#  ('00180', ['walk']),
#  ('00181', ['walk', 'counterclockwis']),
#  ('00181', ['long', 'make', 'walk', 'counterclockwis']),
#  ('00182', ['walk', 'clockwis']),
#  ('00183', ['walk']),
#  ('00183', ['walk', 'forward', 'counterclockwis']),
#  ('00183', ['left', 'walk']),
#  ('00184', ['walk', 'counterclockwis']),
#  ('00185', ['counter-clockwis', 'walk']),
#  ('00186', ['walk']),
#  ('00186', ['walk', 'counterclockwis']),
#  ('00187', ['left', 'walk']),
#  ('00188', ['walk', 'clockwis']),
#  ('00189', ['walk', 'clockwis']),
#  ('00189', ['walk']),
#  ('00190', ['walk']),
#  ('00191', ['walk', 'clockwis']),
#  ('00191', ['walk', 'clockwis']),
#  ('00191', ['walk']),
#  ('00191', ['walk']),
#  ('00192', ['walk']),
#  ('00192', ['walk']),
#  ('00193', ['walk', 'clockwis']),
#  ('00194', ['walk', 'clockwis']),
#  ('00194', ['walk']),
#  ('00194', ['walk']),
#  ('00195', ['walk', 'clockwis']),
#  ('00196', ['walk', 'clockwis']),
#  ('00196', ['goe', 'clockwis']),
#  ('00197', ['walk']),
#  ('00197', ['walk']),
#  ('00198', ['goe']),
#  ('00199', ['walk', 'bend']),
#  ('00199', ['walk']),
#  ('00200', ['walk']),
#  ('00201', ['walk']),
#  ('00201', ['goe', 'clockwis']),
#  ('00202', ['walk', 'turn', 'forward', 'perform']),
#  ('00202', ['walk']),
#  ('00203', ['walk']),
#  ('00204', ['turn']),
#  ('00204', ['walk', 'turn']),
#  ('00205', ['walk']),
#  ('00206', ['turn', 'make', 'clockwis']),
#  ('00206', ['walk', 'clockwis']),
#  ('00207', ['turn']),
#  ('00207', ['walk', 'clockwis']),
#  ('00207', ['walk']),
#  ('00207', ['turn']),
#  ('00208', ['walk', 'forward']),
#  ('00208', ['walk', 'forward']),
#  ('00208', ['walk', 'forward']),
#  ('00209', ['walk']),
#  ('00209', ['walk', 'forward']),
#  ('00210', ['walk', 'forward']),
#  ('00211', ['walk', 'forward']),
#  ('00211', ['walk', 'forward']),
#  ('00212', ['walk']),
#  ('00213', ['left', 'walk']),
#  ('00213', ['walk', 'forward']),
#  ('00214', ['walk', 'forward']),
#  ('00215', ['walk', 'forward']),
#  ('00216', ['walk', 'forward']),
#  ('00217', ['walk', 'forward']),
#  ('00217', ['walk', 'forward']),
#  ('00218', ['walk', 'backward']),
#  ('00218', ['goe', 'left', 'backward']),
#  ('00218', ['walk', 'backward']),
#  ('00218', ['walk', 'backward']),
#  ('00219', ['walk', 'backward']),
#  ('00219', ['walk', 'backward']),
#  ('00219', ['walk', 'back']),
#  ('00222', ['backward', 'move']),
#  ('00223', ['walk', 'backward']),
#  ('00223', ['walk', 'backward']),
#  ('00224', ['walk', 'backward']),
#  ('00224', ['walk', 'backward']),
#  ('00225', ['walk', 'backward']),
#  ('00225', ['goe', 'backward']),
#  ('00225', ['walk', 'backward']),
#  ('00225', ['walk', 'backward']),
#  ('00226', ['walk', 'backward']),
#  ('00227', ['walk', 'counterclockwis']),
#  ('00227', ['walk']),
#  ('00228', ['walk']),
#  ('00228', ['counter-clockwis', 'walk']),
#  ('00228', ['left', 'walk']),
#  ('00228', ['anti-clockwis', 'move']),
#  ('00228', ['walk']),
#  ('00229', ['counter-clockwis', 'walk']),
#  ('00229', ['counterclockwis']),
#  ('00229', ['left', 'walk']),
#  ('00229', ['walk']),
#  ('00229', ['walk', 'counterclockwis']),
#  ('00229', ['goe', 'left', 'around']),
#  ('00230', ['walk', 'counterclockwis']),
#  ('00230', ['walk']),
#  ('00231', ['counter-clockwis', 'walk']),
#  ('00231', ['walk']),
#  ('00231', ['walk', 'anticlockwis']),
#  ('00232', ['walk']),
#  ('00232', ['left', 'walk']),
#  ('00232', ['walk']),
#  ('00233', ['walk', 'make', 'along']),
#  ('00233', ['walk', 'counterclockwis']),
#  ('00233', ['walk', 'left']),
#  ('00233', ['walk']),
#  ('00234', ['move']),
#  ('00235', ['move', 'clockwis']),
#  ('00235', ['left', 'walk']),
#  ('00236', ['counter', 'walk', 'clockwis']),
#  ('00237', ['walk', 'clockwis']),
#  ('00237', ['walk']),
#  ('00238', ['walk', 'clockwis']),
#  ('00239', ['walk']),
#  ('00239', ['walk', 'forward', 'clockwis']),
#  ('00239', ['walk']),
#  ('00240', ['walk']),
#  ('00240', ['walk', 'clockwis']),
#  ('00241', ['walk']),
#  ('00241', ['goe', 'around']),
#  ('00241', ['walk']),
#  ('00241', ['perform']),
#  ('00242', ['walk']),
#  ('00243', ['walk', 'clockwis']),
#  ('00243', ['walk', 'forward', 'clockwis']),
#  ('00244', ['walk', 'clockwis']),
#  ('00244', ['walk', 'up']),
#  ('00245', ['walk', 'clockwis']),
#  ('00245', ['walk']),
#  ('00245', ['walk', 'forward', 'clockwis']),
#  ('00246', ['perform']),
#  ('00246', ['walk']),
#  ('00247', ['walk']),
#  ('00247', ['walk']),
#  ('00248', ['walk', 'turn']),
#  ('00248', ['walk', 'turn']),
#  ('00248', ['walk']),
#  ('00249', ['turn', 'make', 'clockwis']),
#  ('00249', ['walk']),
#  ('00250', ['left', 'turn']),
#  ('00251', ['walk']),
#  ('00251', ['walk', 'clockwis']),
#  ('00251', ['walk']),
#  ('00252', ['toward']),
#  ('00252', ['walk', 'turn']),
#  ('00253', ['around', 'turn', 'toward']),
#  ('00253', ['walk']),
#  ('00254', ['left', 'turn', 'walk']),
#  ('00254', ['turn']),
#  ('00254', ['walk', 'perform', 'bend']),
#  ('00255', ['walk']),
#  ('00255', ['walk', 'turn']),
#  ('00255', ['perform']),
#  ('00255', ['walk']),
#  ('00255', ['turn']),
#  ('00256', ['turn', 'perform', 'forward', 'walk']),
#  ('00256', ['walk']),
#  ('00256', ['walk', 'toward']),
#  ('00256', ['come']),
#  ('00256', ['walk']),
#  ('00256', ['come']),
#  ('00256', ['turn']),
#  ('00256', ['walk']),
#  ('00256', ['walk']),
#  ('00256', ['walk', 'turn', 'toward']),
#  ('00256', ['by', 'turn']),
#  ('00256', ['walk']),
#  ('00256', ['perform']),
#  ('00256', ['walk']),
#  ('00256', ['walk', 'perform']),
#  ('00256', ['walk', 'forward']),
#  ('00256', ['turn', 'perfom']),
#  ('00256', ['turn', 'do']),
#  ('00256', ['walk', 'perform', 'bend']),
#  ('00257', ['left', 'toward']),
#  ('00257', ['goe', 'counterclockwis']),
#  ('00258', ['left', 'toward', 'walk']),
#  ('00258', ['goe', 'counterclockwis']),
#  ('00258', ['left', 'walk']),
#  ('00259', ['left', 'turn', 'walk']),
#  ('00260', ['left', 'bend', 'walk']),
#  ('00260', ['walk', 'left']),
#  ('00260', ['left', 'turn']),
#  ('00260', ['left', 'walk']),
#  ('00260', ['left', 'turn', 'walk']),
#  ('00260', ['left', 'walk']),
#  ('00260', ['walk', 'left']),
#  ('00260', ['walk', 'forward']),
#  ('00260', ['turn', 'left', 'perfom']),
#  ('00262', ['counter', 'walk', 'clockwis']),
#  ('00262', ['left', 'turn', 'walk']),
#  ('00262', ['left', 'walk']),
#  ('00263', ['around', 'perform', 'left', 'move']),
#  ('00263', ['turn', 'left', 'perfom']),
#  ('00264', ['left', 'turn']),
#  ('00265', ['walk']),
#  ('00265', ['walk', 'perform', 'left']),
#  ('00265', ['left', 'walk']),
#  ('00266', ['left', 'turn']),
#  ('00266', ['left', 'walk']),
#  ('00267', ['walk', 'backward']),
#  ('00267', ['walk', 'backward']),
#  ('00268', ['walk', 'backward']),
#  ('00268', ['walk', 'backward']),
#  ('00269', ['walk', 'backward']),
#  ('00269', ['walk', 'backward']),
#  ('00269', ['left', 'backward', 'walk']),
#  ('00269', ['perfom', 'backward']),
#  ('00269', ['goe', 'backward']),
#  ('00270', ['back']),
#  ('00270', ['backward']),
#  ('00271', ['walk', 'backward']),
#  ('00271', ['walk', 'backward']),
#  ('00272', ['walk', 'backward']),
#  ('00273', ['back']),
#  ('00273', ['walk', 'backward']),
#  ('00273', ['walk', 'backward']),
#  ('00274', ['walk', 'backward']),
#  ('00274', ['walk', 'backward']),
#  ('00274', ['walk', 'backward']),
#  ('00275', ['back']),
#  ('00275', ['walk', 'backward']),
#  ('00275', ['walk', 'backward']),
#  ('00276', ['walk', 'backward']),
#  ('00276', ['walk', 'backward']),
#  ('00276', ['walk', 'backward']),
#  ('00277', ['left', 'walk']),
#  ('00277', ['counter-clockwis', 'walk']),
#  ('00277', ['left', 'walk']),
#  ('00277', ['walk']),
#  ('00278', ['left', 'walk']),
#  ('00279', ['walk', 'counterclockwis']),
#  ('00280', ['left', 'walk']),
#  ('00281', ['walk']),
#  ('00281', ['walk', 'left']),
#  ('00282', ['counter-clockwis', 'walk']),
#  ('00282', ['walk', 'counterclockwis']),
#  ('00283', ['walk', 'perform']),
#  ('00283', ['walk']),
#  ('00283', ['left', 'walk']),
#  ('00283', ['walk']),
#  ('00284', ['walk', 'counterclockwis']),
#  ('00284', ['left', 'walk']),
#  ('00284', ['left', 'walk']),
#  ('00285', ['walk']),
#  ('00286', ['move']),
#  ('00286', ['walk']),
#  ('00286', ['left', 'walk']),
#  ('00287', ['walk']),
#  ('00287', ['goe', 'clockwis']),
#  ('00287', ['move']),
#  ('00287', ['walk', 'clockwis']),
#  ('00288', ['walk', 'clockwis']),
#  ('00289', ['walk', 'clockwis']),
#  ('00289', ['goe', 'clockwis']),
#  ('00289', ['walk']),
#  ('00290', ['walk', 'clockwis']),
#  ('00291', ['clockwis']),
#  ('00291', ['walk']),
#  ('00291', ['walk']),
#  ('00292', ['walk', 'clockwis']),
#  ('00293', ['walk']),
#  ('00293', ['walk']),
#  ('00294', ['walk']),
#  ('00295', ['walk']),
#  ('00295', ['walk']),
#  ('00296', ['walk', 'counterclockwis']),
#  ('00297', ['left', 'turn', 'walk']),
#  ('00297', ['walk', 'counterclockwis']),
#  ('00297', ['around', 'turn', 'left']),
#  ('00298', ['left', 'walk']),
#  ('00299', ['counter', 'walk', 'clockwis']),
#  ('00299', ['left', 'perform', 'bend', 'walk']),
#  ('00300', ['walk', 'counterclockwis']),
#  ('00300', ['left', 'turn']),
#  ('00301', ['left', 'turn', 'walk']),
#  ('00301', ['left']),
#  ('00302', ['left', 'turn', 'walk', 'ahead']),
#  ('00302', ['walk', 'left']),
#  ('00303', ['left', 'walk']),
#  ('00304', ['turn', 'left', 'forward', 'walk']),
#  ('00304', ['left', 'forward', 'walk']),
#  ('00304', ['turn', 'left', 'perfom']),
#  ('00305', ['walk', 'counterclockwis']),
#  ('00305', ['walk', 'perform', 'left']),
#  ('00305', ['turn', 'left', 'perfom']),
#  ('00306', ['left', 'bend', 'walk']),
#  ('00307', ['turn', 'walk', 'forward']),
#  ('00307', ['goe', 'along']),
#  ('00308', ['stand', 'walk']),
#  ('00308', ['walk', 'turn']),
#  ('00309', ['walk']),
#  ('00310', ['walk', 'turn']),
#  ('00310', ['goe', 'clockwis']),
#  ('00310', ['walk', 'perform']),
#  ('00311', ['walk']),
#  ('00311', ['turn']),
#  ('00312', ['walk']),
#  ('00312', ['walk']),
#  ('00313', ['walk', 'clockwis']),
#  ('00314', ['walk']),
#  ('00314', ['turn']),
#  ('00315', ['walk', 'clockwis']),
#  ('00316', ['turn']),
#  ('00317', ['walk', 'forward']),
#  ('00318', ['walk', 'forward']),
#  ('00318', ['walk', 'forward']),
#  ('00319', ['walk', 'forward']),
#  ('00319', ['walk', 'forward']),
#  ('00320', ['walk']),
#  ('00320', ['walk', 'forward']),
#  ('00320', ['make', 'forward']),
#  ('00320', ['left', 'perform', 'jump']),
#  ('00321', ['walk', 'forward']),
#  ('00321', ['walk', 'forward']),
#  ('00321', ['walk', 'forward']),
#  ('00321', ['walk', 'forward']),
#  ('00322', ['walk', 'forward']),
#  ('00322', ['walk', 'forward']),
#  ('00322', ['walk', 'forward']),
#  ('00323', ['goe', 'forward']),
#  ('00324', ['walk', 'forward']),
#  ('00324', ['walk', 'forward']),
#  ('00325', ['walk', 'forward']),
#  ('00325', ['walk']),
#  ('00326', ['walk', 'forward']),
#  ('00326', ['left', 'forward', 'walk']),
#  ('00326', ['walk', 'forward']),
#  ('00326', ['walk', 'forward']),
#  ('00327', ['swing', 'by', 'walk', 'backward']),
#  ('00327', ['walk', 'backward']),
#  ('00327', ['walk', 'backward']),
#  ('00328', ['walk', 'backward']),
#  ('00329', ['walk', 'backward']),
#  ('00330', ['walk', 'backward']),
#  ('00331', ['stand', 'walk', 'back']),
#  ('00331', ['walk', 'backward']),
#  ('00331', ['backward']),
#  ('00331', ['walk', 'backward']),
#  ('00331', ['walk', 'backward']),
#  ('00332', ['walk', 'backward']),
#  ('00332', ['walk', 'backward']),
#  ('00332', ['left', 'backward', 'walk']),
#  ('00332', ['walk', 'backward']),
#  ('00332', ['walk', 'backward']),
#  ('00333', ['walk', 'backward']),
#  ('00334', ['walk', 'backward']),
#  ('00334', ['left', 'backward']),
#  ('00334', ['walk', 'backward']),
#  ('00334', ['walk', 'backward']),
#  ('00334', ['walk', 'backward']),
#  ('00335', ['walk', 'backward']),
#  ('00335', ['walk', 'backward']),
#  ('00336', ['walk', 'backward']),
#  ('00336', ['backward']),
#  ('00336', ['walk', 'backward']),
#  ('00336', ['walk', 'backward']),
#  ('00337', ['counter', 'walk', 'clockwis']),
#  ('00338', ['walk']),
#  ('00339', ['walk', 'counterclockwis']),
#  ('00339', ['walk', 'counterclockwis']),
#  ('00339', ['left', 'walk']),
#  ('00340', ['walk', 'counterclockwis']),
#  ('00341', ['counter', 'walk', 'clockwis']),
#  ('00341', ['walk']),
#  ('00342', ['left', 'walk']),
#  ('00342', ['counter-clockwis', 'walk']),
#  ('00342', ['walk', 'anticlockwis']),
#  ('00343', ['counter', 'walk']),
#  ('00343', ['walk']),
#  ('00344', ['walk', 'counterclockwis']),
#  ('00344', ['walk']),
#  ('00345', ['left', 'walk']),
#  ('00346', ['walk', 'counterclockwis']),
#  ('00346', ['walk', 'forward', 'counterclockwis']),
#  ('00347', ['by', 'walk', 'back']),
#  ('00347', ['walk']),
#  ('00347', ['walk', 'clockwis']),
#  ('00348', ['walk', 'clockwis']),
#  ('00348', ['walk', 'clockwis']),
#  ('00348', ['walk']),
#  ('00348', ['walk']),
#  ('00349', ['walk']),
#  ('00349', ['walk']),
#  ('00349', ['walk']),
#  ('00350', ['walk', 'clockwis']),
#  ('00350', ['walk', 'clockwis']),
#  ('00350', ['walk', 'clockwis']),
#  ('00351', ['walk', 'clockwis']),
#  ('00352', ['walk']),
#  ('00352', ['walk']),
#  ('00353', ['walk', 'clockwis']),
#  ('00354', ['walk', 'clockwis']),
#  ('00355', ['walk', 'clockwis']),
#  ('00355', ['walk', 'clockwis']),
#  ('00356', ['walk']),
#  ('00356', ['left', 'perform', 'jump']),
#  ('00357', ['left', 'bend', 'walk']),
#  ('00358', ['left', 'turn']),
#  ('00358', ['left', 'walk']),
#  ('00358', ['left', 'turn']),
#  ('00359', ['walk', 'counterclockwis']),
#  ('00359', ['walk', 'left']),
#  ('00360', ['left', 'walk']),
#  ('00360', ['goe', 'left', 'counterclockwis']),
#  ('00361', ['left', 'turn', 'walk']),
#  ('00361', ['goe', 'left', 'along']),
#  ('00361', ['left', 'turn']),
#  ('00362', ['walk', 'counterclockwis']),
#  ('00362', ['walk', 'perform', 'left']),
#  ('00363', ['walk', 'counterclockwis']),
#  ('00364', ['left', 'turn']),
#  ('00364', ['left', 'turn', 'walk']),
#  ('00365', ['goe', 'left', 'counterclockwis']),
#  ('00366', ['walk', 'clockwis']),
#  ('00367', ['turn']),
#  ('00367', ['walk']),
#  ('00367', ['walk']),
#  ('00368', ['walk', 'clockwis']),
#  ('00369', ['walk', 'clockwis']),
#  ('00369', ['perform']),
#  ('00370', ['turn']),
#  ('00370', ['walk']),
#  ('00371', ['walk', 'clockwis']),
#  ('00372', ['walk', 'turn']),
#  ('00372', ['turn']),
#  ('00372', ['walk']),
#  ('00373', ['walk']),
#  ('00373', ['walk', 'perform']),
#  ('00373', ['walk', 'clockwis']),
#  ('00374', ['walk']),
#  ('00374', ['turn', 'walk', 'forward']),
#  ('00375', ['walk']),
#  ('00375', ['goe', 'clockwis']),
#  ('00376', ['walk', 'forward']),
#  ('00377', ['walk']),
#  ('00377', ['walk', 'forward']),
#  ('00378', ['walk', 'forward']),
#  ('00379', ['walk', 'forward']),
#  ('00380', ['walk', 'forward']),
#  ('00381', ['walk', 'forward']),
#  ('00381', ['walk', 'forward']),
#  ('00381', ['goe']),
#  ('00381', ['walk']),
#  ('00381', ['walk', 'forward']),
#  ('00381', ['walk', 'forward']),
#  ('00381', ['walk', 'forward']),
#  ('00381', ['walk', 'forward']),
#  ('00381', ['walk']),
#  ('00382', ['goe', 'forward']),
#  ('00383', ['swing', 'walk', 'are']),
#  ('00383', ['walk', 'forward']),
#  ('00384', ['walk', 'forward']),
#  ('00384', ['walk', 'forward']),
#  ('00384', ['walk', 'forward']),
#  ('00385', ['walk', 'backward']),
#  ('00385', ['left', 'backward']),
#  ('00386', ['walk', 'backward']),
#  ('00386', ['walk', 'backward']),
#  ('00386', ['walk', 'backward']),
#  ('00387', ['walk', 'backward']),
#  ('00388', ['walk', 'backward', 'move']),
#  ('00388', ['walk', 'forward', 'backward']),
#  ('00388', ['walk', 'backward']),
#  ('00388', ['walk', 'backward']),
#  ('00388', ['backward']),
#  ('00389', ['walk', 'backward']),
#  ('00389', ['walk', 'back']),
#  ('00389', ['walk', 'backward']),
#  ('00390', ['walk', 'backward']),
#  ('00390', ['walk', 'backward']),
#  ('00390', ['goe', 'backward']),
#  ('00391', ['walk', 'backward']),
#  ('00391', ['walk', 'backward']),
#  ('00391', ['walk', 'backward']),
#  ('00391', ['goe', 'backward']),
#  ('00392', ['walk', 'backward']),
#  ('00392', ['walk', 'backward']),
#  ('00393', ['walk', 'backward']),
#  ('00393', ['walk', 'backward']),
#  ('00394', ['walk', 'backward']),
#  ('00394', ['walk', 'backward']),
#  ('00396', ['counter', 'walk', 'clockwis']),
#  ('00396', ['counter-clockwis', 'walk']),
#  ('00397', ['walk']),
#  ('00397', ['walk', 'forward', 'counterclockwis']),
#  ('00397', ['left', 'walk']),
#  ('00398', ['walk']),
#  ('00398', ['counter-clockwis', 'do']),
#  ('00398', ['left', 'walk']),
#  ('00399', ['counter', 'walk', 'clockwis']),
#  ('00399', ['left', 'walk']),
#  ('00400', ['left', 'walk']),
#  ('00401', ['counter-clockwis', 'walk']),
#  ('00401', ['walk']),
#  ('00402', ['walk']),
#  ('00402', ['walk']),
#  ('00402', ['left', 'walk']),
#  ('00403', ['around', 'walk', 'clockwis']),
#  ('00403', ['walk', 'clockwis']),
#  ('00403', ['walk', 'clockwis']),
#  ('00403', ['walk']),
#  ('00404', ['left', 'walk']),
#  ('00404', ['walk']),
#  ('00404', ['walk']),
#  ('00405', ['walk', 'rightward']),
#  ('00406', ['by', 'walk', 'back']),
#  ('00407', ['walk']),
#  ('00407', ['walk']),
#  ('00407', ['walk']),
#  ('00408', ['walk', 'clockwis']),
#  ('00408', ['goe', 'around']),
#  ('00408', ['goe', 'clockwis']),
#  ('00409', ['walk', 'clockwis']),
#  ('00410', ['left', 'walk']),
#  ('00410', ['left', 'forward', 'walk']),
#  ('00411', ['walk']),
#  ('00412', ['walk', 'left']),
#  ('00412', ['left', 'walk']),
#  ('00412', ['left', 'turn', 'walk']),
#  ('00412', ['left', 'walk']),
#  ('00413', ['around', 'walk']),
#  ('00414', ['turn']),
#  ('00414', ['walk', 'perform']),
#  ('00415', ['make', 'move']),
#  ('00415', ['turn', 'walk', 'forward']),
#  ('00415', ['walk', 'forward', 'back', 'perform']),
#  ('00416', ['turn']),
#  ('00417', ['around', 'walk']),
#  ('00417', ['perform', 'forward', 'walk']),
#  ('00417', ['walk', 'forward']),
#  ('00417', ['walk', 'turn']),
#  ('00418', ['walk']),
#  ('00419', ['walk']),
#  ('00420', ['turn']),
#  ('00421', ['left', 'walk']),
#  ('00422', ['turn', 'walk', 'forward']),
#  ('00422', ['walk', 'turn']),
#  ('00422', ['walk']),
#  ('00423', ['turn']),
#  ('00424', ['walk', 'forward']),
#  ('00424', ['forward']),
#  ...]

# %%
with open('filtered_labels.txt', 'w') as f:
    for line in narrowed_sentences:
        words = ' '.join(line[1])
        f.write(line[0] +  ': ' + words + '\n')
